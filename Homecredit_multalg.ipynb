# %% [markdown]
# <img src="img/ibidat.png" alt="drawing" width="600"/>

# %% [markdown]
# # Introducción
#
# En este cuaderno vamos a probar todas las parejas posibles de métodos de fairness que afecten a distintas partes del proceso de la construcción del algoritmo de machine learning. Vamos a usar el dataset `homecredit`.

# %% [markdown]
# # Carga de librerías

# %%
# Con esta celda, podemos hacer cambios en cualquier script/libreria y verlo reflejado en las funciones del notebook.
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
## CARGAMOS LIBRERIAS
# Obs: La primera vez puede tardar en cargar porque AIF360 pre-compila algunas cosas de tensorflow
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Cargamos librerías de sklearn
# vanilla LR
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline

# Cargamos xgboost
from xgboost import XGBClassifier

# Cargamos algoritmos de fairness
# Pre-procesado
from aif360.algorithms.preprocessing import Reweighing
from aif360.algorithms.preprocessing import DisparateImpactRemover
# In-procesado
from aif360.algorithms.inprocessing import PrejudiceRemover
from aif360.algorithms.inprocessing import MetaFairClassifier
from aif360.algorithms.inprocessing.adversarial_debiasing import AdversarialDebiasing
# Post-procesado
from aif360.algorithms.postprocessing import RejectOptionClassification # when scores are given
from aif360.algorithms.postprocessing import CalibratedEqOddsPostprocessing # when scores (R) are given
from aif360.algorithms.postprocessing import EqOddsPostprocessing # when labels (Y^hat) are given
from aif360.datasets import GermanDataset

# TF para adversarial debiasing
import tensorflow.compat.v1 as tf
tf.disable_eager_execution()

from IPython.display import Markdown, display

# Librería local con funciones de ayuda extra
import utils

seed = 12345 # fijamos la semilla de números aleatorios para reproducir exactamante el notebook
# Out:
# WARNING:root:
# `load_boston` has been removed from scikit-learn since version 1.2.
#
# The Boston housing prices dataset has an ethical problem: as
# investigated in [1], the authors of this dataset engineered a
# non-invertible variable "B" assuming that racial self-segregation had a
# positive impact on house prices [2]. Furthermore the goal of the
# research that led to the creation of this dataset was to study the
# impact of air quality but it did not give adequate demonstration of the
# validity of this assumption.
#
# The scikit-learn maintainers therefore strongly discourage the use of
# this dataset unless the purpose of the code is to study and educate
# about ethical issues in data science and machine learning.
#
# In this special case, you can fetch the dataset from the original
# source::
#
#     import pandas as pd
#     import numpy as np
#
#     data_url = "http://lib.stat.cmu.edu/datasets/boston"
#     raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#     data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#     target = raw_df.values[1::2, 2]
#
# Alternative datasets include the California housing dataset and the
# Ames housing dataset. You can load the datasets as follows::
#
#     from sklearn.datasets import fetch_california_housing
#     housing = fetch_california_housing()
#
# for the California housing dataset and::
#
#     from sklearn.datasets import fetch_openml
#     housing = fetch_openml(name="house_prices", as_frame=True)
#
# for the Ames housing dataset.
#
# [1] M Carlisle.
# "Racist data destruction?"
# <https://medium.com/@docintangible/racist-data-destruction-113e3eff54a8>
#
# [2] Harrison Jr, David, and Daniel L. Rubinfeld.
# "Hedonic housing prices and the demand for clean air."
# Journal of environmental economics and management 5.1 (1978): 81-102.
# <https://www.researchgate.net/publication/4974606_Hedonic_housing_prices_and_the_demand_for_clean_air>
# : LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# 2024-06-16 20:59:44.970327: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-16 20:59:45.045749: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-16 20:59:46.007979: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Selección de dataset.
#
# El siguiente bloque permite seleccionar el conjunto de datos sobre el que trabajar. Debe recordarse que el conjunto de `homecredit` es mucho mayor por lo que tardará más tiempo en ejecutarse.

# %%
dataset_name = 'homecredit' # valid options are: german; homecredit

if dataset_name == 'german':
    dataset_german = GermanDataset(
        protected_attribute_names=['age'],            
        privileged_classes=[lambda x: x >= 25],      
        features_to_drop=['personal_status', 'sex'] 
    )
    

    # xgboost requiere que los labels empiecen en 0, y en este conjunto empiezan en 1
    # dataset_german.labels = dataset_german.labels - 1
    # dataset_german.favorable_label = dataset_german.favorable_label - 1
    # dataset_german.unfavorable_label = dataset_german.unfavorable_label - 1
    # cambiar los labels 2 a 0 (label 2 es desfavorabel y 1 es favorable) 
    dataset_german.labels[dataset_german.labels.ravel() == 2] =  dataset_german.labels[dataset_german.labels.ravel() == 2] - 2
    dataset_german.unfavorable_label = dataset_german.unfavorable_label - 2

    
    
    # Separamos el conjunto de datos en train, validate, test
    data_train, vt = dataset_german.split([0.7], shuffle=True, seed=seed)
    data_val, data_test = vt.split([0.5], shuffle=True, seed=seed)

    # Obtenemos los indicadores del grupo sensible
    sensitive_attribute = dataset_german.protected_attribute_names[0] # age
    privileged_groups, unprivileged_groups = utils.get_privileged_groups(dataset_german)
    
    print(f'Dimensiones del conjunto de datos: {dataset_german.features.shape}')
    print("Grupos privilegiados:", privileged_groups)
    print("Grupos no privilegiados:", unprivileged_groups)
    print("Label del grupo favorable:", dataset_german.favorable_label)
    print("Label del grupo desfavorable:", dataset_german.unfavorable_label) 
    
elif dataset_name == 'homecredit':
    dataset_homecredit = pd.read_csv('data/homecredit.zip', compression='zip', header=0, sep=',', quotechar='"')

    dataset_homecredit = utils.preprocess_homecredit(dataset_homecredit)

    dataset_homecredit_aif = utils.convert_to_standard_dataset(
            df=dataset_homecredit,
            target_label_name='TARGET',
            sensitive_attribute='AGE',
            priviledged_classes=[lambda x: x >= 25],
            favorable_target_label=[1],
            features_to_keep=[],
            categorical_features=[])

    # para hacer submuestra 
    sample_size_hc = 5000
    dataset_homecredit_aif = dataset_homecredit_aif.subset(np.random.randint(0, 307511+1, size=(sample_size_hc)))
    # Separamos el conjunto de datos en train, validate, test
    data_train, vt = dataset_homecredit_aif.split([0.7], shuffle=True, seed=seed)
    data_val, data_test = vt.split([0.5], shuffle=True, seed=seed)

    # Obtenemos los indicadores del grupo sensible
    sensitive_attribute = dataset_homecredit_aif.protected_attribute_names[0] # age
    privileged_groups, unprivileged_groups = utils.get_privileged_groups(dataset_homecredit_aif)

    print(f'Dimensiones del conjunto de datos: {dataset_homecredit_aif.features.shape}')
    print("Grupos privilegiados:", privileged_groups)
    print("Grupos no privilegiados:", unprivileged_groups)
    print("Label del grupo favorable:", dataset_homecredit_aif.favorable_label)
    print("Label del grupo desfavorable:", dataset_homecredit_aif.unfavorable_label) 
else:
    print('Invalid dataset selected')
# Out:
# /home/arturo_perez/DEFINITIVO/utils.py:1129: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['AGE'] = -df['DAYS_BIRTH'].astype('float') / 365
# Dimensiones del conjunto de datos: (5000, 226)
# Grupos privilegiados: [{'AGE': 1.0}]
# Grupos no privilegiados: [{'AGE': 0.0}]
# Label del grupo favorable: 1.0
# Label del grupo desfavorable: 0.0

# %% [markdown]
# ## Modelos
# Para esta sección, creamos un diccionario de métricas y modelos para poder acceder los resultados de todos los modelos.

# %%
# Inicializamos diccionarios
models = dict()

# Rango de umbrales para evaluar el score de los modelos
thresh_sweep = np.linspace(0.01, 1.0, 50)

metrics_sweep = dict()

# Store results from validation and test
metrics_best_thresh_validate = dict()
metrics_best_thresh_test = dict()

# %% [markdown]
# ### Regresión Logística

# %%
# %%time 

# Nombramos al modelo
model_name = 'logistic_regression'
fairness_method = ''

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Parámetros del modelo
fit_params = {'logisticregression__sample_weight': data_train_copy.instance_weights}

# Asignamos el modelo al diccionario
models[model_name+fairness_method] = make_pipeline(
            #StandardScaler(),
            LogisticRegression(solver='liblinear', random_state=seed))

# Entrenamos el modelo
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy.features, data_train_copy.labels.ravel(), **fit_params)
# Out:
# CPU times: user 1.58 s, sys: 3.46 s, total: 5.04 s
# Wall time: 5.16 s

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_threshold_sweep(
    dataset=data_val_copy,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics(
    dataset=data_test_copy, 
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.1110
# AUC: 0.5905
# Balanced accuracy: 0.5743
# Accuracy: 0.6560
# Independence ( |ΔP(Y_pred = 1)| ): 0.4534
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0086
# Sufficiency ( |ΔPPV| ) : 0.0737
# CPU times: user 25.9 s, sys: 28.4 s, total: 54.2 s
# Wall time: 49.8 s

# %%
display(Markdown("**Test set results**"))
utils.print_metrics(metrics_best_thresh_test[model_name+fairness_method])
# Out:
# **Test set results**
# Threshold corresponding to *best balanced accuracy*: 0.1110
# AUC: 0.6014
# Balanced accuracy: 0.5551
# Accuracy: 0.6267
# Independence ( |ΔP(Y_pred = 1)| ): 0.4831
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0573
# Sufficiency ( |ΔPPV| ) : 0.0712

# %% [markdown]
# ### XGBoost

# %%
# %%time 

# Nombramos al modelo
model_name = 'xgb_classifier'
fairness_method = ''

# Parámetros del modelo
fit_params = {'eval_metric': 'error', 'eta':0.1, 'max_depth':6, 'subsample':0.8}

# Asignamos el modelo al diccionario
models[model_name+fairness_method] = XGBClassifier(**fit_params)

# Entrenamos el modelo
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy.features, data_train_copy.labels.ravel())
# Out:
# CPU times: user 49min 10s, sys: 3.31 s, total: 49min 13s
# Wall time: 2min 23s

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_threshold_sweep(
    dataset=data_val_copy,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics(
    dataset=data_test_copy, 
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.0504
# AUC: 0.6950
# Balanced accuracy: 0.6624
# Accuracy: 0.6720
# Independence ( |ΔP(Y_pred = 1)| ): 0.3159
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1294
# Sufficiency ( |ΔPPV| ) : 0.0267
# CPU times: user 25.9 s, sys: 24.9 s, total: 50.7 s
# Wall time: 51.3 s

# %%
display(Markdown("**Test set results**"))
utils.print_metrics(metrics_best_thresh_test[model_name+fairness_method])
# Out:
# **Test set results**
# Threshold corresponding to *best balanced accuracy*: 0.0504
# AUC: 0.7024
# Balanced accuracy: 0.6583
# Accuracy: 0.6600
# Independence ( |ΔP(Y_pred = 1)| ): 0.3347
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0329
# Sufficiency ( |ΔPPV| ) : 0.0609

# %% [markdown]
# ## Técnicas de preprocesado

# %% [markdown]
# ### Reponderación

# %%
# %%time 

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos el pre-procesado al conjunto train
# Inicializamos la clase de pre-procesado 
PreProcessor = Reweighing(
    unprivileged_groups=unprivileged_groups,
    privileged_groups=privileged_groups
)
# Pre-procesamos (modifica los datos)
PreProcessor.fit(data_train_copy)
data_train_REW = PreProcessor.transform(data_train_copy)
data_val_REW = PreProcessor.transform(data_val_copy)
data_test_REW = PreProcessor.transform(data_test_copy)
# Out:
# CPU times: user 3.03 s, sys: 2.54 s, total: 5.57 s
# Wall time: 6.44 s

# %% [markdown]
# De aquí en adelante, se aplica el modelo de preferencia de manera estándar

# %% [markdown]
# ### Eliminador de impacto dispar

# %%
# %%time 

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Parámetros del modelo
nivel_reparacion = 0.5 # un valor 0 inidica ausencia de reparación (datos se mantienen igual) 
                       # un valor 1 indica reparación completa (se puede perder nivel predictivo).
                       # Se puede establecer cualquier valor entre 0 y 1.

# Hacemos el pre-procesado al conjunto train
# Inicializamos la clase de pre-procesado 
PreProcessor = DisparateImpactRemover(
    repair_level=nivel_reparacion,
    sensitive_attribute=sensitive_attribute
)
# Pre-procesamos (modifica los datos)
PreProcessor.fit_transform(data_train_copy)
data_train_DIR = PreProcessor.fit_transform(data_train_copy)
data_val_DIR = PreProcessor.fit_transform(data_val_copy)
data_test_DIR = PreProcessor.fit_transform(data_test_copy)
# Out:
# CPU times: user 6.65 s, sys: 1.77 s, total: 8.42 s
# Wall time: 9.42 s

# %% [markdown]
# ## Entrenamiento de técnicas de inprocesado

# %% [markdown]
# Entrenamos ahora los algoritmos de inprocesado para aplicarlos posteriormente cuando hagan falta.

# %% [markdown]
# ### Eliminador de prejuicios por regularización

# %%
# %%time 
# Nombramos al modelo
model_name = 'prejudice_remover'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Parámetros del modelo
η = 50.0 # hyper-parameter de regularización

# Inicializamos el modelo y lo asignamos al diccionario
models[model_name] = PrejudiceRemover(sensitive_attr=sensitive_attribute, eta=η)

# Entrenamos el modelo
models[model_name] = models[model_name].fit(data_train_copy)

models[model_name].scores_train = models[model_name].predict(data_train_copy).scores
models[model_name].scores_val = models[model_name].predict(data_val_copy).scores
models[model_name].scores_test = models[model_name].predict(data_test_copy).scores
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File <timed exec>:14
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/prejudice_remover.py:160, in PrejudiceRemover.fit(self, dataset)
#     156 train_pr = os.path.join(k_path, 'kamfadm-2012ecmlpkdd', 'train_pr.py')
#     157 # changed paths in the calls below to (a) specify path of train_pr,
#     158 # predict_lr RELATIVE to this file, and (b) compute & use absolute path
#     159 #  and (c) replace python3 with python
# --> 160 subprocess.call(['python', train_pr,
#     161                  '-e', str(self.eta),
#     162                  '-i', train_name,
#     163                  '-o', model_name,
#     164                  '--quiet'])
#     165 os.unlink(train_name)
#     167 self.model_name = model_name
#
# File ~/miniconda3/envs/aif360/lib/python3.9/subprocess.py:349, in call(timeout, *popenargs, **kwargs)
#     341 def call(*popenargs, timeout=None, **kwargs):
#     342     """Run command with arguments.  Wait for command to complete or
#     343     timeout, then return the returncode attribute.
#     344
#    (...)
#     347     retcode = call(["ls", "-l"])
#     348     """
# --> 349     with Popen(*popenargs, **kwargs) as p:
#     350         try:
#     351             return p.wait(timeout=timeout)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/subprocess.py:951, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     947         if self.text_mode:
#     948             self.stderr = io.TextIOWrapper(self.stderr,
#     949                     encoding=encoding, errors=errors)
# --> 951     self._execute_child(args, executable, preexec_fn, close_fds,
#     952                         pass_fds, cwd, env,
#     953                         startupinfo, creationflags, shell,
#     954                         p2cread, p2cwrite,
#     955                         c2pread, c2pwrite,
#     956                         errread, errwrite,
#     957                         restore_signals,
#     958                         gid, gids, uid, umask,
#     959                         start_new_session)
#     960 except:
#     961     # Cleanup if the child failed starting.
#     962     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~/miniconda3/envs/aif360/lib/python3.9/subprocess.py:1837, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1835     if errno_num != 0:
#    1836         err_msg = os.strerror(errno_num)
# -> 1837     raise child_exception_type(errno_num, err_msg, err_filename)
#    1838 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'python'

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name] = utils.metrics_threshold_sweep(
    dataset=data_val_copy,
    model=models[model_name],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name] = utils.describe_metrics(metrics_sweep[model_name])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name] = utils.compute_metrics(
    dataset=data_test_copy, 
    model=models[model_name], 
    threshold=metrics_best_thresh_validate[model_name]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name])

# Graficamos el comportamiento del modelo para el rango de umbrales 
f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name])
a.set_title(model_name)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/DEFINITIVO/utils.py:502, in metrics_threshold_sweep(dataset, model, thresh_arr)
#     500 try:
#     501     # sklearn classifier
# --> 502     y_val_pred_prob = model.predict_proba(dataset.features)
#     503     pos_ind = np.where(model.classes_ == dataset.favorable_label)[0][0]
#
# AttributeError: 'PrejudiceRemover' object has no attribute 'predict_proba'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:506, in metrics_threshold_sweep(dataset, model, thresh_arr)
#     503     pos_ind = np.where(model.classes_ == dataset.favorable_label)[0][0]
#     504 except AttributeError:
#     505     # aif360 inprocessing algorithm
# --> 506     y_val_pred_prob = model.predict(dataset).scores
#     507     pos_ind = 0
#     509 # Remove nans and turn them into score of random prediction (R=0.5)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/prejudice_remover.py:204, in PrejudiceRemover.predict(self, dataset)
#     198 predict_lr = os.path.join(k_path, 'kamfadm-2012ecmlpkdd', 'predict_lr.py')
#     199 # changed paths in the calls below to (a) specify path of train_pr,
#     200 # predict_lr RELATIVE to this file, and (b) compute & use absolute path,
#     201 # and (c) replace python3 with python
#     202 subprocess.call(['python', predict_lr,
#     203                  '-i', test_name,
# --> 204                  '-m', self.model_name,
#     205                  '-o', output_name,
#     206                  '--quiet'])
#     207 os.unlink(test_name)
#     208 m = np.loadtxt(output_name)
#
# AttributeError: 'PrejudiceRemover' object has no attribute 'model_name'

# %% [markdown]
# ### Algoritmo de metafairness

# %%
# %%time 
# Nombramos al modelo
model_name = 'meta_fairness'

# Parámetros del modelo
# hyper-parameter de regularización
τ = 0.8
# métricas fairness a optimizar
quality_constraints = ['sr', 'fdr'] # sr: statistical rate, fdr: false discovery rate

# Optimizamos un modelo nuevo por cada métrica
for quality in quality_constraints:
    
    # Hacemos una copia de los datasets
    data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
    
    # nombramos al modelo con su métrica específica
    model_name_quality = '{}_{}'.format(model_name, quality)
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_quality] = MetaFairClassifier(tau=τ, sensitive_attr=sensitive_attribute, type=quality, seed=seed)

    # Entrenamos el modelo
    models[model_name_quality] = models[ model_name_quality ].fit( data_train_copy )
    models[model_name_quality].scores_train = models[model_name_quality].predict(data_train_copy).scores
    models[model_name_quality].scores_val = models[model_name_quality].predict(data_val_copy).scores
    models[model_name_quality].scores_test = models[model_name_quality].predict(data_test_copy).scores
# Out:
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# CPU times: user 9min 46s, sys: 10min 57s, total: 20min 43s
# Wall time: 2min 11s

# %%
# %%time 

for quality in quality_constraints:
    
    name_suffix = '_{}'.format(quality)
    print(f'Results for {model_name+name_suffix}')

    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name+name_suffix] = utils.metrics_threshold_sweep(
        dataset=data_val_copy,
        model=models[model_name+name_suffix],
        thresh_arr=thresh_sweep
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name+name_suffix] = utils.describe_metrics(metrics_sweep[model_name+name_suffix])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name+name_suffix] = utils.compute_metrics(
        dataset=data_test_copy, 
        model=models[model_name+name_suffix], 
        threshold=metrics_best_thresh_validate[model_name+name_suffix]['best_threshold'])

    utils.print_metrics(metrics_best_thresh_validate[model_name+name_suffix])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name+name_suffix])
    # plt.title(model_name+name_suffix)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+name_suffix])
    a.set_title(model_name+name_suffix)
    f
# Out:
# Results for meta_fairness_sr
# Threshold corresponding to *best balanced accuracy*: 0.0100
# AUC: 0.4446
# Balanced accuracy: 0.5000
# Accuracy: 0.0840
# Independence ( |ΔP(Y_pred = 1)| ): 0.0000
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0000
# Sufficiency ( |ΔPPV| ) : 0.0836
#
#
# Results for meta_fairness_fdr
# Threshold corresponding to *best balanced accuracy*: 0.0100
# AUC: 0.5561
# Balanced accuracy: 0.5000
# Accuracy: 0.0840
# Independence ( |ΔP(Y_pred = 1)| ): 0.0000
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0000
# Sufficiency ( |ΔPPV| ) : 0.0836
#
#
# CPU times: user 55.2 s, sys: 1min 4s, total: 1min 59s
# Wall time: 1min 53s

# %% [markdown]
# ### Eliminación de prejuicios adversarios

# %%
# %%time

# Nombramos al modelo
model_name = 'NN_adversarial_debiasing'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

sess = tf.Session()

models[model_name] = AdversarialDebiasing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    scope_name = 'debiased_classifier',
    debias=True,
    sess=sess,
    num_epochs=80)

models[model_name].fit(data_train_copy)

models[model_name].scores_train = models[model_name].predict(data_train_copy).scores
models[model_name].scores_val = models[model_name].predict(data_val_copy).scores
models[model_name].scores_test = models[model_name].predict(data_test_copy).scores
# Out:
# 2024-06-16 21:08:42.319491: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# WARNING:tensorflow:From /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1260: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# 2024-06-16 21:08:42.743653: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:388] MLIR V1 optimization pass is not enabled
# epoch 90; iter: 0; batch classifier loss: 0.547349
# epoch 91; iter: 0; batch classifier loss: 0.481975
# epoch 92; iter: 0; batch classifier loss: 0.446946
# epoch 93; iter: 0; batch classifier loss: 0.313307
# epoch 94; iter: 0; batch classifier loss: 1.075867
# epoch 95; iter: 0; batch classifier loss: 0.369801
# epoch 96; iter: 0; batch classifier loss: 0.400131
# epoch 97; iter: 0; batch classifier loss: 0.513183
# epoch 98; iter: 0; batch classifier loss: 0.298819
# epoch 99; iter: 0; batch classifier loss: 0.423956
# epoch 100; iter: 0; batch classifier loss: 0.373340
# epoch 101; iter: 0; batch classifier loss: 0.480316
# epoch 102; iter: 0; batch classifier loss: 0.638311
# epoch 103; iter: 0; batch classifier loss: 0.266838
# epoch 104; iter: 0; batch classifier loss: 0.510032
# epoch 105; iter: 0; batch classifier loss: 0.292320
# epoch 106; iter: 0; batch classifier loss: 0.357331
# epoch 107; iter: 0; batch classifier loss: 0.367765
# epoch 108; iter: 0; batch classifier loss: 0.300408
# epoch 109; iter: 0; batch classifier loss: 0.406369
# epoch 110; iter: 0; batch classifier loss: 0.524829
# epoch 111; iter: 0; batch classifier loss: 0.373438
# epoch 112; iter: 0; batch classifier loss: 0.512627
# epoch 113; iter: 0; batch classifier loss: 0.401669
# epoch 114; iter: 0; batch classifier loss: 0.542102
# epoch 115; iter: 0; batch classifier loss: 0.254736
# epoch 116; iter: 0; batch classifier loss: 0.790910
# epoch 117; iter: 0; batch classifier loss: 0.218140
# epoch 118; iter: 0; batch classifier loss: 0.456304
# epoch 119; iter: 0; batch classifier loss: 0.431388
# epoch 120; iter: 0; batch classifier loss: 0.232393
# epoch 121; iter: 0; batch classifier loss: 0.376738
# epoch 122; iter: 0; batch classifier loss: 0.358116
# epoch 123; iter: 0; batch classifier loss: 0.342470
# epoch 124; iter: 0; batch classifier loss: 0.381656
# CPU times: user 12.6 s, sys: 4.79 s, total: 17.4 s
# Wall time: 12 s

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name] = utils.metrics_threshold_sweep(
    dataset=data_val_copy,
    model=models[model_name],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name] = utils.describe_metrics(metrics_sweep[model_name])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name] = utils.compute_metrics(
    dataset=data_test_copy, 
    model=models[model_name], 
    threshold=metrics_best_thresh_validate[model_name]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name])

# Graficamos el comportamiento del modelo para el rango de umbrales 
f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name])
a.set_title(model_name)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.1110
# AUC: 0.5062
# Balanced accuracy: 0.5325
# Accuracy: 0.5133
# Independence ( |ΔP(Y_pred = 1)| ): 0.3620
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1062
# Sufficiency ( |ΔPPV| ) : 0.0496
# CPU times: user 24.9 s, sys: 21 s, total: 45.9 s
# Wall time: 1min 36s

# %% [markdown]
# ## Preprocesado + Inprocesado

# %% [markdown]
# ### Reponderación + Eliminador de prejuicios

# %%
# Nombre del modelo
model_name = 'reweighting_prejudice_remover'

# Hacemos una copia de los datasets (usando uno de lo métodos de pre-procesado vistos anteriormente)
data_train_copy, data_val_copy, data_test_copy = data_train_REW.copy(deepcopy=True), data_val_REW.copy(deepcopy=True), data_test_REW.copy(deepcopy=True)

# Parámetros del modelo
η = 50.0 # hyper-parameter de regularización

# Inicializamos el modelo y lo asignamos al diccionario
models[model_name] = PrejudiceRemover(sensitive_attr=sensitive_attribute, eta=η)

# Entrenamos el modelo
models[model_name] = models[model_name].fit(data_train_copy)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 14
#      11 models[model_name] = PrejudiceRemover(sensitive_attr=sensitive_attribute, eta=η)
#      13 # Entrenamos el modelo
# ---> 14 models[model_name] = models[model_name].fit(data_train_copy)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/prejudice_remover.py:160, in PrejudiceRemover.fit(self, dataset)
#     156 train_pr = os.path.join(k_path, 'kamfadm-2012ecmlpkdd', 'train_pr.py')
#     157 # changed paths in the calls below to (a) specify path of train_pr,
#     158 # predict_lr RELATIVE to this file, and (b) compute & use absolute path
#     159 #  and (c) replace python3 with python
# --> 160 subprocess.call(['python', train_pr,
#     161                  '-e', str(self.eta),
#     162                  '-i', train_name,
#     163                  '-o', model_name,
#     164                  '--quiet'])
#     165 os.unlink(train_name)
#     167 self.model_name = model_name
#
# File ~/miniconda3/envs/aif360/lib/python3.9/subprocess.py:349, in call(timeout, *popenargs, **kwargs)
#     341 def call(*popenargs, timeout=None, **kwargs):
#     342     """Run command with arguments.  Wait for command to complete or
#     343     timeout, then return the returncode attribute.
#     344
#    (...)
#     347     retcode = call(["ls", "-l"])
#     348     """
# --> 349     with Popen(*popenargs, **kwargs) as p:
#     350         try:
#     351             return p.wait(timeout=timeout)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/subprocess.py:951, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     947         if self.text_mode:
#     948             self.stderr = io.TextIOWrapper(self.stderr,
#     949                     encoding=encoding, errors=errors)
# --> 951     self._execute_child(args, executable, preexec_fn, close_fds,
#     952                         pass_fds, cwd, env,
#     953                         startupinfo, creationflags, shell,
#     954                         p2cread, p2cwrite,
#     955                         c2pread, c2pwrite,
#     956                         errread, errwrite,
#     957                         restore_signals,
#     958                         gid, gids, uid, umask,
#     959                         start_new_session)
#     960 except:
#     961     # Cleanup if the child failed starting.
#     962     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~/miniconda3/envs/aif360/lib/python3.9/subprocess.py:1837, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1835     if errno_num != 0:
#    1836         err_msg = os.strerror(errno_num)
# -> 1837     raise child_exception_type(errno_num, err_msg, err_filename)
#    1838 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'python'

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name] = utils.metrics_threshold_sweep(
    dataset=data_val_copy,
    model=models[model_name],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name] = utils.describe_metrics(metrics_sweep[model_name])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name] = utils.compute_metrics(
    dataset=data_test_copy, 
    model=models[model_name], 
    threshold=metrics_best_thresh_validate[model_name]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name])

# Graficamos el comportamiento del modelo para el rango de umbrales 
f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name])
a.set_title(model_name)
f

# %% [markdown]
# ### Impacto dispar + Eliminador de prejuicios

# %%
# Nombre del modelo
model_name = 'disparate_impact_prejudice_remover'

# Hacemos una copia de los datasets (usando uno de lo métodos de pre-procesado vistos anteriormente)
data_train_copy, data_val_copy, data_test_copy = data_train_DIR.copy(deepcopy=True), data_val_DIR.copy(deepcopy=True), data_test_DIR.copy(deepcopy=True)

# Parámetros del modelo
η = 50.0 # hyper-parameter de regularización

# Inicializamos el modelo y lo asignamos al diccionario
models[model_name] = PrejudiceRemover(sensitive_attr=sensitive_attribute, eta=η)

# Entrenamos el modelo
models[model_name] = models[model_name].fit(data_train_copy)

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name] = utils.metrics_threshold_sweep(
    dataset=data_val_copy,
    model=models[model_name],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name] = utils.describe_metrics(metrics_sweep[model_name])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name] = utils.compute_metrics(
    dataset=data_test_copy, 
    model=models[model_name], 
    threshold=metrics_best_thresh_validate[model_name]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name])

# Graficamos el comportamiento del modelo para el rango de umbrales 
f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name])
a.set_title(model_name)
f

# %% [markdown]
# ### Reponderación + metafairness

# %%
# %%time 
# Nombramos al modelo
model_name = 'reweighing_meta_fairness'

# Parámetros del modelo
# hyper-parameter de regularización
τ = 0.8
# métricas fairness a optimizar
quality_constraints = ['sr', 'fdr'] # sr: statistical rate, fdr: false discovery rate

# Optimizamos un modelo nuevo por cada métrica
for quality in quality_constraints:
    
    # Hacemos una copia de los datasets
    data_train_copy, data_val_copy, data_test_copy = data_train_REW.copy(deepcopy=True), data_val_REW.copy(deepcopy=True), data_test_REW.copy(deepcopy=True)
    
    # nombramos al modelo con su métrica específica
    model_name_quality = '{}_{}'.format(model_name, quality)
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_quality] = MetaFairClassifier(tau=τ, sensitive_attr=sensitive_attribute, type=quality, seed=seed)

    # Entrenamos el modelo
    models[model_name_quality] = models[ model_name_quality ].fit( data_train_copy )
# Out:
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# CPU times: user 9min 31s, sys: 11min 4s, total: 20min 36s
# Wall time: 2min 45s

# %%
# %%time 

for quality in quality_constraints:
    
    name_suffix = '_{}'.format(quality)
    print(f'Results for {model_name+name_suffix}')

    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name+name_suffix] = utils.metrics_threshold_sweep(
        dataset=data_val_copy,
        model=models[model_name+name_suffix],
        thresh_arr=thresh_sweep
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name+name_suffix] = utils.describe_metrics(metrics_sweep[model_name+name_suffix])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name+name_suffix] = utils.compute_metrics(
        dataset=data_test_copy, 
        model=models[model_name+name_suffix], 
        threshold=metrics_best_thresh_validate[model_name+name_suffix]['best_threshold'])

    utils.print_metrics(metrics_best_thresh_validate[model_name+name_suffix])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name+name_suffix])
    # plt.title(model_name+name_suffix)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+name_suffix])
    a.set_title(model_name+name_suffix)
    f
# Out:
# Results for reweighing_meta_fairness_sr
# Threshold corresponding to *best balanced accuracy*: 0.0100
# AUC: 0.4446
# Balanced accuracy: 0.5000
# Accuracy: 0.0825
# Independence ( |ΔP(Y_pred = 1)| ): 0.0000
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0000
# Sufficiency ( |ΔPPV| ) : 0.0071
#
#
# Results for reweighing_meta_fairness_fdr
# Threshold corresponding to *best balanced accuracy*: 0.0100
# AUC: 0.5561
# Balanced accuracy: 0.5000
# Accuracy: 0.0825
# Independence ( |ΔP(Y_pred = 1)| ): 0.0000
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0000
# Sufficiency ( |ΔPPV| ) : 0.0071
#
#
# CPU times: user 52.9 s, sys: 1min 15s, total: 2min 8s
# Wall time: 1min 49s

# %% [markdown]
# ### Impacto dispar + metafairness

# %%
# %%time 
# Nombramos al modelo
model_name = 'disparate_impact_meta_fairness'

# Parámetros del modelo
# hyper-parameter de regularización
τ = 0.8
# métricas fairness a optimizar
quality_constraints = ['sr', 'fdr'] # sr: statistical rate, fdr: false discovery rate

# Optimizamos un modelo nuevo por cada métrica
for quality in quality_constraints:
    
    # Hacemos una copia de los datasets
    data_train_copy, data_val_copy, data_test_copy = data_train_DIR.copy(deepcopy=True), data_val_DIR.copy(deepcopy=True), data_test_DIR.copy(deepcopy=True)
    
    # nombramos al modelo con su métrica específica
    model_name_quality = '{}_{}'.format(model_name, quality)
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_quality] = MetaFairClassifier(tau=τ, sensitive_attr=sensitive_attribute, type=quality, seed=seed)

    # Entrenamos el modelo
    models[model_name_quality] = models[ model_name_quality ].fit( data_train_copy )
# Out:
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/scipy/stats/_multivariate.py:757: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)
# CPU times: user 5min 46s, sys: 2min 57s, total: 8min 43s
# Wall time: 22.1 s

# %%
# %%time 

for quality in quality_constraints:
    
    name_suffix = '_{}'.format(quality)
    print(f'Results for {model_name+name_suffix}')

    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name+name_suffix] = utils.metrics_threshold_sweep(
        dataset=data_val_copy,
        model=models[model_name+name_suffix],
        thresh_arr=thresh_sweep
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name+name_suffix] = utils.describe_metrics(metrics_sweep[model_name+name_suffix])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name+name_suffix] = utils.compute_metrics(
        dataset=data_test_copy, 
        model=models[model_name+name_suffix], 
        threshold=metrics_best_thresh_validate[model_name+name_suffix]['best_threshold'])

    utils.print_metrics(metrics_best_thresh_validate[model_name+name_suffix])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name+name_suffix])
    # plt.title(model_name+name_suffix)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+name_suffix])
    a.set_title(model_name+name_suffix)
    f
# Out:
# Results for disparate_impact_meta_fairness_sr
# Threshold corresponding to *best balanced accuracy*: 0.0100
# AUC: 0.4515
# Balanced accuracy: 0.5000
# Accuracy: 0.0840
# Independence ( |ΔP(Y_pred = 1)| ): 0.0000
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0000
# Sufficiency ( |ΔPPV| ) : 0.0836
#
#
# Results for disparate_impact_meta_fairness_fdr
# Threshold corresponding to *best balanced accuracy*: 0.0100
# AUC: 0.5485
# Balanced accuracy: 0.5000
# Accuracy: 0.0840
# Independence ( |ΔP(Y_pred = 1)| ): 0.0000
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0000
# Sufficiency ( |ΔPPV| ) : 0.0836
#
#
# CPU times: user 52 s, sys: 1min 9s, total: 2min 1s
# Wall time: 1min 37s

# %% [markdown]
# ### Reponderación + prejuicios adversarios

# %%
# %%time

# Nombramos al modelo
model_name = 'reweighing_NN_adversarial_debiasing'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train_REW.copy(deepcopy=True), data_val_REW.copy(deepcopy=True), data_test_REW.copy(deepcopy=True)

sess = tf.Session()

models[model_name] = AdversarialDebiasing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    scope_name = 'debiased_classifier',
    debias=True,
    sess=sess,
    num_epochs=80)

models[model_name].fit(data_train_copy)
# Out:
# epoch 0; iter: 0; batch classifier loss: 85744.765625; batch adversarial loss: 0.355489
# epoch 1; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 2; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 3; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 4; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 5; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 6; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 7; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 8; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 9; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 10; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 11; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 12; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 13; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 14; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 15; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 16; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 17; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 18; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 19; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 20; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 21; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 22; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 23; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 24; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 25; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 26; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 27; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 28; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 29; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 30; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 31; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 32; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 33; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 34; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 35; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 36; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 37; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 38; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 39; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 40; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 41; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 42; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 43; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 44; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 45; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 46; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 47; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 48; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 49; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 50; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 51; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 52; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 53; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 54; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 55; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 56; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 57; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 58; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 59; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 60; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 61; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 62; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 63; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 64; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 65; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 66; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 67; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 68; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 69; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 70; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 71; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 72; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 73; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 74; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 75; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 76; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 77; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 78; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# epoch 79; iter: 0; batch classifier loss: nan; batch adversarial loss: nan
# CPU times: user 28.7 s, sys: 7.14 s, total: 35.8 s
# Wall time: 11.4 s

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name] = utils.metrics_threshold_sweep(
    dataset=data_val_copy,
    model=models[model_name],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name] = utils.describe_metrics(metrics_sweep[model_name])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name] = utils.compute_metrics(
    dataset=data_test_copy, 
    model=models[model_name], 
    threshold=metrics_best_thresh_validate[model_name]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name])

# Graficamos el comportamiento del modelo para el rango de umbrales 
f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name])
a.set_title(model_name)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.0100
# AUC: 0.5000
# Balanced accuracy: 0.5000
# Accuracy: 0.0825
# Independence ( |ΔP(Y_pred = 1)| ): 0.0000
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0000
# Sufficiency ( |ΔPPV| ) : 0.0071
# CPU times: user 21.8 s, sys: 22.2 s, total: 44 s
# Wall time: 44.3 s

# %% [markdown]
# ### Reponderación + red neuronal normal

# %%
# %%time

sess.close()
tf.reset_default_graph()
sess = tf.Session()

# Nombramos al modelo
model_name = 'reweighin_basic_NN_no_adversarial_debiasing'

# Hacemos una copia de los datasets"
data_train_copy, data_val_copy, data_test_copy = data_train_REW.copy(deepcopy=True), data_val_REW.copy(deepcopy=True), data_test_REW.copy(deepcopy=True)

models[model_name] = AdversarialDebiasing(privileged_groups = privileged_groups,
                                          unprivileged_groups = unprivileged_groups,
                                          scope_name = 'biased_classifier',
                                          debias=False,
                                          sess=sess,
                                          num_epochs=125)
models[model_name].fit(data_train_copy)
# Out:
# epoch 0; iter: 0; batch classifier loss: 7736.623047
# epoch 1; iter: 0; batch classifier loss: 6388.323242
# epoch 2; iter: 0; batch classifier loss: 2910.271973
# epoch 3; iter: 0; batch classifier loss: 991.719666
# epoch 4; iter: 0; batch classifier loss: 2987.678223
# epoch 5; iter: 0; batch classifier loss: 1831.657593
# epoch 6; iter: 0; batch classifier loss: 2024.812500
# epoch 7; iter: 0; batch classifier loss: 816.734131
# epoch 8; iter: 0; batch classifier loss: 476.979431
# epoch 9; iter: 0; batch classifier loss: 719.677856
# epoch 10; iter: 0; batch classifier loss: 477.012817
# epoch 11; iter: 0; batch classifier loss: 398.159607
# epoch 12; iter: 0; batch classifier loss: 456.880859
# epoch 13; iter: 0; batch classifier loss: 527.483521
# epoch 14; iter: 0; batch classifier loss: 196.302200
# epoch 15; iter: 0; batch classifier loss: 370.473663
# epoch 16; iter: 0; batch classifier loss: 141.409058
# epoch 17; iter: 0; batch classifier loss: 157.371262
# epoch 18; iter: 0; batch classifier loss: 74.194229
# epoch 19; iter: 0; batch classifier loss: 125.021271
# epoch 20; iter: 0; batch classifier loss: 46.530830
# epoch 21; iter: 0; batch classifier loss: 69.436981
# epoch 22; iter: 0; batch classifier loss: 11.792612
# epoch 23; iter: 0; batch classifier loss: 47.628685
# epoch 97; iter: 0; batch classifier loss: 1.195744
# epoch 98; iter: 0; batch classifier loss: 2.355463
# epoch 99; iter: 0; batch classifier loss: 1.212450
# epoch 100; iter: 0; batch classifier loss: 1.806415
# epoch 101; iter: 0; batch classifier loss: 0.993012
# epoch 102; iter: 0; batch classifier loss: 0.524555
# epoch 103; iter: 0; batch classifier loss: 0.308646
# epoch 104; iter: 0; batch classifier loss: 1.403272
# epoch 105; iter: 0; batch classifier loss: 0.998163
# epoch 106; iter: 0; batch classifier loss: 0.605810
# epoch 107; iter: 0; batch classifier loss: 0.607140
# epoch 108; iter: 0; batch classifier loss: 0.742997
# epoch 109; iter: 0; batch classifier loss: 0.893061
# epoch 110; iter: 0; batch classifier loss: 0.570001
# epoch 111; iter: 0; batch classifier loss: 0.244695
# epoch 112; iter: 0; batch classifier loss: 0.401748
# epoch 113; iter: 0; batch classifier loss: 0.478369
# epoch 114; iter: 0; batch classifier loss: 0.572832
# epoch 115; iter: 0; batch classifier loss: 0.399060
# epoch 116; iter: 0; batch classifier loss: 0.576737
# epoch 117; iter: 0; batch classifier loss: 1.758254
# epoch 118; iter: 0; batch classifier loss: 0.362305
# epoch 119; iter: 0; batch classifier loss: 0.471125
# epoch 120; iter: 0; batch classifier loss: 0.494090
# epoch 121; iter: 0; batch classifier loss: 0.405071
# epoch 122; iter: 0; batch classifier loss: 0.465580
# epoch 123; iter: 0; batch classifier loss: 2.973741
# epoch 124; iter: 0; batch classifier loss: 0.398912
# CPU times: user 35.1 s, sys: 8.57 s, total: 43.6 s
# Wall time: 12.7 s

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name] = utils.metrics_threshold_sweep(
    dataset=data_val_copy,
    model=models[model_name],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name] = utils.describe_metrics(metrics_sweep[model_name])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name] = utils.compute_metrics(
    dataset=data_test_copy, 
    model=models[model_name], 
    threshold=metrics_best_thresh_validate[model_name]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name])

# Graficamos el comportamiento del modelo para el rango de umbrales 
f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name])
a.set_title(model_name)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.0302
# AUC: 0.5448
# Balanced accuracy: 0.5477
# Accuracy: 0.3827
# Independence ( |ΔP(Y_pred = 1)| ): 0.0661
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1506
# Sufficiency ( |ΔPPV| ) : 0.0362
# CPU times: user 21.8 s, sys: 23.2 s, total: 44.9 s
# Wall time: 45.2 s

# %% [markdown]
# ## Preprocesado + Postprocesado

# %% [markdown]
# ### Entrenamiento de modelos con técnicas de preprocesado

# %% [markdown]
# #### Reponderación

# %%
# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train_REW.copy(deepcopy=True), data_val_REW.copy(deepcopy=True), data_test_REW.copy(deepcopy=True)

# Regresión logística
model_name = 'reweighin_logistic_regression'

# Parámetros del modelo
fit_params = {'logisticregression__sample_weight': data_train_copy.instance_weights}

# Asignamos el modelo al diccionario
models[model_name+fairness_method] = make_pipeline(
            #StandardScaler(),
            LogisticRegression(solver='liblinear', random_state=seed))

# Entrenamos el modelo
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy.features, data_train_copy.labels.ravel(), **fit_params)

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_threshold_sweep(
    dataset=data_val_copy,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics(
    dataset=data_test_copy, 
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.1110
# AUC: 0.5919
# Balanced accuracy: 0.5632
# Accuracy: 0.6468
# Independence ( |ΔP(Y_pred = 1)| ): 0.4239
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0852
# Sufficiency ( |ΔPPV| ) : 0.0282

# %%
# %%time 

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train_REW.copy(deepcopy=True), data_val_REW.copy(deepcopy=True), data_test_REW.copy(deepcopy=True)

# Nombramos al modelo
model_name = 'reweighin_xgb_classifier'

# Parámetros del modelo
fit_params = {'eval_metric': 'error', 'eta':0.1, 'max_depth':6, 'subsample':0.8}

# Asignamos el modelo al diccionario
models[model_name+fairness_method] = XGBClassifier(**fit_params)

# Entrenamos el modelo
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy.features, data_train_copy.labels.ravel())

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_threshold_sweep(
    dataset=data_val_copy,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics(
    dataset=data_test_copy, 
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.0504
# AUC: 0.6950
# Balanced accuracy: 0.6599
# Accuracy: 0.6704
# Independence ( |ΔP(Y_pred = 1)| ): 0.3094
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1294
# Sufficiency ( |ΔPPV| ) : 0.0583
# CPU times: user 43min 56s, sys: 30.3 s, total: 44min 26s
# Wall time: 2min 8s

# %% [markdown]
# #### Disparate impact

# %%
# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train_DIR.copy(deepcopy=True), data_val_DIR.copy(deepcopy=True), data_test_DIR.copy(deepcopy=True)

# Regresión logística
model_name = 'disparate_impact_logistic_regression'

# Parámetros del modelo
fit_params = {'logisticregression__sample_weight': data_train_copy.instance_weights}

# Asignamos el modelo al diccionario
models[model_name+fairness_method] = make_pipeline(
            #StandardScaler(),
            LogisticRegression(solver='liblinear', random_state=seed))

# Entrenamos el modelo
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy.features, data_train_copy.labels.ravel(), **fit_params)

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_threshold_sweep(
    dataset=data_val_copy,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics(
    dataset=data_test_copy, 
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.0706
# AUC: 0.5794
# Balanced accuracy: 0.5646
# Accuracy: 0.4400
# Independence ( |ΔP(Y_pred = 1)| ): 0.1819
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1016
# Sufficiency ( |ΔPPV| ) : 0.0549

# %%
# %%time 

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train_DIR.copy(deepcopy=True), data_val_DIR.copy(deepcopy=True), data_test_DIR.copy(deepcopy=True)

# Nombramos al modelo
model_name = 'disparate_impact_xgb_classifier'

# Parámetros del modelo
fit_params = {'eval_metric': 'error', 'eta':0.1, 'max_depth':6, 'subsample':0.8}

# Asignamos el modelo al diccionario
models[model_name+fairness_method] = XGBClassifier(**fit_params)

# Entrenamos el modelo
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy.features, data_train_copy.labels.ravel())

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_threshold_sweep(
    dataset=data_val_copy,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics(
    dataset=data_test_copy, 
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.0504
# AUC: 0.6949
# Balanced accuracy: 0.6565
# Accuracy: 0.6613
# Independence ( |ΔP(Y_pred = 1)| ): 0.1319
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0744
# Sufficiency ( |ΔPPV| ) : 0.1468
# CPU times: user 46min 22s, sys: 23.8 s, total: 46min 46s
# Wall time: 1min 54s

# %%
#Anotamos los nombres de los modelos
model_names = ['reweighin_logistic_regression', 'reweighin_xgb_classifier', 'disparate_impact_logistic_regression', 'disparate_impact_xgb_classifier']

# %% [markdown]
# ### Aplicación de técnicas de postprocesado

# %% [markdown]
# #### Reponderación + Clasificación de rechazo de opción

# %%
# %%time 

# Nombramos al modelo
fairness_method = '_reject_option'

# Nombre del modelo al que le aplicaremos post-processing
model_name = 'reweighin_logistic_regression'

# métricas fair a optimizar
fair_metrics = {'spd': "Statistical parity difference", 'aod': "Average odds difference", 'eod': "Equal opportunity difference"}

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])

# Optimizamos un modelo nuevo por cada métrica
for key_metric in fair_metrics:
    
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    models[model_name_metric] = RejectOptionClassification(
        unprivileged_groups=unprivileged_groups, 
        privileged_groups=privileged_groups, 
        metric_name=fair_metrics[key_metric],
        metric_lb=-0.01, metric_ub=0.01)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 33.4 s, sys: 13.9 s, total: 47.3 s
# Wall time: 33 s

# %%
display(Markdown("**Validation set results for logistic regression**"))
for key_metric in fair_metrics:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_val_copy, 
        dataset_preds=data_val_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
    
    print(model_name_metric)
    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')
    
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_test_copy, 
        dataset_preds=data_test_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
# Out:
# **Validation set results for logistic regression**
# reweighin_logistic_regression_reject_option_spd
# Threshold corresponding to *best balanced accuracy*: 0.3763
# AUC: 0.5919
# Balanced accuracy: 0.5000
# Accuracy: 0.9160
# Independence ( |ΔP(Y_pred = 1)| ): 0.0000
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0000
# Sufficiency ( |ΔPPV| ) : 0.0000
#
#
# reweighin_logistic_regression_reject_option_aod
# Threshold corresponding to *best balanced accuracy*: 0.3763
# AUC: 0.5919
# Balanced accuracy: 0.5000
# Accuracy: 0.9160
# Independence ( |ΔP(Y_pred = 1)| ): 0.0000
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0000
# Sufficiency ( |ΔPPV| ) : 0.0000
#
#
# reweighin_logistic_regression_reject_option_eod
# Threshold corresponding to *best balanced accuracy*: 0.3763
# AUC: 0.5919
# Balanced accuracy: 0.5000
# Accuracy: 0.9160
# Independence ( |ΔP(Y_pred = 1)| ): 0.0000
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0000
# Sufficiency ( |ΔPPV| ) : 0.0000

# %%
# %%time 

# Nombramos al modelo
fairness_method = '_reject_option'

# Nombre del modelo al que le aplicaremos post-processing
model_name = 'reweighin_xgb_classifier'

# métricas fair a optimizar
fair_metrics = {'spd': "Statistical parity difference", 'aod': "Average odds difference", 'eod': "Equal opportunity difference"}

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])

# Optimizamos un modelo nuevo por cada métrica
for key_metric in fair_metrics:
    
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    models[model_name_metric] = RejectOptionClassification(
        unprivileged_groups=unprivileged_groups, 
        privileged_groups=privileged_groups, 
        metric_name=fair_metrics[key_metric],
        metric_lb=-0.01, metric_ub=0.01)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 36.3 s, sys: 2.43 s, total: 38.7 s
# Wall time: 32.9 s

# %%
display(Markdown("**Validation set results for xgb classifier**"))
for key_metric in fair_metrics:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_val_copy, 
        dataset_preds=data_val_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
    
    print(model_name_metric)
    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')
    
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_test_copy, 
        dataset_preds=data_test_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
# Out:
# **Validation set results for xgb classifier**
# reweighin_xgb_classifier_reject_option_spd
# Threshold corresponding to *best balanced accuracy*: 0.8118
# AUC: 0.6950
# Balanced accuracy: 0.5000
# Accuracy: 0.9160
# Independence ( |ΔP(Y_pred = 1)| ): 0.0000
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0000
# Sufficiency ( |ΔPPV| ) : 0.0000
#
#
# reweighin_xgb_classifier_reject_option_aod
# Threshold corresponding to *best balanced accuracy*: 0.2080
# AUC: 0.6950
# Balanced accuracy: 0.5813
# Accuracy: 0.8933
# Independence ( |ΔP(Y_pred = 1)| ): 0.2352
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0161
# Sufficiency ( |ΔPPV| ) : 0.0726
#
#
# reweighin_xgb_classifier_reject_option_eod
# Threshold corresponding to *best balanced accuracy*: 0.1981
# AUC: 0.6950
# Balanced accuracy: 0.5813
# Accuracy: 0.8933
# Independence ( |ΔP(Y_pred = 1)| ): 0.2599
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0015
# Sufficiency ( |ΔPPV| ) : 0.1026

# %% [markdown]
# #### Impacto dispar + Rechazo de opción

# %%
# %%time 

# Nombramos al modelo
fairness_method = '_reject_option'

# Nombre del modelo al que le aplicaremos post-processing
model_name = 'disparate_impact_logistic_regression'

# métricas fair a optimizar
fair_metrics = {'spd': "Statistical parity difference", 'aod': "Average odds difference", 'eod': "Equal opportunity difference"}

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])

# Optimizamos un modelo nuevo por cada métrica
for key_metric in fair_metrics:
    
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    models[model_name_metric] = RejectOptionClassification(
        unprivileged_groups=unprivileged_groups, 
        privileged_groups=privileged_groups, 
        metric_name=fair_metrics[key_metric],
        metric_lb=-0.01, metric_ub=0.01)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 33.7 s, sys: 14.1 s, total: 47.8 s
# Wall time: 33.3 s

# %%
display(Markdown("**Validation set results for logistic regression**"))
for key_metric in fair_metrics:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_val_copy, 
        dataset_preds=data_val_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
    
    print(model_name_metric)
    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')
    
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_test_copy, 
        dataset_preds=data_test_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
# Out:
# **Validation set results for logistic regression**
# disparate_impact_logistic_regression_reject_option_spd
# Threshold corresponding to *best balanced accuracy*: 0.1981
# AUC: 0.5241
# Balanced accuracy: 0.5199
# Accuracy: 0.7280
# Independence ( |ΔP(Y_pred = 1)| ): 0.0008
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0820
# Sufficiency ( |ΔPPV| ) : 0.0030
#
#
# disparate_impact_logistic_regression_reject_option_aod
# Threshold corresponding to *best balanced accuracy*: 0.6534
# AUC: 0.5241
# Balanced accuracy: 0.5000
# Accuracy: 0.9160
# Independence ( |ΔP(Y_pred = 1)| ): 0.0000
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0000
# Sufficiency ( |ΔPPV| ) : 0.0000
#
#
# disparate_impact_logistic_regression_reject_option_eod
# Threshold corresponding to *best balanced accuracy*: 0.6534
# AUC: 0.5241
# Balanced accuracy: 0.5000
# Accuracy: 0.9160
# Independence ( |ΔP(Y_pred = 1)| ): 0.0000
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0000
# Sufficiency ( |ΔPPV| ) : 0.0000

# %%
# %%time 

# Nombramos al modelo
fairness_method = '_reject_option'

# Nombre del modelo al que le aplicaremos post-processing
model_name = 'disparate_impact_xgb_classifier'

# métricas fair a optimizar
fair_metrics = {'spd': "Statistical parity difference", 'aod': "Average odds difference", 'eod': "Equal opportunity difference"}

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])

# Optimizamos un modelo nuevo por cada métrica
for key_metric in fair_metrics:
    
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    models[model_name_metric] = RejectOptionClassification(
        unprivileged_groups=unprivileged_groups, 
        privileged_groups=privileged_groups, 
        metric_name=fair_metrics[key_metric],
        metric_lb=-0.01, metric_ub=0.01)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 36.7 s, sys: 2.28 s, total: 39 s
# Wall time: 33.1 s

# %%
display(Markdown("**Validation set results for xgb classifier**"))
for key_metric in fair_metrics:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_val_copy, 
        dataset_preds=data_val_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
    
    print(model_name_metric)
    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')
    
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_test_copy, 
        dataset_preds=data_test_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
# Out:
# **Validation set results for xgb classifier**
# disparate_impact_xgb_classifier_reject_option_spd
# Threshold corresponding to *best balanced accuracy*: 0.8415
# AUC: 0.6952
# Balanced accuracy: 0.5000
# Accuracy: 0.9160
# Independence ( |ΔP(Y_pred = 1)| ): 0.0000
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0000
# Sufficiency ( |ΔPPV| ) : 0.0000
#
#
# disparate_impact_xgb_classifier_reject_option_aod
# Threshold corresponding to *best balanced accuracy*: 0.5148
# AUC: 0.6952
# Balanced accuracy: 0.5296
# Accuracy: 0.9173
# Independence ( |ΔP(Y_pred = 1)| ): 0.0641
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1126
# Sufficiency ( |ΔPPV| ) : 0.1667
#
#
# disparate_impact_xgb_classifier_reject_option_eod
# Threshold corresponding to *best balanced accuracy*: 0.0496
# AUC: 0.6952
# Balanced accuracy: 0.6316
# Accuracy: 0.7080
# Independence ( |ΔP(Y_pred = 1)| ): 0.3739
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0930
# Sufficiency ( |ΔPPV| ) : 0.0306

# %% [markdown]
# #### Reponderación y impacto dispar + Escalado de Platt por grupos

# %%
# %%time
fairness_method = '_platt_scaling'
model_names = model_names
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy = True), data_val.copy(deepcopy = True), data_test.copy(deepcopy = True)

for model_name in model_names:
    # Hacemos una copia de las predicciones del modelo de referencia
    model_thresh = metrics_best_thresh_validate[model_name]['best_threshold']
    data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name], class_thresh = model_thresh)
    ## Plat Scaling:
    #1. dividir el validation data usando los groups sensibles
    data_val_preds_priv, data_val_preds_unpriv, priv_indices, unpriv_indices = utils.split_dataset_on_sensitive_attribute(
        dataset = data_val_preds, privileged_group_label = list((privileged_groups[0].values()))[0])
    #2. copia el validation data para guardar los scores
    data_val_preds2 = data_val_preds.copy(deepcopy = True)
    #3. hacer un modelo para cada grupo
    sensitive_groups_data = {'priv': [data_val_preds_priv, priv_indices],
                             'unpriv': [data_val_preds_unpriv, unpriv_indices]}

    for group, data_group_list in sensitive_groups_data.items():

        # nombramos al modelo con su grupo específico
        model_name_group = '{}_{}_{}'.format(model_name, fairness_method, group)

        # Inicializamos el modelo y lo asignamos al diccionario
        models[model_name_group] = LogisticRegression()

        # Realizamos el modelo usando datos para cada grupo en el validation data
        models[ model_name_group ] = models[model_name_group].fit(data_group_list[0].scores,   # data_group_list[0] -> data_val_preds_priv or data_val_preds_unpriv
                                                                  data_val_copy.subset(data_group_list[1]).labels.ravel()) # data_group_list[1] -> priv_indices or unpriv_indices
        # haz predicciones de probabilidad con el modelo de cada groupo y guardar lo en data_val_preds2
        # las predicciones de probabilidad son los platt scores
        scores_group = models[model_name_group].predict_proba(data_group_list[0].scores)
        pos_ind_group = np.where(models[model_name_group].classes_ == data_group_list[0].favorable_label)[0][0]
        data_val_preds2.scores[data_group_list[1]] = scores_group[:, pos_ind_group].reshape(-1,1)
        
        # Evaluamos a los modelos para el rango de umbrales
    thresh_sweep_platt = np.linspace(np.min(data_val_preds2.scores.ravel()),
                                     np.max(data_val_preds2.scores.ravel()),
                                     50)

    metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep_from_scores(
            dataset_true = data_val_copy,
            dataset_preds = data_val_preds2,
            thresh_arr = thresh_sweep_platt
        )

    # Evaluamos las métricas para el mejor umbral y las guardamos
    metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics( metrics_sweep[model_name+fairness_method] )

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    print('\nValidation set results for {}'.format(model_name))
    utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
    # utils.plot_fairness_and_accuracy( metrics_sweep[model_name+fairness_method] )
    # plt.title( model_name+fairness_method )
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
    a.set_title(model_name+fairness_method )
    f
# Out:
# Validation set results for reweighin_logistic_regression
# Threshold corresponding to *best balanced accuracy*: 0.0805
# AUC: 0.6043
# Balanced accuracy: 0.5750
# Accuracy: 0.6440
# Independence ( |ΔP(Y_pred = 1)| ): 0.6846
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0614
# Sufficiency ( |ΔPPV| ) : 0.0552
#
# Validation set results for reweighin_xgb_classifier
# Threshold corresponding to *best balanced accuracy*: 0.0785
# AUC: 0.6915
# Balanced accuracy: 0.6415
# Accuracy: 0.6867
# Independence ( |ΔP(Y_pred = 1)| ): 0.7129
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1350
# Sufficiency ( |ΔPPV| ) : 0.0150
#
# Validation set results for disparate_impact_logistic_regression
# Threshold corresponding to *best balanced accuracy*: 0.1608
# AUC: 0.5138
# Balanced accuracy: 0.5301
# Accuracy: 0.8787
# Independence ( |ΔP(Y_pred = 1)| ): 0.9767
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0139
# Sufficiency ( |ΔPPV| ) : 0.1667
#
# Validation set results for disparate_impact_xgb_classifier
# Threshold corresponding to *best balanced accuracy*: 0.0753
# AUC: 0.6890
# Balanced accuracy: 0.6473
# Accuracy: 0.5520
# Independence ( |ΔP(Y_pred = 1)| ): 0.5389
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1472
# Sufficiency ( |ΔPPV| ) : 0.0370
# CPU times: user 1min 27s, sys: 1min 24s, total: 2min 51s
# Wall time: 2min 37s

# %%
# usa el optimal cutoff para predecir usando el test dato

for model_name in model_names:
    model_thresh = metrics_best_thresh_validate[model_name]['best_threshold']
    data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name], class_thresh = model_thresh)
    
    # 1. dividir el validation data usando los groups sensibles
    data_test_preds_priv, data_test_preds_unpriv, priv_indices, unpriv_indices = utils.split_dataset_on_sensitive_attribute(dataset = data_test_preds,
                                                                                                                            privileged_group_label = list((privileged_groups[0].values()))[0])
    # 2. copia el test data para guardar los platt scores
    data_test_preds2 = data_test_preds.copy(deepcopy = True)
    
    # 3. predecir con el modelo de cada grupo
    sensitive_groups_data_test = {'priv': [data_test_preds_priv, priv_indices],
                                  'unpriv': [data_test_preds_unpriv, unpriv_indices]}

    for group, data_group_list in sensitive_groups_data_test.items():    
        # nombramos al modelo con su grupo específico
        model_name_group = '{}_{}_{}'.format(model_name, fairness_method, group)

        # haz predicciones de probabilidad con el modelo de cada groupo y guardar lo en data_val_preds2
        # las predicciones de probabilidad son los platt scores
        scores_group = models[model_name_group].predict_proba(data_group_list[0].scores)
        pos_ind_group = np.where(models[model_name_group].classes_ == data_group_list[0].favorable_label)[0][0]
        data_test_preds2.scores[data_group_list[1]] = scores_group[:, pos_ind_group].reshape(-1,1)
    
    metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_from_scores(dataset_true = data_test_copy,
                                                                                             dataset_pred = data_test_preds2,
                                                                                             threshold = metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

# %% [markdown]
# #### Reponderación + Procesador de probabilidades igualadas

# %% [markdown]
# ##### Usando labels

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'reweighin_logistic_regression'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:23
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:144, in EqOddsPostprocessing.fit(self, dataset_true, dataset_pred)
#     139 oflip = np.ravel(
#     140     dataset_pred.labels[cond_vec_unpriv] == dataset_pred.unfavorable_label)
#     142 y_true = dataset_true.labels.ravel()
# --> 144 sm_tn = np.logical_and(sflip,
#     145     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     146     dtype=np.float64)
#     147 sm_fn = np.logical_and(sflip,
#     148     y_true[cond_vec_priv] == dataset_true.favorable_label,
#     149     dtype=np.float64)
#     150 sm_fp = np.logical_and(sconst,
#     151     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     152     dtype=np.float64)
#
# TypeError: No loop matching the specified signature and casting was found for ufunc logical_and

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing(
    dataset_true=data_test_copy,
    dataset_preds=data_test_preds,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'reweighin_xgb_classifier'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:23
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:144, in EqOddsPostprocessing.fit(self, dataset_true, dataset_pred)
#     139 oflip = np.ravel(
#     140     dataset_pred.labels[cond_vec_unpriv] == dataset_pred.unfavorable_label)
#     142 y_true = dataset_true.labels.ravel()
# --> 144 sm_tn = np.logical_and(sflip,
#     145     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     146     dtype=np.float64)
#     147 sm_fn = np.logical_and(sflip,
#     148     y_true[cond_vec_priv] == dataset_true.favorable_label,
#     149     dtype=np.float64)
#     150 sm_fp = np.logical_and(sconst,
#     151     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     152     dtype=np.float64)
#
# TypeError: No loop matching the specified signature and casting was found for ufunc logical_and

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing(
    dataset_true=data_test_copy,
    dataset_preds=data_test_preds,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %% [markdown]
# #### Usando scores

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'reweighin_logistic_regression'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 7.42 s, sys: 17.5 s, total: 24.9 s
# Wall time: 6.66 s

# %%
display(Markdown("**Validation set results for logistic regression**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_test_copy,
        dataset_preds=data_test_preds,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for logistic regression**
# Results for reweighin_logistic_regression_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.1110
# AUC: 0.5919
# Balanced accuracy: 0.5707
# Accuracy: 0.6493
# Independence ( |ΔP(Y_pred = 1)| ): 0.4217
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0852
# Sufficiency ( |ΔPPV| ) : 0.0466
#
#
# Results for reweighin_logistic_regression_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.1110
# AUC: 0.5919
# Balanced accuracy: 0.5800
# Accuracy: 0.6400
# Independence ( |ΔP(Y_pred = 1)| ): 0.6775
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0673
# Sufficiency ( |ΔPPV| ) : 0.0531
#
#
# Results for reweighin_logistic_regression_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.1110
# AUC: 0.5919
# Balanced accuracy: 0.5707
# Accuracy: 0.6493
# Independence ( |ΔP(Y_pred = 1)| ): 0.4217
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0852
# Sufficiency ( |ΔPPV| ) : 0.0466

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'reweighin_xgb_classifier'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 8.75 s, sys: 3.68 s, total: 12.4 s
# Wall time: 6.77 s

# %%
display(Markdown("**Validation set results for xgb classifier**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_test_copy,
        dataset_preds=data_test_preds,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for xgb classifier**
# Results for reweighin_xgb_classifier_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.0908
# AUC: 0.6950
# Balanced accuracy: 0.5653
# Accuracy: 0.8507
# Independence ( |ΔP(Y_pred = 1)| ): 0.3352
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1346
# Sufficiency ( |ΔPPV| ) : 0.1252
#
#
# Results for reweighin_xgb_classifier_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.0504
# AUC: 0.6950
# Balanced accuracy: 0.6616
# Accuracy: 0.6707
# Independence ( |ΔP(Y_pred = 1)| ): 0.3392
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1432
# Sufficiency ( |ΔPPV| ) : 0.0205
#
#
# Results for reweighin_xgb_classifier_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.0908
# AUC: 0.6950
# Balanced accuracy: 0.5667
# Accuracy: 0.8533
# Independence ( |ΔP(Y_pred = 1)| ): 0.3380
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1331
# Sufficiency ( |ΔPPV| ) : 0.1199

# %% [markdown]
# #### Impacto dispar + Procesador de probabilidades igualadas

# %% [markdown]
# ##### Usando labels

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'disparate_impact_logistic_regression'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:23
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:144, in EqOddsPostprocessing.fit(self, dataset_true, dataset_pred)
#     139 oflip = np.ravel(
#     140     dataset_pred.labels[cond_vec_unpriv] == dataset_pred.unfavorable_label)
#     142 y_true = dataset_true.labels.ravel()
# --> 144 sm_tn = np.logical_and(sflip,
#     145     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     146     dtype=np.float64)
#     147 sm_fn = np.logical_and(sflip,
#     148     y_true[cond_vec_priv] == dataset_true.favorable_label,
#     149     dtype=np.float64)
#     150 sm_fp = np.logical_and(sconst,
#     151     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     152     dtype=np.float64)
#
# TypeError: No loop matching the specified signature and casting was found for ufunc logical_and

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing(
    dataset_true=data_test_copy,
    dataset_preds=data_test_preds,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'disparate_impact_xgb_classifier'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:23
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:144, in EqOddsPostprocessing.fit(self, dataset_true, dataset_pred)
#     139 oflip = np.ravel(
#     140     dataset_pred.labels[cond_vec_unpriv] == dataset_pred.unfavorable_label)
#     142 y_true = dataset_true.labels.ravel()
# --> 144 sm_tn = np.logical_and(sflip,
#     145     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     146     dtype=np.float64)
#     147 sm_fn = np.logical_and(sflip,
#     148     y_true[cond_vec_priv] == dataset_true.favorable_label,
#     149     dtype=np.float64)
#     150 sm_fp = np.logical_and(sconst,
#     151     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     152     dtype=np.float64)
#
# TypeError: No loop matching the specified signature and casting was found for ufunc logical_and

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing(
    dataset_true=data_test_copy,
    dataset_preds=data_test_preds,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %% [markdown]
# ##### Usando scores

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'disparate_impact_logistic_regression'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 7.62 s, sys: 17.8 s, total: 25.4 s
# Wall time: 6.85 s

# %%
display(Markdown("**Validation set results for logistic regression**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_test_copy,
        dataset_preds=data_test_preds,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for logistic regression**
# Results for disparate_impact_logistic_regression_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.1514
# AUC: 0.5241
# Balanced accuracy: 0.5341
# Accuracy: 0.6747
# Independence ( |ΔP(Y_pred = 1)| ): 0.2463
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0057
# Sufficiency ( |ΔPPV| ) : 0.0808
#
#
# Results for disparate_impact_logistic_regression_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.1514
# AUC: 0.5241
# Balanced accuracy: 0.5461
# Accuracy: 0.7760
# Independence ( |ΔP(Y_pred = 1)| ): 0.3708
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0151
# Sufficiency ( |ΔPPV| ) : 0.0618
#
#
# Results for disparate_impact_logistic_regression_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.1514
# AUC: 0.5241
# Balanced accuracy: 0.5341
# Accuracy: 0.6747
# Independence ( |ΔP(Y_pred = 1)| ): 0.2463
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0057
# Sufficiency ( |ΔPPV| ) : 0.0808

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'disparate_impact_xgb_classifier'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 8.02 s, sys: 3.4 s, total: 11.4 s
# Wall time: 7.57 s

# %%
display(Markdown("**Validation set results for xgb classifier**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_test_copy,
        dataset_preds=data_test_preds,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for xgb classifier**
# Results for disparate_impact_xgb_classifier_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.1110
# AUC: 0.6952
# Balanced accuracy: 0.5410
# Accuracy: 0.8987
# Independence ( |ΔP(Y_pred = 1)| ): 0.3812
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1788
# Sufficiency ( |ΔPPV| ) : 0.0941
#
#
# Results for disparate_impact_xgb_classifier_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.0302
# AUC: 0.6952
# Balanced accuracy: 0.6567
# Accuracy: 0.5560
# Independence ( |ΔP(Y_pred = 1)| ): 0.3676
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0550
# Sufficiency ( |ΔPPV| ) : 0.0679
#
#
# Results for disparate_impact_xgb_classifier_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.0302
# AUC: 0.6952
# Balanced accuracy: 0.5485
# Accuracy: 0.2520
# Independence ( |ΔP(Y_pred = 1)| ): 0.0022
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0694
# Sufficiency ( |ΔPPV| ) : 0.1133

# %% [markdown]
# ## Inprocesado + Postprocesado

# %%
#Anotamos los nombres de los modelos que vamos a usar
model_names = ['prejudice_remover', 'meta_fairness_sr', 'meta_fairness_fdr', 'NN_adversarial_debiasing', 'Basic_NN_no_adversarial_debiasing']

# %% [markdown]
# ### Eliminador de prejuicios + rechazo de opción

# %%
# %%time 

# Nombramos al modelo
fairness_method = '_reject_option'

# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[0]

# métricas fair a optimizar
fair_metrics = {'spd': "Statistical parity difference", 'aod': "Average odds difference", 'eod': "Equal opportunity difference"}

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])

# Optimizamos un modelo nuevo por cada métrica
for key_metric in fair_metrics:
    
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    models[model_name_metric] = RejectOptionClassification(
        unprivileged_groups=unprivileged_groups, 
        privileged_groups=privileged_groups, 
        metric_name=fair_metrics[key_metric],
        metric_lb=-0.01, metric_ub=0.01)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/DEFINITIVO/utils.py:142, in update_dataset_from_model(dataset, model, class_thresh)
#     141 try:
# --> 142     y_pred_prob = model.predict_proba(dataset_pred.features)[:, pos_ind]
#     143 except:
#
# AttributeError: 'PrejudiceRemover' object has no attribute 'predict_proba'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:14
#
# File ~/DEFINITIVO/utils.py:144, in update_dataset_from_model(dataset, model, class_thresh)
#     142     y_pred_prob = model.predict_proba(dataset_pred.features)[:, pos_ind]
#     143 except:
# --> 144     y_pred_prob = model.predict(dataset_pred).scores
#     145 # Obtain predicted labels according to class_threshold
#     146 y_pred = np.zeros_like(dataset_pred.labels)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/prejudice_remover.py:204, in PrejudiceRemover.predict(self, dataset)
#     198 predict_lr = os.path.join(k_path, 'kamfadm-2012ecmlpkdd', 'predict_lr.py')
#     199 # changed paths in the calls below to (a) specify path of train_pr,
#     200 # predict_lr RELATIVE to this file, and (b) compute & use absolute path,
#     201 # and (c) replace python3 with python
#     202 subprocess.call(['python', predict_lr,
#     203                  '-i', test_name,
# --> 204                  '-m', self.model_name,
#     205                  '-o', output_name,
#     206                  '--quiet'])
#     207 os.unlink(test_name)
#     208 m = np.loadtxt(output_name)
#
# AttributeError: 'PrejudiceRemover' object has no attribute 'model_name'

# %%
display(Markdown("**Validation set results for logistic regression**"))
for key_metric in fair_metrics:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_val_copy, 
        dataset_preds=data_val_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
    
    print(model_name_metric)
    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')
    
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_test_copy, 
        dataset_preds=data_test_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
# Out:
# **Validation set results for logistic regression**
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[67], line 9
#       2 for key_metric in fair_metrics:
#       4     model_name_metric = model_name + fairness_method + '_' + key_metric
#       6     metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing(
#       7         dataset_true=data_val_copy,
#       8         dataset_preds=data_val_preds,
# ----> 9         model=models[model_name_metric],
#      10         required_threshold=False)
#      12     print(model_name_metric)
#      13     utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
#
# KeyError: 'prejudice_remover_reject_option_spd'

# %% [markdown]
# ### Metafairness + rechazo de opción

# %%
# %%time 

# Nombramos al modelo
fairness_method = '_reject_option'

# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[1]

# métricas fair a optimizar
fair_metrics = {'spd': "Statistical parity difference", 'aod': "Average odds difference", 'eod': "Equal opportunity difference"}

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
#data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
#data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
#data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])

# Optimizamos un modelo nuevo por cada métrica
for key_metric in fair_metrics:
    
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    models[model_name_metric] = RejectOptionClassification(
        unprivileged_groups=unprivileged_groups, 
        privileged_groups=privileged_groups, 
        metric_name=fair_metrics[key_metric],
        metric_lb=-0.01, metric_ub=0.01)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 38.7 s, sys: 1.46 s, total: 40.1 s
# Wall time: 1min 1s

# %%
display(Markdown("**Validation set results for logistic regression**"))
for key_metric in fair_metrics:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_val_copy, 
        dataset_preds=data_val_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
    
    print(model_name_metric)
    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')
    
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_test_copy, 
        dataset_preds=data_test_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
# Out:
# **Validation set results for logistic regression**
# meta_fairness_sr_reject_option_spd
# Threshold corresponding to *best balanced accuracy*: 0.8415
# AUC: 0.6952
# Balanced accuracy: 0.5000
# Accuracy: 0.9160
# Independence ( |ΔP(Y_pred = 1)| ): 0.0000
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0000
# Sufficiency ( |ΔPPV| ) : 0.0000
#
#
# meta_fairness_sr_reject_option_aod
# Threshold corresponding to *best balanced accuracy*: 0.5148
# AUC: 0.6952
# Balanced accuracy: 0.5296
# Accuracy: 0.9173
# Independence ( |ΔP(Y_pred = 1)| ): 0.0641
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1126
# Sufficiency ( |ΔPPV| ) : 0.1667
#
#
# meta_fairness_sr_reject_option_eod
# Threshold corresponding to *best balanced accuracy*: 0.0496
# AUC: 0.6952
# Balanced accuracy: 0.6316
# Accuracy: 0.7080
# Independence ( |ΔP(Y_pred = 1)| ): 0.3739
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0930
# Sufficiency ( |ΔPPV| ) : 0.0306

# %% [markdown]
# ### Prejuicios adversarios + rechazo de opción

# %%
# %%time 

# Nombramos al modelo
fairness_method = '_reject_option'

# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[2]

# métricas fair a optimizar
fair_metrics = {'spd': "Statistical parity difference", 'aod': "Average odds difference", 'eod': "Equal opportunity difference"}

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
#data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
#data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
#data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])

# Optimizamos un modelo nuevo por cada métrica
for key_metric in fair_metrics:
    
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    models[model_name_metric] = RejectOptionClassification(
        unprivileged_groups=unprivileged_groups, 
        privileged_groups=privileged_groups, 
        metric_name=fair_metrics[key_metric],
        metric_lb=-0.01, metric_ub=0.01)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 38.7 s, sys: 1.93 s, total: 40.7 s
# Wall time: 1min

# %%
display(Markdown("**Validation set results for logistic regression**"))
for key_metric in fair_metrics:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_val_copy, 
        dataset_preds=data_val_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
    
    print(model_name_metric)
    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')
    
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_test_copy, 
        dataset_preds=data_test_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
# Out:
# **Validation set results for logistic regression**
# meta_fairness_fdr_reject_option_spd
# Threshold corresponding to *best balanced accuracy*: 0.8415
# AUC: 0.6952
# Balanced accuracy: 0.5000
# Accuracy: 0.9160
# Independence ( |ΔP(Y_pred = 1)| ): 0.0000
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0000
# Sufficiency ( |ΔPPV| ) : 0.0000
#
#
# meta_fairness_fdr_reject_option_aod
# Threshold corresponding to *best balanced accuracy*: 0.5148
# AUC: 0.6952
# Balanced accuracy: 0.5296
# Accuracy: 0.9173
# Independence ( |ΔP(Y_pred = 1)| ): 0.0641
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1126
# Sufficiency ( |ΔPPV| ) : 0.1667
#
#
# meta_fairness_fdr_reject_option_eod
# Threshold corresponding to *best balanced accuracy*: 0.0496
# AUC: 0.6952
# Balanced accuracy: 0.6316
# Accuracy: 0.7080
# Independence ( |ΔP(Y_pred = 1)| ): 0.3739
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0930
# Sufficiency ( |ΔPPV| ) : 0.0306

# %% [markdown]
# ### Red neuronal normal + rechazo de opción

# %%
# %%time 

# Nombramos al modelo
fairness_method = '_reject_option'

# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[3]

# métricas fair a optimizar
fair_metrics = {'spd': "Statistical parity difference", 'aod': "Average odds difference", 'eod': "Equal opportunity difference"}

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
#data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
#data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
#data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])

# Optimizamos un modelo nuevo por cada métrica
for key_metric in fair_metrics:
    
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    models[model_name_metric] = RejectOptionClassification(
        unprivileged_groups=unprivileged_groups, 
        privileged_groups=privileged_groups, 
        metric_name=fair_metrics[key_metric],
        metric_lb=-0.01, metric_ub=0.01)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 39.9 s, sys: 2.03 s, total: 42 s
# Wall time: 58.5 s

# %%
display(Markdown("**Validation set results for logistic regression**"))
for key_metric in fair_metrics:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_val_copy, 
        dataset_preds=data_val_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
    
    print(model_name_metric)
    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')
    
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_test_copy, 
        dataset_preds=data_test_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
# Out:
# **Validation set results for logistic regression**
# NN_adversarial_debiasing_reject_option_spd
# Threshold corresponding to *best balanced accuracy*: 0.8415
# AUC: 0.6952
# Balanced accuracy: 0.5000
# Accuracy: 0.9160
# Independence ( |ΔP(Y_pred = 1)| ): 0.0000
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0000
# Sufficiency ( |ΔPPV| ) : 0.0000
#
#
# NN_adversarial_debiasing_reject_option_aod
# Threshold corresponding to *best balanced accuracy*: 0.5148
# AUC: 0.6952
# Balanced accuracy: 0.5296
# Accuracy: 0.9173
# Independence ( |ΔP(Y_pred = 1)| ): 0.0641
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1126
# Sufficiency ( |ΔPPV| ) : 0.1667
#
#
# NN_adversarial_debiasing_reject_option_eod
# Threshold corresponding to *best balanced accuracy*: 0.0496
# AUC: 0.6952
# Balanced accuracy: 0.6316
# Accuracy: 0.7080
# Independence ( |ΔP(Y_pred = 1)| ): 0.3739
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0930
# Sufficiency ( |ΔPPV| ) : 0.0306

# %% [markdown]
# ### Inprocesado + Escalado Platt por grupos

# %%
# %%time
fairness_method = '_platt_scaling'

model_names = ['NN_adversarial_debiasing', 'Basic_NN_no_adversarial_debiasing']
#model_names = ['meta_fairness_fdr', 'meta_fairness_sr', 'NN_adversarial_debiasing', 'Basic_NN_no_adversarial_debiasing']
#model_names = ['prejudice_remover', 'meta_fairness_sr', 'meta_fairness_fdr', 'NN_adversarial_debiasing', 'Basic_NN_no_adversarial_debiasing']
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy = True), data_val.copy(deepcopy = True), data_test.copy(deepcopy = True)
    
for model_name in model_names:
    # Hacemos una copia de las predicciones del modelo de referencia
    model_thresh = metrics_best_thresh_validate[model_name]['best_threshold']
    data_val_preds = utils.update_dataset_from_scores(data_val_copy, models[model_name].scores_val, model_thresh)
    ## Plat Scaling:
    #1. dividir el validation data usando los groups sensibles
    data_val_preds_priv, data_val_preds_unpriv, priv_indices, unpriv_indices = utils.split_dataset_on_sensitive_attribute(
        dataset = data_val_preds, privileged_group_label = list((privileged_groups[0].values()))[0])
    #2. copia el validation data para guardar los scores
    data_val_preds2 = data_val_preds.copy(deepcopy = True)
    #3. hacer un modelo para cada grupo
    sensitive_groups_data = {'priv': [data_val_preds_priv, priv_indices],
                            'unpriv': [data_val_preds_unpriv, unpriv_indices]}
    
    for group, data_group_list in sensitive_groups_data.items():
    
        # nombramos al modelo con su grupo específico
        model_name_group = '{}_{}_{}'.format(model_name, fairness_method, group)
    
        # Inicializamos el modelo y lo asignamos al diccionario
        models[model_name_group] = LogisticRegression()
    
        # Realizamos el modelo usando datos para cada grupo en el validation data
        models[ model_name_group ] = models[model_name_group].fit(data_group_list[0].scores,   # data_group_list[0] -> data_val_preds_priv or data_val_preds_unpriv
                                                                      data_val_copy.subset(data_group_list[1]).labels.ravel()) # data_group_list[1] -> priv_indices or unpriv_indices
        # haz predicciones de probabilidad con el modelo de cada groupo y guardar lo en data_val_preds2
        # las predicciones de probabilidad son los platt scores
        scores_group = models[model_name_group].predict_proba(data_group_list[0].scores)
        pos_ind_group = np.where(models[model_name_group].classes_ == data_group_list[0].favorable_label)[0][0]
        data_val_preds2.scores[data_group_list[1]] = scores_group[:, pos_ind_group].reshape(-1,1)
            
        # Evaluamos a los modelos para el rango de umbrales
        thresh_sweep_platt = np.linspace(np.min(data_val_preds2.scores.ravel()),
                                         np.max(data_val_preds2.scores.ravel()),
                                         50)
    
        metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep_from_scores(
                dataset_true = data_val_copy,
                dataset_preds = data_val_preds2,
                thresh_arr = thresh_sweep_platt
            )
    
        # Evaluamos las métricas para el mejor umbral y las guardamos
        metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics( metrics_sweep[model_name+fairness_method] )
    
        # Graficamos el comportamiento del modelo para el rango de umbrales 
        print('\nValidation set results for {}'.format(model_name))
        utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
        # utils.plot_fairness_and_accuracy( metrics_sweep[model_name+fairness_method] )
        # plt.title( model_name+fairness_method )
        
        f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
        a.set_title(model_name+fairness_method )
        f
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File <timed exec>:31
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1201, in LogisticRegression.fit(self, X, y, sample_weight)
#    1198 else:
#    1199     _dtype = [np.float64, np.float32]
# -> 1201 X, y = self._validate_data(
#    1202     X,
#    1203     y,
#    1204     accept_sparse="csr",
#    1205     dtype=_dtype,
#    1206     order="C",
#    1207     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1208 )
#    1209 check_classification_targets(y)
#    1210 self.classes_ = np.unique(y)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/sklearn/base.py:650, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     648         y = check_array(y, input_name="y", **check_y_params)
#     649     else:
# --> 650         X, y = check_X_y(X, y, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/sklearn/utils/validation.py:1263, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1258         estimator_name = _check_estimator_name(estimator)
#    1259     raise ValueError(
#    1260         f"{estimator_name} requires y to be passed, but the target y is None"
#    1261     )
# -> 1263 X = check_array(
#    1264     X,
#    1265     accept_sparse=accept_sparse,
#    1266     accept_large_sparse=accept_large_sparse,
#    1267     dtype=dtype,
#    1268     order=order,
#    1269     copy=copy,
#    1270     force_all_finite=force_all_finite,
#    1271     ensure_2d=ensure_2d,
#    1272     allow_nd=allow_nd,
#    1273     ensure_min_samples=ensure_min_samples,
#    1274     ensure_min_features=ensure_min_features,
#    1275     estimator=estimator,
#    1276     input_name="X",
#    1277 )
#    1279 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1281 check_consistent_length(X, y)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/sklearn/utils/validation.py:1049, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1043     raise ValueError(
#    1044         "Found array with dim %d. %s expected <= 2."
#    1045         % (array.ndim, estimator_name)
#    1046     )
#    1048 if force_all_finite:
# -> 1049     _assert_all_finite(
#    1050         array,
#    1051         input_name=input_name,
#    1052         estimator_name=estimator_name,
#    1053         allow_nan=force_all_finite == "allow-nan",
#    1054     )
#    1056 if copy:
#    1057     if _is_numpy_namespace(xp):
#    1058         # only make a copy if `array` and `array_orig` may share memory`
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/sklearn/utils/validation.py:126, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     123 if first_pass_isfinite:
#     124     return
# --> 126 _assert_all_finite_element_wise(
#     127     X,
#     128     xp=xp,
#     129     allow_nan=allow_nan,
#     130     msg_dtype=msg_dtype,
#     131     estimator_name=estimator_name,
#     132     input_name=input_name,
#     133 )
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/sklearn/utils/validation.py:175, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     158 if estimator_name and input_name == "X" and has_nan_error:
#     159     # Improve the error message on how to handle missing values in
#     160     # scikit-learn.
#     161     msg_err += (
#     162         f"\n{estimator_name} does not accept missing values"
#     163         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     173         "#estimators-that-handle-nan-values"
#     174     )
# --> 175 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# LogisticRegression does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
# usa el optimal cutoff para predecir usando el test dato

for model_name in model_names:
    model_thresh = metrics_best_thresh_validate[model_name]['best_threshold']
    data_test_preds = utils.update_dataset_from_scores(data_test_copy, models[model_name].scores_test, model_thresh)
    
    # 1. dividir el validation data usando los groups sensibles
    data_test_preds_priv, data_test_preds_unpriv, priv_indices, unpriv_indices = utils.split_dataset_on_sensitive_attribute(dataset = data_test_preds,
                                                                                                                            privileged_group_label = list((privileged_groups[0].values()))[0])
    # 2. copia el test data para guardar los platt scores
    data_test_preds2 = data_test_preds.copy(deepcopy = True)
    
    # 3. predecir con el modelo de cada grupo
    sensitive_groups_data_test = {'priv': [data_test_preds_priv, priv_indices],
                                  'unpriv': [data_test_preds_unpriv, unpriv_indices]}

    for group, data_group_list in sensitive_groups_data_test.items():    
        # nombramos al modelo con su grupo específico
        model_name_group = '{}_{}_{}'.format(model_name, fairness_method, group)

        # haz predicciones de probabilidad con el modelo de cada groupo y guardar lo en data_val_preds2
        # las predicciones de probabilidad son los platt scores
        scores_group = models[model_name_group].predict_proba(data_group_list[0].scores)
        pos_ind_group = np.where(models[model_name_group].classes_ == data_group_list[0].favorable_label)[0][0]
        data_test_preds2.scores[data_group_list[1]] = scores_group[:, pos_ind_group].reshape(-1,1)
    
    metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_from_scores(dataset_true = data_test_copy,
                                                                                             dataset_pred = data_test_preds2,
                                                                                             threshold = metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[75], line 23
#      19 model_name_group = '{}_{}_{}'.format(model_name, fairness_method, group)
#      21 # haz predicciones de probabilidad con el modelo de cada groupo y guardar lo en data_val_preds2
#      22 # las predicciones de probabilidad son los platt scores
# ---> 23 scores_group = models[model_name_group].predict_proba(data_group_list[0].scores)
#      24 pos_ind_group = np.where(models[model_name_group].classes_ == data_group_list[0].favorable_label)[0][0]
#      25 data_test_preds2.scores[data_group_list[1]] = scores_group[:, pos_ind_group].reshape(-1,1)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1367, in LogisticRegression.predict_proba(self, X)
#    1341 def predict_proba(self, X):
#    1342     """
#    1343     Probability estimates.
#    1344
#    (...)
#    1365         where classes are ordered as they are in ``self.classes_``.
#    1366     """
# -> 1367     check_is_fitted(self)
#    1369     ovr = self.multi_class in ["ovr", "warn"] or (
#    1370         self.multi_class == "auto"
#    1371         and (
#    (...)
#    1374         )
#    1375     )
#    1376     if ovr:
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/sklearn/utils/validation.py:1622, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1619     raise TypeError("%s is not an estimator instance." % (estimator))
#    1621 if not _is_fitted(estimator, attributes, all_or_any):
# -> 1622     raise NotFittedError(msg % {"name": type(estimator).__name__})
#
# NotFittedError: This LogisticRegression instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %% [markdown]
# #### Eliminador de prejuicios + Procesador de probabilidades igualadas

# %% [markdown]
# ##### Usando labels

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[0]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing(
    dataset_true=data_test_copy,
    dataset_preds=data_test_preds,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f

# %% [markdown]
# #### Usando scores

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[0]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)

# %%
display(Markdown("**Validation set results for prejudice remover**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_test_copy,
        dataset_preds=data_test_preds,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f

# %% [markdown]
# #### Metafairness + Procesador de probabilidades igualadas

# %% [markdown]
# ##### Usando labels

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[1]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# 2024-06-16 21:51:41.627312: W tensorflow/c/c_api.cc:305] Operation '{name:'biased_classifier/biased_classifier/classifier_model/b2/Adam_1/Assign' id:264 op device:{requested: '', assigned: ''} def:{{{node biased_classifier/biased_classifier/classifier_model/b2/Adam_1/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](biased_classifier/biased_classifier/classifier_model/b2/Adam_1, biased_classifier/biased_classifier/classifier_model/b2/Adam_1/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:23
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:144, in EqOddsPostprocessing.fit(self, dataset_true, dataset_pred)
#     139 oflip = np.ravel(
#     140     dataset_pred.labels[cond_vec_unpriv] == dataset_pred.unfavorable_label)
#     142 y_true = dataset_true.labels.ravel()
# --> 144 sm_tn = np.logical_and(sflip,
#     145     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     146     dtype=np.float64)
#     147 sm_fn = np.logical_and(sflip,
#     148     y_true[cond_vec_priv] == dataset_true.favorable_label,
#     149     dtype=np.float64)
#     150 sm_fp = np.logical_and(sconst,
#     151     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     152     dtype=np.float64)
#
# TypeError: No loop matching the specified signature and casting was found for ufunc logical_and

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing(
    dataset_true=data_test_copy,
    dataset_preds=data_test_preds,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %% [markdown]
# #### Usando scores

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[1]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 5.36 s, sys: 4.23 s, total: 9.58 s
# Wall time: 9.8 s

# %%
display(Markdown("**Validation set results for metafairness**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_test_copy,
        dataset_preds=data_test_preds,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for metafairness**
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.1110
# AUC: 0.5062
# Balanced accuracy: 0.5325
# Accuracy: 0.5133
# Independence ( |ΔP(Y_pred = 1)| ): 0.3620
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1062
# Sufficiency ( |ΔPPV| ) : 0.0496
#
#
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.1110
# AUC: 0.5062
# Balanced accuracy: 0.5325
# Accuracy: 0.5133
# Independence ( |ΔP(Y_pred = 1)| ): 0.3620
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1062
# Sufficiency ( |ΔPPV| ) : 0.0496
#
#
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.1110
# AUC: 0.5062
# Balanced accuracy: 0.5325
# Accuracy: 0.5133
# Independence ( |ΔP(Y_pred = 1)| ): 0.3620
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1062
# Sufficiency ( |ΔPPV| ) : 0.0496

# %% [markdown]
# ##### Usando labels

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[2]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File <timed exec>:4
#
# IndexError: list index out of range

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing(
    dataset_true=data_test_copy,
    dataset_preds=data_test_preds,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %% [markdown]
# #### Usando scores

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[2]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File <timed exec>:4
#
# IndexError: list index out of range

# %%
display(Markdown("**Validation set results for metafairness**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_test_copy,
        dataset_preds=data_test_preds,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for metafairness**
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.1110
# AUC: 0.5062
# Balanced accuracy: 0.5325
# Accuracy: 0.5133
# Independence ( |ΔP(Y_pred = 1)| ): 0.3620
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1062
# Sufficiency ( |ΔPPV| ) : 0.0496
#
#
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.1110
# AUC: 0.5062
# Balanced accuracy: 0.5325
# Accuracy: 0.5133
# Independence ( |ΔP(Y_pred = 1)| ): 0.3620
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1062
# Sufficiency ( |ΔPPV| ) : 0.0496
#
#
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.1110
# AUC: 0.5062
# Balanced accuracy: 0.5325
# Accuracy: 0.5133
# Independence ( |ΔP(Y_pred = 1)| ): 0.3620
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1062
# Sufficiency ( |ΔPPV| ) : 0.0496

# %% [markdown]
# #### Prejuicios adversarios + Procesador de probabilidades igualadas

# %% [markdown]
# ##### Usando labels

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[3]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

thresh_NN_ADV = metrics_best_thresh_validate['NN_adversarial_debiasing']['best_threshold']

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_scores(data_train_copy, models[model_name].scores_train, thresh_NN_ADV)
data_val_preds = utils.update_dataset_from_scores(data_val_copy, models[model_name].scores_val, thresh_NN_ADV)
data_test_preds = utils.update_dataset_from_scores(data_test_copy, models[model_name].scores_test, thresh_NN_ADV)


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File <timed exec>:4
#
# IndexError: list index out of range

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing(
    dataset_true=data_test_copy,
    dataset_preds=data_test_preds,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %% [markdown]
# #### Usando scores

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[3]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

thresh_NN_ADV = metrics_best_thresh_validate['NN_adversarial_debiasing']['best_threshold']

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_scores(data_train_copy, models[model_name].scores_train, thresh_NN_ADV)
data_val_preds = utils.update_dataset_from_scores(data_val_copy, models[model_name].scores_val, thresh_NN_ADV)
data_test_preds = utils.update_dataset_from_scores(data_test_copy, models[model_name].scores_test, thresh_NN_ADV)


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File <timed exec>:4
#
# IndexError: list index out of range

# %%
display(Markdown("**Validation set results for adversarial debiasing**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_test_copy,
        dataset_preds=data_test_preds,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for adversarial debiasing**
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.1110
# AUC: 0.5062
# Balanced accuracy: 0.5325
# Accuracy: 0.5133
# Independence ( |ΔP(Y_pred = 1)| ): 0.3620
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1062
# Sufficiency ( |ΔPPV| ) : 0.0496
#
#
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.1110
# AUC: 0.5062
# Balanced accuracy: 0.5325
# Accuracy: 0.5133
# Independence ( |ΔP(Y_pred = 1)| ): 0.3620
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1062
# Sufficiency ( |ΔPPV| ) : 0.0496
#
#
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.1110
# AUC: 0.5062
# Balanced accuracy: 0.5325
# Accuracy: 0.5133
# Independence ( |ΔP(Y_pred = 1)| ): 0.3620
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1062
# Sufficiency ( |ΔPPV| ) : 0.0496

# %% [markdown]
# #### Red neuronal normal + Procesador de probabilidades igualadas

# %% [markdown]
# ##### Usando labels

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[4]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

thresh_no_NN_ADV = metrics_best_thresh_validate['Basic_NN_no_adversarial_debiasing']['best_threshold']

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_scores(data_train_copy, models[model_name].scores_train, thresh_no_NN_ADV)
data_val_preds = utils.update_dataset_from_scores(data_val_copy, models[model_name].scores_val, thresh_no_NN_ADV)
data_test_preds = utils.update_dataset_from_scores(data_test_copy, models[model_name].scores_test, thresh_no_NN_ADV)


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File <timed exec>:4
#
# IndexError: list index out of range

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing(
    dataset_true=data_test_copy,
    dataset_preds=data_test_preds,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %% [markdown]
# #### Usando scores

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[4]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

thresh_no_NN_ADV = metrics_best_thresh_validate['Basic_NN_no_adversarial_debiasing']['best_threshold']

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_scores(data_train_copy, models[model_name].scores_train, thresh_no_NN_ADV)
data_val_preds = utils.update_dataset_from_scores(data_val_copy, models[model_name].scores_val, thresh_no_NN_ADV)
data_test_preds = utils.update_dataset_from_scores(data_test_copy, models[model_name].scores_test, thresh_no_NN_ADV)


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File <timed exec>:4
#
# IndexError: list index out of range

# %%
display(Markdown("**Validation set results for basic NN**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_test_copy,
        dataset_preds=data_test_preds,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for basic NN**
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.1110
# AUC: 0.5062
# Balanced accuracy: 0.5325
# Accuracy: 0.5133
# Independence ( |ΔP(Y_pred = 1)| ): 0.3620
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1062
# Sufficiency ( |ΔPPV| ) : 0.0496
#
#
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.1110
# AUC: 0.5062
# Balanced accuracy: 0.5325
# Accuracy: 0.5133
# Independence ( |ΔP(Y_pred = 1)| ): 0.3620
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1062
# Sufficiency ( |ΔPPV| ) : 0.0496
#
#
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.1110
# AUC: 0.5062
# Balanced accuracy: 0.5325
# Accuracy: 0.5133
# Independence ( |ΔP(Y_pred = 1)| ): 0.3620
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1062
# Sufficiency ( |ΔPPV| ) : 0.0496

# %% [markdown]
# ## Comparación de modelos
#
# Podemos usar los diccionarios que resumen la calidad de los modelos fair para compararlos todos.

# %% [markdown]
# ### Resultados en validación

# %%
algorithm_performance_summary = pd.DataFrame(metrics_best_thresh_validate).T
algorithm_performance_summary
# Out:
#                                                     best_threshold   bal_acc  \
# logistic_regression                                       0.111020  0.574340
# xgb_classifier                                            0.050408  0.662369
# meta_fairness_sr                                          0.010000  0.500000
# meta_fairness_fdr                                         0.010000  0.500000
# NN_adversarial_debiasing                                  0.010000  0.500000
# Basic_NN_no_adversarial_debiasing                         0.111020  0.532508
# reweighing_meta_fairness_sr                               0.010000  0.500000
# reweighing_meta_fairness_fdr                              0.010000  0.500000
# disparate_impact_meta_fairness_sr                         0.010000  0.500000
# disparate_impact_meta_fairness_fdr                        0.010000  0.500000
# reweighing_NN_adversarial_debiasing                       0.010000  0.500000
# reweighin_basic_NN_no_adversarial_debiasing               0.111020  0.551979
# disparate_impact_NN_adversarial_debiasing                 0.010000  0.500000
# disparate_impact_basic_NN_no_adversarial_debiasing        0.030204  0.547688
# reweighin_logistic_regression                             0.111020  0.563152
# reweighin_xgb_classifier                                  0.050408  0.659899
# disparate_impact_logistic_regression                      0.070612  0.564566
# disparate_impact_xgb_classifier                           0.050408  0.656547
# reweighin_logistic_regression_reject_option_spd           0.376263  0.500000
# reweighin_logistic_regression_reject_option_aod           0.376263  0.500000
# reweighin_logistic_regression_reject_option_eod           0.376263  0.500000
# reweighin_xgb_classifier_reject_option_spd                0.811818  0.500000
# reweighin_xgb_classifier_reject_option_aod                0.207980  0.581341
# reweighin_xgb_classifier_reject_option_eod                0.198081  0.581341
# disparate_impact_logistic_regression_reject_opt...        0.198081  0.519928
# disparate_impact_logistic_regression_reject_opt...        0.653434  0.500000
# disparate_impact_logistic_regression_reject_opt...        0.653434  0.500000
# disparate_impact_xgb_classifier_reject_option_spd         0.841515  0.500000
# disparate_impact_xgb_classifier_reject_option_aod         0.514848  0.529563
# disparate_impact_xgb_classifier_reject_option_eod         0.049596  0.631559
# reweighin_logistic_regression_platt_scaling               0.080516  0.574998
# reweighin_xgb_classifier_platt_scaling                    0.078495  0.641540
# disparate_impact_logistic_regression_platt_scaling        0.160797  0.530082
# disparate_impact_xgb_classifier_platt_scaling             0.075303  0.647328
# reweighin_logistic_regression_equal_odds_weighted         0.111020  0.570701
# reweighin_logistic_regression_equal_odds_fnr              0.111020  0.580024
# reweighin_logistic_regression_equal_odds_fpr              0.111020  0.570701
# reweighin_xgb_classifier_equal_odds_weighted              0.090816  0.565260
# reweighin_xgb_classifier_equal_odds_fnr                   0.050408  0.661641
# reweighin_xgb_classifier_equal_odds_fpr                   0.090816  0.566715
# disparate_impact_logistic_regression_equal_odds...        0.151429  0.534068
# disparate_impact_logistic_regression_equal_odds...        0.151429  0.546129
# disparate_impact_logistic_regression_equal_odds...        0.151429  0.534068
# disparate_impact_xgb_classifier_equal_odds_weig...        0.111020  0.541000
# disparate_impact_xgb_classifier_equal_odds_fnr            0.030204  0.656720
# disparate_impact_xgb_classifier_equal_odds_fpr            0.030204  0.548451
# meta_fairness_sr_reject_option_spd                        0.841515  0.500000
# meta_fairness_sr_reject_option_aod                        0.514848  0.529563
# meta_fairness_sr_reject_option_eod                        0.049596  0.631559
# meta_fairness_fdr_reject_option_spd                       0.841515  0.500000
# meta_fairness_fdr_reject_option_aod                       0.514848  0.529563
# meta_fairness_fdr_reject_option_eod                       0.049596  0.631559
# NN_adversarial_debiasing_reject_option_spd                0.841515  0.500000
# NN_adversarial_debiasing_reject_option_aod                0.514848  0.529563
# NN_adversarial_debiasing_reject_option_eod                0.049596  0.631559
# Basic_NN_no_adversarial_debiasing_equal_odds_we...        0.111020  0.532508
# Basic_NN_no_adversarial_debiasing_equal_odds_fnr          0.111020  0.532508
# Basic_NN_no_adversarial_debiasing_equal_odds_fpr          0.111020  0.532508
#
#                                                          acc  independence  \
# logistic_regression                                 0.656000      0.453439
# xgb_classifier                                      0.672000      0.315944
# meta_fairness_sr                                    0.084000      0.000000
# meta_fairness_fdr                                   0.084000      0.000000
# NN_adversarial_debiasing                            0.084000      0.000000
# Basic_NN_no_adversarial_debiasing                   0.513333      0.361962
# reweighing_meta_fairness_sr                         0.082511      0.000000
# reweighing_meta_fairness_fdr                        0.082511      0.000000
# disparate_impact_meta_fairness_sr                   0.084000      0.000000
# disparate_impact_meta_fairness_fdr                  0.084000      0.000000
# reweighing_NN_adversarial_debiasing                 0.082511      0.000000
# reweighin_basic_NN_no_adversarial_debiasing         0.451058      0.273619
# disparate_impact_NN_adversarial_debiasing           0.084000      0.000000
# disparate_impact_basic_NN_no_adversarial_debiasing  0.382667      0.066050
# reweighin_logistic_regression                       0.646800      0.423934
# reweighin_xgb_classifier                            0.670444      0.309430
# disparate_impact_logistic_regression                0.440000      0.181869
# disparate_impact_xgb_classifier                     0.661333      0.131936
# reweighin_logistic_regression_reject_option_spd     0.916000      0.000000
# reweighin_logistic_regression_reject_option_aod     0.916000      0.000000
# reweighin_logistic_regression_reject_option_eod     0.916000      0.000000
# reweighin_xgb_classifier_reject_option_spd          0.916000      0.000000
# reweighin_xgb_classifier_reject_option_aod          0.893333      0.235223
# reweighin_xgb_classifier_reject_option_eod          0.893333      0.259893
# disparate_impact_logistic_regression_reject_opt...  0.728000      0.000822
# disparate_impact_logistic_regression_reject_opt...  0.916000      0.000000
# disparate_impact_logistic_regression_reject_opt...  0.916000      0.000000
# disparate_impact_xgb_classifier_reject_option_spd   0.916000      0.000000
# disparate_impact_xgb_classifier_reject_option_aod   0.917333      0.064110
# disparate_impact_xgb_classifier_reject_option_eod   0.708000      0.373935
# reweighin_logistic_regression_platt_scaling         0.644000      0.684583
# reweighin_xgb_classifier_platt_scaling              0.686667      0.712871
# disparate_impact_logistic_regression_platt_scaling  0.878667      0.976744
# disparate_impact_xgb_classifier_platt_scaling       0.552000      0.538897
# reweighin_logistic_regression_equal_odds_weighted   0.649333      0.421697
# reweighin_logistic_regression_equal_odds_fnr        0.640000      0.677511
# reweighin_logistic_regression_equal_odds_fpr        0.649333      0.421697
# reweighin_xgb_classifier_equal_odds_weighted        0.850667      0.335153
# reweighin_xgb_classifier_equal_odds_fnr             0.670667      0.339199
# reweighin_xgb_classifier_equal_odds_fpr             0.853333      0.337982
# disparate_impact_logistic_regression_equal_odds...  0.674667      0.246341
# disparate_impact_logistic_regression_equal_odds...  0.776000      0.370810
# disparate_impact_logistic_regression_equal_odds...  0.674667      0.246341
# disparate_impact_xgb_classifier_equal_odds_weig...  0.898667      0.381205
# disparate_impact_xgb_classifier_equal_odds_fnr      0.556000      0.367619
# disparate_impact_xgb_classifier_equal_odds_fpr      0.252000      0.002171
# meta_fairness_sr_reject_option_spd                  0.916000      0.000000
# meta_fairness_sr_reject_option_aod                  0.917333      0.064110
# meta_fairness_sr_reject_option_eod                  0.708000      0.373935
# meta_fairness_fdr_reject_option_spd                 0.916000      0.000000
# meta_fairness_fdr_reject_option_aod                 0.917333      0.064110
# meta_fairness_fdr_reject_option_eod                 0.708000      0.373935
# NN_adversarial_debiasing_reject_option_spd          0.916000      0.000000
# NN_adversarial_debiasing_reject_option_aod          0.917333      0.064110
# NN_adversarial_debiasing_reject_option_eod          0.708000      0.373935
# Basic_NN_no_adversarial_debiasing_equal_odds_we...  0.513333      0.361962
# Basic_NN_no_adversarial_debiasing_equal_odds_fnr    0.513333      0.361962
# Basic_NN_no_adversarial_debiasing_equal_odds_fpr    0.513333      0.361962
#
#                                                     separation  sufficiency  \
# logistic_regression                                   0.008641     0.073710
# xgb_classifier                                        0.129352     0.026673
# meta_fairness_sr                                      0.000000     0.083583
# meta_fairness_fdr                                     0.000000     0.083583
# NN_adversarial_debiasing                              0.000000     0.083583
# Basic_NN_no_adversarial_debiasing                     0.106247     0.049603
# reweighing_meta_fairness_sr                           0.000000     0.007136
# reweighing_meta_fairness_fdr                          0.000000     0.007136
# disparate_impact_meta_fairness_sr                     0.000000     0.083583
# disparate_impact_meta_fairness_fdr                    0.000000     0.083583
# reweighing_NN_adversarial_debiasing                   0.000000     0.007136
# reweighin_basic_NN_no_adversarial_debiasing           0.041955     0.004997
# disparate_impact_NN_adversarial_debiasing             0.000000     0.083583
# disparate_impact_basic_NN_no_adversarial_debiasing    0.150634     0.036160
# reweighin_logistic_regression                         0.085157     0.028168
# reweighin_xgb_classifier                              0.129352     0.058268
# disparate_impact_logistic_regression                  0.101639     0.054897
# disparate_impact_xgb_classifier                       0.074405     0.146825
# reweighin_logistic_regression_reject_option_spd       0.000000     0.000000
# reweighin_logistic_regression_reject_option_aod       0.000000     0.000000
# reweighin_logistic_regression_reject_option_eod       0.000000     0.000000
# reweighin_xgb_classifier_reject_option_spd            0.000000     0.000000
# reweighin_xgb_classifier_reject_option_aod            0.016129     0.072581
# reweighin_xgb_classifier_reject_option_eod            0.001472     0.102564
# disparate_impact_logistic_regression_reject_opt...    0.081989     0.003030
# disparate_impact_logistic_regression_reject_opt...    0.000000     0.000000
# disparate_impact_logistic_regression_reject_opt...    0.000000     0.000000
# disparate_impact_xgb_classifier_reject_option_spd     0.000000     0.000000
# disparate_impact_xgb_classifier_reject_option_aod     0.112647     0.166667
# disparate_impact_xgb_classifier_reject_option_eod     0.092966     0.030612
# reweighin_logistic_regression_platt_scaling           0.061444     0.055167
# reweighin_xgb_classifier_platt_scaling                0.134985     0.015007
# disparate_impact_logistic_regression_platt_scaling    0.013889     0.166667
# disparate_impact_xgb_classifier_platt_scaling         0.147177     0.037024
# reweighin_logistic_regression_equal_odds_weighted     0.085157     0.046601
# reweighin_logistic_regression_equal_odds_fnr          0.067300     0.053142
# reweighin_logistic_regression_equal_odds_fpr          0.085157     0.046601
# reweighin_xgb_classifier_equal_odds_weighted          0.134633     0.125235
# reweighin_xgb_classifier_equal_odds_fnr               0.143241     0.020515
# reweighin_xgb_classifier_equal_odds_fpr               0.133097     0.119883
# disparate_impact_logistic_regression_equal_odds...    0.005728     0.080776
# disparate_impact_logistic_regression_equal_odds...    0.015137     0.061844
# disparate_impact_logistic_regression_equal_odds...    0.005728     0.080776
# disparate_impact_xgb_classifier_equal_odds_weig...    0.178763     0.094118
# disparate_impact_xgb_classifier_equal_odds_fnr        0.055044     0.067938
# disparate_impact_xgb_classifier_equal_odds_fpr        0.069444     0.113345
# meta_fairness_sr_reject_option_spd                    0.000000     0.000000
# meta_fairness_sr_reject_option_aod                    0.112647     0.166667
# meta_fairness_sr_reject_option_eod                    0.092966     0.030612
# meta_fairness_fdr_reject_option_spd                   0.000000     0.000000
# meta_fairness_fdr_reject_option_aod                   0.112647     0.166667
# meta_fairness_fdr_reject_option_eod                   0.092966     0.030612
# NN_adversarial_debiasing_reject_option_spd            0.000000     0.000000
# NN_adversarial_debiasing_reject_option_aod            0.112647     0.166667
# NN_adversarial_debiasing_reject_option_eod            0.092966     0.030612
# Basic_NN_no_adversarial_debiasing_equal_odds_we...    0.106247     0.049603
# Basic_NN_no_adversarial_debiasing_equal_odds_fnr      0.106247     0.049603
# Basic_NN_no_adversarial_debiasing_equal_odds_fpr      0.106247     0.049603
#
#                                                          auc
# logistic_regression                                 0.590536
# xgb_classifier                                      0.695016
# meta_fairness_sr                                    0.444560
# meta_fairness_fdr                                   0.556087
# NN_adversarial_debiasing                            0.500000
# Basic_NN_no_adversarial_debiasing                   0.506204
# reweighing_meta_fairness_sr                         0.444560
# reweighing_meta_fairness_fdr                        0.556087
# disparate_impact_meta_fairness_sr                   0.451515
# disparate_impact_meta_fairness_fdr                  0.548532
# reweighing_NN_adversarial_debiasing                 0.500000
# reweighin_basic_NN_no_adversarial_debiasing         0.557300
# disparate_impact_NN_adversarial_debiasing           0.500000
# disparate_impact_basic_NN_no_adversarial_debiasing  0.544766
# reweighin_logistic_regression                       0.591923
# reweighin_xgb_classifier                            0.695016
# disparate_impact_logistic_regression                0.579354
# disparate_impact_xgb_classifier                     0.694947
# reweighin_logistic_regression_reject_option_spd     0.591923
# reweighin_logistic_regression_reject_option_aod     0.591923
# reweighin_logistic_regression_reject_option_eod     0.591923
# reweighin_xgb_classifier_reject_option_spd          0.695016
# reweighin_xgb_classifier_reject_option_aod          0.695016
# reweighin_xgb_classifier_reject_option_eod          0.695016
# disparate_impact_logistic_regression_reject_opt...  0.524110
# disparate_impact_logistic_regression_reject_opt...  0.524110
# disparate_impact_logistic_regression_reject_opt...  0.524110
# disparate_impact_xgb_classifier_reject_option_spd   0.695155
# disparate_impact_xgb_classifier_reject_option_aod   0.695155
# disparate_impact_xgb_classifier_reject_option_eod   0.695155
# reweighin_logistic_regression_platt_scaling         0.604330
# reweighin_xgb_classifier_platt_scaling              0.691527
# disparate_impact_logistic_regression_platt_scaling  0.513759
# disparate_impact_xgb_classifier_platt_scaling       0.689032
# reweighin_logistic_regression_equal_odds_weighted   0.591923
# reweighin_logistic_regression_equal_odds_fnr        0.591923
# reweighin_logistic_regression_equal_odds_fpr        0.591923
# reweighin_xgb_classifier_equal_odds_weighted        0.695016
# reweighin_xgb_classifier_equal_odds_fnr             0.695016
# reweighin_xgb_classifier_equal_odds_fpr             0.695016
# disparate_impact_logistic_regression_equal_odds...  0.524110
# disparate_impact_logistic_regression_equal_odds...  0.524110
# disparate_impact_logistic_regression_equal_odds...  0.524110
# disparate_impact_xgb_classifier_equal_odds_weig...  0.695155
# disparate_impact_xgb_classifier_equal_odds_fnr      0.695155
# disparate_impact_xgb_classifier_equal_odds_fpr      0.695155
# meta_fairness_sr_reject_option_spd                  0.695155
# meta_fairness_sr_reject_option_aod                  0.695155
# meta_fairness_sr_reject_option_eod                  0.695155
# meta_fairness_fdr_reject_option_spd                 0.695155
# meta_fairness_fdr_reject_option_aod                 0.695155
# meta_fairness_fdr_reject_option_eod                 0.695155
# NN_adversarial_debiasing_reject_option_spd          0.695155
# NN_adversarial_debiasing_reject_option_aod          0.695155
# NN_adversarial_debiasing_reject_option_eod          0.695155
# Basic_NN_no_adversarial_debiasing_equal_odds_we...  0.506204
# Basic_NN_no_adversarial_debiasing_equal_odds_fnr    0.506204
# Basic_NN_no_adversarial_debiasing_equal_odds_fpr    0.506204

# %% [markdown]
# ### Resultados en test

# %%
algorithm_performance_summary = pd.DataFrame(metrics_best_thresh_test).T
algorithm_performance_summary
# Out:
#                                                     best_threshold   bal_acc  \
# logistic_regression                                       0.111020  0.555075
# xgb_classifier                                            0.050408  0.658300
# meta_fairness_sr                                          0.010000  0.500000
# meta_fairness_fdr                                         0.010000  0.500000
# NN_adversarial_debiasing                                  0.010000  0.500000
# Basic_NN_no_adversarial_debiasing                         0.111020  0.533118
# reweighing_meta_fairness_sr                               0.010000  0.500000
# reweighing_meta_fairness_fdr                              0.010000  0.500000
# disparate_impact_meta_fairness_sr                         0.010000  0.500000
# disparate_impact_meta_fairness_fdr                        0.010000  0.500000
# reweighing_NN_adversarial_debiasing                       0.010000  0.500000
# reweighin_basic_NN_no_adversarial_debiasing               0.111020  0.527267
# disparate_impact_NN_adversarial_debiasing                 0.010000  0.500000
# disparate_impact_basic_NN_no_adversarial_debiasing        0.030204  0.550656
# reweighin_logistic_regression                             0.111020  0.540410
# reweighin_xgb_classifier                                  0.050408  0.651145
# disparate_impact_logistic_regression                      0.070612  0.570745
# disparate_impact_xgb_classifier                           0.050408  0.653198
# reweighin_logistic_regression_reject_option_spd           0.376263  0.507812
# reweighin_logistic_regression_reject_option_aod           0.376263  0.507812
# reweighin_logistic_regression_reject_option_eod           0.376263  0.507812
# reweighin_xgb_classifier_reject_option_spd                0.811818  0.500000
# reweighin_xgb_classifier_reject_option_aod                0.207980  0.563343
# reweighin_xgb_classifier_reject_option_eod                0.198081  0.571884
# disparate_impact_logistic_regression_reject_opt...        0.198081  0.492757
# disparate_impact_logistic_regression_reject_opt...        0.653434  0.507812
# disparate_impact_logistic_regression_reject_opt...        0.653434  0.507812
# disparate_impact_xgb_classifier_reject_option_spd         0.841515  0.500000
# disparate_impact_xgb_classifier_reject_option_aod         0.514848  0.505626
# disparate_impact_xgb_classifier_reject_option_eod         0.049596  0.638598
# reweighin_logistic_regression_platt_scaling               0.080516  0.550702
# reweighin_xgb_classifier_platt_scaling                    0.078495  0.631628
# disparate_impact_logistic_regression_platt_scaling        0.160797  0.510113
# disparate_impact_xgb_classifier_platt_scaling             0.075303  0.640830
# reweighin_logistic_regression_equal_odds_weighted         0.111020  0.551430
# reweighin_logistic_regression_equal_odds_fnr              0.111020  0.547057
# reweighin_logistic_regression_equal_odds_fpr              0.111020  0.551430
# reweighin_xgb_classifier_equal_odds_weighted              0.090816  0.535646
# reweighin_xgb_classifier_equal_odds_fnr                   0.050408  0.658300
# reweighin_xgb_classifier_equal_odds_fpr                   0.090816  0.540019
# disparate_impact_logistic_regression_equal_odds...        0.151429  0.528813
# disparate_impact_logistic_regression_equal_odds...        0.151429  0.495353
# disparate_impact_logistic_regression_equal_odds...        0.151429  0.528813
# disparate_impact_xgb_classifier_equal_odds_weig...        0.111020  0.538653
# disparate_impact_xgb_classifier_equal_odds_fnr            0.030204  0.643017
# disparate_impact_xgb_classifier_equal_odds_fpr            0.030204  0.544962
# meta_fairness_sr_reject_option_spd                        0.841515  0.500000
# meta_fairness_sr_reject_option_aod                        0.514848  0.505626
# meta_fairness_sr_reject_option_eod                        0.049596  0.638598
# meta_fairness_fdr_reject_option_spd                       0.841515  0.500000
# meta_fairness_fdr_reject_option_aod                       0.514848  0.505626
# meta_fairness_fdr_reject_option_eod                       0.049596  0.638598
# NN_adversarial_debiasing_reject_option_spd                0.841515  0.500000
# NN_adversarial_debiasing_reject_option_aod                0.514848  0.505626
# NN_adversarial_debiasing_reject_option_eod                0.049596  0.638598
# Basic_NN_no_adversarial_debiasing_equal_odds_we...        0.111020  0.533118
# Basic_NN_no_adversarial_debiasing_equal_odds_fnr          0.111020  0.533118
# Basic_NN_no_adversarial_debiasing_equal_odds_fpr          0.111020  0.533118
#
#                                                          acc  independence  \
# logistic_regression                                 0.626667      0.483117
# xgb_classifier                                      0.660000      0.334665
# meta_fairness_sr                                    0.085333      0.000000
# meta_fairness_fdr                                   0.085333      0.000000
# NN_adversarial_debiasing                            0.085333      0.000000
# Basic_NN_no_adversarial_debiasing                   0.534667      0.255544
# reweighing_meta_fairness_sr                         0.085145      0.000000
# reweighing_meta_fairness_fdr                        0.085145      0.000000
# disparate_impact_meta_fairness_sr                   0.085333      0.000000
# disparate_impact_meta_fairness_fdr                  0.085333      0.000000
# reweighing_NN_adversarial_debiasing                 0.085145      0.000000
# reweighin_basic_NN_no_adversarial_debiasing         0.458125      0.202807
# disparate_impact_NN_adversarial_debiasing           0.085333      0.000000
# disparate_impact_basic_NN_no_adversarial_debiasing  0.385333      0.149650
# reweighin_logistic_regression                       0.616793      0.462815
# reweighin_xgb_classifier                            0.657861      0.309789
# disparate_impact_logistic_regression                0.448000      0.191009
# disparate_impact_xgb_classifier                     0.650667      0.234965
# reweighin_logistic_regression_reject_option_spd     0.916000      0.028571
# reweighin_logistic_regression_reject_option_aod     0.916000      0.028571
# reweighin_logistic_regression_reject_option_eod     0.916000      0.028571
# reweighin_xgb_classifier_reject_option_spd          0.914667      0.000000
# reweighin_xgb_classifier_reject_option_aod          0.888000      0.210989
# reweighin_xgb_classifier_reject_option_eod          0.890667      0.240959
# disparate_impact_logistic_regression_reject_opt...  0.720000      0.236164
# disparate_impact_logistic_regression_reject_opt...  0.916000      0.028571
# disparate_impact_logistic_regression_reject_opt...  0.916000      0.028571
# disparate_impact_xgb_classifier_reject_option_spd   0.914667      0.000000
# disparate_impact_xgb_classifier_reject_option_aod   0.912000      0.024376
# disparate_impact_xgb_classifier_reject_option_eod   0.714667      0.381618
# reweighin_logistic_regression_platt_scaling         0.618667      0.654545
# reweighin_xgb_classifier_platt_scaling              0.676000      0.695105
# disparate_impact_logistic_regression_platt_scaling  0.881333      0.942857
# disparate_impact_xgb_classifier_platt_scaling       0.537333      0.516084
# reweighin_logistic_regression_equal_odds_weighted   0.620000      0.476124
# reweighin_logistic_regression_equal_odds_fnr        0.612000      0.647552
# reweighin_logistic_regression_equal_odds_fpr        0.620000      0.476124
# reweighin_xgb_classifier_equal_odds_weighted        0.837333      0.337662
# reweighin_xgb_classifier_equal_odds_fnr             0.660000      0.334665
# reweighin_xgb_classifier_equal_odds_fpr             0.845333      0.346054
# disparate_impact_logistic_regression_equal_odds...  0.669333      0.307692
# disparate_impact_logistic_regression_equal_odds...  0.750667      0.423776
# disparate_impact_logistic_regression_equal_odds...  0.669333      0.307692
# disparate_impact_xgb_classifier_equal_odds_weig...  0.894667      0.498901
# disparate_impact_xgb_classifier_equal_odds_fnr      0.541333      0.250549
# disparate_impact_xgb_classifier_equal_odds_fpr      0.245333      0.085115
# meta_fairness_sr_reject_option_spd                  0.914667      0.000000
# meta_fairness_sr_reject_option_aod                  0.912000      0.024376
# meta_fairness_sr_reject_option_eod                  0.714667      0.381618
# meta_fairness_fdr_reject_option_spd                 0.914667      0.000000
# meta_fairness_fdr_reject_option_aod                 0.912000      0.024376
# meta_fairness_fdr_reject_option_eod                 0.714667      0.381618
# NN_adversarial_debiasing_reject_option_spd          0.914667      0.000000
# NN_adversarial_debiasing_reject_option_aod          0.912000      0.024376
# NN_adversarial_debiasing_reject_option_eod          0.714667      0.381618
# Basic_NN_no_adversarial_debiasing_equal_odds_we...  0.534667      0.255544
# Basic_NN_no_adversarial_debiasing_equal_odds_fnr    0.534667      0.255544
# Basic_NN_no_adversarial_debiasing_equal_odds_fpr    0.534667      0.255544
#
#                                                     separation  sufficiency  \
# logistic_regression                                   0.057343     0.071199
# xgb_classifier                                        0.032884     0.060923
# meta_fairness_sr                                      0.000000     0.060340
# meta_fairness_fdr                                     0.000000     0.060340
# NN_adversarial_debiasing                              0.000000     0.060340
# Basic_NN_no_adversarial_debiasing                     0.022897     0.068537
# reweighing_meta_fairness_sr                           0.000000     0.008044
# reweighing_meta_fairness_fdr                          0.000000     0.008044
# disparate_impact_meta_fairness_sr                     0.000000     0.060340
# disparate_impact_meta_fairness_fdr                    0.000000     0.060340
# reweighing_NN_adversarial_debiasing                   0.000000     0.008044
# reweighin_basic_NN_no_adversarial_debiasing           0.110351     0.010713
# disparate_impact_NN_adversarial_debiasing             0.000000     0.060340
# disparate_impact_basic_NN_no_adversarial_debiasing    0.073906     0.086098
# reweighin_logistic_regression                         0.061154     0.007744
# reweighin_xgb_classifier                              0.032884     0.035304
# disparate_impact_logistic_regression                  0.070937     0.086390
# disparate_impact_xgb_classifier                       0.090506     0.096333
# reweighin_logistic_regression_reject_option_spd       0.100000     1.000000
# reweighin_logistic_regression_reject_option_aod       0.100000     1.000000
# reweighin_logistic_regression_reject_option_eod       0.100000     1.000000
# reweighin_xgb_classifier_reject_option_spd            0.000000     0.000000
# reweighin_xgb_classifier_reject_option_aod            0.025355     0.050505
# reweighin_xgb_classifier_reject_option_eod            0.124593     0.018750
# disparate_impact_logistic_regression_reject_opt...    0.102156     0.117880
# disparate_impact_logistic_regression_reject_opt...    0.100000     1.000000
# disparate_impact_logistic_regression_reject_opt...    0.100000     1.000000
# disparate_impact_xgb_classifier_reject_option_spd     0.000000     0.000000
# disparate_impact_xgb_classifier_reject_option_aod     0.023617     0.333333
# disparate_impact_xgb_classifier_reject_option_eod     0.073049     0.065107
# reweighin_logistic_regression_platt_scaling           0.042657     0.041643
# reweighin_xgb_classifier_platt_scaling                0.129418     0.003932
# disparate_impact_logistic_regression_platt_scaling    0.083333     0.121212
# disparate_impact_xgb_classifier_platt_scaling         0.142698     0.015690
# reweighin_logistic_regression_equal_odds_weighted     0.061154     0.073207
# reweighin_logistic_regression_equal_odds_fnr          0.038846     0.043651
# reweighin_logistic_regression_equal_odds_fpr          0.061154     0.073207
# reweighin_xgb_classifier_equal_odds_weighted          0.201552     0.158974
# reweighin_xgb_classifier_equal_odds_fnr               0.032884     0.060923
# reweighin_xgb_classifier_equal_odds_fpr               0.196979     0.148023
# disparate_impact_logistic_regression_equal_odds...    0.226370     0.151971
# disparate_impact_logistic_regression_equal_odds...    0.264713     0.182540
# disparate_impact_logistic_regression_equal_odds...    0.226370     0.151971
# disparate_impact_xgb_classifier_equal_odds_weig...    0.273244     0.095960
# disparate_impact_xgb_classifier_equal_odds_fnr        0.011875     0.067308
# disparate_impact_xgb_classifier_equal_odds_fpr        0.111671     0.102781
# meta_fairness_sr_reject_option_spd                    0.000000     0.000000
# meta_fairness_sr_reject_option_aod                    0.023617     0.333333
# meta_fairness_sr_reject_option_eod                    0.073049     0.065107
# meta_fairness_fdr_reject_option_spd                   0.000000     0.000000
# meta_fairness_fdr_reject_option_aod                   0.023617     0.333333
# meta_fairness_fdr_reject_option_eod                   0.073049     0.065107
# NN_adversarial_debiasing_reject_option_spd            0.000000     0.000000
# NN_adversarial_debiasing_reject_option_aod            0.023617     0.333333
# NN_adversarial_debiasing_reject_option_eod            0.073049     0.065107
# Basic_NN_no_adversarial_debiasing_equal_odds_we...    0.022897     0.068537
# Basic_NN_no_adversarial_debiasing_equal_odds_fnr      0.022897     0.068537
# Basic_NN_no_adversarial_debiasing_equal_odds_fpr      0.022897     0.068537
#
#                                                          auc
# logistic_regression                                 0.601426
# xgb_classifier                                      0.702419
# meta_fairness_sr                                    0.471870
# meta_fairness_fdr                                   0.528631
# NN_adversarial_debiasing                            0.500000
# Basic_NN_no_adversarial_debiasing                   0.555006
# reweighing_meta_fairness_sr                         0.471870
# reweighing_meta_fairness_fdr                        0.528631
# disparate_impact_meta_fairness_sr                   0.466837
# disparate_impact_meta_fairness_fdr                  0.533254
# reweighing_NN_adversarial_debiasing                 0.500000
# reweighin_basic_NN_no_adversarial_debiasing         0.581359
# disparate_impact_NN_adversarial_debiasing           0.500000
# disparate_impact_basic_NN_no_adversarial_debiasing  0.543026
# reweighin_logistic_regression                       0.599034
# reweighin_xgb_classifier                            0.702419
# disparate_impact_logistic_regression                0.617689
# disparate_impact_xgb_classifier                     0.698888
# reweighin_logistic_regression_reject_option_spd     0.599034
# reweighin_logistic_regression_reject_option_aod     0.599034
# reweighin_logistic_regression_reject_option_eod     0.599034
# reweighin_xgb_classifier_reject_option_spd          0.702419
# reweighin_xgb_classifier_reject_option_aod          0.702419
# reweighin_xgb_classifier_reject_option_eod          0.702419
# disparate_impact_logistic_regression_reject_opt...  0.543424
# disparate_impact_logistic_regression_reject_opt...  0.543424
# disparate_impact_logistic_regression_reject_opt...  0.543424
# disparate_impact_xgb_classifier_reject_option_spd   0.679141
# disparate_impact_xgb_classifier_reject_option_aod   0.679141
# disparate_impact_xgb_classifier_reject_option_eod   0.679141
# reweighin_logistic_regression_platt_scaling         0.593203
# reweighin_xgb_classifier_platt_scaling              0.688502
# disparate_impact_logistic_regression_platt_scaling  0.487074
# disparate_impact_xgb_classifier_platt_scaling       0.666522
# reweighin_logistic_regression_equal_odds_weighted   0.599034
# reweighin_logistic_regression_equal_odds_fnr        0.599034
# reweighin_logistic_regression_equal_odds_fpr        0.599034
# reweighin_xgb_classifier_equal_odds_weighted        0.702419
# reweighin_xgb_classifier_equal_odds_fnr             0.702419
# reweighin_xgb_classifier_equal_odds_fpr             0.702419
# disparate_impact_logistic_regression_equal_odds...  0.543424
# disparate_impact_logistic_regression_equal_odds...  0.543424
# disparate_impact_logistic_regression_equal_odds...  0.543424
# disparate_impact_xgb_classifier_equal_odds_weig...  0.679141
# disparate_impact_xgb_classifier_equal_odds_fnr      0.679141
# disparate_impact_xgb_classifier_equal_odds_fpr      0.679141
# meta_fairness_sr_reject_option_spd                  0.679141
# meta_fairness_sr_reject_option_aod                  0.679141
# meta_fairness_sr_reject_option_eod                  0.679141
# meta_fairness_fdr_reject_option_spd                 0.679141
# meta_fairness_fdr_reject_option_aod                 0.679141
# meta_fairness_fdr_reject_option_eod                 0.679141
# NN_adversarial_debiasing_reject_option_spd          0.679141
# NN_adversarial_debiasing_reject_option_aod          0.679141
# NN_adversarial_debiasing_reject_option_eod          0.679141
# Basic_NN_no_adversarial_debiasing_equal_odds_we...  0.555006
# Basic_NN_no_adversarial_debiasing_equal_odds_fnr    0.555006
# Basic_NN_no_adversarial_debiasing_equal_odds_fpr    0.555006

# %%
algorithm_performance_summary.to_csv('PERFORMANCE_HOMECREDIT_MULTALG', index = True, sep=',', encoding='utf-8')
