# %% [markdown]
# <img src="img/ibidat.png" alt="drawing" width="600"/>

# %% [markdown]
# # Introducción
#
# En este cuaderno vamos a probar todas las parejas posibles de métodos de fairness que afecten a distintas partes del proceso de la construcción del algoritmo de machine learning usando dos variables sensibles. Vamos a hacer un estudio de simulación.

# %% [markdown]
# # Carga de librerías

# %%
# Con esta celda, podemos hacer cambios en cualquier script/libreria y verlo reflejado en las funciones del notebook.
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
## CARGAMOS LIBRERIAS
# Obs: La primera vez puede tardar en cargar porque AIF360 pre-compila algunas cosas de tensorflow
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Cargamos librerías de sklearn
# vanilla LR
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline

# Cargamos xgboost
from xgboost import XGBClassifier

# Cargamos algoritmos de fairness
# Pre-procesado
from aif360.algorithms.preprocessing import Reweighing
from aif360.algorithms.preprocessing import DisparateImpactRemover
# In-procesado
from aif360.algorithms.inprocessing import PrejudiceRemover
from aif360.algorithms.inprocessing import MetaFairClassifier
from aif360.algorithms.inprocessing.adversarial_debiasing import AdversarialDebiasing
# Post-procesado
from aif360.algorithms.postprocessing import RejectOptionClassification # when scores are given
from aif360.algorithms.postprocessing import CalibratedEqOddsPostprocessing # when scores (R) are given
from aif360.algorithms.postprocessing import EqOddsPostprocessing # when labels (Y^hat) are given
from aif360.datasets import GermanDataset

#Simulacion
from aif360.datasets import BinaryLabelDataset

# TF para adversarial debiasing
import tensorflow.compat.v1 as tf
tf.disable_eager_execution()

from IPython.display import Markdown, display

# Librería local con funciones de ayuda extra
import utils

seed = 12345 # fijamos la semilla de números aleatorios para reproducir exactamante el notebook
# Out:
# WARNING:root:
# `load_boston` has been removed from scikit-learn since version 1.2.
#
# The Boston housing prices dataset has an ethical problem: as
# investigated in [1], the authors of this dataset engineered a
# non-invertible variable "B" assuming that racial self-segregation had a
# positive impact on house prices [2]. Furthermore the goal of the
# research that led to the creation of this dataset was to study the
# impact of air quality but it did not give adequate demonstration of the
# validity of this assumption.
#
# The scikit-learn maintainers therefore strongly discourage the use of
# this dataset unless the purpose of the code is to study and educate
# about ethical issues in data science and machine learning.
#
# In this special case, you can fetch the dataset from the original
# source::
#
#     import pandas as pd
#     import numpy as np
#
#     data_url = "http://lib.stat.cmu.edu/datasets/boston"
#     raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#     data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#     target = raw_df.values[1::2, 2]
#
# Alternative datasets include the California housing dataset and the
# Ames housing dataset. You can load the datasets as follows::
#
#     from sklearn.datasets import fetch_california_housing
#     housing = fetch_california_housing()
#
# for the California housing dataset and::
#
#     from sklearn.datasets import fetch_openml
#     housing = fetch_openml(name="house_prices", as_frame=True)
#
# for the Ames housing dataset.
#
# [1] M Carlisle.
# "Racist data destruction?"
# <https://medium.com/@docintangible/racist-data-destruction-113e3eff54a8>
#
# [2] Harrison Jr, David, and Daniel L. Rubinfeld.
# "Hedonic housing prices and the demand for clean air."
# Journal of environmental economics and management 5.1 (1978): 81-102.
# <https://www.researchgate.net/publication/4974606_Hedonic_housing_prices_and_the_demand_for_clean_air>
# : LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# 2024-06-19 10:14:40.787563: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-19 10:14:40.846043: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-19 10:14:41.801173: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Selección de dataset.
#
# El siguiente bloque permite seleccionar el conjunto de datos sobre el que trabajar. Debe recordarse que el conjunto de `homecredit` es mucho mayor por lo que tardará más tiempo en ejecutarse.

# %%
def logit(x):
    return np.log(x/(1-x))

def inv_logit(x):
    return np.exp(x)/(1+np.exp(x))

def simulated_dataset(n_obs, n_var, n_sens, mean_vec, cov, beta, gamma):
    
    p = n_var + n_sens
    coef = np.concatenate((gamma, beta))
        
    X = np.random.multivariate_normal(mean_vec, cov, size = n_obs)
    probs_var = inv_logit(X)
    bin = np.random.binomial(1, probs_var)
    
    probs_Y = inv_logit(coef.dot(X.T))
    Y = np.random.binomial(1, probs_Y)
    
    names = ['0' for i in range(p+1)]
    sens = ['0' for i in range(n_sens)]
    var = 1
    
    names[0] = 'response'
    
    for i in range(1,p+1):
        if i-1 < n_sens:
            sens[i-1] = 'sens ' + str(i)
            names[i] = 'sens ' + str(i)
        if i-1 >= n_sens:
            names[i] = 'var ' + str(var)
            var += 1
    
    names = np.array(names)
    sens = np.array(sens)
    response = np.array(['response'])
    
    Y = Y.reshape((n_obs,1))
    
    bin = np.concatenate((Y, bin), axis = 1)
    
    data_pd = pd.DataFrame(bin, columns = names)
    data = BinaryLabelDataset(df = data_pd, favorable_label = 1, unfavorable_label = 0, label_names = response, protected_attribute_names = sens)
    return data

# %%
n_obs = 1000
n_var = 30
n_sens = 2
mean_vec = np.zeros(n_var+n_sens)
cov = np.identity(n_var+n_sens)
beta = np.zeros(n_var)
gamma = np.ones(n_sens)

dataset1 = simulated_dataset(n_obs, n_var, n_sens, mean_vec, cov, beta, gamma)

#dataset.favorable_label = 1
#dataset.unfavorable_label = 0

new_data = dataset1.convert_to_dataframe()[0]

sens1 = new_data.loc[:,'sens 1']
sens2 = new_data.loc[:,'sens 2']
new_sens = sens1.copy()
new_sens[sens2 == 1] = 1

new_data = new_data.drop(['sens 1', 'sens 2'], axis = 1)
new_data['sens 1'] = new_sens

names = np.array(new_data.columns)
sens = np.array(['sens 1'])
response = np.array(['response'])

dataset = BinaryLabelDataset(df = new_data,
                             favorable_label = 1,
                             unfavorable_label = 0,
                             label_names = response,
                             protected_attribute_names = sens)

# Separamos el conjunto de datos en train, validate, test
data_train, vt = dataset.split([0.7], shuffle=True, seed=seed)
data_val, data_test = vt.split([0.5], shuffle=True, seed=seed)

data_train2, vt2 = dataset1.split([0.7], shuffle=True, seed=seed)
data_val2, data_test2 = vt2.split([0.5], shuffle=True, seed=seed)

# Obtenemos los indicadores del grupo sensible
sensitive_attribute = dataset.protected_attribute_names[0]
privileged_groups, unprivileged_groups = utils.get_privileged_groups(dataset)
    
print(f'Dimensiones del conjunto de datos: {dataset.features.shape}')
print("Grupos privilegiados:", privileged_groups)
print("Grupos no privilegiados:", unprivileged_groups)
print("Label del grupo favorable:", dataset.favorable_label)
print("Label del grupo desfavorable:", dataset.unfavorable_label)
# Out:
# Dimensiones del conjunto de datos: (1000, 31)
# Grupos privilegiados: [{'sens 1': 1.0}]
# Grupos no privilegiados: [{'sens 1': 0.0}]
# Label del grupo favorable: 1.0
# Label del grupo desfavorable: 0.0

# %% [markdown]
# ## Modelos
# Para esta sección, creamos un diccionario de métricas y modelos para poder acceder los resultados de todos los modelos.

# %%
# Inicializamos diccionarios
models = dict()

# Rango de umbrales para evaluar el score de los modelos
thresh_sweep = np.linspace(0.01, 1.0, 50)

metrics_sweep = dict()

# Store results from validation and test
metrics_best_thresh_validate = dict()
metrics_best_thresh_test = dict()

# %% [markdown]
# ### Regresión Logística

# %%
# %%time 

# Nombramos al modelo
model_name = 'logistic_regression'
fairness_method = ''

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Parámetros del modelo
fit_params = {'logisticregression__sample_weight': data_train_copy.instance_weights}

# Asignamos el modelo al diccionario
models[model_name+fairness_method] = make_pipeline(
            #StandardScaler(),
            LogisticRegression(solver='liblinear', random_state=seed))

# Entrenamos el modelo
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy.features, data_train_copy.labels.ravel(), **fit_params)
# Out:
# CPU times: user 12 ms, sys: 7 µs, total: 12 ms
# Wall time: 11.2 ms

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_threshold_sweep_mult(
    dataset=data_val_copy,
    dataset2=data_val2_copy,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_mult(
    dataset=data_test_copy, 
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.4141
# AUC: 0.5367
# Balanced accuracy: 0.5650
# Accuracy: 0.5600
# Independence ( |ΔP(Y_pred = 1)| ): 0.2082
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1498
# Sufficiency ( |ΔPPV| ) : 0.2462
# CPU times: user 170 ms, sys: 10.7 ms, total: 181 ms
# Wall time: 163 ms

# %%
display(Markdown("**Test set results**"))
utils.print_metrics(metrics_best_thresh_test[model_name+fairness_method])
# Out:
# **Test set results**
# Threshold corresponding to *best balanced accuracy*: 0.4141
# AUC: 0.5376
# Balanced accuracy: 0.5267
# Accuracy: 0.5267
# Independence ( |ΔP(Y_pred = 1)| ): 0.2025
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0279
# Sufficiency ( |ΔPPV| ) : 0.1100

# %% [markdown]
# ### XGBoost

# %%
# %%time 

# Nombramos al modelo
model_name = 'xgb_classifier'
fairness_method = ''

# Parámetros del modelo
fit_params = {'eval_metric': 'error', 'eta':0.1, 'max_depth':6, 'subsample':0.8}

# Asignamos el modelo al diccionario
models[model_name+fairness_method] = XGBClassifier(**fit_params)

# Entrenamos el modelo
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy.features, data_train_copy.labels.ravel())
# Out:
# CPU times: user 33.4 s, sys: 276 ms, total: 33.7 s
# Wall time: 591 ms

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_threshold_sweep_mult(
    dataset=data_val_copy,
    dataset2=data_val2_copy,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_mult(
    dataset=data_test_copy, 
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.0908
# AUC: 0.4613
# Balanced accuracy: 0.5519
# Accuracy: 0.5400
# Independence ( |ΔP(Y_pred = 1)| ): 0.0466
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0301
# Sufficiency ( |ΔPPV| ) : 0.1261
# CPU times: user 2.3 s, sys: 0 ns, total: 2.3 s
# Wall time: 161 ms

# %%
display(Markdown("**Test set results**"))
utils.print_metrics(metrics_best_thresh_test[model_name+fairness_method])
# Out:
# **Test set results**
# Threshold corresponding to *best balanced accuracy*: 0.0908
# AUC: 0.4868
# Balanced accuracy: 0.5000
# Accuracy: 0.5000
# Independence ( |ΔP(Y_pred = 1)| ): 0.0548
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0053
# Sufficiency ( |ΔPPV| ) : 0.0962

# %% [markdown]
# ## Técnicas de preprocesado

# %% [markdown]
# ### Reponderación

# %%
# %%time 

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos el pre-procesado al conjunto train
# Inicializamos la clase de pre-procesado 
PreProcessor = Reweighing(
    unprivileged_groups=unprivileged_groups,
    privileged_groups=privileged_groups
)
# Pre-procesamos (modifica los datos)
PreProcessor.fit(data_train_copy)
data_train_REW = PreProcessor.transform(data_train_copy)
data_val_REW = PreProcessor.transform(data_val_copy)
data_test_REW = PreProcessor.transform(data_test_copy)
# Out:
# CPU times: user 12.8 ms, sys: 130 µs, total: 12.9 ms
# Wall time: 11.8 ms

# %% [markdown]
# De aquí en adelante, se aplica el modelo de preferencia de manera estándar

# %% [markdown]
# ### Eliminador de impacto dispar

# %%
# %%time 

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Parámetros del modelo
nivel_reparacion = 0.5 # un valor 0 inidica ausencia de reparación (datos se mantienen igual) 
                       # un valor 1 indica reparación completa (se puede perder nivel predictivo).
                       # Se puede establecer cualquier valor entre 0 y 1.

# Hacemos el pre-procesado al conjunto train
# Inicializamos la clase de pre-procesado 
PreProcessor = DisparateImpactRemover(
    repair_level=nivel_reparacion,
    sensitive_attribute=sensitive_attribute
)
# Pre-procesamos (modifica los datos)
PreProcessor.fit(data_train_copy)
data_train_DIR = PreProcessor.fit_transform(data_train_copy)
data_val_DIR = PreProcessor.fit_transform(data_val_copy)
data_test_DIR = PreProcessor.fit_transform(data_test_copy)
# Out:
# CPU times: user 149 ms, sys: 20.1 ms, total: 169 ms
# Wall time: 168 ms

# %% [markdown]
# ## Entrenamiento de técnicas de inprocesado

# %% [markdown]
# Entrenamos ahora los algoritmos de inprocesado para aplicarlos posteriormente cuando hagan falta.

# %% [markdown]
# ### Eliminador de prejuicios por regularización

# %%
# %%time 
# Nombramos al modelo
model_name = 'prejudice_remover'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Parámetros del modelo
η = 50.0 # hyper-parameter de regularización

# Inicializamos el modelo y lo asignamos al diccionario
models[model_name] = PrejudiceRemover(sensitive_attr=sensitive_attribute, eta=η)

# Entrenamos el modelo
models[model_name] = models[model_name].fit(data_train_copy)

models[model_name].scores_train = models[model_name].predict(data_train_copy).scores
models[model_name].scores_val = models[model_name].predict(data_val_copy).scores
models[model_name].scores_test = models[model_name].predict(data_test_copy).scores
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File <timed exec>:15
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/prejudice_remover.py:160, in PrejudiceRemover.fit(self, dataset)
#     156 train_pr = os.path.join(k_path, 'kamfadm-2012ecmlpkdd', 'train_pr.py')
#     157 # changed paths in the calls below to (a) specify path of train_pr,
#     158 # predict_lr RELATIVE to this file, and (b) compute & use absolute path
#     159 #  and (c) replace python3 with python
# --> 160 subprocess.call(['python', train_pr,
#     161                  '-e', str(self.eta),
#     162                  '-i', train_name,
#     163                  '-o', model_name,
#     164                  '--quiet'])
#     165 os.unlink(train_name)
#     167 self.model_name = model_name
#
# File ~/miniconda3/envs/aif360/lib/python3.9/subprocess.py:349, in call(timeout, *popenargs, **kwargs)
#     341 def call(*popenargs, timeout=None, **kwargs):
#     342     """Run command with arguments.  Wait for command to complete or
#     343     timeout, then return the returncode attribute.
#     344
#    (...)
#     347     retcode = call(["ls", "-l"])
#     348     """
# --> 349     with Popen(*popenargs, **kwargs) as p:
#     350         try:
#     351             return p.wait(timeout=timeout)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/subprocess.py:951, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     947         if self.text_mode:
#     948             self.stderr = io.TextIOWrapper(self.stderr,
#     949                     encoding=encoding, errors=errors)
# --> 951     self._execute_child(args, executable, preexec_fn, close_fds,
#     952                         pass_fds, cwd, env,
#     953                         startupinfo, creationflags, shell,
#     954                         p2cread, p2cwrite,
#     955                         c2pread, c2pwrite,
#     956                         errread, errwrite,
#     957                         restore_signals,
#     958                         gid, gids, uid, umask,
#     959                         start_new_session)
#     960 except:
#     961     # Cleanup if the child failed starting.
#     962     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~/miniconda3/envs/aif360/lib/python3.9/subprocess.py:1837, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1835     if errno_num != 0:
#    1836         err_msg = os.strerror(errno_num)
# -> 1837     raise child_exception_type(errno_num, err_msg, err_filename)
#    1838 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'python'

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name] = utils.metrics_threshold_sweep_mult(
    dataset=data_val_copy,
    dataset2=data_val2_copy,
    model=models[model_name],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name] = utils.describe_metrics(metrics_sweep[model_name])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name] = utils.compute_metrics_mult(
    dataset=data_test_copy, 
    dataset2=data_test2_copy,
    model=models[model_name], 
    threshold=metrics_best_thresh_validate[model_name]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name])

# Graficamos el comportamiento del modelo para el rango de umbrales 
f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name])
a.set_title(model_name)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/DEFINITIVO/utils.py:583, in metrics_threshold_sweep_mult(dataset, dataset2, model, thresh_arr)
#     581 try:
#     582     # sklearn classifier
# --> 583     y_val_pred_prob = model.predict_proba(dataset.features)
#     584     pos_ind = np.where(model.classes_ == dataset.favorable_label)[0][0]
#
# AttributeError: 'PrejudiceRemover' object has no attribute 'predict_proba'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:587, in metrics_threshold_sweep_mult(dataset, dataset2, model, thresh_arr)
#     584     pos_ind = np.where(model.classes_ == dataset.favorable_label)[0][0]
#     585 except AttributeError:
#     586     # aif360 inprocessing algorithm
# --> 587     y_val_pred_prob = model.predict(dataset).scores
#     588     pos_ind = 0
#     590 # Remove nans and turn them into score of random prediction (R=0.5)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/prejudice_remover.py:204, in PrejudiceRemover.predict(self, dataset)
#     198 predict_lr = os.path.join(k_path, 'kamfadm-2012ecmlpkdd', 'predict_lr.py')
#     199 # changed paths in the calls below to (a) specify path of train_pr,
#     200 # predict_lr RELATIVE to this file, and (b) compute & use absolute path,
#     201 # and (c) replace python3 with python
#     202 subprocess.call(['python', predict_lr,
#     203                  '-i', test_name,
# --> 204                  '-m', self.model_name,
#     205                  '-o', output_name,
#     206                  '--quiet'])
#     207 os.unlink(test_name)
#     208 m = np.loadtxt(output_name)
#
# AttributeError: 'PrejudiceRemover' object has no attribute 'model_name'

# %% [markdown]
# ### Algoritmo de metafairness

# %%
# %%time 
# Nombramos al modelo
model_name = 'meta_fairness'

# Parámetros del modelo
# hyper-parameter de regularización
τ = 0.8
# métricas fairness a optimizar
quality_constraints = ['sr', 'fdr'] # sr: statistical rate, fdr: false discovery rate

# Optimizamos un modelo nuevo por cada métrica
for quality in quality_constraints:
    
    # Hacemos una copia de los datasets
    data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
    data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)
    
    # nombramos al modelo con su métrica específica
    model_name_quality = '{}_{}'.format(model_name, quality)
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_quality] = MetaFairClassifier(tau=τ, sensitive_attr=sensitive_attribute, type=quality, seed=seed)

    # Entrenamos el modelo
    models[model_name_quality] = models[ model_name_quality ].fit( data_train_copy )
    models[model_name_quality].scores_train = models[model_name_quality].predict(data_train_copy).scores
    models[model_name_quality].scores_val = models[model_name_quality].predict(data_val_copy).scores
    models[model_name_quality].scores_test = models[model_name_quality].predict(data_test_copy).scores
# Out:
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/StatisticalRate.py:36: RuntimeWarning: invalid value encountered in divide
#   prob_y_1 = (prob_1_1 + prob_1_0) / total
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/StatisticalRate.py:37: RuntimeWarning: invalid value encountered in divide
#   prob_z_0 = (prob_m1_0 + prob_1_0) / total
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/StatisticalRate.py:38: RuntimeWarning: invalid value encountered in divide
#   prob_z_1 = (prob_m1_1 + prob_1_1) / total
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:24
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/meta_fair_classifier.py:66, in MetaFairClassifier.fit(self, dataset)
#      59 y_train = np.where(dataset.labels.flatten() == dataset.favorable_label,
#      60                    1, -1)
#      61 x_control_train = np.where(
#      62         np.isin(dataset.protected_attributes[:, sens_idx],
#      63                 dataset.privileged_protected_attributes[sens_idx]),
#      64         1, 0)
# ---> 66 self.model = self.obj.getModel(self.tau, x_train, y_train,
#      67     x_control_train, self.seed)
#      69 return self
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/General.py:99, in General.getModel(self, tau, X, y, sens, random_state)
#      96 samples = dist_x.rvs(size=20)  # TODO: why 20?
#      97 params = self.gradientDescent(dist, a, b, samples, z_1)
# ---> 99 t = self.getValueForX(dist, a, b, params, z_1, X)
#     100 y_pred = np.where(t > 0, 1, -1)
#     102 acc = accuracy_score(y, y_pred)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/StatisticalRate.py:23, in StatisticalRate.getValueForX(self, dist, a, b, params, z_prior, x, return_cs)
#      22 def getValueForX(self, dist, a, b, params, z_prior, x, return_cs=False):
# ---> 23     l_1, l_2 = params
#      24     z_0, z_1 = 1-z_prior, z_prior
#      26     pos = np.ones(len(x))
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
# %%time 

for quality in quality_constraints:
    
    name_suffix = '_{}'.format(quality)
    print(f'Results for {model_name+name_suffix}')

    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name+name_suffix] = utils.metrics_threshold_sweep_mult(
        dataset=data_val_copy,
        dataset2=data_val2_copy,
        model=models[model_name+name_suffix],
        thresh_arr=thresh_sweep
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name+name_suffix] = utils.describe_metrics(metrics_sweep[model_name+name_suffix])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name+name_suffix] = utils.compute_metrics_mult(
        dataset=data_test_copy, 
        dataset2=data_test2_copy,
        model=models[model_name+name_suffix], 
        threshold=metrics_best_thresh_validate[model_name+name_suffix]['best_threshold'])

    utils.print_metrics(metrics_best_thresh_validate[model_name+name_suffix])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name+name_suffix])
    # plt.title(model_name+name_suffix)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+name_suffix])
    a.set_title(model_name+name_suffix)
    f
# Out:
# Results for meta_fairness_sr
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/DEFINITIVO/utils.py:583, in metrics_threshold_sweep_mult(dataset, dataset2, model, thresh_arr)
#     581 try:
#     582     # sklearn classifier
# --> 583     y_val_pred_prob = model.predict_proba(dataset.features)
#     584     pos_ind = np.where(model.classes_ == dataset.favorable_label)[0][0]
#
# AttributeError: 'MetaFairClassifier' object has no attribute 'predict_proba'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:7
#
# File ~/DEFINITIVO/utils.py:587, in metrics_threshold_sweep_mult(dataset, dataset2, model, thresh_arr)
#     584     pos_ind = np.where(model.classes_ == dataset.favorable_label)[0][0]
#     585 except AttributeError:
#     586     # aif360 inprocessing algorithm
# --> 587     y_val_pred_prob = model.predict(dataset).scores
#     588     pos_ind = 0
#     590 # Remove nans and turn them into score of random prediction (R=0.5)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/meta_fair_classifier.py:82, in MetaFairClassifier.predict(self, dataset)
#      71 def predict(self, dataset):
#      72     """Obtain the predictions for the provided dataset using the learned
#      73     classifier model.
#      74
#    (...)
#      80         BinaryLabelDataset: Transformed dataset.
#      81     """
# ---> 82     t = self.model(dataset.features)
#      84     pred_dataset = dataset.copy()
#      85     pred_dataset.labels = (t > 0).astype(int).reshape((-1, 1))
#
# AttributeError: 'MetaFairClassifier' object has no attribute 'model'

# %% [markdown]
# ### Eliminación de prejuicios adversarios

# %%
# %%time

# Nombramos al modelo
model_name = 'NN_adversarial_debiasing'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

sess = tf.Session()

models[model_name] = AdversarialDebiasing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    scope_name = 'debiased_classifier',
    debias=True,
    sess=sess,
    num_epochs=80)

models[model_name].fit(data_train_copy)

models[model_name].scores_train = models[model_name].predict(data_train_copy).scores
models[model_name].scores_val = models[model_name].predict(data_val_copy).scores
models[model_name].scores_test = models[model_name].predict(data_test_copy).scores
# Out:
# 2024-06-19 10:14:46.106079: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# WARNING:tensorflow:From /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1260: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# 2024-06-19 10:14:46.354616: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:388] MLIR V1 optimization pass is not enabled
# epoch 0; iter: 0; batch classifier loss: 0.749668; batch adversarial loss: 0.640720
# epoch 1; iter: 0; batch classifier loss: 0.720532; batch adversarial loss: 0.619733
# epoch 2; iter: 0; batch classifier loss: 0.682275; batch adversarial loss: 0.631128
# epoch 3; iter: 0; batch classifier loss: 0.736333; batch adversarial loss: 0.622782
# epoch 4; iter: 0; batch classifier loss: 0.686564; batch adversarial loss: 0.628857
# epoch 5; iter: 0; batch classifier loss: 0.705573; batch adversarial loss: 0.633000
# epoch 6; iter: 0; batch classifier loss: 0.698191; batch adversarial loss: 0.632932
# epoch 7; iter: 0; batch classifier loss: 0.666563; batch adversarial loss: 0.654302
# epoch 8; iter: 0; batch classifier loss: 0.703034; batch adversarial loss: 0.662812
# epoch 9; iter: 0; batch classifier loss: 0.708887; batch adversarial loss: 0.669348
# epoch 10; iter: 0; batch classifier loss: 0.669129; batch adversarial loss: 0.652118
# epoch 112; iter: 0; batch classifier loss: 0.336606
# epoch 113; iter: 0; batch classifier loss: 0.328833
# epoch 114; iter: 0; batch classifier loss: 0.317229
# epoch 115; iter: 0; batch classifier loss: 0.341523
# epoch 116; iter: 0; batch classifier loss: 0.348926
# epoch 117; iter: 0; batch classifier loss: 0.329056
# epoch 118; iter: 0; batch classifier loss: 0.308845
# epoch 119; iter: 0; batch classifier loss: 0.302540
# epoch 120; iter: 0; batch classifier loss: 0.310816
# epoch 121; iter: 0; batch classifier loss: 0.319609
# epoch 122; iter: 0; batch classifier loss: 0.295094
# epoch 123; iter: 0; batch classifier loss: 0.327602
# epoch 124; iter: 0; batch classifier loss: 0.324973
# CPU times: user 5.45 s, sys: 1.91 s, total: 7.37 s
# Wall time: 2.52 s

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name] = utils.metrics_threshold_sweep_mult(
    dataset=data_val_copy,
    dataset2=data_val2_copy,
    model=models[model_name],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name] = utils.describe_metrics(metrics_sweep[model_name])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name] = utils.compute_metrics_mult(
    dataset=data_test_copy, 
    dataset2=data_test2_copy,
    model=models[model_name], 
    threshold=metrics_best_thresh_validate[model_name]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name])

# Graficamos el comportamiento del modelo para el rango de umbrales 
f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name])
a.set_title(model_name)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.2322
# AUC: 0.5254
# Balanced accuracy: 0.5747
# Accuracy: 0.5667
# Independence ( |ΔP(Y_pred = 1)| ): 0.2089
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0694
# Sufficiency ( |ΔPPV| ) : 0.0879
# CPU times: user 167 ms, sys: 18.7 ms, total: 185 ms
# Wall time: 166 ms

# %% [markdown]
# ## Preprocesado + Inprocesado

# %% [markdown]
# ### Reponderación + Eliminador de prejuicios

# %%
# Nombre del modelo
model_name = 'reweighting_prejudice_remover'

# Hacemos una copia de los datasets (usando uno de lo métodos de pre-procesado vistos anteriormente)
data_train_copy, data_val_copy, data_test_copy = data_train_REW.copy(deepcopy=True), data_val_REW.copy(deepcopy=True), data_test_REW.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Parámetros del modelo
η = 50.0 # hyper-parameter de regularización

# Inicializamos el modelo y lo asignamos al diccionario
models[model_name] = PrejudiceRemover(sensitive_attr=sensitive_attribute, eta=η)

# Entrenamos el modelo
models[model_name] = models[model_name].fit(data_train_copy)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 15
#      12 models[model_name] = PrejudiceRemover(sensitive_attr=sensitive_attribute, eta=η)
#      14 # Entrenamos el modelo
# ---> 15 models[model_name] = models[model_name].fit(data_train_copy)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/prejudice_remover.py:160, in PrejudiceRemover.fit(self, dataset)
#     156 train_pr = os.path.join(k_path, 'kamfadm-2012ecmlpkdd', 'train_pr.py')
#     157 # changed paths in the calls below to (a) specify path of train_pr,
#     158 # predict_lr RELATIVE to this file, and (b) compute & use absolute path
#     159 #  and (c) replace python3 with python
# --> 160 subprocess.call(['python', train_pr,
#     161                  '-e', str(self.eta),
#     162                  '-i', train_name,
#     163                  '-o', model_name,
#     164                  '--quiet'])
#     165 os.unlink(train_name)
#     167 self.model_name = model_name
#
# File ~/miniconda3/envs/aif360/lib/python3.9/subprocess.py:349, in call(timeout, *popenargs, **kwargs)
#     341 def call(*popenargs, timeout=None, **kwargs):
#     342     """Run command with arguments.  Wait for command to complete or
#     343     timeout, then return the returncode attribute.
#     344
#    (...)
#     347     retcode = call(["ls", "-l"])
#     348     """
# --> 349     with Popen(*popenargs, **kwargs) as p:
#     350         try:
#     351             return p.wait(timeout=timeout)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/subprocess.py:951, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     947         if self.text_mode:
#     948             self.stderr = io.TextIOWrapper(self.stderr,
#     949                     encoding=encoding, errors=errors)
# --> 951     self._execute_child(args, executable, preexec_fn, close_fds,
#     952                         pass_fds, cwd, env,
#     953                         startupinfo, creationflags, shell,
#     954                         p2cread, p2cwrite,
#     955                         c2pread, c2pwrite,
#     956                         errread, errwrite,
#     957                         restore_signals,
#     958                         gid, gids, uid, umask,
#     959                         start_new_session)
#     960 except:
#     961     # Cleanup if the child failed starting.
#     962     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~/miniconda3/envs/aif360/lib/python3.9/subprocess.py:1837, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1835     if errno_num != 0:
#    1836         err_msg = os.strerror(errno_num)
# -> 1837     raise child_exception_type(errno_num, err_msg, err_filename)
#    1838 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'python'

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name] = utils.metrics_threshold_sweep_mult(
    dataset=data_val_copy,
    dataset2=data_val2_copy,
    model=models[model_name],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name] = utils.describe_metrics(metrics_sweep[model_name])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name] = utils.compute_metrics_mult(
    dataset=data_test_copy, 
    dataset2=data_test2_copy,
    model=models[model_name], 
    threshold=metrics_best_thresh_validate[model_name]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name])

# Graficamos el comportamiento del modelo para el rango de umbrales 
f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name])
a.set_title(model_name)
f

# %% [markdown]
# ### Impacto dispar + Eliminador de prejuicios

# %%
# Nombre del modelo
model_name = 'disparate_impact_prejudice_remover'

# Hacemos una copia de los datasets (usando uno de lo métodos de pre-procesado vistos anteriormente)
data_train_copy, data_val_copy, data_test_copy = data_train_DIR.copy(deepcopy=True), data_val_DIR.copy(deepcopy=True), data_test_DIR.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Parámetros del modelo
η = 50.0 # hyper-parameter de regularización

# Inicializamos el modelo y lo asignamos al diccionario
models[model_name] = PrejudiceRemover(sensitive_attr=sensitive_attribute, eta=η)

# Entrenamos el modelo
models[model_name] = models[model_name].fit(data_train_copy)

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name] = utils.metrics_threshold_sweep_mult(
    dataset=data_val_copy,
    dataset2=data_val2_copy,
    model=models[model_name],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name] = utils.describe_metrics(metrics_sweep[model_name])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name] = utils.compute_metrics_mult(
    dataset=data_test_copy, 
    dataset2=data_test2_copy,
    model=models[model_name], 
    threshold=metrics_best_thresh_validate[model_name]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name])

# Graficamos el comportamiento del modelo para el rango de umbrales 
f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name])
a.set_title(model_name)
f

# %% [markdown]
# ### Reponderación + metafairness

# %%
# %%time 
# Nombramos al modelo
model_name = 'reweighing_meta_fairness'

# Parámetros del modelo
# hyper-parameter de regularización
τ = 0.8
# métricas fairness a optimizar
quality_constraints = ['sr', 'fdr'] # sr: statistical rate, fdr: false discovery rate

# Optimizamos un modelo nuevo por cada métrica
for quality in quality_constraints:
    
    # Hacemos una copia de los datasets
    data_train_copy, data_val_copy, data_test_copy = data_train_REW.copy(deepcopy=True), data_val_REW.copy(deepcopy=True), data_test_REW.copy(deepcopy=True)
    data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)
    
    # nombramos al modelo con su métrica específica
    model_name_quality = '{}_{}'.format(model_name, quality)
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_quality] = MetaFairClassifier(tau=τ, sensitive_attr=sensitive_attribute, type=quality, seed=seed)

    # Entrenamos el modelo
    models[model_name_quality] = models[ model_name_quality ].fit( data_train_copy )
# Out:
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/StatisticalRate.py:36: RuntimeWarning: invalid value encountered in divide
#   prob_y_1 = (prob_1_1 + prob_1_0) / total
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/StatisticalRate.py:37: RuntimeWarning: invalid value encountered in divide
#   prob_z_0 = (prob_m1_0 + prob_1_0) / total
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/StatisticalRate.py:38: RuntimeWarning: invalid value encountered in divide
#   prob_z_1 = (prob_m1_1 + prob_1_1) / total
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:24
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/meta_fair_classifier.py:66, in MetaFairClassifier.fit(self, dataset)
#      59 y_train = np.where(dataset.labels.flatten() == dataset.favorable_label,
#      60                    1, -1)
#      61 x_control_train = np.where(
#      62         np.isin(dataset.protected_attributes[:, sens_idx],
#      63                 dataset.privileged_protected_attributes[sens_idx]),
#      64         1, 0)
# ---> 66 self.model = self.obj.getModel(self.tau, x_train, y_train,
#      67     x_control_train, self.seed)
#      69 return self
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/General.py:99, in General.getModel(self, tau, X, y, sens, random_state)
#      96 samples = dist_x.rvs(size=20)  # TODO: why 20?
#      97 params = self.gradientDescent(dist, a, b, samples, z_1)
# ---> 99 t = self.getValueForX(dist, a, b, params, z_1, X)
#     100 y_pred = np.where(t > 0, 1, -1)
#     102 acc = accuracy_score(y, y_pred)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/StatisticalRate.py:23, in StatisticalRate.getValueForX(self, dist, a, b, params, z_prior, x, return_cs)
#      22 def getValueForX(self, dist, a, b, params, z_prior, x, return_cs=False):
# ---> 23     l_1, l_2 = params
#      24     z_0, z_1 = 1-z_prior, z_prior
#      26     pos = np.ones(len(x))
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
# %%time 

for quality in quality_constraints:
    
    name_suffix = '_{}'.format(quality)
    print(f'Results for {model_name+name_suffix}')

    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name+name_suffix] = utils.metrics_threshold_sweep_mult(
        dataset=data_val_copy,
        dataset2=data_val2_copy,
        model=models[model_name+name_suffix],
        thresh_arr=thresh_sweep
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name+name_suffix] = utils.describe_metrics(metrics_sweep[model_name+name_suffix])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name+name_suffix] = utils.compute_metrics_mult(
        dataset=data_test_copy, 
        dataset2=data_test2_copy,
        model=models[model_name+name_suffix], 
        threshold=metrics_best_thresh_validate[model_name+name_suffix]['best_threshold'])

    utils.print_metrics(metrics_best_thresh_validate[model_name+name_suffix])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name+name_suffix])
    # plt.title(model_name+name_suffix)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+name_suffix])
    a.set_title(model_name+name_suffix)
    f
# Out:
# Results for reweighing_meta_fairness_sr
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/DEFINITIVO/utils.py:583, in metrics_threshold_sweep_mult(dataset, dataset2, model, thresh_arr)
#     581 try:
#     582     # sklearn classifier
# --> 583     y_val_pred_prob = model.predict_proba(dataset.features)
#     584     pos_ind = np.where(model.classes_ == dataset.favorable_label)[0][0]
#
# AttributeError: 'MetaFairClassifier' object has no attribute 'predict_proba'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:7
#
# File ~/DEFINITIVO/utils.py:587, in metrics_threshold_sweep_mult(dataset, dataset2, model, thresh_arr)
#     584     pos_ind = np.where(model.classes_ == dataset.favorable_label)[0][0]
#     585 except AttributeError:
#     586     # aif360 inprocessing algorithm
# --> 587     y_val_pred_prob = model.predict(dataset).scores
#     588     pos_ind = 0
#     590 # Remove nans and turn them into score of random prediction (R=0.5)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/meta_fair_classifier.py:82, in MetaFairClassifier.predict(self, dataset)
#      71 def predict(self, dataset):
#      72     """Obtain the predictions for the provided dataset using the learned
#      73     classifier model.
#      74
#    (...)
#      80         BinaryLabelDataset: Transformed dataset.
#      81     """
# ---> 82     t = self.model(dataset.features)
#      84     pred_dataset = dataset.copy()
#      85     pred_dataset.labels = (t > 0).astype(int).reshape((-1, 1))
#
# AttributeError: 'MetaFairClassifier' object has no attribute 'model'

# %% [markdown]
# ### Impacto dispar + metafairness

# %%
# %%time 
# Nombramos al modelo
model_name = 'disparate_impact_meta_fairness'

# Parámetros del modelo
# hyper-parameter de regularización
τ = 0.8
# métricas fairness a optimizar
quality_constraints = ['sr', 'fdr'] # sr: statistical rate, fdr: false discovery rate

# Optimizamos un modelo nuevo por cada métrica
for quality in quality_constraints:
    
    # Hacemos una copia de los datasets
    data_train_copy, data_val_copy, data_test_copy = data_train_DIR.copy(deepcopy=True), data_val_DIR.copy(deepcopy=True), data_test_DIR.copy(deepcopy=True)
    data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)
    
    # nombramos al modelo con su métrica específica
    model_name_quality = '{}_{}'.format(model_name, quality)
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_quality] = MetaFairClassifier(tau=τ, sensitive_attr=sensitive_attribute, type=quality, seed=seed)

    # Entrenamos el modelo
    models[model_name_quality] = models[ model_name_quality ].fit( data_train_copy )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:24
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/meta_fair_classifier.py:66, in MetaFairClassifier.fit(self, dataset)
#      59 y_train = np.where(dataset.labels.flatten() == dataset.favorable_label,
#      60                    1, -1)
#      61 x_control_train = np.where(
#      62         np.isin(dataset.protected_attributes[:, sens_idx],
#      63                 dataset.privileged_protected_attributes[sens_idx]),
#      64         1, 0)
# ---> 66 self.model = self.obj.getModel(self.tau, x_train, y_train,
#      67     x_control_train, self.seed)
#      69 return self
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/General.py:99, in General.getModel(self, tau, X, y, sens, random_state)
#      96 samples = dist_x.rvs(size=20)  # TODO: why 20?
#      97 params = self.gradientDescent(dist, a, b, samples, z_1)
# ---> 99 t = self.getValueForX(dist, a, b, params, z_1, X)
#     100 y_pred = np.where(t > 0, 1, -1)
#     102 acc = accuracy_score(y, y_pred)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/StatisticalRate.py:23, in StatisticalRate.getValueForX(self, dist, a, b, params, z_prior, x, return_cs)
#      22 def getValueForX(self, dist, a, b, params, z_prior, x, return_cs=False):
# ---> 23     l_1, l_2 = params
#      24     z_0, z_1 = 1-z_prior, z_prior
#      26     pos = np.ones(len(x))
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
# %%time 

for quality in quality_constraints:
    
    name_suffix = '_{}'.format(quality)
    print(f'Results for {model_name+name_suffix}')

    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name+name_suffix] = utils.metrics_threshold_sweep_mult(
        dataset=data_val_copy,
        dataset2=data_val2_copy,
        model=models[model_name+name_suffix],
        thresh_arr=thresh_sweep
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name+name_suffix] = utils.describe_metrics(metrics_sweep[model_name+name_suffix])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name+name_suffix] = utils.compute_metrics_mult(
        dataset=data_test_copy, 
        dataset2=data_test2_copy,
        model=models[model_name+name_suffix], 
        threshold=metrics_best_thresh_validate[model_name+name_suffix]['best_threshold'])

    utils.print_metrics(metrics_best_thresh_validate[model_name+name_suffix])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name+name_suffix])
    # plt.title(model_name+name_suffix)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+name_suffix])
    a.set_title(model_name+name_suffix)
    f
# Out:
# Results for disparate_impact_meta_fairness_sr
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/DEFINITIVO/utils.py:583, in metrics_threshold_sweep_mult(dataset, dataset2, model, thresh_arr)
#     581 try:
#     582     # sklearn classifier
# --> 583     y_val_pred_prob = model.predict_proba(dataset.features)
#     584     pos_ind = np.where(model.classes_ == dataset.favorable_label)[0][0]
#
# AttributeError: 'MetaFairClassifier' object has no attribute 'predict_proba'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:7
#
# File ~/DEFINITIVO/utils.py:587, in metrics_threshold_sweep_mult(dataset, dataset2, model, thresh_arr)
#     584     pos_ind = np.where(model.classes_ == dataset.favorable_label)[0][0]
#     585 except AttributeError:
#     586     # aif360 inprocessing algorithm
# --> 587     y_val_pred_prob = model.predict(dataset).scores
#     588     pos_ind = 0
#     590 # Remove nans and turn them into score of random prediction (R=0.5)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/meta_fair_classifier.py:82, in MetaFairClassifier.predict(self, dataset)
#      71 def predict(self, dataset):
#      72     """Obtain the predictions for the provided dataset using the learned
#      73     classifier model.
#      74
#    (...)
#      80         BinaryLabelDataset: Transformed dataset.
#      81     """
# ---> 82     t = self.model(dataset.features)
#      84     pred_dataset = dataset.copy()
#      85     pred_dataset.labels = (t > 0).astype(int).reshape((-1, 1))
#
# AttributeError: 'MetaFairClassifier' object has no attribute 'model'

# %% [markdown]
# ### Reponderación + prejuicios adversarios

# %%
# %%time

# Nombramos al modelo
model_name = 'reweighing_NN_adversarial_debiasing'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train_REW.copy(deepcopy=True), data_val_REW.copy(deepcopy=True), data_test_REW.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

sess = tf.Session()

models[model_name] = AdversarialDebiasing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    scope_name = 'debiased_classifier',
    debias=True,
    sess=sess,
    num_epochs=80)

models[model_name].fit(data_train_copy)
# Out:
# epoch 0; iter: 0; batch classifier loss: 0.682557; batch adversarial loss: 0.812126
# epoch 1; iter: 0; batch classifier loss: 0.731113; batch adversarial loss: 0.871086
# epoch 2; iter: 0; batch classifier loss: 0.722729; batch adversarial loss: 0.867104
# epoch 3; iter: 0; batch classifier loss: 0.723143; batch adversarial loss: 0.846327
# epoch 4; iter: 0; batch classifier loss: 0.696984; batch adversarial loss: 0.803001
# epoch 5; iter: 0; batch classifier loss: 0.659646; batch adversarial loss: 0.800822
# epoch 6; iter: 0; batch classifier loss: 0.703563; batch adversarial loss: 0.854183
# epoch 7; iter: 0; batch classifier loss: 0.696488; batch adversarial loss: 0.885983
# epoch 8; iter: 0; batch classifier loss: 0.657613; batch adversarial loss: 0.836639
# epoch 9; iter: 0; batch classifier loss: 0.692013; batch adversarial loss: 0.865651
# epoch 10; iter: 0; batch classifier loss: 0.649643; batch adversarial loss: 0.801761
# epoch 11; iter: 0; batch classifier loss: 0.688126; batch adversarial loss: 0.862427
Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train_REW.copy(deepcopy=True), data_val_REW.copy(deepcopy=True), data_test_REW.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Regresión logística
model_name = 'reweighin_logistic_regression'

# Parámetros del modelo
fit_params = {'logisticregression__sample_weight': data_train_copy.instance_weights}

# Asignamos el modelo al diccionario
models[model_name+fairness_method] = make_pipeline(
            #StandardScaler(),
            LogisticRegression(solver='liblinear', random_state=seed))

# Entrenamos el modelo
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy.features, data_train_copy.labels.ravel(), **fit_params)

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_threshold_sweep_mult(
    dataset=data_val_copy,
    dataset2=data_val2_copy,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_mult(
    dataset=data_test_copy, 
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.3535
# AUC: 0.5058
# Balanced accuracy: 0.5819
# Accuracy: 0.5733
# Independence ( |ΔP(Y_pred = 1)| ): 0.0319
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0862
# Sufficiency ( |ΔPPV| ) : 0.1966

# %%
# %%time 

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train_REW.copy(deepcopy=True), data_val_REW.copy(deepcopy=True), data_test_REW.copy(deepcopy=True)

# Nombramos al modelo
model_name = 'reweighin_xgb_classifier'

# Parámetros del modelo
fit_params = {'eval_metric': 'error', 'eta':0.1, 'max_depth':6, 'subsample':0.8}

# Asignamos el modelo al diccionario
models[model_name+fairness_method] = XGBClassifier(**fit_params)

# Entrenamos el modelo
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy.features, data_train_copy.labels.ravel())

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_threshold_sweep_mult(
    dataset=data_val_copy,
    dataset2=data_val2_copy,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_mult(
    dataset=data_test_copy, 
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.0908
# AUC: 0.4613
# Balanced accuracy: 0.5519
# Accuracy: 0.5400
# Independence ( |ΔP(Y_pred = 1)| ): 0.0466
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0301
# Sufficiency ( |ΔPPV| ) : 0.1261
# CPU times: user 32.3 s, sys: 194 ms, total: 32.5 s
# Wall time: 647 ms

# %% [markdown]
# #### Disparate impact

# %%
# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train_DIR.copy(deepcopy=True), data_val_DIR.copy(deepcopy=True), data_test_DIR.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Regresión logística
model_name = 'disparate_impact_logistic_regression'

# Parámetros del modelo
fit_params = {'logisticregression__sample_weight': data_train_copy.instance_weights}

# Asignamos el modelo al diccionario
models[model_name+fairness_method] = make_pipeline(
            #StandardScaler(),
            LogisticRegression(solver='liblinear', random_state=seed))

# Entrenamos el modelo
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy.features, data_train_copy.labels.ravel(), **fit_params)

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_threshold_sweep_mult(
    dataset=data_val_copy,
    dataset2=data_val2_copy,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_mult(
    dataset=data_test_copy, 
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.4141
# AUC: 0.5367
# Balanced accuracy: 0.5650
# Accuracy: 0.5600
# Independence ( |ΔP(Y_pred = 1)| ): 0.2082
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1498
# Sufficiency ( |ΔPPV| ) : 0.2462

# %%
# %%time 

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train_DIR.copy(deepcopy=True), data_val_DIR.copy(deepcopy=True), data_test_DIR.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Nombramos al modelo
model_name = 'disparate_impact_xgb_classifier'

# Parámetros del modelo
fit_params = {'eval_metric': 'error', 'eta':0.1, 'max_depth':6, 'subsample':0.8}

# Asignamos el modelo al diccionario
models[model_name+fairness_method] = XGBClassifier(**fit_params)

# Entrenamos el modelo
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy.features, data_train_copy.labels.ravel())

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_threshold_sweep_mult(
    dataset=data_val_copy,
    dataset2=data_val2_copy,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_mult(
    dataset=data_test_copy, 
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.0908
# AUC: 0.4613
# Balanced accuracy: 0.5519
# Accuracy: 0.5400
# Independence ( |ΔP(Y_pred = 1)| ): 0.0466
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0301
# Sufficiency ( |ΔPPV| ) : 0.1261
# CPU times: user 33.5 s, sys: 174 ms, total: 33.6 s
# Wall time: 669 ms

# %%
#Anotamos los nombres de los modelos
model_names = ['reweighin_logistic_regression', 'reweighin_xgb_classifier', 'disparate_impact_logistic_regression', 'disparate_impact_xgb_classifier']

# %% [markdown]
# ### Aplicación de técnicas de postprocesado

# %% [markdown]
# #### Reponderación + Clasificación de rechazo de opción

# %%
# %%time 

# Nombramos al modelo
fairness_method = '_reject_option'

# Nombre del modelo al que le aplicaremos post-processing
model_name = 'reweighin_logistic_regression'

# métricas fair a optimizar
fair_metrics = {'spd': "Statistical parity difference", 'aod': "Average odds difference", 'eod': "Equal opportunity difference"}

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])

# Optimizamos un modelo nuevo por cada métrica
for key_metric in fair_metrics:
    
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    models[model_name_metric] = RejectOptionClassification(
        unprivileged_groups=unprivileged_groups, 
        privileged_groups=privileged_groups, 
        metric_name=fair_metrics[key_metric],
        metric_lb=-0.01, metric_ub=0.01)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 11 s, sys: 3.47 s, total: 14.4 s
# Wall time: 10.4 s

# %%
display(Markdown("**Validation set results for logistic regression**"))
for key_metric in fair_metrics:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_val_copy, 
        dataset_preds=data_val_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
    
    print(model_name_metric)
    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')
    
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy, 
        dataset_preds=data_test_preds, 
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        required_threshold=False)
# Out:
# **Validation set results for logistic regression**
# reweighin_logistic_regression_reject_option_spd
# Threshold corresponding to *best balanced accuracy*: 0.4654
# AUC: 0.5058
# Balanced accuracy: 0.4674
# Accuracy: 0.4667
# Independence ( |ΔP(Y_pred = 1)| ): 0.0311
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1025
# Sufficiency ( |ΔPPV| ) : 0.2579
#
#
# reweighin_logistic_regression_reject_option_aod
# Threshold corresponding to *best balanced accuracy*: 0.5247
# AUC: 0.5058
# Balanced accuracy: 0.4829
# Accuracy: 0.4867
# Independence ( |ΔP(Y_pred = 1)| ): 0.0188
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1120
# Sufficiency ( |ΔPPV| ) : 0.3227
#
#
# reweighin_logistic_regression_reject_option_eod
# Threshold corresponding to *best balanced accuracy*: 0.5742
# AUC: 0.5058
# Balanced accuracy: 0.4462
# Accuracy: 0.4533
# Independence ( |ΔP(Y_pred = 1)| ): 0.0955
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0422
# Sufficiency ( |ΔPPV| ) : 0.2009

# %%
# %%time 

# Nombramos al modelo
fairness_method = '_reject_option'

# Nombre del modelo al que le aplicaremos post-processing
model_name = 'reweighin_xgb_classifier'

# métricas fair a optimizar
fair_metrics = {'spd': "Statistical parity difference", 'aod': "Average odds difference", 'eod': "Equal opportunity difference"}

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])

# Optimizamos un modelo nuevo por cada métrica
for key_metric in fair_metrics:
    
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    models[model_name_metric] = RejectOptionClassification(
        unprivileged_groups=unprivileged_groups, 
        privileged_groups=privileged_groups, 
        metric_name=fair_metrics[key_metric],
        metric_lb=-0.01, metric_ub=0.01)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 11 s, sys: 180 ms, total: 11.2 s
# Wall time: 9.67 s

# %%
display(Markdown("**Validation set results for xgb classifier**"))
for key_metric in fair_metrics:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_val_copy, 
        dataset_preds=data_val_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
    
    print(model_name_metric)
    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')
    
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy, 
        dataset_preds=data_test_preds, 
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        required_threshold=False)
# Out:
# **Validation set results for xgb classifier**
# reweighin_xgb_classifier_reject_option_spd
# Threshold corresponding to *best balanced accuracy*: 0.3466
# AUC: 0.4613
# Balanced accuracy: 0.4403
# Accuracy: 0.4400
# Independence ( |ΔP(Y_pred = 1)| ): 0.3896
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.2077
# Sufficiency ( |ΔPPV| ) : 0.0173
#
#
# reweighin_xgb_classifier_reject_option_aod
# Threshold corresponding to *best balanced accuracy*: 0.2476
# AUC: 0.4613
# Balanced accuracy: 0.5271
# Accuracy: 0.5200
# Independence ( |ΔP(Y_pred = 1)| ): 0.1810
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0406
# Sufficiency ( |ΔPPV| ) : 0.2027
#
#
# reweighin_xgb_classifier_reject_option_eod
# Threshold corresponding to *best balanced accuracy*: 0.2476
# AUC: 0.4613
# Balanced accuracy: 0.5271
# Accuracy: 0.5200
# Independence ( |ΔP(Y_pred = 1)| ): 0.1810
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0406
# Sufficiency ( |ΔPPV| ) : 0.2027

# %% [markdown]
# #### Impacto dispar + Rechazo de opción

# %%
# %%time 

# Nombramos al modelo
fairness_method = '_reject_option'

# Nombre del modelo al que le aplicaremos post-processing
model_name = 'disparate_impact_logistic_regression'

# métricas fair a optimizar
fair_metrics = {'spd': "Statistical parity difference", 'aod': "Average odds difference", 'eod': "Equal opportunity difference"}

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])

# Optimizamos un modelo nuevo por cada métrica
for key_metric in fair_metrics:
    
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    models[model_name_metric] = RejectOptionClassification(
        unprivileged_groups=unprivileged_groups, 
        privileged_groups=privileged_groups, 
        metric_name=fair_metrics[key_metric],
        metric_lb=-0.01, metric_ub=0.01)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 10.1 s, sys: 3.44 s, total: 13.6 s
# Wall time: 9.32 s

# %%
display(Markdown("**Validation set results for logistic regression**"))
for key_metric in fair_metrics:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_val_copy, 
        dataset_preds=data_val_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
    
    print(model_name_metric)
    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')
    
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy, 
        dataset_preds=data_test_preds, 
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        required_threshold=False)
# Out:
# **Validation set results for logistic regression**
# disparate_impact_logistic_regression_reject_option_spd
# Threshold corresponding to *best balanced accuracy*: 0.4357
# AUC: 0.5367
# Balanced accuracy: 0.4663
# Accuracy: 0.4667
# Independence ( |ΔP(Y_pred = 1)| ): 0.0476
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0926
# Sufficiency ( |ΔPPV| ) : 0.2692
#
#
# disparate_impact_logistic_regression_reject_option_aod
# Threshold corresponding to *best balanced accuracy*: 0.4258
# AUC: 0.5367
# Balanced accuracy: 0.4803
# Accuracy: 0.4800
# Independence ( |ΔP(Y_pred = 1)| ): 0.0806
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1078
# Sufficiency ( |ΔPPV| ) : 0.2849
#
#
# disparate_impact_logistic_regression_reject_option_eod
# Threshold corresponding to *best balanced accuracy*: 0.4456
# AUC: 0.5367
# Balanced accuracy: 0.4663
# Accuracy: 0.4667
# Independence ( |ΔP(Y_pred = 1)| ): 0.0903
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0577
# Sufficiency ( |ΔPPV| ) : 0.2418

# %%
# %%time 

# Nombramos al modelo
fairness_method = '_reject_option'

# Nombre del modelo al que le aplicaremos post-processing
model_name = 'disparate_impact_xgb_classifier'

# métricas fair a optimizar
fair_metrics = {'spd': "Statistical parity difference", 'aod': "Average odds difference", 'eod': "Equal opportunity difference"}

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])

# Optimizamos un modelo nuevo por cada métrica
for key_metric in fair_metrics:
    
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    models[model_name_metric] = RejectOptionClassification(
        unprivileged_groups=unprivileged_groups, 
        privileged_groups=privileged_groups, 
        metric_name=fair_metrics[key_metric],
        metric_lb=-0.01, metric_ub=0.01)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 10.8 s, sys: 99.7 ms, total: 10.9 s
# Wall time: 9.44 s

# %%
display(Markdown("**Validation set results for xgb classifier**"))
for key_metric in fair_metrics:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_val_copy, 
        dataset_preds=data_val_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
    
    print(model_name_metric)
    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')
    
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy, 
        dataset_preds=data_test_preds, 
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        required_threshold=False)
# Out:
# **Validation set results for xgb classifier**
# disparate_impact_xgb_classifier_reject_option_spd
# Threshold corresponding to *best balanced accuracy*: 0.3466
# AUC: 0.4613
# Balanced accuracy: 0.4403
# Accuracy: 0.4400
# Independence ( |ΔP(Y_pred = 1)| ): 0.3896
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.2077
# Sufficiency ( |ΔPPV| ) : 0.0173
#
#
# disparate_impact_xgb_classifier_reject_option_aod
# Threshold corresponding to *best balanced accuracy*: 0.2476
# AUC: 0.4613
# Balanced accuracy: 0.5271
# Accuracy: 0.5200
# Independence ( |ΔP(Y_pred = 1)| ): 0.1810
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0406
# Sufficiency ( |ΔPPV| ) : 0.2027
#
#
# disparate_impact_xgb_classifier_reject_option_eod
# Threshold corresponding to *best balanced accuracy*: 0.2476
# AUC: 0.4613
# Balanced accuracy: 0.5271
# Accuracy: 0.5200
# Independence ( |ΔP(Y_pred = 1)| ): 0.1810
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0406
# Sufficiency ( |ΔPPV| ) : 0.2027

# %% [markdown]
# #### Reponderación y impacto dispar + Escalado de Platt por grupos

# %%
# %%time
fairness_method = '_platt_scaling'
model_names = model_names
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy = True), data_val.copy(deepcopy = True), data_test.copy(deepcopy = True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

for model_name in model_names:
    # Hacemos una copia de las predicciones del modelo de referencia
    model_thresh = metrics_best_thresh_validate[model_name]['best_threshold']
    data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name], class_thresh = model_thresh)
    data_val_preds_m = utils.update_dataset_from_model2(data_val, data_val2_copy, models[model_name], class_thresh = model_thresh)
    ## Plat Scaling:
    #1. dividir el validation data usando los groups sensibles
    data_val_preds_priv, data_val_preds_unpriv, priv_indices, unpriv_indices = utils.split_dataset_on_sensitive_attribute(
        dataset = data_val_preds, privileged_group_label = list((privileged_groups[0].values()))[0])
    #2. copia el validation data para guardar los scores
    data_val_preds2_m = data_val_preds_m.copy(deepcopy = True)
    data_val_preds2 = data_val_preds.copy(deepcopy = True)
    #3. hacer un modelo para cada grupo
    sensitive_groups_data = {'priv': [data_val_preds_priv, priv_indices],
                             'unpriv': [data_val_preds_unpriv, unpriv_indices]}

    for group, data_group_list in sensitive_groups_data.items():

        # nombramos al modelo con su grupo específico
        model_name_group = '{}_{}_{}'.format(model_name, fairness_method, group)

        # Inicializamos el modelo y lo asignamos al diccionario
        models[model_name_group] = LogisticRegression()

        # Realizamos el modelo usando datos para cada grupo en el validation data
        models[ model_name_group ] = models[model_name_group].fit(data_group_list[0].scores,   # data_group_list[0] -> data_val_preds_priv or data_val_preds_unpriv
                                                                  data_val_copy.subset(data_group_list[1]).labels.ravel()) # data_group_list[1] -> priv_indices or unpriv_indices
        # haz predicciones de probabilidad con el modelo de cada groupo y guardar lo en data_val_preds2
        # las predicciones de probabilidad son los platt scores
        scores_group = models[model_name_group].predict_proba(data_group_list[0].scores)
        pos_ind_group = np.where(models[model_name_group].classes_ == data_group_list[0].favorable_label)[0][0]
        data_val_preds2.scores[data_group_list[1]] = scores_group[:, pos_ind_group].reshape(-1,1)
        data_val_preds2_m.scores[data_group_list[1]] = scores_group[:, pos_ind_group].reshape(-1,1)
        
        # Evaluamos a los modelos para el rango de umbrales
    thresh_sweep_platt = np.linspace(np.min(data_val_preds2.scores.ravel()),
                                     np.max(data_val_preds2.scores.ravel()),
                                     50)

    metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep_from_scores_mult(
            dataset_true = data_val_copy,
            dataset2 =data_val2_copy,
            dataset_preds = data_val_preds2_m,
            thresh_arr = thresh_sweep_platt
        )

    # Evaluamos las métricas para el mejor umbral y las guardamos
    metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics( metrics_sweep[model_name+fairness_method] )

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    print('\nValidation set results for {}'.format(model_name))
    utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
    # utils.plot_fairness_and_accuracy( metrics_sweep[model_name+fairness_method] )
    # plt.title( model_name+fairness_method )
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
    a.set_title(model_name+fairness_method )
    f
# Out:
# Validation set results for reweighin_logistic_regression
# Threshold corresponding to *best balanced accuracy*: 0.5196
# AUC: 0.5435
# Balanced accuracy: 0.5712
# Accuracy: 0.5667
# Independence ( |ΔP(Y_pred = 1)| ): 0.4216
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0697
# Sufficiency ( |ΔPPV| ) : 0.0541
#
# Validation set results for reweighin_xgb_classifier
# Threshold corresponding to *best balanced accuracy*: 0.4877
# AUC: 0.6186
# Balanced accuracy: 0.6296
# Accuracy: 0.6267
# Independence ( |ΔP(Y_pred = 1)| ): 0.4567
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0873
# Sufficiency ( |ΔPPV| ) : 0.0333
#
# Validation set results for disparate_impact_logistic_regression
# Threshold corresponding to *best balanced accuracy*: 0.3549
# AUC: 0.5465
# Balanced accuracy: 0.5549
# Accuracy: 0.5467
# Independence ( |ΔP(Y_pred = 1)| ): 0.4677
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0568
# Sufficiency ( |ΔPPV| ) : 0.0909
#
# Validation set results for disparate_impact_xgb_classifier
# Threshold corresponding to *best balanced accuracy*: 0.4877
# AUC: 0.6186
# Balanced accuracy: 0.6296
# Accuracy: 0.6267
# Independence ( |ΔP(Y_pred = 1)| ): 0.4567
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0873
# Sufficiency ( |ΔPPV| ) : 0.0333
# CPU times: user 8.3 s, sys: 515 ms, total: 8.81 s
# Wall time: 544 ms

# %%
# usa el optimal cutoff para predecir usando el test dato

for model_name in model_names:
    model_thresh = metrics_best_thresh_validate[model_name]['best_threshold']
    data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name], class_thresh = model_thresh)
    data_test_preds_m = utils.update_dataset_from_model2(data_test_copy, data_test2_copy, models[model_name], class_thresh = model_thresh)
    
    # 1. dividir el validation data usando los groups sensibles
    data_test_preds_priv, data_test_preds_unpriv, priv_indices, unpriv_indices = utils.split_dataset_on_sensitive_attribute(dataset = data_test_preds,
                                                                                                                            privileged_group_label = list((privileged_groups[0].values()))[0])
    # 2. copia el test data para guardar los platt scores
    data_test_preds2 = data_test_preds.copy(deepcopy = True)
    data_test_preds2_m = data_test_preds_m.copy(deepcopy = True)
    
    # 3. predecir con el modelo de cada grupo
    sensitive_groups_data_test = {'priv': [data_test_preds_priv, priv_indices],
                                  'unpriv': [data_test_preds_unpriv, unpriv_indices]}

    for group, data_group_list in sensitive_groups_data_test.items():    
        # nombramos al modelo con su grupo específico
        model_name_group = '{}_{}_{}'.format(model_name, fairness_method, group)

        # haz predicciones de probabilidad con el modelo de cada groupo y guardar lo en data_val_preds2
        # las predicciones de probabilidad son los platt scores
        scores_group = models[model_name_group].predict_proba(data_group_list[0].scores)
        pos_ind_group = np.where(models[model_name_group].classes_ == data_group_list[0].favorable_label)[0][0]
        data_test_preds2.scores[data_group_list[1]] = scores_group[:, pos_ind_group].reshape(-1,1)

    data_test_preds2_m = data_test2_copy.copy(deepcopy = True)
    data_test_preds2_m.scores = data_test_preds2.scores
    
    metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_from_scores_mult(dataset_true = data_test_copy,
                                                                                             dataset_pred = data_test_preds2_m,
                                                                                             dataset2=data_test2_copy,
                                                                                             threshold = metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

# %% [markdown]
# #### Reponderación + Procesador de probabilidades igualadas

# %% [markdown]
# ##### Usando labels

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'reweighin_logistic_regression'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:24
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:144, in EqOddsPostprocessing.fit(self, dataset_true, dataset_pred)
#     139 oflip = np.ravel(
#     140     dataset_pred.labels[cond_vec_unpriv] == dataset_pred.unfavorable_label)
#     142 y_true = dataset_true.labels.ravel()
# --> 144 sm_tn = np.logical_and(sflip,
#     145     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     146     dtype=np.float64)
#     147 sm_fn = np.logical_and(sflip,
#     148     y_true[cond_vec_priv] == dataset_true.favorable_label,
#     149     dtype=np.float64)
#     150 sm_fp = np.logical_and(sconst,
#     151     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     152     dtype=np.float64)
#
# TypeError: No loop matching the specified signature and casting was found for ufunc logical_and

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing_mult(
    dataset_true=data_test_copy,
    dataset2=data_test2_copy,
    dataset_preds=data_test_preds,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'reweighin_xgb_classifier'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:24
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:144, in EqOddsPostprocessing.fit(self, dataset_true, dataset_pred)
#     139 oflip = np.ravel(
#     140     dataset_pred.labels[cond_vec_unpriv] == dataset_pred.unfavorable_label)
#     142 y_true = dataset_true.labels.ravel()
# --> 144 sm_tn = np.logical_and(sflip,
#     145     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     146     dtype=np.float64)
#     147 sm_fn = np.logical_and(sflip,
#     148     y_true[cond_vec_priv] == dataset_true.favorable_label,
#     149     dtype=np.float64)
#     150 sm_fp = np.logical_and(sconst,
#     151     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     152     dtype=np.float64)
#
# TypeError: No loop matching the specified signature and casting was found for ufunc logical_and

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing_mult(
    dataset_true=data_test_copy,
    dataset_preds=data_test_preds,
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %% [markdown]
# #### Usando scores

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'reweighin_logistic_regression'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 226 ms, sys: 1.02 s, total: 1.24 s
# Wall time: 39.9 ms

# %%
display(Markdown("**Validation set results for logistic regression**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy,
        dataset_preds=data_test_preds,
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for logistic regression**
# Results for reweighin_logistic_regression_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.3535
# AUC: 0.5058
# Balanced accuracy: 0.5819
# Accuracy: 0.5733
# Independence ( |ΔP(Y_pred = 1)| ): 0.0094
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0578
# Sufficiency ( |ΔPPV| ) : 0.1490
#
#
# Results for reweighin_logistic_regression_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.3535
# AUC: 0.5058
# Balanced accuracy: 0.5751
# Accuracy: 0.5667
# Independence ( |ΔP(Y_pred = 1)| ): 0.0251
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0078
# Sufficiency ( |ΔPPV| ) : 0.1744
#
#
# Results for reweighin_logistic_regression_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.3535
# AUC: 0.5058
# Balanced accuracy: 0.5819
# Accuracy: 0.5733
# Independence ( |ΔP(Y_pred = 1)| ): 0.0094
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0578
# Sufficiency ( |ΔPPV| ) : 0.1490

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'reweighin_xgb_classifier'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 4.06 s, sys: 119 ms, total: 4.18 s
# Wall time: 80 ms

# %%
display(Markdown("**Validation set results for xgb classifier**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy,
        dataset2=data_test2_copy,
        dataset_preds=data_test_preds,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for xgb classifier**
# Results for reweighin_xgb_classifier_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.0908
# AUC: 0.4613
# Balanced accuracy: 0.5519
# Accuracy: 0.5400
# Independence ( |ΔP(Y_pred = 1)| ): 0.1476
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1057
# Sufficiency ( |ΔPPV| ) : 0.1172
#
#
# Results for reweighin_xgb_classifier_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.0908
# AUC: 0.4613
# Balanced accuracy: 0.5519
# Accuracy: 0.5400
# Independence ( |ΔP(Y_pred = 1)| ): 0.1476
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1057
# Sufficiency ( |ΔPPV| ) : 0.1172
#
#
# Results for reweighin_xgb_classifier_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.0908
# AUC: 0.4613
# Balanced accuracy: 0.5519
# Accuracy: 0.5400
# Independence ( |ΔP(Y_pred = 1)| ): 0.1476
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1057
# Sufficiency ( |ΔPPV| ) : 0.1172

# %% [markdown]
# #### Impacto dispar + Procesador de probabilidades igualadas

# %% [markdown]
# ##### Usando labels

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'disparate_impact_logistic_regression'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:24
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:144, in EqOddsPostprocessing.fit(self, dataset_true, dataset_pred)
#     139 oflip = np.ravel(
#     140     dataset_pred.labels[cond_vec_unpriv] == dataset_pred.unfavorable_label)
#     142 y_true = dataset_true.labels.ravel()
# --> 144 sm_tn = np.logical_and(sflip,
#     145     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     146     dtype=np.float64)
#     147 sm_fn = np.logical_and(sflip,
#     148     y_true[cond_vec_priv] == dataset_true.favorable_label,
#     149     dtype=np.float64)
#     150 sm_fp = np.logical_and(sconst,
#     151     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     152     dtype=np.float64)
#
# TypeError: No loop matching the specified signature and casting was found for ufunc logical_and

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing_mult(
    dataset_true=data_test_copy,
    dataset2=data_test2_copy,
    dataset_preds=data_test_preds,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'disparate_impact_xgb_classifier'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:24
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:144, in EqOddsPostprocessing.fit(self, dataset_true, dataset_pred)
#     139 oflip = np.ravel(
#     140     dataset_pred.labels[cond_vec_unpriv] == dataset_pred.unfavorable_label)
#     142 y_true = dataset_true.labels.ravel()
# --> 144 sm_tn = np.logical_and(sflip,
#     145     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     146     dtype=np.float64)
#     147 sm_fn = np.logical_and(sflip,
#     148     y_true[cond_vec_priv] == dataset_true.favorable_label,
#     149     dtype=np.float64)
#     150 sm_fp = np.logical_and(sconst,
#     151     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     152     dtype=np.float64)
#
# TypeError: No loop matching the specified signature and casting was found for ufunc logical_and

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing_mult(
    dataset_true=data_test_copy,
    dataset2=data_test2_copy,
    dataset_preds=data_test_preds,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %% [markdown]
# ##### Usando scores

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'disparate_impact_logistic_regression'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 163 ms, sys: 1.04 s, total: 1.21 s
# Wall time: 39.1 ms

# %%
display(Markdown("**Validation set results for logistic regression**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy,
        dataset2=data_test2_copy,
        dataset_preds=data_test_preds,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for logistic regression**
# Results for disparate_impact_logistic_regression_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.3939
# AUC: 0.5367
# Balanced accuracy: 0.5982
# Accuracy: 0.5933
# Independence ( |ΔP(Y_pred = 1)| ): 0.8430
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0644
# Sufficiency ( |ΔPPV| ) : 0.5588
#
#
# Results for disparate_impact_logistic_regression_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.4747
# AUC: 0.5367
# Balanced accuracy: 0.5423
# Accuracy: 0.5333
# Independence ( |ΔP(Y_pred = 1)| ): 0.8621
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0289
# Sufficiency ( |ΔPPV| ) : 0.2707
#
#
# Results for disparate_impact_logistic_regression_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.3939
# AUC: 0.5367
# Balanced accuracy: 0.5982
# Accuracy: 0.5933
# Independence ( |ΔP(Y_pred = 1)| ): 0.8430
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0644
# Sufficiency ( |ΔPPV| ) : 0.5588

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'disparate_impact_xgb_classifier'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 4.1 s, sys: 132 ms, total: 4.23 s
# Wall time: 80.8 ms

# %%
display(Markdown("**Validation set results for xgb classifier**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy,
        dataset_preds=data_test_preds,
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for xgb classifier**
# Results for disparate_impact_xgb_classifier_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.0908
# AUC: 0.4613
# Balanced accuracy: 0.5519
# Accuracy: 0.5400
# Independence ( |ΔP(Y_pred = 1)| ): 0.1476
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1057
# Sufficiency ( |ΔPPV| ) : 0.1172
#
#
# Results for disparate_impact_xgb_classifier_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.0908
# AUC: 0.4613
# Balanced accuracy: 0.5519
# Accuracy: 0.5400
# Independence ( |ΔP(Y_pred = 1)| ): 0.1476
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1057
# Sufficiency ( |ΔPPV| ) : 0.1172
#
#
# Results for disparate_impact_xgb_classifier_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.0908
# AUC: 0.4613
# Balanced accuracy: 0.5519
# Accuracy: 0.5400
# Independence ( |ΔP(Y_pred = 1)| ): 0.1476
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1057
# Sufficiency ( |ΔPPV| ) : 0.1172

# %% [markdown]
# ## Inprocesado + Postprocesado

# %%
#Anotamos los nombres de los modelos que vamos a usar
model_names = ['prejudice_remover', 'meta_fairness_sr', 'meta_fairness_fdr', 'NN_adversarial_debiasing', 'Basic_NN_no_adversarial_debiasing']

# %% [markdown]
# ### Eliminador de prejuicios + rechazo de opción

# %%
# %%time 

# Nombramos al modelo
fairness_method = '_reject_option'

# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[0]

# métricas fair a optimizar
fair_metrics = {'spd': "Statistical parity difference", 'aod': "Average odds difference", 'eod': "Equal opportunity difference"}

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])

# Optimizamos un modelo nuevo por cada métrica
for key_metric in fair_metrics:
    
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    models[model_name_metric] = RejectOptionClassification(
        unprivileged_groups=unprivileged_groups, 
        privileged_groups=privileged_groups, 
        metric_name=fair_metrics[key_metric],
        metric_lb=-0.01, metric_ub=0.01)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/DEFINITIVO/utils.py:142, in update_dataset_from_model(dataset, model, class_thresh)
#     141 try:
# --> 142     y_pred_prob = model.predict_proba(dataset_pred.features)[:, pos_ind]
#     143 except:
#
# AttributeError: 'PrejudiceRemover' object has no attribute 'predict_proba'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:15
#
# File ~/DEFINITIVO/utils.py:144, in update_dataset_from_model(dataset, model, class_thresh)
#     142     y_pred_prob = model.predict_proba(dataset_pred.features)[:, pos_ind]
#     143 except:
# --> 144     y_pred_prob = model.predict(dataset_pred).scores
#     145 # Obtain predicted labels according to class_threshold
#     146 y_pred = np.zeros_like(dataset_pred.labels)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/prejudice_remover.py:204, in PrejudiceRemover.predict(self, dataset)
#     198 predict_lr = os.path.join(k_path, 'kamfadm-2012ecmlpkdd', 'predict_lr.py')
#     199 # changed paths in the calls below to (a) specify path of train_pr,
#     200 # predict_lr RELATIVE to this file, and (b) compute & use absolute path,
#     201 # and (c) replace python3 with python
#     202 subprocess.call(['python', predict_lr,
#     203                  '-i', test_name,
# --> 204                  '-m', self.model_name,
#     205                  '-o', output_name,
#     206                  '--quiet'])
#     207 os.unlink(test_name)
#     208 m = np.loadtxt(output_name)
#
# AttributeError: 'PrejudiceRemover' object has no attribute 'model_name'

# %%
display(Markdown("**Validation set results for logistic regression**"))
for key_metric in fair_metrics:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_val_copy, 
        dataset_preds=data_val_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
    
    print(model_name_metric)
    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')
    
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy, 
        dataset_preds=data_test_preds, 
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        required_threshold=False)
# Out:
# **Validation set results for logistic regression**
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[68], line 9
#       2 for key_metric in fair_metrics:
#       4     model_name_metric = model_name + fairness_method + '_' + key_metric
#       6     metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing(
#       7         dataset_true=data_val_copy,
#       8         dataset_preds=data_val_preds,
# ----> 9         model=models[model_name_metric],
#      10         required_threshold=False)
#      12     print(model_name_metric)
#      13     utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
#
# KeyError: 'prejudice_remover_reject_option_spd'

# %% [markdown]
# ### Metafairness + rechazo de opción

# %%
# %%time 

# Nombramos al modelo
fairness_method = '_reject_option'

# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[1]

# métricas fair a optimizar
fair_metrics = {'spd': "Statistical parity difference", 'aod': "Average odds difference", 'eod': "Equal opportunity difference"}

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
#data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
#data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
#data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])

# Optimizamos un modelo nuevo por cada métrica
for key_metric in fair_metrics:
    
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    models[model_name_metric] = RejectOptionClassification(
        unprivileged_groups=unprivileged_groups, 
        privileged_groups=privileged_groups, 
        metric_name=fair_metrics[key_metric],
        metric_lb=-0.01, metric_ub=0.01)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 9.34 s, sys: 135 ms, total: 9.47 s
# Wall time: 9.47 s

# %%
display(Markdown("**Validation set results for logistic regression**"))
for key_metric in fair_metrics:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_val_copy, 
        dataset_preds=data_val_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
    
    print(model_name_metric)
    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')
    
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy, 
        dataset_preds=data_test_preds, 
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        required_threshold=False)
# Out:
# **Validation set results for logistic regression**
# meta_fairness_sr_reject_option_spd
# Threshold corresponding to *best balanced accuracy*: 0.3466
# AUC: 0.4613
# Balanced accuracy: 0.4403
# Accuracy: 0.4400
# Independence ( |ΔP(Y_pred = 1)| ): 0.3896
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.2077
# Sufficiency ( |ΔPPV| ) : 0.0173
#
#
# meta_fairness_sr_reject_option_aod
# Threshold corresponding to *best balanced accuracy*: 0.2476
# AUC: 0.4613
# Balanced accuracy: 0.5271
# Accuracy: 0.5200
# Independence ( |ΔP(Y_pred = 1)| ): 0.1810
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0406
# Sufficiency ( |ΔPPV| ) : 0.2027
#
#
# meta_fairness_sr_reject_option_eod
# Threshold corresponding to *best balanced accuracy*: 0.2476
# AUC: 0.4613
# Balanced accuracy: 0.5271
# Accuracy: 0.5200
# Independence ( |ΔP(Y_pred = 1)| ): 0.1810
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0406
# Sufficiency ( |ΔPPV| ) : 0.2027

# %% [markdown]
# ### Prejuicios adversarios + rechazo de opción

# %%
# %%time 

# Nombramos al modelo
fairness_method = '_reject_option'

# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[2]

# métricas fair a optimizar
fair_metrics = {'spd': "Statistical parity difference", 'aod': "Average odds difference", 'eod': "Equal opportunity difference"}

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
#data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
#data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
#data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])

# Optimizamos un modelo nuevo por cada métrica
for key_metric in fair_metrics:
    
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    models[model_name_metric] = RejectOptionClassification(
        unprivileged_groups=unprivileged_groups, 
        privileged_groups=privileged_groups, 
        metric_name=fair_metrics[key_metric],
        metric_lb=-0.01, metric_ub=0.01)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 9.5 s, sys: 115 ms, total: 9.62 s
# Wall time: 9.62 s

# %%
display(Markdown("**Validation set results for logistic regression**"))
for key_metric in fair_metrics:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_val_copy, 
        dataset_preds=data_val_preds, 
        dataset2=data_val2_copy,
        model=models[model_name_metric], 
        required_threshold=False)
    
    print(model_name_metric)
    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')
    
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy, 
        dataset2=data_test2_copy,
        dataset_preds=data_test_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
# Out:
# **Validation set results for logistic regression**
# meta_fairness_fdr_reject_option_spd
# Threshold corresponding to *best balanced accuracy*: 0.3466
# AUC: 0.4613
# Balanced accuracy: 0.4537
# Accuracy: 0.4533
# Independence ( |ΔP(Y_pred = 1)| ): 0.0777
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0068
# Sufficiency ( |ΔPPV| ) : 0.1552
#
#
# meta_fairness_fdr_reject_option_aod
# Threshold corresponding to *best balanced accuracy*: 0.2476
# AUC: 0.4613
# Balanced accuracy: 0.4537
# Accuracy: 0.4533
# Independence ( |ΔP(Y_pred = 1)| ): 0.0777
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0068
# Sufficiency ( |ΔPPV| ) : 0.1552
#
#
# meta_fairness_fdr_reject_option_eod
# Threshold corresponding to *best balanced accuracy*: 0.2476
# AUC: 0.4613
# Balanced accuracy: 0.4537
# Accuracy: 0.4533
# Independence ( |ΔP(Y_pred = 1)| ): 0.0777
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0068
# Sufficiency ( |ΔPPV| ) : 0.1552

# %% [markdown]
# ### Red neuronal normal + rechazo de opción

# %%
# %%time 

# Nombramos al modelo
fairness_method = '_reject_option'

# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[3]

# métricas fair a optimizar
fair_metrics = {'spd': "Statistical parity difference", 'aod': "Average odds difference", 'eod': "Equal opportunity difference"}

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
#data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
#data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
#data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])

# Optimizamos un modelo nuevo por cada métrica
for key_metric in fair_metrics:
    
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    models[model_name_metric] = RejectOptionClassification(
        unprivileged_groups=unprivileged_groups, 
        privileged_groups=privileged_groups, 
        metric_name=fair_metrics[key_metric],
        metric_lb=-0.01, metric_ub=0.01)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 9.66 s, sys: 82.5 ms, total: 9.74 s
# Wall time: 9.74 s

# %%
display(Markdown("**Validation set results for logistic regression**"))
for key_metric in fair_metrics:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_val_copy, 
        dataset_preds=data_val_preds, 
        dataset2=data_val2_copy,
        model=models[model_name_metric], 
        required_threshold=False)
    
    print(model_name_metric)
    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')
    
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy, 
        dataset_preds=data_test_preds, 
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        required_threshold=False)
# Out:
# **Validation set results for logistic regression**
# NN_adversarial_debiasing_reject_option_spd
# Threshold corresponding to *best balanced accuracy*: 0.3466
# AUC: 0.4613
# Balanced accuracy: 0.4537
# Accuracy: 0.4533
# Independence ( |ΔP(Y_pred = 1)| ): 0.0777
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0068
# Sufficiency ( |ΔPPV| ) : 0.1552
#
#
# NN_adversarial_debiasing_reject_option_aod
# Threshold corresponding to *best balanced accuracy*: 0.2476
# AUC: 0.4613
# Balanced accuracy: 0.4537
# Accuracy: 0.4533
# Independence ( |ΔP(Y_pred = 1)| ): 0.0777
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0068
# Sufficiency ( |ΔPPV| ) : 0.1552
#
#
# NN_adversarial_debiasing_reject_option_eod
# Threshold corresponding to *best balanced accuracy*: 0.2476
# AUC: 0.4613
# Balanced accuracy: 0.4537
# Accuracy: 0.4533
# Independence ( |ΔP(Y_pred = 1)| ): 0.0777
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0068
# Sufficiency ( |ΔPPV| ) : 0.1552

# %% [markdown]
# ### Inprocesado + Escalado Platt por grupos

# %%
# %%time
fairness_method = '_platt_scaling'

model_names = ['NN_adversarial_debiasing', 'Basic_NN_no_adversarial_debiasing']
#model_names = ['meta_fairness_fdr', 'meta_fairness_sr', 'NN_adversarial_debiasing', 'Basic_NN_no_adversarial_debiasing']
#model_names = ['prejudice_remover', 'meta_fairness_sr', 'meta_fairness_fdr', 'NN_adversarial_debiasing', 'Basic_NN_no_adversarial_debiasing']
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy = True), data_val.copy(deepcopy = True), data_test.copy(deepcopy = True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

for model_name in model_names:
    # Hacemos una copia de las predicciones del modelo de referencia
    model_thresh = metrics_best_thresh_validate[model_name]['best_threshold']
    data_val_preds = utils.update_dataset_from_scores(data_val_copy, models[model_name].scores_val, model_thresh)
    ## Plat Scaling:
    #1. dividir el validation data usando los groups sensibles
    data_val_preds_priv, data_val_preds_unpriv, priv_indices, unpriv_indices = utils.split_dataset_on_sensitive_attribute(
        dataset = data_val_preds, privileged_group_label = list((privileged_groups[0].values()))[0])
    #2. copia el validation data para guardar los scores
    data_val_preds2 = data_val_preds.copy(deepcopy = True)
    #3. hacer un modelo para cada grupo
    sensitive_groups_data = {'priv': [data_val_preds_priv, priv_indices],
                            'unpriv': [data_val_preds_unpriv, unpriv_indices]}
    
    for group, data_group_list in sensitive_groups_data.items():
    
        # nombramos al modelo con su grupo específico
        model_name_group = '{}_{}_{}'.format(model_name, fairness_method, group)
    
        # Inicializamos el modelo y lo asignamos al diccionario
        models[model_name_group] = LogisticRegression()
    
        # Realizamos el modelo usando datos para cada grupo en el validation data
        models[ model_name_group ] = models[model_name_group].fit(data_group_list[0].scores,   # data_group_list[0] -> data_val_preds_priv or data_val_preds_unpriv
                                                                      data_val_copy.subset(data_group_list[1]).labels.ravel()) # data_group_list[1] -> priv_indices or unpriv_indices
        # haz predicciones de probabilidad con el modelo de cada groupo y guardar lo en data_val_preds2
        # las predicciones de probabilidad son los platt scores
        scores_group = models[model_name_group].predict_proba(data_group_list[0].scores)
        pos_ind_group = np.where(models[model_name_group].classes_ == data_group_list[0].favorable_label)[0][0]
        data_val_preds2.scores[data_group_list[1]] = scores_group[:, pos_ind_group].reshape(-1,1)
            
        # Evaluamos a los modelos para el rango de umbrales
        thresh_sweep_platt = np.linspace(np.min(data_val_preds2.scores.ravel()),
                                         np.max(data_val_preds2.scores.ravel()),
                                         50)
        data_val_preds2_m = data_val2_copy.copy(deepcopy = True)
        data_val_preds2_m.scores = data_val_preds2.scores
        metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep_from_scores_mult(
                dataset_true = data_val_copy,
                dataset2=data_val2_copy,
                dataset_preds = data_val_preds2_m,
                thresh_arr = thresh_sweep_platt
            )
    
        # Evaluamos las métricas para el mejor umbral y las guardamos
        metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics( metrics_sweep[model_name+fairness_method] )
    
        # Graficamos el comportamiento del modelo para el rango de umbrales 
        print('\nValidation set results for {}'.format(model_name))
        utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
        # utils.plot_fairness_and_accuracy( metrics_sweep[model_name+fairness_method] )
        # plt.title( model_name+fairness_method )
        
        f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
        a.set_title(model_name+fairness_method )
        f
# Out:
# Validation set results for NN_adversarial_debiasing
# Threshold corresponding to *best balanced accuracy*: 0.5134
# AUC: 0.4709
# Balanced accuracy: 0.5228
# Accuracy: 0.5133
# Independence ( |ΔP(Y_pred = 1)| ): 0.0026
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0603
# Sufficiency ( |ΔPPV| ) : 0.1771
#
# Validation set results for NN_adversarial_debiasing
# Threshold corresponding to *best balanced accuracy*: 0.5071
# AUC: 0.5807
# Balanced accuracy: 0.6000
# Accuracy: 0.5933
# Independence ( |ΔP(Y_pred = 1)| ): 0.4479
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0452
# Sufficiency ( |ΔPPV| ) : 0.0732
#
# Validation set results for Basic_NN_no_adversarial_debiasing
# Threshold corresponding to *best balanced accuracy*: 0.2466
# AUC: 0.5616
# Balanced accuracy: 0.5574
# Accuracy: 0.5467
# Independence ( |ΔP(Y_pred = 1)| ): 0.2419
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1022
# Sufficiency ( |ΔPPV| ) : 0.0774
#
# Validation set results for Basic_NN_no_adversarial_debiasing
# Threshold corresponding to *best balanced accuracy*: 0.5168
# AUC: 0.5734
# Balanced accuracy: 0.6001
# Accuracy: 0.6000
# Independence ( |ΔP(Y_pred = 1)| ): 0.4399
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0468
# Sufficiency ( |ΔPPV| ) : 0.0167
# CPU times: user 561 ms, sys: 397 ms, total: 958 ms
# Wall time: 384 ms

# %%
# usa el optimal cutoff para predecir usando el test dato

for model_name in model_names:
    model_thresh = metrics_best_thresh_validate[model_name]['best_threshold']
    data_test_preds = utils.update_dataset_from_scores(data_test_copy, models[model_name].scores_test, model_thresh)
    
    # 1. dividir el validation data usando los groups sensibles
    data_test_preds_priv, data_test_preds_unpriv, priv_indices, unpriv_indices = utils.split_dataset_on_sensitive_attribute(dataset = data_test_preds,
                                                                                                                            privileged_group_label = list((privileged_groups[0].values()))[0])
    # 2. copia el test data para guardar los platt scores
    data_test_preds2 = data_test_preds.copy(deepcopy = True)
    
    # 3. predecir con el modelo de cada grupo
    sensitive_groups_data_test = {'priv': [data_test_preds_priv, priv_indices],
                                  'unpriv': [data_test_preds_unpriv, unpriv_indices]}

    for group, data_group_list in sensitive_groups_data_test.items():    
        # nombramos al modelo con su grupo específico
        model_name_group = '{}_{}_{}'.format(model_name, fairness_method, group)

        # haz predicciones de probabilidad con el modelo de cada groupo y guardar lo en data_val_preds2
        # las predicciones de probabilidad son los platt scores
        scores_group = models[model_name_group].predict_proba(data_group_list[0].scores)
        pos_ind_group = np.where(models[model_name_group].classes_ == data_group_list[0].favorable_label)[0][0]
        data_test_preds2.scores[data_group_list[1]] = scores_group[:, pos_ind_group].reshape(-1,1)
    data_test_preds2_m = data_test2_copy.copy(deepcopy=True)
    data_test_preds2_m.scores = data_test2_copy.scores
    metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_from_scores_mult(dataset_true = data_test_copy,
                                                                                             dataset_pred = data_test_preds2,
                                                                                             dataset2=data_test2_copy,
                                                                                             threshold = metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

# %% [markdown]
# #### Eliminador de prejuicios + Procesador de probabilidades igualadas

# %% [markdown]
# ##### Usando labels

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[0]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

thresh_NN_ADV = metrics_best_thresh_validate['NN_adversarial_debiasing']['best_threshold']

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_scores(data_train_copy, models[model_name].scores_train, thresh_NN_ADV)
data_val_preds = utils.update_dataset_from_scores(data_val_copy, models[model_name].scores_val, thresh_NN_ADV)
data_test_preds = utils.update_dataset_from_scores(data_test_copy, models[model_name].scores_test, thresh_NN_ADV)


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:26
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:144, in EqOddsPostprocessing.fit(self, dataset_true, dataset_pred)
#     139 oflip = np.ravel(
#     140     dataset_pred.labels[cond_vec_unpriv] == dataset_pred.unfavorable_label)
#     142 y_true = dataset_true.labels.ravel()
# --> 144 sm_tn = np.logical_and(sflip,
#     145     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     146     dtype=np.float64)
#     147 sm_fn = np.logical_and(sflip,
#     148     y_true[cond_vec_priv] == dataset_true.favorable_label,
#     149     dtype=np.float64)
#     150 sm_fp = np.logical_and(sconst,
#     151     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     152     dtype=np.float64)
#
# TypeError: No loop matching the specified signature and casting was found for ufunc logical_and

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing_mult(
    dataset_true=data_test_copy,
    dataset_preds=data_test_preds,
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %% [markdown]
# #### Usando scores

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[0]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

thresh_no_NN_ADV = metrics_best_thresh_validate['Basic_NN_no_adversarial_debiasing']['best_threshold']

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_scores(data_train_copy, models[model_name].scores_train, thresh_no_NN_ADV)
data_val_preds = utils.update_dataset_from_scores(data_val_copy, models[model_name].scores_val, thresh_no_NN_ADV)
data_test_preds = utils.update_dataset_from_scores(data_test_copy, models[model_name].scores_test, thresh_no_NN_ADV)


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 15 ms, sys: 2.99 ms, total: 18 ms
# Wall time: 17.1 ms

# %%
display(Markdown("**Validation set results for prejudice remover**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy,
        dataset_preds=data_test_preds,
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for prejudice remover**
# Results for NN_adversarial_debiasing_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.0100
# AUC: 0.4215
# Balanced accuracy: 0.5000
# Accuracy: 0.4867
# Independence ( |ΔP(Y_pred = 1)| ): 0.0000
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0000
# Sufficiency ( |ΔPPV| ) : 0.1758
#
#
# Results for NN_adversarial_debiasing_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.0908
# AUC: 0.4215
# Balanced accuracy: 0.5195
# Accuracy: 0.5067
# Independence ( |ΔP(Y_pred = 1)| ): 0.0248
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0259
# Sufficiency ( |ΔPPV| ) : 0.1891
#
#
# Results for NN_adversarial_debiasing_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.0100
# AUC: 0.4215
# Balanced accuracy: 0.5000
# Accuracy: 0.4867
# Independence ( |ΔP(Y_pred = 1)| ): 0.0000
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0000
# Sufficiency ( |ΔPPV| ) : 0.1758

# %% [markdown]
# #### Metafairness + Procesador de probabilidades igualadas

# %% [markdown]
# ##### Usando labels

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[1]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# 2024-06-19 10:19:06.509046: W tensorflow/c/c_api.cc:305] Operation '{name:'biased_classifier/biased_classifier/classifier_model/b2/Adam_1/Assign' id:264 op device:{requested: '', assigned: ''} def:{{{node biased_classifier/biased_classifier/classifier_model/b2/Adam_1/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](biased_classifier/biased_classifier/classifier_model/b2/Adam_1, biased_classifier/biased_classifier/classifier_model/b2/Adam_1/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:24
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:144, in EqOddsPostprocessing.fit(self, dataset_true, dataset_pred)
#     139 oflip = np.ravel(
#     140     dataset_pred.labels[cond_vec_unpriv] == dataset_pred.unfavorable_label)
#     142 y_true = dataset_true.labels.ravel()
# --> 144 sm_tn = np.logical_and(sflip,
#     145     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     146     dtype=np.float64)
#     147 sm_fn = np.logical_and(sflip,
#     148     y_true[cond_vec_priv] == dataset_true.favorable_label,
#     149     dtype=np.float64)
#     150 sm_fp = np.logical_and(sconst,
#     151     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     152     dtype=np.float64)
#
# TypeError: No loop matching the specified signature and casting was found for ufunc logical_and

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing_mult(
    dataset_true=data_test_copy,
    dataset_preds=data_test_preds,
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %% [markdown]
# #### Usando scores

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[1]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 37.1 ms, sys: 5.05 ms, total: 42.1 ms
# Wall time: 30.7 ms

# %%
display(Markdown("**Validation set results for metafairness**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy,
        dataset_preds=data_test_preds,
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for metafairness**
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.3333
# AUC: 0.5254
# Balanced accuracy: 0.5794
# Accuracy: 0.5733
# Independence ( |ΔP(Y_pred = 1)| ): 0.2169
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1468
# Sufficiency ( |ΔPPV| ) : 0.0484
#
#
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.2322
# AUC: 0.5254
# Balanced accuracy: 0.5819
# Accuracy: 0.5733
# Independence ( |ΔP(Y_pred = 1)| ): 0.4181
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1286
# Sufficiency ( |ΔPPV| ) : 0.0413
#
#
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.3535
# AUC: 0.5254
# Balanced accuracy: 0.5715
# Accuracy: 0.5667
# Independence ( |ΔP(Y_pred = 1)| ): 0.3728
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0487
# Sufficiency ( |ΔPPV| ) : 0.0949

# %% [markdown]
# ##### Usando labels

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[2]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File <timed exec>:4
#
# IndexError: list index out of range

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing_mult(
    dataset_true=data_test_copy,
    dataset_preds=data_test_preds,
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %% [markdown]
# #### Usando scores

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[2]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File <timed exec>:4
#
# IndexError: list index out of range

# %%
display(Markdown("**Validation set results for metafairness**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy,
        dataset_preds=data_test_preds,
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for metafairness**
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.3333
# AUC: 0.5254
# Balanced accuracy: 0.5794
# Accuracy: 0.5733
# Independence ( |ΔP(Y_pred = 1)| ): 0.2169
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1468
# Sufficiency ( |ΔPPV| ) : 0.0484
#
#
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.2322
# AUC: 0.5254
# Balanced accuracy: 0.5819
# Accuracy: 0.5733
# Independence ( |ΔP(Y_pred = 1)| ): 0.4181
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1286
# Sufficiency ( |ΔPPV| ) : 0.0413
#
#
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.3535
# AUC: 0.5254
# Balanced accuracy: 0.5715
# Accuracy: 0.5667
# Independence ( |ΔP(Y_pred = 1)| ): 0.3728
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0487
# Sufficiency ( |ΔPPV| ) : 0.0949

# %% [markdown]
# #### Prejuicios adversarios + Procesador de probabilidades igualadas

# %% [markdown]
# ##### Usando labels

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[3]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

thresh_NN_ADV = metrics_best_thresh_validate['NN_adversarial_debiasing']['best_threshold']

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_scores(data_train_copy, models[model_name].scores_train, thresh_NN_ADV)
data_val_preds = utils.update_dataset_from_scores(data_val_copy, models[model_name].scores_val, thresh_NN_ADV)
data_test_preds = utils.update_dataset_from_scores(data_test_copy, models[model_name].scores_test, thresh_NN_ADV)


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File <timed exec>:4
#
# IndexError: list index out of range

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing_mult(
    dataset_true=data_test_copy,
    dataset_preds=data_test_preds,
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %% [markdown]
# #### Usando scores

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[3]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

thresh_NN_ADV = metrics_best_thresh_validate['NN_adversarial_debiasing']['best_threshold']

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_scores(data_train_copy, models[model_name].scores_train, thresh_NN_ADV)
data_val_preds = utils.update_dataset_from_scores(data_val_copy, models[model_name].scores_val, thresh_NN_ADV)
data_test_preds = utils.update_dataset_from_scores(data_test_copy, models[model_name].scores_test, thresh_NN_ADV)


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File <timed exec>:4
#
# IndexError: list index out of range

# %%
display(Markdown("**Validation set results for adversarial debiasing**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy,
        dataset_preds=data_test_preds,
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for adversarial debiasing**
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.3333
# AUC: 0.5254
# Balanced accuracy: 0.5794
# Accuracy: 0.5733
# Independence ( |ΔP(Y_pred = 1)| ): 0.2169
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1468
# Sufficiency ( |ΔPPV| ) : 0.0484
#
#
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.2322
# AUC: 0.5254
# Balanced accuracy: 0.5819
# Accuracy: 0.5733
# Independence ( |ΔP(Y_pred = 1)| ): 0.4181
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1286
# Sufficiency ( |ΔPPV| ) : 0.0413
#
#
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.3535
# AUC: 0.5254
# Balanced accuracy: 0.5715
# Accuracy: 0.5667
# Independence ( |ΔP(Y_pred = 1)| ): 0.3728
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0487
# Sufficiency ( |ΔPPV| ) : 0.0949

# %% [markdown]
# #### Red neuronal normal + Procesador de probabilidades igualadas

# %% [markdown]
# ##### Usando labels

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[4]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

thresh_no_NN_ADV = metrics_best_thresh_validate['Basic_NN_no_adversarial_debiasing']['best_threshold']

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_scores(data_train_copy, models[model_name].scores_train, thresh_no_NN_ADV)
data_val_preds = utils.update_dataset_from_scores(data_val_copy, models[model_name].scores_val, thresh_no_NN_ADV)
data_test_preds = utils.update_dataset_from_scores(data_test_copy, models[model_name].scores_test, thresh_no_NN_ADV)


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File <timed exec>:4
#
# IndexError: list index out of range

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing_mult(
    dataset_true=data_test_copy,
    dataset_preds=data_test_preds,
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %% [markdown]
# #### Usando scores

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[4]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

thresh_no_NN_ADV = metrics_best_thresh_validate['Basic_NN_no_adversarial_debiasing']['best_threshold']

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_scores(data_train_copy, models[model_name].scores_train, thresh_no_NN_ADV)
data_val_preds = utils.update_dataset_from_scores(data_val_copy, models[model_name].scores_val, thresh_no_NN_ADV)
data_test_preds = utils.update_dataset_from_scores(data_test_copy, models[model_name].scores_test, thresh_no_NN_ADV)


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File <timed exec>:4
#
# IndexError: list index out of range

# %%
display(Markdown("**Validation set results for basic NN**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy,
        dataset_preds=data_test_preds,
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for basic NN**
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.3333
# AUC: 0.5254
# Balanced accuracy: 0.5794
# Accuracy: 0.5733
# Independence ( |ΔP(Y_pred = 1)| ): 0.2169
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1468
# Sufficiency ( |ΔPPV| ) : 0.0484
#
#
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.2322
# AUC: 0.5254
# Balanced accuracy: 0.5819
# Accuracy: 0.5733
# Independence ( |ΔP(Y_pred = 1)| ): 0.4181
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1286
# Sufficiency ( |ΔPPV| ) : 0.0413
#
#
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.3535
# AUC: 0.5254
# Balanced accuracy: 0.5715
# Accuracy: 0.5667
# Independence ( |ΔP(Y_pred = 1)| ): 0.3728
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0487
# Sufficiency ( |ΔPPV| ) : 0.0949

# %% [markdown]
# ## Comparación de modelos
#
# Podemos usar los diccionarios que resumen la calidad de los modelos fair para compararlos todos.

# %% [markdown]
# ### Resultados en validación

# %%
algorithm_performance_summary = pd.DataFrame(metrics_best_thresh_validate).T
algorithm_performance_summary
# Out:
#                                                     best_threshold   bal_acc  \
# logistic_regression                                       0.414082  0.565024
# xgb_classifier                                            0.090816  0.551948
# NN_adversarial_debiasing                                  0.090816  0.519481
# Basic_NN_no_adversarial_debiasing                         0.232245  0.574720
# reweighing_NN_adversarial_debiasing                       0.636327  0.553905
# reweighin_basic_NN_no_adversarial_debiasing               0.232245  0.581925
# disparate_impact_NN_adversarial_debiasing                 0.232245  0.526419
# disparate_impact_basic_NN_no_adversarial_debiasing        0.353469  0.559242
# reweighin_logistic_regression                             0.353469  0.581925
# reweighin_xgb_classifier                                  0.090816  0.551948
# disparate_impact_logistic_regression                      0.414082  0.565024
# disparate_impact_xgb_classifier                           0.090816  0.551948
# reweighin_logistic_regression_reject_option_spd           0.465354  0.467355
# reweighin_logistic_regression_reject_option_aod           0.524747  0.482921
# reweighin_logistic_regression_reject_option_eod           0.574242  0.446184
# reweighin_xgb_classifier_reject_option_spd                0.346566  0.440313
# reweighin_xgb_classifier_reject_option_aod                0.247576  0.527130
# reweighin_xgb_classifier_reject_option_eod                0.247576  0.527130
# disparate_impact_logistic_regression_reject_opt...        0.435657  0.466287
# disparate_impact_logistic_regression_reject_opt...        0.425758  0.480342
# disparate_impact_logistic_regression_reject_opt...        0.445556  0.466287
# disparate_impact_xgb_classifier_reject_option_spd         0.346566  0.440313
# disparate_impact_xgb_classifier_reject_option_aod         0.247576  0.527130
# disparate_impact_xgb_classifier_reject_option_eod         0.247576  0.527130
# reweighin_logistic_regression_platt_scaling               0.519643  0.571162
# reweighin_xgb_classifier_platt_scaling                    0.487744  0.629603
# disparate_impact_logistic_regression_platt_scaling        0.354892  0.554883
# disparate_impact_xgb_classifier_platt_scaling             0.487744  0.629603
# reweighin_logistic_regression_equal_odds_weighted         0.353469  0.581925
# reweighin_logistic_regression_equal_odds_fnr              0.353469  0.575076
# reweighin_logistic_regression_equal_odds_fpr              0.353469  0.581925
# reweighin_xgb_classifier_equal_odds_weighted              0.090816  0.551948
# reweighin_xgb_classifier_equal_odds_fnr                   0.090816  0.551948
# reweighin_xgb_classifier_equal_odds_fpr                   0.090816  0.551948
# disparate_impact_logistic_regression_equal_odds...        0.393878  0.598203
# disparate_impact_logistic_regression_equal_odds...        0.474694  0.542252
# disparate_impact_logistic_regression_equal_odds...        0.393878  0.598203
# disparate_impact_xgb_classifier_equal_odds_weig...        0.090816  0.551948
# disparate_impact_xgb_classifier_equal_odds_fnr            0.090816  0.551948
# disparate_impact_xgb_classifier_equal_odds_fpr            0.090816  0.551948
# meta_fairness_sr_reject_option_spd                        0.346566  0.440313
# meta_fairness_sr_reject_option_aod                        0.247576  0.527130
# meta_fairness_sr_reject_option_eod                        0.247576  0.527130
# meta_fairness_fdr_reject_option_spd                       0.346566  0.453656
# meta_fairness_fdr_reject_option_aod                       0.247576  0.453656
# meta_fairness_fdr_reject_option_eod                       0.247576  0.453656
# NN_adversarial_debiasing_reject_option_spd                0.346566  0.453656
# NN_adversarial_debiasing_reject_option_aod                0.247576  0.453656
# NN_adversarial_debiasing_reject_option_eod                0.247576  0.453656
# NN_adversarial_debiasing_platt_scaling                    0.507144  0.599982
# Basic_NN_no_adversarial_debiasing_platt_scaling           0.516796  0.600071
# NN_adversarial_debiasing_equal_odds_weighted              0.010000  0.500000
# NN_adversarial_debiasing_equal_odds_fnr                   0.090816  0.519481
# NN_adversarial_debiasing_equal_odds_fpr                   0.010000  0.500000
# Basic_NN_no_adversarial_debiasing_equal_odds_we...        0.333265  0.579434
# Basic_NN_no_adversarial_debiasing_equal_odds_fnr          0.232245  0.581925
# Basic_NN_no_adversarial_debiasing_equal_odds_fpr          0.353469  0.571518
#
#                                                          acc  independence  \
# logistic_regression                                 0.560000      0.208211
# xgb_classifier                                      0.540000      0.046554
# NN_adversarial_debiasing                            0.506667      0.034091
# Basic_NN_no_adversarial_debiasing                   0.566667      0.208944
# reweighing_NN_adversarial_debiasing                 0.553333      0.199047
# reweighin_basic_NN_no_adversarial_debiasing         0.573333      0.188050
# disparate_impact_NN_adversarial_debiasing           0.520000      0.085777
# disparate_impact_basic_NN_no_adversarial_debiasing  0.553333      0.155059
# reweighin_logistic_regression                       0.573333      0.031891
# reweighin_xgb_classifier                            0.540000      0.046554
# disparate_impact_logistic_regression                0.560000      0.208211
# disparate_impact_xgb_classifier                     0.540000      0.046554
# reweighin_logistic_regression_reject_option_spd     0.466667      0.031063
# reweighin_logistic_regression_reject_option_aod     0.486667      0.018809
# reweighin_logistic_regression_reject_option_eod     0.453333      0.095469
# reweighin_xgb_classifier_reject_option_spd          0.440000      0.389570
# reweighin_xgb_classifier_reject_option_aod          0.520000      0.180963
# reweighin_xgb_classifier_reject_option_eod          0.520000      0.180963
# disparate_impact_logistic_regression_reject_opt...  0.466667      0.047592
# disparate_impact_logistic_regression_reject_opt...  0.480000      0.080650
# disparate_impact_logistic_regression_reject_opt...  0.466667      0.090339
# disparate_impact_xgb_classifier_reject_option_spd   0.440000      0.389570
# disparate_impact_xgb_classifier_reject_option_aod   0.520000      0.180963
# disparate_impact_xgb_classifier_reject_option_eod   0.520000      0.180963
# reweighin_logistic_regression_platt_scaling         0.566667      0.421554
# reweighin_xgb_classifier_platt_scaling              0.626667      0.456745
# disparate_impact_logistic_regression_platt_scaling  0.546667      0.467742
# disparate_impact_xgb_classifier_platt_scaling       0.626667      0.456745
# reweighin_logistic_regression_equal_odds_weighted   0.573333      0.009404
# reweighin_logistic_regression_equal_odds_fnr        0.566667      0.025078
# reweighin_logistic_regression_equal_odds_fpr        0.573333      0.009404
# reweighin_xgb_classifier_equal_odds_weighted        0.540000      0.147620
# reweighin_xgb_classifier_equal_odds_fnr             0.540000      0.147620
# reweighin_xgb_classifier_equal_odds_fpr             0.540000      0.147620
# disparate_impact_logistic_regression_equal_odds...  0.593333      0.842975
# disparate_impact_logistic_regression_equal_odds...  0.533333      0.862069
# disparate_impact_logistic_regression_equal_odds...  0.593333      0.842975
# disparate_impact_xgb_classifier_equal_odds_weig...  0.540000      0.147620
# disparate_impact_xgb_classifier_equal_odds_fnr      0.540000      0.147620
# disparate_impact_xgb_classifier_equal_odds_fpr      0.540000      0.147620
# meta_fairness_sr_reject_option_spd                  0.440000      0.389570
# meta_fairness_sr_reject_option_aod                  0.520000      0.180963
# meta_fairness_sr_reject_option_eod                  0.520000      0.180963
# meta_fairness_fdr_reject_option_spd                 0.453333      0.077713
# meta_fairness_fdr_reject_option_aod                 0.453333      0.077713
# meta_fairness_fdr_reject_option_eod                 0.453333      0.077713
# NN_adversarial_debiasing_reject_option_spd          0.453333      0.077713
# NN_adversarial_debiasing_reject_option_aod          0.453333      0.077713
# NN_adversarial_debiasing_reject_option_eod          0.453333      0.077713
# NN_adversarial_debiasing_platt_scaling              0.593333      0.447947
# Basic_NN_no_adversarial_debiasing_platt_scaling     0.600000      0.439883
# NN_adversarial_debiasing_equal_odds_weighted        0.486667      0.000000
# NN_adversarial_debiasing_equal_odds_fnr             0.506667      0.024793
# NN_adversarial_debiasing_equal_odds_fpr             0.486667      0.000000
# Basic_NN_no_adversarial_debiasing_equal_odds_we...  0.573333      0.216871
# Basic_NN_no_adversarial_debiasing_equal_odds_fnr    0.573333      0.418068
# Basic_NN_no_adversarial_debiasing_equal_odds_fpr    0.566667      0.372756
#
#                                                     separation  sufficiency  \
# logistic_regression                                   0.149797     0.246218
# xgb_classifier                                        0.030068     0.126109
# NN_adversarial_debiasing                              0.037500     0.161480
# Basic_NN_no_adversarial_debiasing                     0.069369     0.087912
# reweighing_NN_adversarial_debiasing                   0.073536     0.203774
# reweighin_basic_NN_no_adversarial_debiasing           0.009009     0.127733
# disparate_impact_NN_adversarial_debiasing             0.098322     0.209019
# disparate_impact_basic_NN_no_adversarial_debiasing    0.011464     0.143813
# reweighin_logistic_regression                         0.086239     0.196641
# reweighin_xgb_classifier                              0.030068     0.126109
# disparate_impact_logistic_regression                  0.149797     0.246218
# disparate_impact_xgb_classifier                       0.030068     0.126109
# reweighin_logistic_regression_reject_option_spd       0.102516     0.257937
# reweighin_logistic_regression_reject_option_aod       0.112032     0.322727
# reweighin_logistic_regression_reject_option_eod       0.042202     0.200855
# reweighin_xgb_classifier_reject_option_spd            0.207660     0.017296
# reweighin_xgb_classifier_reject_option_aod            0.040557     0.202749
# reweighin_xgb_classifier_reject_option_eod            0.040557     0.202749
# disparate_impact_logistic_regression_reject_opt...    0.092632     0.269231
# disparate_impact_logistic_regression_reject_opt...    0.107821     0.284856
# disparate_impact_logistic_regression_reject_opt...    0.057696     0.241803
# disparate_impact_xgb_classifier_reject_option_spd     0.207660     0.017296
# disparate_impact_xgb_classifier_reject_option_aod     0.040557     0.202749
# disparate_impact_xgb_classifier_reject_option_eod     0.040557     0.202749
# reweighin_logistic_regression_platt_scaling           0.069741     0.054054
# reweighin_xgb_classifier_platt_scaling                0.087309     0.033333
# disparate_impact_logistic_regression_platt_scaling    0.056757     0.090909
# disparate_impact_xgb_classifier_platt_scaling         0.087309     0.033333
# reweighin_logistic_regression_equal_odds_weighted     0.057824     0.148990
# reweighin_logistic_regression_equal_odds_fnr          0.007824     0.174352
# reweighin_logistic_regression_equal_odds_fpr          0.057824     0.148990
# reweighin_xgb_classifier_equal_odds_weighted          0.105717     0.117232
# reweighin_xgb_classifier_equal_odds_fnr               0.105717     0.117232
# reweighin_xgb_classifier_equal_odds_fpr               0.105717     0.117232
# disparate_impact_logistic_regression_equal_odds...    0.064450     0.558824
# disparate_impact_logistic_regression_equal_odds...    0.028947     0.270661
# disparate_impact_logistic_regression_equal_odds...    0.064450     0.558824
# disparate_impact_xgb_classifier_equal_odds_weig...    0.105717     0.117232
# disparate_impact_xgb_classifier_equal_odds_fnr        0.105717     0.117232
# disparate_impact_xgb_classifier_equal_odds_fpr        0.105717     0.117232
# meta_fairness_sr_reject_option_spd                    0.207660     0.017296
# meta_fairness_sr_reject_option_aod                    0.040557     0.202749
# meta_fairness_sr_reject_option_eod                    0.040557     0.202749
# meta_fairness_fdr_reject_option_spd                   0.006757     0.155172
# meta_fairness_fdr_reject_option_aod                   0.006757     0.155172
# meta_fairness_fdr_reject_option_eod                   0.006757     0.155172
# NN_adversarial_debiasing_reject_option_spd            0.006757     0.155172
# NN_adversarial_debiasing_reject_option_aod            0.006757     0.155172
# NN_adversarial_debiasing_reject_option_eod            0.006757     0.155172
# NN_adversarial_debiasing_platt_scaling                0.045214     0.073171
# Basic_NN_no_adversarial_debiasing_platt_scaling       0.046836     0.016667
# NN_adversarial_debiasing_equal_odds_weighted          0.000000     0.175834
# NN_adversarial_debiasing_equal_odds_fnr               0.025862     0.189071
# NN_adversarial_debiasing_equal_odds_fpr               0.000000     0.175834
# Basic_NN_no_adversarial_debiasing_equal_odds_we...    0.146781     0.048387
# Basic_NN_no_adversarial_debiasing_equal_odds_fnr      0.128570     0.041284
# Basic_NN_no_adversarial_debiasing_equal_odds_fpr      0.048728     0.094905
#
#                                                          auc
# logistic_regression                                 0.536737
# xgb_classifier                                      0.461306
# NN_adversarial_debiasing                            0.421455
# Basic_NN_no_adversarial_debiasing                   0.525351
# reweighing_NN_adversarial_debiasing                 0.546878
# reweighin_basic_NN_no_adversarial_debiasing         0.528732
# disparate_impact_NN_adversarial_debiasing           0.490482
# disparate_impact_basic_NN_no_adversarial_debiasing  0.501868
# reweighin_logistic_regression                       0.505782
# reweighin_xgb_classifier                            0.461306
# disparate_impact_logistic_regression                0.536737
# disparate_impact_xgb_classifier                     0.461306
# reweighin_logistic_regression_reject_option_spd     0.505782
# reweighin_logistic_regression_reject_option_aod     0.505782
# reweighin_logistic_regression_reject_option_eod     0.505782
# reweighin_xgb_classifier_reject_option_spd          0.461306
# reweighin_xgb_classifier_reject_option_aod          0.461306
# reweighin_xgb_classifier_reject_option_eod          0.461306
# disparate_impact_logistic_regression_reject_opt...  0.536737
# disparate_impact_logistic_regression_reject_opt...  0.536737
# disparate_impact_logistic_regression_reject_opt...  0.536737
# disparate_impact_xgb_classifier_reject_option_spd   0.461306
# disparate_impact_xgb_classifier_reject_option_aod   0.461306
# disparate_impact_xgb_classifier_reject_option_eod   0.461306
# reweighin_logistic_regression_platt_scaling         0.543498
# reweighin_xgb_classifier_platt_scaling              0.618573
# disparate_impact_logistic_regression_platt_scaling  0.546522
# disparate_impact_xgb_classifier_platt_scaling       0.618573
# reweighin_logistic_regression_equal_odds_weighted   0.505782
# reweighin_logistic_regression_equal_odds_fnr        0.505782
# reweighin_logistic_regression_equal_odds_fpr        0.505782
# reweighin_xgb_classifier_equal_odds_weighted        0.461306
# reweighin_xgb_classifier_equal_odds_fnr             0.461306
# reweighin_xgb_classifier_equal_odds_fpr             0.461306
# disparate_impact_logistic_regression_equal_odds...  0.536737
# disparate_impact_logistic_regression_equal_odds...  0.536737
# disparate_impact_logistic_regression_equal_odds...  0.536737
# disparate_impact_xgb_classifier_equal_odds_weig...  0.461306
# disparate_impact_xgb_classifier_equal_odds_fnr      0.461306
# disparate_impact_xgb_classifier_equal_odds_fpr      0.461306
# meta_fairness_sr_reject_option_spd                  0.461306
# meta_fairness_sr_reject_option_aod                  0.461306
# meta_fairness_sr_reject_option_eod                  0.461306
# meta_fairness_fdr_reject_option_spd                 0.461306
# meta_fairness_fdr_reject_option_aod                 0.461306
# meta_fairness_fdr_reject_option_eod                 0.461306
# NN_adversarial_debiasing_reject_option_spd          0.461306
# NN_adversarial_debiasing_reject_option_aod          0.461306
# NN_adversarial_debiasing_reject_option_eod          0.461306
# NN_adversarial_debiasing_platt_scaling              0.580680
# Basic_NN_no_adversarial_debiasing_platt_scaling     0.573386
# NN_adversarial_debiasing_equal_odds_weighted        0.421455
# NN_adversarial_debiasing_equal_odds_fnr             0.421455
# NN_adversarial_debiasing_equal_odds_fpr             0.421455
# Basic_NN_no_adversarial_debiasing_equal_odds_we...  0.525351
# Basic_NN_no_adversarial_debiasing_equal_odds_fnr    0.525351
# Basic_NN_no_adversarial_debiasing_equal_odds_fpr    0.525351

# %% [markdown]
# ### Resultados en test

# %%
algorithm_performance_summary = pd.DataFrame(metrics_best_thresh_test).T
algorithm_performance_summary
# Out:
#                                                     best_threshold   bal_acc  \
# logistic_regression                                       0.414082  0.526667
# xgb_classifier                                            0.090816  0.500000
# NN_adversarial_debiasing                                  0.090816  0.500000
# Basic_NN_no_adversarial_debiasing                         0.232245  0.466667
# reweighing_NN_adversarial_debiasing                       0.636327  0.506667
# reweighin_basic_NN_no_adversarial_debiasing               0.232245  0.513333
# disparate_impact_NN_adversarial_debiasing                 0.232245  0.520000
# disparate_impact_basic_NN_no_adversarial_debiasing        0.353469  0.460000
# reweighin_logistic_regression                             0.353469  0.500000
# reweighin_xgb_classifier                                  0.090816  0.500000
# disparate_impact_logistic_regression                      0.414082  0.526667
# disparate_impact_xgb_classifier                           0.090816  0.500000
# reweighin_logistic_regression_reject_option_spd           0.465354  0.526667
# reweighin_logistic_regression_reject_option_aod           0.524747  0.526667
# reweighin_logistic_regression_reject_option_eod           0.574242  0.526667
# reweighin_xgb_classifier_reject_option_spd                0.346566  0.493333
# reweighin_xgb_classifier_reject_option_aod                0.247576  0.493333
# reweighin_xgb_classifier_reject_option_eod                0.247576  0.493333
# disparate_impact_logistic_regression_reject_opt...        0.435657  0.520000
# disparate_impact_logistic_regression_reject_opt...        0.425758  0.520000
# disparate_impact_logistic_regression_reject_opt...        0.445556  0.520000
# disparate_impact_xgb_classifier_reject_option_spd         0.346566  0.493333
# disparate_impact_xgb_classifier_reject_option_aod         0.247576  0.493333
# disparate_impact_xgb_classifier_reject_option_eod         0.247576  0.493333
# reweighin_logistic_regression_platt_scaling               0.519643  0.526667
# reweighin_xgb_classifier_platt_scaling                    0.487744  0.500000
# disparate_impact_logistic_regression_platt_scaling        0.354892  0.520000
# disparate_impact_xgb_classifier_platt_scaling             0.487744  0.500000
# reweighin_logistic_regression_equal_odds_weighted         0.353469  0.500000
# reweighin_logistic_regression_equal_odds_fnr              0.353469  0.500000
# reweighin_logistic_regression_equal_odds_fpr              0.353469  0.500000
# reweighin_xgb_classifier_equal_odds_weighted              0.090816  0.500000
# reweighin_xgb_classifier_equal_odds_fnr                   0.090816  0.500000
# reweighin_xgb_classifier_equal_odds_fpr                   0.090816  0.493333
# disparate_impact_logistic_regression_equal_odds...        0.393878  0.533333
# disparate_impact_logistic_regression_equal_odds...        0.474694  0.520000
# disparate_impact_logistic_regression_equal_odds...        0.393878  0.533333
# disparate_impact_xgb_classifier_equal_odds_weig...        0.090816  0.500000
# disparate_impact_xgb_classifier_equal_odds_fnr            0.090816  0.500000
# disparate_impact_xgb_classifier_equal_odds_fpr            0.090816  0.493333
# meta_fairness_sr_reject_option_spd                        0.346566  0.493333
# meta_fairness_sr_reject_option_aod                        0.247576  0.493333
# meta_fairness_sr_reject_option_eod                        0.247576  0.493333
# meta_fairness_fdr_reject_option_spd                       0.346566  0.493333
# meta_fairness_fdr_reject_option_aod                       0.247576  0.493333
# meta_fairness_fdr_reject_option_eod                       0.247576  0.493333
# NN_adversarial_debiasing_reject_option_spd                0.346566  0.493333
# NN_adversarial_debiasing_reject_option_aod                0.247576  0.493333
# NN_adversarial_debiasing_reject_option_eod                0.247576  0.493333
# NN_adversarial_debiasing_platt_scaling                    0.507144  0.500000
# Basic_NN_no_adversarial_debiasing_platt_scaling           0.516796  0.526667
# NN_adversarial_debiasing_equal_odds_weighted              0.010000  0.500000
# NN_adversarial_debiasing_equal_odds_fnr                   0.090816  0.500000
# NN_adversarial_debiasing_equal_odds_fpr                   0.010000  0.500000
# Basic_NN_no_adversarial_debiasing_equal_odds_we...        0.333265  0.486667
# Basic_NN_no_adversarial_debiasing_equal_odds_fnr          0.232245  0.473333
# Basic_NN_no_adversarial_debiasing_equal_odds_fpr          0.353469  0.506667
#
#                                                          acc  independence  \
# logistic_regression                                 0.526667      0.202455
# xgb_classifier                                      0.500000      0.054795
# NN_adversarial_debiasing                            0.500000      0.025974
# Basic_NN_no_adversarial_debiasing                   0.466667      0.102295
# reweighing_NN_adversarial_debiasing                 0.506667      0.283046
# reweighin_basic_NN_no_adversarial_debiasing         0.513333      0.061911
# disparate_impact_NN_adversarial_debiasing           0.520000      0.025440
# disparate_impact_basic_NN_no_adversarial_debiasing  0.460000      0.125245
# reweighin_logistic_regression                       0.500000      0.008539
# reweighin_xgb_classifier                            0.500000      0.054795
# disparate_impact_logistic_regression                0.526667      0.202455
# disparate_impact_xgb_classifier                     0.500000      0.054795
# reweighin_logistic_regression_reject_option_spd     0.526667      0.026330
# reweighin_logistic_regression_reject_option_aod     0.526667      0.026330
# reweighin_logistic_regression_reject_option_eod     0.526667      0.026330
# reweighin_xgb_classifier_reject_option_spd          0.493333      0.040740
# reweighin_xgb_classifier_reject_option_aod          0.493333      0.040740
# reweighin_xgb_classifier_reject_option_eod          0.493333      0.040740
# disparate_impact_logistic_regression_reject_opt...  0.520000      0.171322
# disparate_impact_logistic_regression_reject_opt...  0.520000      0.171322
# disparate_impact_logistic_regression_reject_opt...  0.520000      0.171322
# disparate_impact_xgb_classifier_reject_option_spd   0.493333      0.040740
# disparate_impact_xgb_classifier_reject_option_aod   0.493333      0.040740
# disparate_impact_xgb_classifier_reject_option_eod   0.493333      0.040740
# reweighin_logistic_regression_platt_scaling         0.526667      0.420922
# reweighin_xgb_classifier_platt_scaling              0.500000      0.397082
# disparate_impact_logistic_regression_platt_scaling  0.520000      0.452055
# disparate_impact_xgb_classifier_platt_scaling       0.500000      0.397082
# reweighin_logistic_regression_equal_odds_weighted   0.500000      0.008539
# reweighin_logistic_regression_equal_odds_fnr        0.500000      0.035937
# reweighin_logistic_regression_equal_odds_fpr        0.500000      0.008539
# reweighin_xgb_classifier_equal_odds_weighted        0.500000      0.054795
# reweighin_xgb_classifier_equal_odds_fnr             0.500000      0.054795
# reweighin_xgb_classifier_equal_odds_fpr             0.493333      0.041096
# disparate_impact_logistic_regression_equal_odds...  0.533333      0.377691
# disparate_impact_logistic_regression_equal_odds...  0.520000      0.342466
# disparate_impact_logistic_regression_equal_odds...  0.533333      0.377691
# disparate_impact_xgb_classifier_equal_odds_weig...  0.500000      0.054795
# disparate_impact_xgb_classifier_equal_odds_fnr      0.500000      0.054795
# disparate_impact_xgb_classifier_equal_odds_fpr      0.493333      0.041096
# meta_fairness_sr_reject_option_spd                  0.493333      0.040740
# meta_fairness_sr_reject_option_aod                  0.493333      0.040740
# meta_fairness_sr_reject_option_eod                  0.493333      0.040740
# meta_fairness_fdr_reject_option_spd                 0.493333      0.040740
# meta_fairness_fdr_reject_option_aod                 0.493333      0.040740
# meta_fairness_fdr_reject_option_eod                 0.493333      0.040740
# NN_adversarial_debiasing_reject_option_spd          0.493333      0.040740
# NN_adversarial_debiasing_reject_option_aod          0.493333      0.040740
# NN_adversarial_debiasing_reject_option_eod          0.493333      0.040740
# NN_adversarial_debiasing_platt_scaling              0.500000      0.440491
# Basic_NN_no_adversarial_debiasing_platt_scaling     0.526667      0.293186
# NN_adversarial_debiasing_equal_odds_weighted        0.500000      0.000000
# NN_adversarial_debiasing_equal_odds_fnr             0.500000      0.025974
# NN_adversarial_debiasing_equal_odds_fpr             0.500000      0.000000
# Basic_NN_no_adversarial_debiasing_equal_odds_we...  0.486667      0.120975
# Basic_NN_no_adversarial_debiasing_equal_odds_fnr    0.473333      0.087885
# Basic_NN_no_adversarial_debiasing_equal_odds_fpr    0.506667      0.245686
#
#                                                     separation  sufficiency  \
# logistic_regression                                   0.027922     0.109971
# xgb_classifier                                        0.005303     0.096179
# NN_adversarial_debiasing                              0.002381     0.094612
# Basic_NN_no_adversarial_debiasing                     0.020292     0.108359
# reweighing_NN_adversarial_debiasing                   0.015801     0.078788
# reweighin_basic_NN_no_adversarial_debiasing           0.002814     0.094612
# disparate_impact_NN_adversarial_debiasing             0.063745     0.137374
# disparate_impact_basic_NN_no_adversarial_debiasing    0.041234     0.131924
# reweighin_logistic_regression                         0.023647     0.079445
# reweighin_xgb_classifier                              0.005303     0.096179
# disparate_impact_logistic_regression                  0.027922     0.109971
# disparate_impact_xgb_classifier                       0.005303     0.096179
# reweighin_logistic_regression_reject_option_spd       0.042965     0.050000
# reweighin_logistic_regression_reject_option_aod       0.042965     0.050000
# reweighin_logistic_regression_reject_option_eod       0.042965     0.050000
# reweighin_xgb_classifier_reject_option_spd            0.056926     0.152338
# reweighin_xgb_classifier_reject_option_aod            0.056926     0.152338
# reweighin_xgb_classifier_reject_option_eod            0.056926     0.152338
# disparate_impact_logistic_regression_reject_opt...    0.088528     0.005682
# disparate_impact_logistic_regression_reject_opt...    0.088528     0.005682
# disparate_impact_logistic_regression_reject_opt...    0.088528     0.005682
# disparate_impact_xgb_classifier_reject_option_spd     0.056926     0.152338
# disparate_impact_xgb_classifier_reject_option_aod     0.056926     0.152338
# disparate_impact_xgb_classifier_reject_option_eod     0.056926     0.152338
# reweighin_logistic_regression_platt_scaling           0.019697     0.107280
# reweighin_xgb_classifier_platt_scaling                0.103517     0.000000
# disparate_impact_logistic_regression_platt_scaling    0.002273     0.095455
# disparate_impact_xgb_classifier_platt_scaling         0.103517     0.000000
# reweighin_logistic_regression_equal_odds_weighted     0.023647     0.079445
# reweighin_logistic_regression_equal_odds_fnr          0.020996     0.080834
# reweighin_logistic_regression_equal_odds_fpr          0.023647     0.079445
# reweighin_xgb_classifier_equal_odds_weighted          0.005303     0.096179
# reweighin_xgb_classifier_equal_odds_fnr               0.005303     0.096179
# reweighin_xgb_classifier_equal_odds_fpr               0.017803     0.102597
# disparate_impact_logistic_regression_equal_odds...    0.032576     0.059740
# disparate_impact_logistic_regression_equal_odds...    0.008333     0.087121
# disparate_impact_logistic_regression_equal_odds...    0.032576     0.059740
# disparate_impact_xgb_classifier_equal_odds_weig...    0.005303     0.096179
# disparate_impact_xgb_classifier_equal_odds_fnr        0.005303     0.096179
# disparate_impact_xgb_classifier_equal_odds_fpr        0.017803     0.102597
# meta_fairness_sr_reject_option_spd                    0.056926     0.152338
# meta_fairness_sr_reject_option_aod                    0.056926     0.152338
# meta_fairness_sr_reject_option_eod                    0.056926     0.152338
# meta_fairness_fdr_reject_option_spd                   0.056926     0.152338
# meta_fairness_fdr_reject_option_aod                   0.056926     0.152338
# meta_fairness_fdr_reject_option_eod                   0.056926     0.152338
# NN_adversarial_debiasing_reject_option_spd            0.056926     0.152338
# NN_adversarial_debiasing_reject_option_aod            0.056926     0.152338
# NN_adversarial_debiasing_reject_option_eod            0.056926     0.152338
# NN_adversarial_debiasing_platt_scaling                0.030790     0.079659
# Basic_NN_no_adversarial_debiasing_platt_scaling       0.095455     0.018462
# NN_adversarial_debiasing_equal_odds_weighted          0.000000     0.093400
# NN_adversarial_debiasing_equal_odds_fnr               0.002381     0.094612
# NN_adversarial_debiasing_equal_odds_fpr               0.000000     0.093400
# Basic_NN_no_adversarial_debiasing_equal_odds_we...    0.078517     0.149214
# Basic_NN_no_adversarial_debiasing_equal_odds_fnr      0.029545     0.112503
# Basic_NN_no_adversarial_debiasing_equal_odds_fpr      0.054004     0.138269
#
#                                                          auc
# logistic_regression                                 0.537600
# xgb_classifier                                      0.486756
# NN_adversarial_debiasing                            0.430933
# Basic_NN_no_adversarial_debiasing                   0.501689
# reweighing_NN_adversarial_debiasing                 0.511289
# reweighin_basic_NN_no_adversarial_debiasing         0.488889
# disparate_impact_NN_adversarial_debiasing           0.474667
# disparate_impact_basic_NN_no_adversarial_debiasing  0.465600
# reweighin_logistic_regression                       0.523556
# reweighin_xgb_classifier                            0.486756
# disparate_impact_logistic_regression                0.537600
# disparate_impact_xgb_classifier                     0.486756
# reweighin_logistic_regression_reject_option_spd     0.523556
# reweighin_logistic_regression_reject_option_aod     0.523556
# reweighin_logistic_regression_reject_option_eod     0.523556
# reweighin_xgb_classifier_reject_option_spd          0.486756
# reweighin_xgb_classifier_reject_option_aod          0.486756
# reweighin_xgb_classifier_reject_option_eod          0.486756
# disparate_impact_logistic_regression_reject_opt...  0.537600
# disparate_impact_logistic_regression_reject_opt...  0.537600
# disparate_impact_logistic_regression_reject_opt...  0.537600
# disparate_impact_xgb_classifier_reject_option_spd   0.486756
# disparate_impact_xgb_classifier_reject_option_aod   0.486756
# disparate_impact_xgb_classifier_reject_option_eod   0.486756
# reweighin_logistic_regression_platt_scaling         0.510400
# reweighin_xgb_classifier_platt_scaling              0.521956
# disparate_impact_logistic_regression_platt_scaling  0.513600
# disparate_impact_xgb_classifier_platt_scaling       0.521956
# reweighin_logistic_regression_equal_odds_weighted   0.523556
# reweighin_logistic_regression_equal_odds_fnr        0.523556
# reweighin_logistic_regression_equal_odds_fpr        0.523556
# reweighin_xgb_classifier_equal_odds_weighted        0.486756
# reweighin_xgb_classifier_equal_odds_fnr             0.486756
# reweighin_xgb_classifier_equal_odds_fpr             0.486756
# disparate_impact_logistic_regression_equal_odds...  0.537600
# disparate_impact_logistic_regression_equal_odds...  0.537600
# disparate_impact_logistic_regression_equal_odds...  0.537600
# disparate_impact_xgb_classifier_equal_odds_weig...  0.486756
# disparate_impact_xgb_classifier_equal_odds_fnr      0.486756
# disparate_impact_xgb_classifier_equal_odds_fpr      0.486756
# meta_fairness_sr_reject_option_spd                  0.486756
# meta_fairness_sr_reject_option_aod                  0.486756
# meta_fairness_sr_reject_option_eod                  0.486756
# meta_fairness_fdr_reject_option_spd                 0.486756
# meta_fairness_fdr_reject_option_aod                 0.486756
# meta_fairness_fdr_reject_option_eod                 0.486756
# NN_adversarial_debiasing_reject_option_spd          0.486756
# NN_adversarial_debiasing_reject_option_aod          0.486756
# NN_adversarial_debiasing_reject_option_eod          0.486756
# NN_adversarial_debiasing_platt_scaling              0.572267
# Basic_NN_no_adversarial_debiasing_platt_scaling     0.545422
# NN_adversarial_debiasing_equal_odds_weighted        0.430933
# NN_adversarial_debiasing_equal_odds_fnr             0.430933
# NN_adversarial_debiasing_equal_odds_fpr             0.430933
# Basic_NN_no_adversarial_debiasing_equal_odds_we...  0.501689
# Basic_NN_no_adversarial_debiasing_equal_odds_fnr    0.501689
# Basic_NN_no_adversarial_debiasing_equal_odds_fpr    0.501689

# %%
algorithm_performance_summary.to_csv('SIMULATION_MULTALG_MULTSENS_high', index = True, sep=',', encoding='utf-8')
