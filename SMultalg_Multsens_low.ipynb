# %% [markdown]
# <img src="img/ibidat.png" alt="drawing" width="600"/>

# %% [markdown]
# # Introducción
#
# En este cuaderno vamos a probar todas las parejas posibles de métodos de fairness que afecten a distintas partes del proceso de la construcción del algoritmo de machine learning usando dos variables sensibles. Vamos a hacer un estudio de simulación.

# %% [markdown]
# # Carga de librerías

# %%
# Con esta celda, podemos hacer cambios en cualquier script/libreria y verlo reflejado en las funciones del notebook.
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
## CARGAMOS LIBRERIAS
# Obs: La primera vez puede tardar en cargar porque AIF360 pre-compila algunas cosas de tensorflow
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Cargamos librerías de sklearn
# vanilla LR
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline

# Cargamos xgboost
from xgboost import XGBClassifier

# Cargamos algoritmos de fairness
# Pre-procesado
from aif360.algorithms.preprocessing import Reweighing
from aif360.algorithms.preprocessing import DisparateImpactRemover
# In-procesado
from aif360.algorithms.inprocessing import PrejudiceRemover
from aif360.algorithms.inprocessing import MetaFairClassifier
from aif360.algorithms.inprocessing.adversarial_debiasing import AdversarialDebiasing
# Post-procesado
from aif360.algorithms.postprocessing import RejectOptionClassification # when scores are given
from aif360.algorithms.postprocessing import CalibratedEqOddsPostprocessing # when scores (R) are given
from aif360.algorithms.postprocessing import EqOddsPostprocessing # when labels (Y^hat) are given
from aif360.datasets import GermanDataset

#Simulacion
from aif360.datasets import BinaryLabelDataset

# TF para adversarial debiasing
import tensorflow.compat.v1 as tf
tf.disable_eager_execution()

from IPython.display import Markdown, display

# Librería local con funciones de ayuda extra
import utils

seed = 12345 # fijamos la semilla de números aleatorios para reproducir exactamante el notebook
# Out:
# WARNING:root:
# `load_boston` has been removed from scikit-learn since version 1.2.
#
# The Boston housing prices dataset has an ethical problem: as
# investigated in [1], the authors of this dataset engineered a
# non-invertible variable "B" assuming that racial self-segregation had a
# positive impact on house prices [2]. Furthermore the goal of the
# research that led to the creation of this dataset was to study the
# impact of air quality but it did not give adequate demonstration of the
# validity of this assumption.
#
# The scikit-learn maintainers therefore strongly discourage the use of
# this dataset unless the purpose of the code is to study and educate
# about ethical issues in data science and machine learning.
#
# In this special case, you can fetch the dataset from the original
# source::
#
#     import pandas as pd
#     import numpy as np
#
#     data_url = "http://lib.stat.cmu.edu/datasets/boston"
#     raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#     data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#     target = raw_df.values[1::2, 2]
#
# Alternative datasets include the California housing dataset and the
# Ames housing dataset. You can load the datasets as follows::
#
#     from sklearn.datasets import fetch_california_housing
#     housing = fetch_california_housing()
#
# for the California housing dataset and::
#
#     from sklearn.datasets import fetch_openml
#     housing = fetch_openml(name="house_prices", as_frame=True)
#
# for the Ames housing dataset.
#
# [1] M Carlisle.
# "Racist data destruction?"
# <https://medium.com/@docintangible/racist-data-destruction-113e3eff54a8>
#
# [2] Harrison Jr, David, and Daniel L. Rubinfeld.
# "Hedonic housing prices and the demand for clean air."
# Journal of environmental economics and management 5.1 (1978): 81-102.
# <https://www.researchgate.net/publication/4974606_Hedonic_housing_prices_and_the_demand_for_clean_air>
# : LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# 2024-06-19 10:01:55.536891: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-19 10:01:55.596245: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-19 10:01:56.571712: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Selección de dataset.
#
# El siguiente bloque permite seleccionar el conjunto de datos sobre el que trabajar. Debe recordarse que el conjunto de `homecredit` es mucho mayor por lo que tardará más tiempo en ejecutarse.

# %%
def logit(x):
    return np.log(x/(1-x))

def inv_logit(x):
    return np.exp(x)/(1+np.exp(x))

def simulated_dataset(n_obs, n_var, n_sens, mean_vec, cov, beta, gamma):
    
    p = n_var + n_sens
    coef = np.concatenate((gamma, beta))
        
    X = np.random.multivariate_normal(mean_vec, cov, size = n_obs)
    probs_var = inv_logit(X)
    bin = np.random.binomial(1, probs_var)
    
    probs_Y = inv_logit(coef.dot(X.T))
    Y = np.random.binomial(1, probs_Y)
    
    names = ['0' for i in range(p+1)]
    sens = ['0' for i in range(n_sens)]
    var = 1
    
    names[0] = 'response'
    
    for i in range(1,p+1):
        if i-1 < n_sens:
            sens[i-1] = 'sens ' + str(i)
            names[i] = 'sens ' + str(i)
        if i-1 >= n_sens:
            names[i] = 'var ' + str(var)
            var += 1
    
    names = np.array(names)
    sens = np.array(sens)
    response = np.array(['response'])
    
    Y = Y.reshape((n_obs,1))
    
    bin = np.concatenate((Y, bin), axis = 1)
    
    data_pd = pd.DataFrame(bin, columns = names)
    data = BinaryLabelDataset(df = data_pd, favorable_label = 1, unfavorable_label = 0, label_names = response, protected_attribute_names = sens)
    return data

# %%
n_obs = 1000
n_var = 30
n_sens = 2
mean_vec = np.zeros(n_var+n_sens)
cov = np.identity(n_var+n_sens)
beta = np.zeros(n_var)
gamma = np.ones(n_sens)

dataset1 = simulated_dataset(n_obs, n_var, n_sens, mean_vec, cov, beta, gamma)

#dataset.favorable_label = 1
#dataset.unfavorable_label = 0

new_data = dataset1.convert_to_dataframe()[0]

sens1 = new_data.loc[:,'sens 1']
sens2 = new_data.loc[:,'sens 2']
new_sens = sens1.copy()
new_sens[sens2 == 1] = 1

new_data = new_data.drop(['sens 1', 'sens 2'], axis = 1)
new_data['sens 1'] = new_sens

names = np.array(new_data.columns)
sens = np.array(['sens 1'])
response = np.array(['response'])

dataset = BinaryLabelDataset(df = new_data,
                             favorable_label = 1,
                             unfavorable_label = 0,
                             label_names = response,
                             protected_attribute_names = sens)

# Separamos el conjunto de datos en train, validate, test
data_train, vt = dataset.split([0.7], shuffle=True, seed=seed)
data_val, data_test = vt.split([0.5], shuffle=True, seed=seed)

data_train2, vt2 = dataset1.split([0.7], shuffle=True, seed=seed)
data_val2, data_test2 = vt2.split([0.5], shuffle=True, seed=seed)

# Obtenemos los indicadores del grupo sensible
sensitive_attribute = dataset.protected_attribute_names[0]
privileged_groups, unprivileged_groups = utils.get_privileged_groups(dataset)
    
print(f'Dimensiones del conjunto de datos: {dataset.features.shape}')
print("Grupos privilegiados:", privileged_groups)
print("Grupos no privilegiados:", unprivileged_groups)
print("Label del grupo favorable:", dataset.favorable_label)
print("Label del grupo desfavorable:", dataset.unfavorable_label)
# Out:
# Dimensiones del conjunto de datos: (1000, 31)
# Grupos privilegiados: [{'sens 1': 1.0}]
# Grupos no privilegiados: [{'sens 1': 0.0}]
# Label del grupo favorable: 1.0
# Label del grupo desfavorable: 0.0

# %% [markdown]
# ## Modelos
# Para esta sección, creamos un diccionario de métricas y modelos para poder acceder los resultados de todos los modelos.

# %%
# Inicializamos diccionarios
models = dict()

# Rango de umbrales para evaluar el score de los modelos
thresh_sweep = np.linspace(0.01, 1.0, 50)

metrics_sweep = dict()

# Store results from validation and test
metrics_best_thresh_validate = dict()
metrics_best_thresh_test = dict()

# %% [markdown]
# ### Regresión Logística

# %%
# %%time 

# Nombramos al modelo
model_name = 'logistic_regression'
fairness_method = ''

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Parámetros del modelo
fit_params = {'logisticregression__sample_weight': data_train_copy.instance_weights}

# Asignamos el modelo al diccionario
models[model_name+fairness_method] = make_pipeline(
            #StandardScaler(),
            LogisticRegression(solver='liblinear', random_state=seed))

# Entrenamos el modelo
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy.features, data_train_copy.labels.ravel(), **fit_params)
# Out:
# CPU times: user 11.3 ms, sys: 0 ns, total: 11.3 ms
# Wall time: 10.5 ms

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_threshold_sweep_mult(
    dataset=data_val_copy,
    dataset2=data_val2_copy,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_mult(
    dataset=data_test_copy, 
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.3737
# AUC: 0.5581
# Balanced accuracy: 0.5857
# Accuracy: 0.5933
# Independence ( |ΔP(Y_pred = 1)| ): 0.3222
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1165
# Sufficiency ( |ΔPPV| ) : 0.0078
# CPU times: user 162 ms, sys: 17.4 ms, total: 179 ms
# Wall time: 162 ms

# %%
display(Markdown("**Test set results**"))
utils.print_metrics(metrics_best_thresh_test[model_name+fairness_method])
# Out:
# **Test set results**
# Threshold corresponding to *best balanced accuracy*: 0.3737
# AUC: 0.5041
# Balanced accuracy: 0.5360
# Accuracy: 0.5600
# Independence ( |ΔP(Y_pred = 1)| ): 0.2834
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0670
# Sufficiency ( |ΔPPV| ) : 0.0383

# %% [markdown]
# ### XGBoost

# %%
# %%time 

# Nombramos al modelo
model_name = 'xgb_classifier'
fairness_method = ''

# Parámetros del modelo
fit_params = {'eval_metric': 'error', 'eta':0.1, 'max_depth':6, 'subsample':0.8}

# Asignamos el modelo al diccionario
models[model_name+fairness_method] = XGBClassifier(**fit_params)

# Entrenamos el modelo
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy.features, data_train_copy.labels.ravel())
# Out:
# CPU times: user 32.8 s, sys: 152 ms, total: 32.9 s
# Wall time: 578 ms

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_threshold_sweep_mult(
    dataset=data_val_copy,
    dataset2=data_val2_copy,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_mult(
    dataset=data_test_copy, 
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.3737
# AUC: 0.5296
# Balanced accuracy: 0.5633
# Accuracy: 0.5667
# Independence ( |ΔP(Y_pred = 1)| ): 0.1701
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0839
# Sufficiency ( |ΔPPV| ) : 0.0213
# CPU times: user 2.42 s, sys: 23.6 ms, total: 2.44 s
# Wall time: 164 ms

# %%
display(Markdown("**Test set results**"))
utils.print_metrics(metrics_best_thresh_test[model_name+fairness_method])
# Out:
# **Test set results**
# Threshold corresponding to *best balanced accuracy*: 0.3737
# AUC: 0.5230
# Balanced accuracy: 0.5375
# Accuracy: 0.5533
# Independence ( |ΔP(Y_pred = 1)| ): 0.2292
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0328
# Sufficiency ( |ΔPPV| ) : 0.0565

# %% [markdown]
# ## Técnicas de preprocesado

# %% [markdown]
# ### Reponderación

# %%
# %%time 

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos el pre-procesado al conjunto train
# Inicializamos la clase de pre-procesado 
PreProcessor = Reweighing(
    unprivileged_groups=unprivileged_groups,
    privileged_groups=privileged_groups, 
)
# Pre-procesamos (modifica los datos)
PreProcessor.fit_transform(data_train_copy)
data_train_REW = PreProcessor.transform(data_train_copy)
data_val_REW = PreProcessor.transform(data_val_copy)
data_test_REW = PreProcessor.transform(data_test_copy)
# Out:
# CPU times: user 14.8 ms, sys: 667 µs, total: 15.5 ms
# Wall time: 14 ms

# %% [markdown]
# De aquí en adelante, se aplica el modelo de preferencia de manera estándar

# %% [markdown]
# ### Eliminador de impacto dispar

# %%
# %%time 

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Parámetros del modelo
nivel_reparacion = 0.5 # un valor 0 inidica ausencia de reparación (datos se mantienen igual) 
                       # un valor 1 indica reparación completa (se puede perder nivel predictivo).
                       # Se puede establecer cualquier valor entre 0 y 1.

# Hacemos el pre-procesado al conjunto train
# Inicializamos la clase de pre-procesado 
PreProcessor = DisparateImpactRemover(
    repair_level=nivel_reparacion,
    sensitive_attribute=sensitive_attribute
)
# Pre-procesamos (modifica los datos)
PreProcessor.fit_transform(data_train_copy)
data_train_DIR = PreProcessor.fit_transform(data_train_copy)
data_val_DIR = PreProcessor.fit_transform(data_val_copy)
data_test_DIR = PreProcessor.fit_transform(data_test_copy)
# Out:
# CPU times: user 205 ms, sys: 3.32 ms, total: 209 ms
# Wall time: 208 ms

# %% [markdown]
# ## Entrenamiento de técnicas de inprocesado

# %% [markdown]
# Entrenamos ahora los algoritmos de inprocesado para aplicarlos posteriormente cuando hagan falta.

# %% [markdown]
# ### Eliminador de prejuicios por regularización

# %%
# %%time 
# Nombramos al modelo
model_name = 'prejudice_remover'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Parámetros del modelo
η = 50.0 # hyper-parameter de regularización

# Inicializamos el modelo y lo asignamos al diccionario
models[model_name] = PrejudiceRemover(sensitive_attr=sensitive_attribute, eta=η)

# Entrenamos el modelo
models[model_name] = models[model_name].fit(data_train_copy)

models[model_name].scores_train = models[model_name].predict(data_train_copy).scores
models[model_name].scores_val = models[model_name].predict(data_val_copy).scores
models[model_name].scores_test = models[model_name].predict(data_test_copy).scores
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File <timed exec>:15
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/prejudice_remover.py:160, in PrejudiceRemover.fit(self, dataset)
#     156 train_pr = os.path.join(k_path, 'kamfadm-2012ecmlpkdd', 'train_pr.py')
#     157 # changed paths in the calls below to (a) specify path of train_pr,
#     158 # predict_lr RELATIVE to this file, and (b) compute & use absolute path
#     159 #  and (c) replace python3 with python
# --> 160 subprocess.call(['python', train_pr,
#     161                  '-e', str(self.eta),
#     162                  '-i', train_name,
#     163                  '-o', model_name,
#     164                  '--quiet'])
#     165 os.unlink(train_name)
#     167 self.model_name = model_name
#
# File ~/miniconda3/envs/aif360/lib/python3.9/subprocess.py:349, in call(timeout, *popenargs, **kwargs)
#     341 def call(*popenargs, timeout=None, **kwargs):
#     342     """Run command with arguments.  Wait for command to complete or
#     343     timeout, then return the returncode attribute.
#     344
#    (...)
#     347     retcode = call(["ls", "-l"])
#     348     """
# --> 349     with Popen(*popenargs, **kwargs) as p:
#     350         try:
#     351             return p.wait(timeout=timeout)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/subprocess.py:951, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     947         if self.text_mode:
#     948             self.stderr = io.TextIOWrapper(self.stderr,
#     949                     encoding=encoding, errors=errors)
# --> 951     self._execute_child(args, executable, preexec_fn, close_fds,
#     952                         pass_fds, cwd, env,
#     953                         startupinfo, creationflags, shell,
#     954                         p2cread, p2cwrite,
#     955                         c2pread, c2pwrite,
#     956                         errread, errwrite,
#     957                         restore_signals,
#     958                         gid, gids, uid, umask,
#     959                         start_new_session)
#     960 except:
#     961     # Cleanup if the child failed starting.
#     962     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~/miniconda3/envs/aif360/lib/python3.9/subprocess.py:1837, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1835     if errno_num != 0:
#    1836         err_msg = os.strerror(errno_num)
# -> 1837     raise child_exception_type(errno_num, err_msg, err_filename)
#    1838 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'python'

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name] = utils.metrics_threshold_sweep_mult(
    dataset=data_val_copy,
    dataset2=data_val2_copy,
    model=models[model_name],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name] = utils.describe_metrics(metrics_sweep[model_name])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name] = utils.compute_metrics_mult(
    dataset=data_test_copy, 
    dataset2=data_test2_copy,
    model=models[model_name], 
    threshold=metrics_best_thresh_validate[model_name]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name])

# Graficamos el comportamiento del modelo para el rango de umbrales 
f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name])
a.set_title(model_name)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/DEFINITIVO/utils.py:583, in metrics_threshold_sweep_mult(dataset, dataset2, model, thresh_arr)
#     581 try:
#     582     # sklearn classifier
# --> 583     y_val_pred_prob = model.predict_proba(dataset.features)
#     584     pos_ind = np.where(model.classes_ == dataset.favorable_label)[0][0]
#
# AttributeError: 'PrejudiceRemover' object has no attribute 'predict_proba'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:587, in metrics_threshold_sweep_mult(dataset, dataset2, model, thresh_arr)
#     584     pos_ind = np.where(model.classes_ == dataset.favorable_label)[0][0]
#     585 except AttributeError:
#     586     # aif360 inprocessing algorithm
# --> 587     y_val_pred_prob = model.predict(dataset).scores
#     588     pos_ind = 0
#     590 # Remove nans and turn them into score of random prediction (R=0.5)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/prejudice_remover.py:204, in PrejudiceRemover.predict(self, dataset)
#     198 predict_lr = os.path.join(k_path, 'kamfadm-2012ecmlpkdd', 'predict_lr.py')
#     199 # changed paths in the calls below to (a) specify path of train_pr,
#     200 # predict_lr RELATIVE to this file, and (b) compute & use absolute path,
#     201 # and (c) replace python3 with python
#     202 subprocess.call(['python', predict_lr,
#     203                  '-i', test_name,
# --> 204                  '-m', self.model_name,
#     205                  '-o', output_name,
#     206                  '--quiet'])
#     207 os.unlink(test_name)
#     208 m = np.loadtxt(output_name)
#
# AttributeError: 'PrejudiceRemover' object has no attribute 'model_name'

# %% [markdown]
# ### Algoritmo de metafairness

# %%
# %%time 
# Nombramos al modelo
model_name = 'meta_fairness'

# Parámetros del modelo
# hyper-parameter de regularización
τ = 0.8
# métricas fairness a optimizar
quality_constraints = ['sr', 'fdr'] # sr: statistical rate, fdr: false discovery rate

# Optimizamos un modelo nuevo por cada métrica
for quality in quality_constraints:
    
    # Hacemos una copia de los datasets
    data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
    data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)
    
    # nombramos al modelo con su métrica específica
    model_name_quality = '{}_{}'.format(model_name, quality)
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_quality] = MetaFairClassifier(tau=τ, sensitive_attr=sensitive_attribute, type=quality, seed=seed)

    # Entrenamos el modelo
    models[model_name_quality] = models[ model_name_quality ].fit( data_train_copy )
    models[model_name_quality].scores_train = models[model_name_quality].predict(data_train_copy).scores
    models[model_name_quality].scores_val = models[model_name_quality].predict(data_val_copy).scores
    models[model_name_quality].scores_test = models[model_name_quality].predict(data_test_copy).scores
# Out:
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/StatisticalRate.py:36: RuntimeWarning: invalid value encountered in divide
#   prob_y_1 = (prob_1_1 + prob_1_0) / total
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/StatisticalRate.py:37: RuntimeWarning: invalid value encountered in divide
#   prob_z_0 = (prob_m1_0 + prob_1_0) / total
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/StatisticalRate.py:38: RuntimeWarning: invalid value encountered in divide
#   prob_z_1 = (prob_m1_1 + prob_1_1) / total
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:24
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/meta_fair_classifier.py:66, in MetaFairClassifier.fit(self, dataset)
#      59 y_train = np.where(dataset.labels.flatten() == dataset.favorable_label,
#      60                    1, -1)
#      61 x_control_train = np.where(
#      62         np.isin(dataset.protected_attributes[:, sens_idx],
#      63                 dataset.privileged_protected_attributes[sens_idx]),
#      64         1, 0)
# ---> 66 self.model = self.obj.getModel(self.tau, x_train, y_train,
#      67     x_control_train, self.seed)
#      69 return self
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/General.py:99, in General.getModel(self, tau, X, y, sens, random_state)
#      96 samples = dist_x.rvs(size=20)  # TODO: why 20?
#      97 params = self.gradientDescent(dist, a, b, samples, z_1)
# ---> 99 t = self.getValueForX(dist, a, b, params, z_1, X)
#     100 y_pred = np.where(t > 0, 1, -1)
#     102 acc = accuracy_score(y, y_pred)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/StatisticalRate.py:23, in StatisticalRate.getValueForX(self, dist, a, b, params, z_prior, x, return_cs)
#      22 def getValueForX(self, dist, a, b, params, z_prior, x, return_cs=False):
# ---> 23     l_1, l_2 = params
#      24     z_0, z_1 = 1-z_prior, z_prior
#      26     pos = np.ones(len(x))
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
# %%time 

for quality in quality_constraints:
    
    name_suffix = '_{}'.format(quality)
    print(f'Results for {model_name+name_suffix}')

    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name+name_suffix] = utils.metrics_threshold_sweep_mult(
        dataset=data_val_copy,
        dataset2=data_val2_copy,
        model=models[model_name+name_suffix],
        thresh_arr=thresh_sweep
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name+name_suffix] = utils.describe_metrics(metrics_sweep[model_name+name_suffix])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name+name_suffix] = utils.compute_metrics_mult(
        dataset=data_test_copy, 
        dataset2=data_test2_copy,
        model=models[model_name+name_suffix], 
        threshold=metrics_best_thresh_validate[model_name+name_suffix]['best_threshold'])

    utils.print_metrics(metrics_best_thresh_validate[model_name+name_suffix])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name+name_suffix])
    # plt.title(model_name+name_suffix)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+name_suffix])
    a.set_title(model_name+name_suffix)
    f
# Out:
# Results for meta_fairness_sr
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/DEFINITIVO/utils.py:583, in metrics_threshold_sweep_mult(dataset, dataset2, model, thresh_arr)
#     581 try:
#     582     # sklearn classifier
# --> 583     y_val_pred_prob = model.predict_proba(dataset.features)
#     584     pos_ind = np.where(model.classes_ == dataset.favorable_label)[0][0]
#
# AttributeError: 'MetaFairClassifier' object has no attribute 'predict_proba'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:7
#
# File ~/DEFINITIVO/utils.py:587, in metrics_threshold_sweep_mult(dataset, dataset2, model, thresh_arr)
#     584     pos_ind = np.where(model.classes_ == dataset.favorable_label)[0][0]
#     585 except AttributeError:
#     586     # aif360 inprocessing algorithm
# --> 587     y_val_pred_prob = model.predict(dataset).scores
#     588     pos_ind = 0
#     590 # Remove nans and turn them into score of random prediction (R=0.5)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/meta_fair_classifier.py:82, in MetaFairClassifier.predict(self, dataset)
#      71 def predict(self, dataset):
#      72     """Obtain the predictions for the provided dataset using the learned
#      73     classifier model.
#      74
#    (...)
#      80         BinaryLabelDataset: Transformed dataset.
#      81     """
# ---> 82     t = self.model(dataset.features)
#      84     pred_dataset = dataset.copy()
#      85     pred_dataset.labels = (t > 0).astype(int).reshape((-1, 1))
#
# AttributeError: 'MetaFairClassifier' object has no attribute 'model'

# %% [markdown]
# ### Eliminación de prejuicios adversarios

# %%
# %%time

# Nombramos al modelo
model_name = 'NN_adversarial_debiasing'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

sess = tf.Session()

models[model_name] = AdversarialDebiasing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    scope_name = 'debiased_classifier',
    debias=True,
    sess=sess,
    num_epochs=80)

models[model_name].fit(data_train_copy)

models[model_name].scores_train = models[model_name].predict(data_train_copy).scores
models[model_name].scores_val = models[model_name].predict(data_val_copy).scores
models[model_name].scores_test = models[model_name].predict(data_test_copy).scores
# Out:
# 2024-06-19 10:02:01.033598: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# WARNING:tensorflow:From /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1260: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# 2024-06-19 10:02:01.451619: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:388] MLIR V1 optimization pass is not enabled
# epoch 0; iter: 0; batch classifier loss: 0.749041; batch adversarial loss: 0.639364
# epoch 1; iter: 0; batch classifier loss: 0.715875; batch adversarial loss: 0.619905
# epoch 2; iter: 0; batch classifier loss: 0.716384; batch adversarial loss: 0.669102
# epoch 3; iter: 0; batch classifier loss: 0.686084; batch adversarial loss: 0.623451
# epoch 4; iter: 0; batch classifier loss: 0.717599; batch adversarial loss: 0.619547
# epoch 5; iter: 0; batch classifier loss: 0.699333; batch adversarial loss: 0.652642
# epoch 6; iter: 0; batch classifier loss: 0.700948; batch adversarial loss: 0.609697
# epoch 7; iter: 0; batch classifier loss: 0.687184; batch adversarial loss: 0.626084
# epoch 8; iter: 0; batch classifier loss: 0.742980; batch adversarial loss: 0.680710
# epoch 9; iter: 0; batch classifier loss: 0.692420; batch adversarial loss: 0.634461
# epoch 10; iter: 0; batch classifier loss: 0.713012; batch adversarial loss: 0.676387
# epoch 112; iter: 0; batch classifier loss: 0.328831
# epoch 113; iter: 0; batch classifier loss: 0.380188
# epoch 114; iter: 0; batch classifier loss: 0.352316
# epoch 115; iter: 0; batch classifier loss: 0.331291
# epoch 116; iter: 0; batch classifier loss: 0.345043
# epoch 117; iter: 0; batch classifier loss: 0.332538
# epoch 118; iter: 0; batch classifier loss: 0.327534
# epoch 119; iter: 0; batch classifier loss: 0.375112
# epoch 120; iter: 0; batch classifier loss: 0.341311
# epoch 121; iter: 0; batch classifier loss: 0.358061
# epoch 122; iter: 0; batch classifier loss: 0.329360
# epoch 123; iter: 0; batch classifier loss: 0.320889
# epoch 124; iter: 0; batch classifier loss: 0.331056
# CPU times: user 5.14 s, sys: 2.35 s, total: 7.5 s
# Wall time: 2.65 s

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name] = utils.metrics_threshold_sweep_mult(
    dataset=data_val_copy,
    dataset2=data_val2_copy,
    model=models[model_name],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name] = utils.describe_metrics(metrics_sweep[model_name])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name] = utils.compute_metrics_mult(
    dataset=data_test_copy, 
    dataset2=data_test2_copy,
    model=models[model_name], 
    threshold=metrics_best_thresh_validate[model_name]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name])

# Graficamos el comportamiento del modelo para el rango de umbrales 
f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name])
a.set_title(model_name)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.5959
# AUC: 0.5376
# Balanced accuracy: 0.5690
# Accuracy: 0.5667
# Independence ( |ΔP(Y_pred = 1)| ): 0.2208
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0660
# Sufficiency ( |ΔPPV| ) : 0.1386
# CPU times: user 174 ms, sys: 11 ms, total: 185 ms
# Wall time: 165 ms

# %% [markdown]
# ## Preprocesado + Inprocesado

# %% [markdown]
# ### Reponderación + Eliminador de prejuicios

# %%
# Nombre del modelo
model_name = 'reweighting_prejudice_remover'

# Hacemos una copia de los datasets (usando uno de lo métodos de pre-procesado vistos anteriormente)
data_train_copy, data_val_copy, data_test_copy = data_train_REW.copy(deepcopy=True), data_val_REW.copy(deepcopy=True), data_test_REW.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Parámetros del modelo
η = 50.0 # hyper-parameter de regularización

# Inicializamos el modelo y lo asignamos al diccionario
models[model_name] = PrejudiceRemover(sensitive_attr=sensitive_attribute, eta=η)

# Entrenamos el modelo
models[model_name] = models[model_name].fit(data_train_copy)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 15
#      12 models[model_name] = PrejudiceRemover(sensitive_attr=sensitive_attribute, eta=η)
#      14 # Entrenamos el modelo
# ---> 15 models[model_name] = models[model_name].fit(data_train_copy)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/prejudice_remover.py:160, in PrejudiceRemover.fit(self, dataset)
#     156 train_pr = os.path.join(k_path, 'kamfadm-2012ecmlpkdd', 'train_pr.py')
#     157 # changed paths in the calls below to (a) specify path of train_pr,
#     158 # predict_lr RELATIVE to this file, and (b) compute & use absolute path
#     159 #  and (c) replace python3 with python
# --> 160 subprocess.call(['python', train_pr,
#     161                  '-e', str(self.eta),
#     162                  '-i', train_name,
#     163                  '-o', model_name,
#     164                  '--quiet'])
#     165 os.unlink(train_name)
#     167 self.model_name = model_name
#
# File ~/miniconda3/envs/aif360/lib/python3.9/subprocess.py:349, in call(timeout, *popenargs, **kwargs)
#     341 def call(*popenargs, timeout=None, **kwargs):
#     342     """Run command with arguments.  Wait for command to complete or
#     343     timeout, then return the returncode attribute.
#     344
#    (...)
#     347     retcode = call(["ls", "-l"])
#     348     """
# --> 349     with Popen(*popenargs, **kwargs) as p:
#     350         try:
#     351             return p.wait(timeout=timeout)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/subprocess.py:951, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     947         if self.text_mode:
#     948             self.stderr = io.TextIOWrapper(self.stderr,
#     949                     encoding=encoding, errors=errors)
# --> 951     self._execute_child(args, executable, preexec_fn, close_fds,
#     952                         pass_fds, cwd, env,
#     953                         startupinfo, creationflags, shell,
#     954                         p2cread, p2cwrite,
#     955                         c2pread, c2pwrite,
#     956                         errread, errwrite,
#     957                         restore_signals,
#     958                         gid, gids, uid, umask,
#     959                         start_new_session)
#     960 except:
#     961     # Cleanup if the child failed starting.
#     962     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~/miniconda3/envs/aif360/lib/python3.9/subprocess.py:1837, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1835     if errno_num != 0:
#    1836         err_msg = os.strerror(errno_num)
# -> 1837     raise child_exception_type(errno_num, err_msg, err_filename)
#    1838 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'python'

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name] = utils.metrics_threshold_sweep_mult(
    dataset=data_val_copy,
    dataset2=data_val2_copy,
    model=models[model_name],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name] = utils.describe_metrics(metrics_sweep[model_name])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name] = utils.compute_metrics_mult(
    dataset=data_test_copy, 
    dataset2=data_test2_copy,
    model=models[model_name], 
    threshold=metrics_best_thresh_validate[model_name]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name])

# Graficamos el comportamiento del modelo para el rango de umbrales 
f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name])
a.set_title(model_name)
f

# %% [markdown]
# ### Impacto dispar + Eliminador de prejuicios

# %%
# Nombre del modelo
model_name = 'disparate_impact_prejudice_remover'

# Hacemos una copia de los datasets (usando uno de lo métodos de pre-procesado vistos anteriormente)
data_train_copy, data_val_copy, data_test_copy = data_train_DIR.copy(deepcopy=True), data_val_DIR.copy(deepcopy=True), data_test_DIR.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Parámetros del modelo
η = 50.0 # hyper-parameter de regularización

# Inicializamos el modelo y lo asignamos al diccionario
models[model_name] = PrejudiceRemover(sensitive_attr=sensitive_attribute, eta=η)

# Entrenamos el modelo
models[model_name] = models[model_name].fit(data_train_copy)

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name] = utils.metrics_threshold_sweep_mult(
    dataset=data_val_copy,
    dataset2=data_val2_copy,
    model=models[model_name],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name] = utils.describe_metrics(metrics_sweep[model_name])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name] = utils.compute_metrics_mult(
    dataset=data_test_copy, 
    dataset2=data_test2_copy,
    model=models[model_name], 
    threshold=metrics_best_thresh_validate[model_name]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name])

# Graficamos el comportamiento del modelo para el rango de umbrales 
f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name])
a.set_title(model_name)
f

# %% [markdown]
# ### Reponderación + metafairness

# %%
# %%time 
# Nombramos al modelo
model_name = 'reweighing_meta_fairness'

# Parámetros del modelo
# hyper-parameter de regularización
τ = 0.8
# métricas fairness a optimizar
quality_constraints = ['sr', 'fdr'] # sr: statistical rate, fdr: false discovery rate

# Optimizamos un modelo nuevo por cada métrica
for quality in quality_constraints:
    
    # Hacemos una copia de los datasets
    data_train_copy, data_val_copy, data_test_copy = data_train_REW.copy(deepcopy=True), data_val_REW.copy(deepcopy=True), data_test_REW.copy(deepcopy=True)
    data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)
    
    # nombramos al modelo con su métrica específica
    model_name_quality = '{}_{}'.format(model_name, quality)
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_quality] = MetaFairClassifier(tau=τ, sensitive_attr=sensitive_attribute, type=quality, seed=seed)

    # Entrenamos el modelo
    models[model_name_quality] = models[ model_name_quality ].fit( data_train_copy )
# Out:
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/StatisticalRate.py:36: RuntimeWarning: invalid value encountered in divide
#   prob_y_1 = (prob_1_1 + prob_1_0) / total
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/StatisticalRate.py:37: RuntimeWarning: invalid value encountered in divide
#   prob_z_0 = (prob_m1_0 + prob_1_0) / total
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/StatisticalRate.py:38: RuntimeWarning: invalid value encountered in divide
#   prob_z_1 = (prob_m1_1 + prob_1_1) / total
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:24
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/meta_fair_classifier.py:66, in MetaFairClassifier.fit(self, dataset)
#      59 y_train = np.where(dataset.labels.flatten() == dataset.favorable_label,
#      60                    1, -1)
#      61 x_control_train = np.where(
#      62         np.isin(dataset.protected_attributes[:, sens_idx],
#      63                 dataset.privileged_protected_attributes[sens_idx]),
#      64         1, 0)
# ---> 66 self.model = self.obj.getModel(self.tau, x_train, y_train,
#      67     x_control_train, self.seed)
#      69 return self
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/General.py:99, in General.getModel(self, tau, X, y, sens, random_state)
#      96 samples = dist_x.rvs(size=20)  # TODO: why 20?
#      97 params = self.gradientDescent(dist, a, b, samples, z_1)
# ---> 99 t = self.getValueForX(dist, a, b, params, z_1, X)
#     100 y_pred = np.where(t > 0, 1, -1)
#     102 acc = accuracy_score(y, y_pred)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/StatisticalRate.py:23, in StatisticalRate.getValueForX(self, dist, a, b, params, z_prior, x, return_cs)
#      22 def getValueForX(self, dist, a, b, params, z_prior, x, return_cs=False):
# ---> 23     l_1, l_2 = params
#      24     z_0, z_1 = 1-z_prior, z_prior
#      26     pos = np.ones(len(x))
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
# %%time 

for quality in quality_constraints:
    
    name_suffix = '_{}'.format(quality)
    print(f'Results for {model_name+name_suffix}')

    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name+name_suffix] = utils.metrics_threshold_sweep_mult(
        dataset=data_val_copy,
        dataset2=data_val2_copy,
        model=models[model_name+name_suffix],
        thresh_arr=thresh_sweep
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name+name_suffix] = utils.describe_metrics(metrics_sweep[model_name+name_suffix])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name+name_suffix] = utils.compute_metrics_mult(
        dataset=data_test_copy, 
        dataset2=data_test2_copy,
        model=models[model_name+name_suffix], 
        threshold=metrics_best_thresh_validate[model_name+name_suffix]['best_threshold'])

    utils.print_metrics(metrics_best_thresh_validate[model_name+name_suffix])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name+name_suffix])
    # plt.title(model_name+name_suffix)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+name_suffix])
    a.set_title(model_name+name_suffix)
    f
# Out:
# Results for reweighing_meta_fairness_sr
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/DEFINITIVO/utils.py:583, in metrics_threshold_sweep_mult(dataset, dataset2, model, thresh_arr)
#     581 try:
#     582     # sklearn classifier
# --> 583     y_val_pred_prob = model.predict_proba(dataset.features)
#     584     pos_ind = np.where(model.classes_ == dataset.favorable_label)[0][0]
#
# AttributeError: 'MetaFairClassifier' object has no attribute 'predict_proba'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:7
#
# File ~/DEFINITIVO/utils.py:587, in metrics_threshold_sweep_mult(dataset, dataset2, model, thresh_arr)
#     584     pos_ind = np.where(model.classes_ == dataset.favorable_label)[0][0]
#     585 except AttributeError:
#     586     # aif360 inprocessing algorithm
# --> 587     y_val_pred_prob = model.predict(dataset).scores
#     588     pos_ind = 0
#     590 # Remove nans and turn them into score of random prediction (R=0.5)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/meta_fair_classifier.py:82, in MetaFairClassifier.predict(self, dataset)
#      71 def predict(self, dataset):
#      72     """Obtain the predictions for the provided dataset using the learned
#      73     classifier model.
#      74
#    (...)
#      80         BinaryLabelDataset: Transformed dataset.
#      81     """
# ---> 82     t = self.model(dataset.features)
#      84     pred_dataset = dataset.copy()
#      85     pred_dataset.labels = (t > 0).astype(int).reshape((-1, 1))
#
# AttributeError: 'MetaFairClassifier' object has no attribute 'model'

# %% [markdown]
# ### Impacto dispar + metafairness

# %%
# %%time 
# Nombramos al modelo
model_name = 'disparate_impact_meta_fairness'

# Parámetros del modelo
# hyper-parameter de regularización
τ = 0.8
# métricas fairness a optimizar
quality_constraints = ['sr', 'fdr'] # sr: statistical rate, fdr: false discovery rate

# Optimizamos un modelo nuevo por cada métrica
for quality in quality_constraints:
    
    # Hacemos una copia de los datasets
    data_train_copy, data_val_copy, data_test_copy = data_train_DIR.copy(deepcopy=True), data_val_DIR.copy(deepcopy=True), data_test_DIR.copy(deepcopy=True)
    data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)
    
    # nombramos al modelo con su métrica específica
    model_name_quality = '{}_{}'.format(model_name, quality)
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_quality] = MetaFairClassifier(tau=τ, sensitive_attr=sensitive_attribute, type=quality, seed=seed)

    # Entrenamos el modelo
    models[model_name_quality] = models[ model_name_quality ].fit( data_train_copy )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:24
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/meta_fair_classifier.py:66, in MetaFairClassifier.fit(self, dataset)
#      59 y_train = np.where(dataset.labels.flatten() == dataset.favorable_label,
#      60                    1, -1)
#      61 x_control_train = np.where(
#      62         np.isin(dataset.protected_attributes[:, sens_idx],
#      63                 dataset.privileged_protected_attributes[sens_idx]),
#      64         1, 0)
# ---> 66 self.model = self.obj.getModel(self.tau, x_train, y_train,
#      67     x_control_train, self.seed)
#      69 return self
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/General.py:99, in General.getModel(self, tau, X, y, sens, random_state)
#      96 samples = dist_x.rvs(size=20)  # TODO: why 20?
#      97 params = self.gradientDescent(dist, a, b, samples, z_1)
# ---> 99 t = self.getValueForX(dist, a, b, params, z_1, X)
#     100 y_pred = np.where(t > 0, 1, -1)
#     102 acc = accuracy_score(y, y_pred)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/StatisticalRate.py:23, in StatisticalRate.getValueForX(self, dist, a, b, params, z_prior, x, return_cs)
#      22 def getValueForX(self, dist, a, b, params, z_prior, x, return_cs=False):
# ---> 23     l_1, l_2 = params
#      24     z_0, z_1 = 1-z_prior, z_prior
#      26     pos = np.ones(len(x))
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
# %%time 

for quality in quality_constraints:
    
    name_suffix = '_{}'.format(quality)
    print(f'Results for {model_name+name_suffix}')

    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name+name_suffix] = utils.metrics_threshold_sweep_mult(
        dataset=data_val_copy,
        dataset2=data_val2_copy,
        model=models[model_name+name_suffix],
        thresh_arr=thresh_sweep
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name+name_suffix] = utils.describe_metrics(metrics_sweep[model_name+name_suffix])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name+name_suffix] = utils.compute_metrics_mult(
        dataset=data_test_copy, 
        dataset2=data_test2_copy,
        model=models[model_name+name_suffix], 
        threshold=metrics_best_thresh_validate[model_name+name_suffix]['best_threshold'])

    utils.print_metrics(metrics_best_thresh_validate[model_name+name_suffix])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name+name_suffix])
    # plt.title(model_name+name_suffix)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+name_suffix])
    a.set_title(model_name+name_suffix)
    f
# Out:
# Results for disparate_impact_meta_fairness_sr
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/DEFINITIVO/utils.py:583, in metrics_threshold_sweep_mult(dataset, dataset2, model, thresh_arr)
#     581 try:
#     582     # sklearn classifier
# --> 583     y_val_pred_prob = model.predict_proba(dataset.features)
#     584     pos_ind = np.where(model.classes_ == dataset.favorable_label)[0][0]
#
# AttributeError: 'MetaFairClassifier' object has no attribute 'predict_proba'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:7
#
# File ~/DEFINITIVO/utils.py:587, in metrics_threshold_sweep_mult(dataset, dataset2, model, thresh_arr)
#     584     pos_ind = np.where(model.classes_ == dataset.favorable_label)[0][0]
#     585 except AttributeError:
#     586     # aif360 inprocessing algorithm
# --> 587     y_val_pred_prob = model.predict(dataset).scores
#     588     pos_ind = 0
#     590 # Remove nans and turn them into score of random prediction (R=0.5)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/meta_fair_classifier.py:82, in MetaFairClassifier.predict(self, dataset)
#      71 def predict(self, dataset):
#      72     """Obtain the predictions for the provided dataset using the learned
#      73     classifier model.
#      74
#    (...)
#      80         BinaryLabelDataset: Transformed dataset.
#      81     """
# ---> 82     t = self.model(dataset.features)
#      84     pred_dataset = dataset.copy()
#      85     pred_dataset.labels = (t > 0).astype(int).reshape((-1, 1))
#
# AttributeError: 'MetaFairClassifier' object has no attribute 'model'

# %% [markdown]
# ### Reponderación + prejuicios adversarios

# %%
# %%time

# Nombramos al modelo
model_name = 'reweighing_NN_adversarial_debiasing'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train_REW.copy(deepcopy=True), data_val_REW.copy(deepcopy=True), data_test_REW.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

sess = tf.Session()

models[model_name] = AdversarialDebiasing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    scope_name = 'debiased_classifier',
    debias=True,
    sess=sess,
    num_epochs=80)

models[model_name].fit(data_train_copy)
# Out:
# epoch 0; iter: 0; batch classifier loss: 0.715623; batch adversarial loss: 0.770134
# epoch 1; iter: 0; batch classifier loss: 0.718078; batch adversarial loss: 0.845650
# epoch 2; iter: 0; batch classifier loss: 0.703984; batch adversarial loss: 0.791471
# epoch 3; iter: 0; batch classifier loss: 0.721734; batch adversarial loss: 0.872058
# epoch 4; iter: 0; batch classifier loss: 0.719997; batch adversarial loss: 0.848077
# epoch 5; iter: 0; batch classifier loss: 0.732676; batch adversarial loss: 0.855093
# epoch 6; iter: 0; batch classifier loss: 0.654529; batch adversarial loss: 0.791269
# epoch 7; iter: 0; batch classifier loss: 0.717592; batch adversarial loss: 0.860092
# epoch 8; iter: 0; batch classifier loss: 0.725713; batch adversarial loss: 0.877899
# epoch 9; iter: 0; batch classifier loss: 0.717247; batch adversarial loss: 0.845587
# epoch 10; iter: 0; batch classifier loss: 0.642822; batch adversarial loss: 0.826816
# epoch 11; iter: 0; batch classifier loss: 0.688717; batch adversarial loss: 0.841249
# epoch 12; iter: 0; batch classifier loss: 0.652707; batch adversarial loss: 0.811385
Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train_REW.copy(deepcopy=True), data_val_REW.copy(deepcopy=True), data_test_REW.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Regresión logística
model_name = 'reweighin_logistic_regression'

# Parámetros del modelo
fit_params = {'logisticregression__sample_weight': data_train_copy.instance_weights}

# Asignamos el modelo al diccionario
models[model_name+fairness_method] = make_pipeline(
            #StandardScaler(),
            LogisticRegression(solver='liblinear', random_state=seed))

# Entrenamos el modelo
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy.features, data_train_copy.labels.ravel(), **fit_params)

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_threshold_sweep_mult(
    dataset=data_val_copy,
    dataset2=data_val2_copy,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_mult(
    dataset=data_test_copy, 
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.5555
# AUC: 0.4764
# Balanced accuracy: 0.5199
# Accuracy: 0.5133
# Independence ( |ΔP(Y_pred = 1)| ): 0.0416
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1002
# Sufficiency ( |ΔPPV| ) : 0.1000

# %%
# %%time 

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train_REW.copy(deepcopy=True), data_val_REW.copy(deepcopy=True), data_test_REW.copy(deepcopy=True)

# Nombramos al modelo
model_name = 'reweighin_xgb_classifier'

# Parámetros del modelo
fit_params = {'eval_metric': 'error', 'eta':0.1, 'max_depth':6, 'subsample':0.8}

# Asignamos el modelo al diccionario
models[model_name+fairness_method] = XGBClassifier(**fit_params)

# Entrenamos el modelo
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy.features, data_train_copy.labels.ravel())

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_threshold_sweep_mult(
    dataset=data_val_copy,
    dataset2=data_val2_copy,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_mult(
    dataset=data_test_copy, 
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.3737
# AUC: 0.5296
# Balanced accuracy: 0.5633
# Accuracy: 0.5667
# Independence ( |ΔP(Y_pred = 1)| ): 0.1701
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0839
# Sufficiency ( |ΔPPV| ) : 0.0213
# CPU times: user 32.1 s, sys: 194 ms, total: 32.3 s
# Wall time: 646 ms

# %% [markdown]
# #### Disparate impact

# %%
# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train_DIR.copy(deepcopy=True), data_val_DIR.copy(deepcopy=True), data_test_DIR.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Regresión logística
model_name = 'disparate_impact_logistic_regression'

# Parámetros del modelo
fit_params = {'logisticregression__sample_weight': data_train_copy.instance_weights}

# Asignamos el modelo al diccionario
models[model_name+fairness_method] = make_pipeline(
            #StandardScaler(),
            LogisticRegression(solver='liblinear', random_state=seed))

# Entrenamos el modelo
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy.features, data_train_copy.labels.ravel(), **fit_params)

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_threshold_sweep_mult(
    dataset=data_val_copy,
    dataset2=data_val2_copy,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_mult(
    dataset=data_test_copy, 
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.3737
# AUC: 0.5581
# Balanced accuracy: 0.5857
# Accuracy: 0.5933
# Independence ( |ΔP(Y_pred = 1)| ): 0.3222
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1165
# Sufficiency ( |ΔPPV| ) : 0.0078

# %%
# %%time 

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train_DIR.copy(deepcopy=True), data_val_DIR.copy(deepcopy=True), data_test_DIR.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Nombramos al modelo
model_name = 'disparate_impact_xgb_classifier'

# Parámetros del modelo
fit_params = {'eval_metric': 'error', 'eta':0.1, 'max_depth':6, 'subsample':0.8}

# Asignamos el modelo al diccionario
models[model_name+fairness_method] = XGBClassifier(**fit_params)

# Entrenamos el modelo
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy.features, data_train_copy.labels.ravel())

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_threshold_sweep_mult(
    dataset=data_val_copy,
    dataset2=data_val2_copy,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_mult(
    dataset=data_test_copy, 
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.3737
# AUC: 0.5296
# Balanced accuracy: 0.5633
# Accuracy: 0.5667
# Independence ( |ΔP(Y_pred = 1)| ): 0.1701
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0839
# Sufficiency ( |ΔPPV| ) : 0.0213
# CPU times: user 33.3 s, sys: 153 ms, total: 33.5 s
# Wall time: 668 ms

# %%
#Anotamos los nombres de los modelos
model_names = ['reweighin_logistic_regression', 'reweighin_xgb_classifier', 'disparate_impact_logistic_regression', 'disparate_impact_xgb_classifier']

# %% [markdown]
# ### Aplicación de técnicas de postprocesado

# %% [markdown]
# #### Reponderación + Clasificación de rechazo de opción

# %%
# %%time 

# Nombramos al modelo
fairness_method = '_reject_option'

# Nombre del modelo al que le aplicaremos post-processing
model_name = 'reweighin_logistic_regression'

# métricas fair a optimizar
fair_metrics = {'spd': "Statistical parity difference", 'aod': "Average odds difference", 'eod': "Equal opportunity difference"}

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])

# Optimizamos un modelo nuevo por cada métrica
for key_metric in fair_metrics:
    
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    models[model_name_metric] = RejectOptionClassification(
        unprivileged_groups=unprivileged_groups, 
        privileged_groups=privileged_groups, 
        metric_name=fair_metrics[key_metric],
        metric_lb=-0.01, metric_ub=0.01)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 10.5 s, sys: 3.31 s, total: 13.8 s
# Wall time: 9.84 s

# %%
display(Markdown("**Validation set results for logistic regression**"))
for key_metric in fair_metrics:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_val_copy, 
        dataset_preds=data_val_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
    
    print(model_name_metric)
    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')
    
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy, 
        dataset_preds=data_test_preds, 
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        required_threshold=False)
# Out:
# **Validation set results for logistic regression**
# reweighin_logistic_regression_reject_option_spd
# Threshold corresponding to *best balanced accuracy*: 0.5346
# AUC: 0.4764
# Balanced accuracy: 0.5322
# Accuracy: 0.5267
# Independence ( |ΔP(Y_pred = 1)| ): 0.0009
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0937
# Sufficiency ( |ΔPPV| ) : 0.0938
#
#
# reweighin_logistic_regression_reject_option_aod
# Threshold corresponding to *best balanced accuracy*: 0.5346
# AUC: 0.4764
# Balanced accuracy: 0.5120
# Accuracy: 0.5067
# Independence ( |ΔP(Y_pred = 1)| ): 0.0772
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1091
# Sufficiency ( |ΔPPV| ) : 0.0429
#
#
# reweighin_logistic_regression_reject_option_eod
# Threshold corresponding to *best balanced accuracy*: 0.4951
# AUC: 0.4764
# Balanced accuracy: 0.4742
# Accuracy: 0.4733
# Independence ( |ΔP(Y_pred = 1)| ): 0.0627
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0156
# Sufficiency ( |ΔPPV| ) : 0.2177

# %%
# %%time 

# Nombramos al modelo
fairness_method = '_reject_option'

# Nombre del modelo al que le aplicaremos post-processing
model_name = 'reweighin_xgb_classifier'

# métricas fair a optimizar
fair_metrics = {'spd': "Statistical parity difference", 'aod': "Average odds difference", 'eod': "Equal opportunity difference"}

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])

# Optimizamos un modelo nuevo por cada métrica
for key_metric in fair_metrics:
    
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    models[model_name_metric] = RejectOptionClassification(
        unprivileged_groups=unprivileged_groups, 
        privileged_groups=privileged_groups, 
        metric_name=fair_metrics[key_metric],
        metric_lb=-0.01, metric_ub=0.01)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 11.1 s, sys: 153 ms, total: 11.3 s
# Wall time: 9.65 s

# %%
display(Markdown("**Validation set results for xgb classifier**"))
for key_metric in fair_metrics:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_val_copy, 
        dataset_preds=data_val_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
    
    print(model_name_metric)
    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')
    
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy, 
        dataset_preds=data_test_preds, 
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        required_threshold=False)
# Out:
# **Validation set results for xgb classifier**
# reweighin_xgb_classifier_reject_option_spd
# Threshold corresponding to *best balanced accuracy*: 0.1684
# AUC: 0.5296
# Balanced accuracy: 0.5039
# Accuracy: 0.5133
# Independence ( |ΔP(Y_pred = 1)| ): 0.1002
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1330
# Sufficiency ( |ΔPPV| ) : 0.3125
#
#
# reweighin_xgb_classifier_reject_option_aod
# Threshold corresponding to *best balanced accuracy*: 0.2080
# AUC: 0.5296
# Balanced accuracy: 0.5252
# Accuracy: 0.5333
# Independence ( |ΔP(Y_pred = 1)| ): 0.2710
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1118
# Sufficiency ( |ΔPPV| ) : 0.3137
#
#
# reweighin_xgb_classifier_reject_option_eod
# Threshold corresponding to *best balanced accuracy*: 0.2080
# AUC: 0.5296
# Balanced accuracy: 0.5252
# Accuracy: 0.5333
# Independence ( |ΔP(Y_pred = 1)| ): 0.2710
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1118
# Sufficiency ( |ΔPPV| ) : 0.3137

# %% [markdown]
# #### Impacto dispar + Rechazo de opción

# %%
# %%time 

# Nombramos al modelo
fairness_method = '_reject_option'

# Nombre del modelo al que le aplicaremos post-processing
model_name = 'disparate_impact_logistic_regression'

# métricas fair a optimizar
fair_metrics = {'spd': "Statistical parity difference", 'aod': "Average odds difference", 'eod': "Equal opportunity difference"}

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])

# Optimizamos un modelo nuevo por cada métrica
for key_metric in fair_metrics:
    
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    models[model_name_metric] = RejectOptionClassification(
        unprivileged_groups=unprivileged_groups, 
        privileged_groups=privileged_groups, 
        metric_name=fair_metrics[key_metric],
        metric_lb=-0.01, metric_ub=0.01)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 9.94 s, sys: 3.42 s, total: 13.4 s
# Wall time: 9.32 s

# %%
display(Markdown("**Validation set results for logistic regression**"))
for key_metric in fair_metrics:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_val_copy, 
        dataset_preds=data_val_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
    
    print(model_name_metric)
    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')
    
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy, 
        dataset_preds=data_test_preds, 
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        required_threshold=False)
# Out:
# **Validation set results for logistic regression**
# disparate_impact_logistic_regression_reject_option_spd
# Threshold corresponding to *best balanced accuracy*: 0.4852
# AUC: 0.5581
# Balanced accuracy: 0.5257
# Accuracy: 0.5200
# Independence ( |ΔP(Y_pred = 1)| ): 0.0253
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1310
# Sufficiency ( |ΔPPV| ) : 0.0170
#
#
# disparate_impact_logistic_regression_reject_option_aod
# Threshold corresponding to *best balanced accuracy*: 0.4654
# AUC: 0.5581
# Balanced accuracy: 0.4965
# Accuracy: 0.4933
# Independence ( |ΔP(Y_pred = 1)| ): 0.0195
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1446
# Sufficiency ( |ΔPPV| ) : 0.0571
#
#
# disparate_impact_logistic_regression_reject_option_eod
# Threshold corresponding to *best balanced accuracy*: 0.4852
# AUC: 0.5581
# Balanced accuracy: 0.5189
# Accuracy: 0.5133
# Independence ( |ΔP(Y_pred = 1)| ): 0.0680
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0982
# Sufficiency ( |ΔPPV| ) : 0.0588

# %%
# %%time 

# Nombramos al modelo
fairness_method = '_reject_option'

# Nombre del modelo al que le aplicaremos post-processing
model_name = 'disparate_impact_xgb_classifier'

# métricas fair a optimizar
fair_metrics = {'spd': "Statistical parity difference", 'aod': "Average odds difference", 'eod': "Equal opportunity difference"}

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])

# Optimizamos un modelo nuevo por cada métrica
for key_metric in fair_metrics:
    
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    models[model_name_metric] = RejectOptionClassification(
        unprivileged_groups=unprivileged_groups, 
        privileged_groups=privileged_groups, 
        metric_name=fair_metrics[key_metric],
        metric_lb=-0.01, metric_ub=0.01)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 10.8 s, sys: 196 ms, total: 11 s
# Wall time: 9.51 s

# %%
display(Markdown("**Validation set results for xgb classifier**"))
for key_metric in fair_metrics:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_val_copy, 
        dataset_preds=data_val_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
    
    print(model_name_metric)
    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')
    
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy, 
        dataset_preds=data_test_preds, 
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        required_threshold=False)
# Out:
# **Validation set results for xgb classifier**
# disparate_impact_xgb_classifier_reject_option_spd
# Threshold corresponding to *best balanced accuracy*: 0.1684
# AUC: 0.5296
# Balanced accuracy: 0.5039
# Accuracy: 0.5133
# Independence ( |ΔP(Y_pred = 1)| ): 0.1002
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1330
# Sufficiency ( |ΔPPV| ) : 0.3125
#
#
# disparate_impact_xgb_classifier_reject_option_aod
# Threshold corresponding to *best balanced accuracy*: 0.2080
# AUC: 0.5296
# Balanced accuracy: 0.5252
# Accuracy: 0.5333
# Independence ( |ΔP(Y_pred = 1)| ): 0.2710
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1118
# Sufficiency ( |ΔPPV| ) : 0.3137
#
#
# disparate_impact_xgb_classifier_reject_option_eod
# Threshold corresponding to *best balanced accuracy*: 0.2080
# AUC: 0.5296
# Balanced accuracy: 0.5252
# Accuracy: 0.5333
# Independence ( |ΔP(Y_pred = 1)| ): 0.2710
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1118
# Sufficiency ( |ΔPPV| ) : 0.3137

# %% [markdown]
# #### Reponderación y impacto dispar + Escalado de Platt por grupos

# %%
# %%time
fairness_method = '_platt_scaling'
model_names = model_names
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy = True), data_val.copy(deepcopy = True), data_test.copy(deepcopy = True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

for model_name in model_names:
    # Hacemos una copia de las predicciones del modelo de referencia
    model_thresh = metrics_best_thresh_validate[model_name]['best_threshold']
    data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name], class_thresh = model_thresh)
    data_val_preds_m = utils.update_dataset_from_model2(data_val, data_val2_copy, models[model_name], class_thresh = model_thresh)
    ## Plat Scaling:
    #1. dividir el validation data usando los groups sensibles
    data_val_preds_priv, data_val_preds_unpriv, priv_indices, unpriv_indices = utils.split_dataset_on_sensitive_attribute(
        dataset = data_val_preds, privileged_group_label = list((privileged_groups[0].values()))[0])
    #2. copia el validation data para guardar los scores
    data_val_preds2_m = data_val_preds_m.copy(deepcopy = True)
    data_val_preds2 = data_val_preds.copy(deepcopy = True)
    #3. hacer un modelo para cada grupo
    sensitive_groups_data = {'priv': [data_val_preds_priv, priv_indices],
                             'unpriv': [data_val_preds_unpriv, unpriv_indices]}

    for group, data_group_list in sensitive_groups_data.items():

        # nombramos al modelo con su grupo específico
        model_name_group = '{}_{}_{}'.format(model_name, fairness_method, group)

        # Inicializamos el modelo y lo asignamos al diccionario
        models[model_name_group] = LogisticRegression()

        # Realizamos el modelo usando datos para cada grupo en el validation data
        models[ model_name_group ] = models[model_name_group].fit(data_group_list[0].scores,   # data_group_list[0] -> data_val_preds_priv or data_val_preds_unpriv
                                                                  data_val_copy.subset(data_group_list[1]).labels.ravel()) # data_group_list[1] -> priv_indices or unpriv_indices
        # haz predicciones de probabilidad con el modelo de cada groupo y guardar lo en data_val_preds2
        # las predicciones de probabilidad son los platt scores
        scores_group = models[model_name_group].predict_proba(data_group_list[0].scores)
        pos_ind_group = np.where(models[model_name_group].classes_ == data_group_list[0].favorable_label)[0][0]
        data_val_preds2.scores[data_group_list[1]] = scores_group[:, pos_ind_group].reshape(-1,1)
        data_val_preds2_m.scores[data_group_list[1]] = scores_group[:, pos_ind_group].reshape(-1,1)
        
        # Evaluamos a los modelos para el rango de umbrales
    thresh_sweep_platt = np.linspace(np.min(data_val_preds2.scores.ravel()),
                                     np.max(data_val_preds2.scores.ravel()),
                                     50)

    metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep_from_scores_mult(
            dataset_true = data_val_copy,
            dataset2 =data_val2_copy,
            dataset_preds = data_val_preds2_m,
            thresh_arr = thresh_sweep_platt
        )

    # Evaluamos las métricas para el mejor umbral y las guardamos
    metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics( metrics_sweep[model_name+fairness_method] )

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    print('\nValidation set results for {}'.format(model_name))
    utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
    # utils.plot_fairness_and_accuracy( metrics_sweep[model_name+fairness_method] )
    # plt.title( model_name+fairness_method )
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
    a.set_title(model_name+fairness_method )
    f
# Out:
# Validation set results for reweighin_logistic_regression
# Threshold corresponding to *best balanced accuracy*: 0.5582
# AUC: 0.6250
# Balanced accuracy: 0.6009
# Accuracy: 0.6067
# Independence ( |ΔP(Y_pred = 1)| ): 0.4670
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1071
# Sufficiency ( |ΔPPV| ) : 0.0128
#
# Validation set results for reweighin_xgb_classifier
# Threshold corresponding to *best balanced accuracy*: 0.5644
# AUC: 0.6239
# Balanced accuracy: 0.6192
# Accuracy: 0.6200
# Independence ( |ΔP(Y_pred = 1)| ): 0.3620
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0327
# Sufficiency ( |ΔPPV| ) : 0.0000
#
# Validation set results for disparate_impact_logistic_regression
# Threshold corresponding to *best balanced accuracy*: 0.5701
# AUC: 0.6248
# Balanced accuracy: 0.6099
# Accuracy: 0.6133
# Independence ( |ΔP(Y_pred = 1)| ): 0.4570
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0461
# Sufficiency ( |ΔPPV| ) : 0.0089
#
# Validation set results for disparate_impact_xgb_classifier
# Threshold corresponding to *best balanced accuracy*: 0.5644
# AUC: 0.6239
# Balanced accuracy: 0.6192
# Accuracy: 0.6200
# Independence ( |ΔP(Y_pred = 1)| ): 0.3620
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0327
# Sufficiency ( |ΔPPV| ) : 0.0000
# CPU times: user 7.19 s, sys: 498 ms, total: 7.68 s
# Wall time: 532 ms

# %%
# usa el optimal cutoff para predecir usando el test dato

for model_name in model_names:
    model_thresh = metrics_best_thresh_validate[model_name]['best_threshold']
    data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name], class_thresh = model_thresh)
    data_test_preds_m = utils.update_dataset_from_model2(data_test_copy, data_test2_copy, models[model_name], class_thresh = model_thresh)
    
    # 1. dividir el validation data usando los groups sensibles
    data_test_preds_priv, data_test_preds_unpriv, priv_indices, unpriv_indices = utils.split_dataset_on_sensitive_attribute(dataset = data_test_preds,
                                                                                                                            privileged_group_label = list((privileged_groups[0].values()))[0])
    # 2. copia el test data para guardar los platt scores
    data_test_preds2 = data_test_preds.copy(deepcopy = True)
    data_test_preds2_m = data_test_preds_m.copy(deepcopy = True)
    
    # 3. predecir con el modelo de cada grupo
    sensitive_groups_data_test = {'priv': [data_test_preds_priv, priv_indices],
                                  'unpriv': [data_test_preds_unpriv, unpriv_indices]}

    for group, data_group_list in sensitive_groups_data_test.items():    
        # nombramos al modelo con su grupo específico
        model_name_group = '{}_{}_{}'.format(model_name, fairness_method, group)

        # haz predicciones de probabilidad con el modelo de cada groupo y guardar lo en data_val_preds2
        # las predicciones de probabilidad son los platt scores
        scores_group = models[model_name_group].predict_proba(data_group_list[0].scores)
        pos_ind_group = np.where(models[model_name_group].classes_ == data_group_list[0].favorable_label)[0][0]
        data_test_preds2.scores[data_group_list[1]] = scores_group[:, pos_ind_group].reshape(-1,1)

    data_test_preds2_m = data_test2_copy.copy(deepcopy = True)
    data_test_preds2_m.scores = data_test_preds2.scores
    
    metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_from_scores_mult(dataset_true = data_test_copy,
                                                                                             dataset_pred = data_test_preds2_m,
                                                                                             dataset2=data_test2_copy,
                                                                                             threshold = metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

# %% [markdown]
# #### Reponderación + Procesador de probabilidades igualadas

# %% [markdown]
# ##### Usando labels

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'reweighin_logistic_regression'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:24
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:144, in EqOddsPostprocessing.fit(self, dataset_true, dataset_pred)
#     139 oflip = np.ravel(
#     140     dataset_pred.labels[cond_vec_unpriv] == dataset_pred.unfavorable_label)
#     142 y_true = dataset_true.labels.ravel()
# --> 144 sm_tn = np.logical_and(sflip,
#     145     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     146     dtype=np.float64)
#     147 sm_fn = np.logical_and(sflip,
#     148     y_true[cond_vec_priv] == dataset_true.favorable_label,
#     149     dtype=np.float64)
#     150 sm_fp = np.logical_and(sconst,
#     151     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     152     dtype=np.float64)
#
# TypeError: No loop matching the specified signature and casting was found for ufunc logical_and

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing_mult(
    dataset_true=data_test_copy,
    dataset2=data_test2_copy,
    dataset_preds=data_test_preds,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'reweighin_xgb_classifier'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:24
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:144, in EqOddsPostprocessing.fit(self, dataset_true, dataset_pred)
#     139 oflip = np.ravel(
#     140     dataset_pred.labels[cond_vec_unpriv] == dataset_pred.unfavorable_label)
#     142 y_true = dataset_true.labels.ravel()
# --> 144 sm_tn = np.logical_and(sflip,
#     145     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     146     dtype=np.float64)
#     147 sm_fn = np.logical_and(sflip,
#     148     y_true[cond_vec_priv] == dataset_true.favorable_label,
#     149     dtype=np.float64)
#     150 sm_fp = np.logical_and(sconst,
#     151     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     152     dtype=np.float64)
#
# TypeError: No loop matching the specified signature and casting was found for ufunc logical_and

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing_mult(
    dataset_true=data_test_copy,
    dataset_preds=data_test_preds,
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %% [markdown]
# #### Usando scores

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'reweighin_logistic_regression'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 267 ms, sys: 860 ms, total: 1.13 s
# Wall time: 39.8 ms

# %%
display(Markdown("**Validation set results for logistic regression**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy,
        dataset_preds=data_test_preds,
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for logistic regression**
# Results for reweighin_logistic_regression_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.5555
# AUC: 0.4764
# Balanced accuracy: 0.5199
# Accuracy: 0.5133
# Independence ( |ΔP(Y_pred = 1)| ): 0.0130
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0894
# Sufficiency ( |ΔPPV| ) : 0.0714
#
#
# Results for reweighin_logistic_regression_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.5555
# AUC: 0.4764
# Balanced accuracy: 0.5199
# Accuracy: 0.5133
# Independence ( |ΔP(Y_pred = 1)| ): 0.0130
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0894
# Sufficiency ( |ΔPPV| ) : 0.0714
#
#
# Results for reweighin_logistic_regression_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.5555
# AUC: 0.4764
# Balanced accuracy: 0.5199
# Accuracy: 0.5133
# Independence ( |ΔP(Y_pred = 1)| ): 0.0130
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0894
# Sufficiency ( |ΔPPV| ) : 0.0714

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'reweighin_xgb_classifier'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 3.93 s, sys: 101 ms, total: 4.03 s
# Wall time: 77.6 ms

# %%
display(Markdown("**Validation set results for xgb classifier**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy,
        dataset2=data_test2_copy,
        dataset_preds=data_test_preds,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for xgb classifier**
# Results for reweighin_xgb_classifier_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.3737
# AUC: 0.5296
# Balanced accuracy: 0.5770
# Accuracy: 0.5800
# Independence ( |ΔP(Y_pred = 1)| ): 0.5084
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0016
# Sufficiency ( |ΔPPV| ) : 0.1976
#
#
# Results for reweighin_xgb_classifier_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.5353
# AUC: 0.5296
# Balanced accuracy: 0.5608
# Accuracy: 0.5600
# Independence ( |ΔP(Y_pred = 1)| ): 0.4164
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0871
# Sufficiency ( |ΔPPV| ) : 0.0067
#
#
# Results for reweighin_xgb_classifier_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.3737
# AUC: 0.5296
# Balanced accuracy: 0.5907
# Accuracy: 0.5933
# Independence ( |ΔP(Y_pred = 1)| ): 0.5572
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0386
# Sufficiency ( |ΔPPV| ) : 0.0976

# %% [markdown]
# #### Impacto dispar + Procesador de probabilidades igualadas

# %% [markdown]
# ##### Usando labels

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'disparate_impact_logistic_regression'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:24
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:144, in EqOddsPostprocessing.fit(self, dataset_true, dataset_pred)
#     139 oflip = np.ravel(
#     140     dataset_pred.labels[cond_vec_unpriv] == dataset_pred.unfavorable_label)
#     142 y_true = dataset_true.labels.ravel()
# --> 144 sm_tn = np.logical_and(sflip,
#     145     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     146     dtype=np.float64)
#     147 sm_fn = np.logical_and(sflip,
#     148     y_true[cond_vec_priv] == dataset_true.favorable_label,
#     149     dtype=np.float64)
#     150 sm_fp = np.logical_and(sconst,
#     151     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     152     dtype=np.float64)
#
# TypeError: No loop matching the specified signature and casting was found for ufunc logical_and

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing_mult(
    dataset_true=data_test_copy,
    dataset2=data_test2_copy,
    dataset_preds=data_test_preds,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'disparate_impact_xgb_classifier'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:24
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:144, in EqOddsPostprocessing.fit(self, dataset_true, dataset_pred)
#     139 oflip = np.ravel(
#     140     dataset_pred.labels[cond_vec_unpriv] == dataset_pred.unfavorable_label)
#     142 y_true = dataset_true.labels.ravel()
# --> 144 sm_tn = np.logical_and(sflip,
#     145     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     146     dtype=np.float64)
#     147 sm_fn = np.logical_and(sflip,
#     148     y_true[cond_vec_priv] == dataset_true.favorable_label,
#     149     dtype=np.float64)
#     150 sm_fp = np.logical_and(sconst,
#     151     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     152     dtype=np.float64)
#
# TypeError: No loop matching the specified signature and casting was found for ufunc logical_and

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing_mult(
    dataset_true=data_test_copy,
    dataset2=data_test2_copy,
    dataset_preds=data_test_preds,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %% [markdown]
# ##### Usando scores

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'disparate_impact_logistic_regression'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 230 ms, sys: 490 ms, total: 721 ms
# Wall time: 28.4 ms

# %%
display(Markdown("**Validation set results for logistic regression**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy,
        dataset2=data_test2_copy,
        dataset_preds=data_test_preds,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for logistic regression**
# Results for disparate_impact_logistic_regression_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.3333
# AUC: 0.5581
# Balanced accuracy: 0.6012
# Accuracy: 0.6067
# Independence ( |ΔP(Y_pred = 1)| ): 0.9725
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0138
# Sufficiency ( |ΔPPV| ) : 0.5849
#
#
# Results for disparate_impact_logistic_regression_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.5353
# AUC: 0.5581
# Balanced accuracy: 0.5937
# Accuracy: 0.6000
# Independence ( |ΔP(Y_pred = 1)| ): 0.9512
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0172
# Sufficiency ( |ΔPPV| ) : 0.0780
#
#
# Results for disparate_impact_logistic_regression_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.3333
# AUC: 0.5581
# Balanced accuracy: 0.6012
# Accuracy: 0.6067
# Independence ( |ΔP(Y_pred = 1)| ): 0.9725
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0138
# Sufficiency ( |ΔPPV| ) : 0.5849

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'disparate_impact_xgb_classifier'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 3.9 s, sys: 75.5 ms, total: 3.98 s
# Wall time: 77.9 ms

# %%
display(Markdown("**Validation set results for xgb classifier**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy,
        dataset_preds=data_test_preds,
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for xgb classifier**
# Results for disparate_impact_xgb_classifier_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.3737
# AUC: 0.5296
# Balanced accuracy: 0.5770
# Accuracy: 0.5800
# Independence ( |ΔP(Y_pred = 1)| ): 0.5084
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0016
# Sufficiency ( |ΔPPV| ) : 0.1976
#
#
# Results for disparate_impact_xgb_classifier_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.5353
# AUC: 0.5296
# Balanced accuracy: 0.5608
# Accuracy: 0.5600
# Independence ( |ΔP(Y_pred = 1)| ): 0.4164
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0871
# Sufficiency ( |ΔPPV| ) : 0.0067
#
#
# Results for disparate_impact_xgb_classifier_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.3737
# AUC: 0.5296
# Balanced accuracy: 0.5907
# Accuracy: 0.5933
# Independence ( |ΔP(Y_pred = 1)| ): 0.5572
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0386
# Sufficiency ( |ΔPPV| ) : 0.0976

# %% [markdown]
# ## Inprocesado + Postprocesado

# %%
#Anotamos los nombres de los modelos que vamos a usar
model_names = ['prejudice_remover', 'meta_fairness_sr', 'meta_fairness_fdr', 'NN_adversarial_debiasing', 'Basic_NN_no_adversarial_debiasing']

# %% [markdown]
# ### Eliminador de prejuicios + rechazo de opción

# %%
# %%time 

# Nombramos al modelo
fairness_method = '_reject_option'

# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[0]

# métricas fair a optimizar
fair_metrics = {'spd': "Statistical parity difference", 'aod': "Average odds difference", 'eod': "Equal opportunity difference"}

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])

# Optimizamos un modelo nuevo por cada métrica
for key_metric in fair_metrics:
    
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    models[model_name_metric] = RejectOptionClassification(
        unprivileged_groups=unprivileged_groups, 
        privileged_groups=privileged_groups, 
        metric_name=fair_metrics[key_metric],
        metric_lb=-0.01, metric_ub=0.01)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/DEFINITIVO/utils.py:142, in update_dataset_from_model(dataset, model, class_thresh)
#     141 try:
# --> 142     y_pred_prob = model.predict_proba(dataset_pred.features)[:, pos_ind]
#     143 except:
#
# AttributeError: 'PrejudiceRemover' object has no attribute 'predict_proba'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:15
#
# File ~/DEFINITIVO/utils.py:144, in update_dataset_from_model(dataset, model, class_thresh)
#     142     y_pred_prob = model.predict_proba(dataset_pred.features)[:, pos_ind]
#     143 except:
# --> 144     y_pred_prob = model.predict(dataset_pred).scores
#     145 # Obtain predicted labels according to class_threshold
#     146 y_pred = np.zeros_like(dataset_pred.labels)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/prejudice_remover.py:204, in PrejudiceRemover.predict(self, dataset)
#     198 predict_lr = os.path.join(k_path, 'kamfadm-2012ecmlpkdd', 'predict_lr.py')
#     199 # changed paths in the calls below to (a) specify path of train_pr,
#     200 # predict_lr RELATIVE to this file, and (b) compute & use absolute path,
#     201 # and (c) replace python3 with python
#     202 subprocess.call(['python', predict_lr,
#     203                  '-i', test_name,
# --> 204                  '-m', self.model_name,
#     205                  '-o', output_name,
#     206                  '--quiet'])
#     207 os.unlink(test_name)
#     208 m = np.loadtxt(output_name)
#
# AttributeError: 'PrejudiceRemover' object has no attribute 'model_name'

# %%
display(Markdown("**Validation set results for logistic regression**"))
for key_metric in fair_metrics:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_val_copy, 
        dataset_preds=data_val_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
    
    print(model_name_metric)
    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')
    
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy, 
        dataset_preds=data_test_preds, 
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        required_threshold=False)
# Out:
# **Validation set results for logistic regression**
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[68], line 9
#       2 for key_metric in fair_metrics:
#       4     model_name_metric = model_name + fairness_method + '_' + key_metric
#       6     metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing(
#       7         dataset_true=data_val_copy,
#       8         dataset_preds=data_val_preds,
# ----> 9         model=models[model_name_metric],
#      10         required_threshold=False)
#      12     print(model_name_metric)
#      13     utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
#
# KeyError: 'prejudice_remover_reject_option_spd'

# %% [markdown]
# ### Metafairness + rechazo de opción

# %%
# %%time 

# Nombramos al modelo
fairness_method = '_reject_option'

# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[1]

# métricas fair a optimizar
fair_metrics = {'spd': "Statistical parity difference", 'aod': "Average odds difference", 'eod': "Equal opportunity difference"}

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
#data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
#data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
#data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])

# Optimizamos un modelo nuevo por cada métrica
for key_metric in fair_metrics:
    
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    models[model_name_metric] = RejectOptionClassification(
        unprivileged_groups=unprivileged_groups, 
        privileged_groups=privileged_groups, 
        metric_name=fair_metrics[key_metric],
        metric_lb=-0.01, metric_ub=0.01)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 9.99 s, sys: 217 ms, total: 10.2 s
# Wall time: 10.2 s

# %%
display(Markdown("**Validation set results for logistic regression**"))
for key_metric in fair_metrics:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_val_copy, 
        dataset_preds=data_val_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
    
    print(model_name_metric)
    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')
    
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy, 
        dataset_preds=data_test_preds, 
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        required_threshold=False)
# Out:
# **Validation set results for logistic regression**
# meta_fairness_sr_reject_option_spd
# Threshold corresponding to *best balanced accuracy*: 0.1684
# AUC: 0.5296
# Balanced accuracy: 0.5039
# Accuracy: 0.5133
# Independence ( |ΔP(Y_pred = 1)| ): 0.1002
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1330
# Sufficiency ( |ΔPPV| ) : 0.3125
#
#
# meta_fairness_sr_reject_option_aod
# Threshold corresponding to *best balanced accuracy*: 0.2080
# AUC: 0.5296
# Balanced accuracy: 0.5252
# Accuracy: 0.5333
# Independence ( |ΔP(Y_pred = 1)| ): 0.2710
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1118
# Sufficiency ( |ΔPPV| ) : 0.3137
#
#
# meta_fairness_sr_reject_option_eod
# Threshold corresponding to *best balanced accuracy*: 0.2080
# AUC: 0.5296
# Balanced accuracy: 0.5252
# Accuracy: 0.5333
# Independence ( |ΔP(Y_pred = 1)| ): 0.2710
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1118
# Sufficiency ( |ΔPPV| ) : 0.3137

# %% [markdown]
# ### Prejuicios adversarios + rechazo de opción

# %%
# %%time 

# Nombramos al modelo
fairness_method = '_reject_option'

# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[2]

# métricas fair a optimizar
fair_metrics = {'spd': "Statistical parity difference", 'aod': "Average odds difference", 'eod': "Equal opportunity difference"}

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
#data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
#data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
#data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])

# Optimizamos un modelo nuevo por cada métrica
for key_metric in fair_metrics:
    
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    models[model_name_metric] = RejectOptionClassification(
        unprivileged_groups=unprivileged_groups, 
        privileged_groups=privileged_groups, 
        metric_name=fair_metrics[key_metric],
        metric_lb=-0.01, metric_ub=0.01)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 9.62 s, sys: 176 ms, total: 9.79 s
# Wall time: 9.79 s

# %%
display(Markdown("**Validation set results for logistic regression**"))
for key_metric in fair_metrics:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_val_copy, 
        dataset_preds=data_val_preds, 
        dataset2=data_val2_copy,
        model=models[model_name_metric], 
        required_threshold=False)
    
    print(model_name_metric)
    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')
    
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy, 
        dataset2=data_test2_copy,
        dataset_preds=data_test_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
# Out:
# **Validation set results for logistic regression**
# meta_fairness_fdr_reject_option_spd
# Threshold corresponding to *best balanced accuracy*: 0.1684
# AUC: 0.5296
# Balanced accuracy: 0.5402
# Accuracy: 0.5400
# Independence ( |ΔP(Y_pred = 1)| ): 0.1068
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1440
# Sufficiency ( |ΔPPV| ) : 0.0512
#
#
# meta_fairness_fdr_reject_option_aod
# Threshold corresponding to *best balanced accuracy*: 0.2080
# AUC: 0.5296
# Balanced accuracy: 0.5402
# Accuracy: 0.5400
# Independence ( |ΔP(Y_pred = 1)| ): 0.1068
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1440
# Sufficiency ( |ΔPPV| ) : 0.0512
#
#
# meta_fairness_fdr_reject_option_eod
# Threshold corresponding to *best balanced accuracy*: 0.2080
# AUC: 0.5296
# Balanced accuracy: 0.5402
# Accuracy: 0.5400
# Independence ( |ΔP(Y_pred = 1)| ): 0.1068
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1440
# Sufficiency ( |ΔPPV| ) : 0.0512

# %% [markdown]
# ### Red neuronal normal + rechazo de opción

# %%
# %%time 

# Nombramos al modelo
fairness_method = '_reject_option'

# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[3]

# métricas fair a optimizar
fair_metrics = {'spd': "Statistical parity difference", 'aod': "Average odds difference", 'eod': "Equal opportunity difference"}

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
#data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
#data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
#data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])

# Optimizamos un modelo nuevo por cada métrica
for key_metric in fair_metrics:
    
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    models[model_name_metric] = RejectOptionClassification(
        unprivileged_groups=unprivileged_groups, 
        privileged_groups=privileged_groups, 
        metric_name=fair_metrics[key_metric],
        metric_lb=-0.01, metric_ub=0.01)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 9.69 s, sys: 229 ms, total: 9.92 s
# Wall time: 9.92 s

# %%
display(Markdown("**Validation set results for logistic regression**"))
for key_metric in fair_metrics:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_val_copy, 
        dataset_preds=data_val_preds, 
        dataset2=data_val2_copy,
        model=models[model_name_metric], 
        required_threshold=False)
    
    print(model_name_metric)
    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')
    
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy, 
        dataset_preds=data_test_preds, 
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        required_threshold=False)
# Out:
# **Validation set results for logistic regression**
# NN_adversarial_debiasing_reject_option_spd
# Threshold corresponding to *best balanced accuracy*: 0.1684
# AUC: 0.5296
# Balanced accuracy: 0.5402
# Accuracy: 0.5400
# Independence ( |ΔP(Y_pred = 1)| ): 0.1068
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1440
# Sufficiency ( |ΔPPV| ) : 0.0512
#
#
# NN_adversarial_debiasing_reject_option_aod
# Threshold corresponding to *best balanced accuracy*: 0.2080
# AUC: 0.5296
# Balanced accuracy: 0.5402
# Accuracy: 0.5400
# Independence ( |ΔP(Y_pred = 1)| ): 0.1068
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1440
# Sufficiency ( |ΔPPV| ) : 0.0512
#
#
# NN_adversarial_debiasing_reject_option_eod
# Threshold corresponding to *best balanced accuracy*: 0.2080
# AUC: 0.5296
# Balanced accuracy: 0.5402
# Accuracy: 0.5400
# Independence ( |ΔP(Y_pred = 1)| ): 0.1068
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1440
# Sufficiency ( |ΔPPV| ) : 0.0512

# %% [markdown]
# ### Inprocesado + Escalado Platt por grupos

# %%
# %%time
fairness_method = '_platt_scaling'

model_names = ['NN_adversarial_debiasing', 'Basic_NN_no_adversarial_debiasing']
#model_names = ['meta_fairness_fdr', 'meta_fairness_sr', 'NN_adversarial_debiasing', 'Basic_NN_no_adversarial_debiasing']
#model_names = ['prejudice_remover', 'meta_fairness_sr', 'meta_fairness_fdr', 'NN_adversarial_debiasing', 'Basic_NN_no_adversarial_debiasing']
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy = True), data_val.copy(deepcopy = True), data_test.copy(deepcopy = True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

for model_name in model_names:
    # Hacemos una copia de las predicciones del modelo de referencia
    model_thresh = metrics_best_thresh_validate[model_name]['best_threshold']
    data_val_preds = utils.update_dataset_from_scores(data_val_copy, models[model_name].scores_val, model_thresh)
    ## Plat Scaling:
    #1. dividir el validation data usando los groups sensibles
    data_val_preds_priv, data_val_preds_unpriv, priv_indices, unpriv_indices = utils.split_dataset_on_sensitive_attribute(
        dataset = data_val_preds, privileged_group_label = list((privileged_groups[0].values()))[0])
    #2. copia el validation data para guardar los scores
    data_val_preds2 = data_val_preds.copy(deepcopy = True)
    #3. hacer un modelo para cada grupo
    sensitive_groups_data = {'priv': [data_val_preds_priv, priv_indices],
                            'unpriv': [data_val_preds_unpriv, unpriv_indices]}
    
    for group, data_group_list in sensitive_groups_data.items():
    
        # nombramos al modelo con su grupo específico
        model_name_group = '{}_{}_{}'.format(model_name, fairness_method, group)
    
        # Inicializamos el modelo y lo asignamos al diccionario
        models[model_name_group] = LogisticRegression()
    
        # Realizamos el modelo usando datos para cada grupo en el validation data
        models[ model_name_group ] = models[model_name_group].fit(data_group_list[0].scores,   # data_group_list[0] -> data_val_preds_priv or data_val_preds_unpriv
                                                                      data_val_copy.subset(data_group_list[1]).labels.ravel()) # data_group_list[1] -> priv_indices or unpriv_indices
        # haz predicciones de probabilidad con el modelo de cada groupo y guardar lo en data_val_preds2
        # las predicciones de probabilidad son los platt scores
        scores_group = models[model_name_group].predict_proba(data_group_list[0].scores)
        pos_ind_group = np.where(models[model_name_group].classes_ == data_group_list[0].favorable_label)[0][0]
        data_val_preds2.scores[data_group_list[1]] = scores_group[:, pos_ind_group].reshape(-1,1)
            
        # Evaluamos a los modelos para el rango de umbrales
        thresh_sweep_platt = np.linspace(np.min(data_val_preds2.scores.ravel()),
                                         np.max(data_val_preds2.scores.ravel()),
                                         50)
        data_val_preds2_m = data_val2_copy.copy(deepcopy = True)
        data_val_preds2_m.scores = data_val_preds2.scores
        metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep_from_scores_mult(
                dataset_true = data_val_copy,
                dataset2=data_val2_copy,
                dataset_preds = data_val_preds2_m,
                thresh_arr = thresh_sweep_platt
            )
    
        # Evaluamos las métricas para el mejor umbral y las guardamos
        metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics( metrics_sweep[model_name+fairness_method] )
    
        # Graficamos el comportamiento del modelo para el rango de umbrales 
        print('\nValidation set results for {}'.format(model_name))
        utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
        # utils.plot_fairness_and_accuracy( metrics_sweep[model_name+fairness_method] )
        # plt.title( model_name+fairness_method )
        
        f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
        a.set_title(model_name+fairness_method )
        f
# Out:
# Validation set results for NN_adversarial_debiasing
# Threshold corresponding to *best balanced accuracy*: 0.9257
# AUC: 0.4165
# Balanced accuracy: 0.5000
# Accuracy: 0.4867
# Independence ( |ΔP(Y_pred = 1)| ): 0.0000
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0000
# Sufficiency ( |ΔPPV| ) : 0.0000
#
# Validation set results for NN_adversarial_debiasing
# Threshold corresponding to *best balanced accuracy*: 0.3445
# AUC: 0.6099
# Balanced accuracy: 0.5940
# Accuracy: 0.6000
# Independence ( |ΔP(Y_pred = 1)| ): 0.4824
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1250
# Sufficiency ( |ΔPPV| ) : 0.0217
#
# Validation set results for Basic_NN_no_adversarial_debiasing
# Threshold corresponding to *best balanced accuracy*: 0.5145
# AUC: 0.5545
# Balanced accuracy: 0.5728
# Accuracy: 0.5800
# Independence ( |ΔP(Y_pred = 1)| ): 0.4000
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0944
# Sufficiency ( |ΔPPV| ) : 0.0202
#
# Validation set results for Basic_NN_no_adversarial_debiasing
# Threshold corresponding to *best balanced accuracy*: 0.3749
# AUC: 0.6084
# Balanced accuracy: 0.5940
# Accuracy: 0.6000
# Independence ( |ΔP(Y_pred = 1)| ): 0.4824
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1250
# Sufficiency ( |ΔPPV| ) : 0.0217
# CPU times: user 572 ms, sys: 391 ms, total: 963 ms
# Wall time: 386 ms

# %%
# usa el optimal cutoff para predecir usando el test dato

for model_name in model_names:
    model_thresh = metrics_best_thresh_validate[model_name]['best_threshold']
    data_test_preds = utils.update_dataset_from_scores(data_test_copy, models[model_name].scores_test, model_thresh)
    
    # 1. dividir el validation data usando los groups sensibles
    data_test_preds_priv, data_test_preds_unpriv, priv_indices, unpriv_indices = utils.split_dataset_on_sensitive_attribute(dataset = data_test_preds,
                                                                                                                            privileged_group_label = list((privileged_groups[0].values()))[0])
    # 2. copia el test data para guardar los platt scores
    data_test_preds2 = data_test_preds.copy(deepcopy = True)
    
    # 3. predecir con el modelo de cada grupo
    sensitive_groups_data_test = {'priv': [data_test_preds_priv, priv_indices],
                                  'unpriv': [data_test_preds_unpriv, unpriv_indices]}

    for group, data_group_list in sensitive_groups_data_test.items():    
        # nombramos al modelo con su grupo específico
        model_name_group = '{}_{}_{}'.format(model_name, fairness_method, group)

        # haz predicciones de probabilidad con el modelo de cada groupo y guardar lo en data_val_preds2
        # las predicciones de probabilidad son los platt scores
        scores_group = models[model_name_group].predict_proba(data_group_list[0].scores)
        pos_ind_group = np.where(models[model_name_group].classes_ == data_group_list[0].favorable_label)[0][0]
        data_test_preds2.scores[data_group_list[1]] = scores_group[:, pos_ind_group].reshape(-1,1)
    data_test_preds2_m = data_test2_copy.copy(deepcopy=True)
    data_test_preds2_m.scores = data_test2_copy.scores
    metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_from_scores_mult(dataset_true = data_test_copy,
                                                                                             dataset_pred = data_test_preds2,
                                                                                             dataset2=data_test2_copy,
                                                                                             threshold = metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

# %% [markdown]
# #### Eliminador de prejuicios + Procesador de probabilidades igualadas

# %% [markdown]
# ##### Usando labels

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[0]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

thresh_NN_ADV = metrics_best_thresh_validate['NN_adversarial_debiasing']['best_threshold']

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_scores(data_train_copy, models[model_name].scores_train, thresh_NN_ADV)
data_val_preds = utils.update_dataset_from_scores(data_val_copy, models[model_name].scores_val, thresh_NN_ADV)
data_test_preds = utils.update_dataset_from_scores(data_test_copy, models[model_name].scores_test, thresh_NN_ADV)


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:26
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:144, in EqOddsPostprocessing.fit(self, dataset_true, dataset_pred)
#     139 oflip = np.ravel(
#     140     dataset_pred.labels[cond_vec_unpriv] == dataset_pred.unfavorable_label)
#     142 y_true = dataset_true.labels.ravel()
# --> 144 sm_tn = np.logical_and(sflip,
#     145     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     146     dtype=np.float64)
#     147 sm_fn = np.logical_and(sflip,
#     148     y_true[cond_vec_priv] == dataset_true.favorable_label,
#     149     dtype=np.float64)
#     150 sm_fp = np.logical_and(sconst,
#     151     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     152     dtype=np.float64)
#
# TypeError: No loop matching the specified signature and casting was found for ufunc logical_and

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing_mult(
    dataset_true=data_test_copy,
    dataset_preds=data_test_preds,
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %% [markdown]
# #### Usando scores

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[0]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

thresh_no_NN_ADV = metrics_best_thresh_validate['Basic_NN_no_adversarial_debiasing']['best_threshold']

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_scores(data_train_copy, models[model_name].scores_train, thresh_no_NN_ADV)
data_val_preds = utils.update_dataset_from_scores(data_val_copy, models[model_name].scores_val, thresh_no_NN_ADV)
data_test_preds = utils.update_dataset_from_scores(data_test_copy, models[model_name].scores_test, thresh_no_NN_ADV)


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 14.6 ms, sys: 3.69 ms, total: 18.2 ms
# Wall time: 17.4 ms

# %%
display(Markdown("**Validation set results for prejudice remover**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy,
        dataset_preds=data_test_preds,
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for prejudice remover**
# Results for NN_adversarial_debiasing_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.0100
# AUC: 0.4165
# Balanced accuracy: 0.5000
# Accuracy: 0.5133
# Independence ( |ΔP(Y_pred = 1)| ): 0.0000
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0000
# Sufficiency ( |ΔPPV| ) : 0.2365
#
#
# Results for NN_adversarial_debiasing_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.1312
# AUC: 0.4165
# Balanced accuracy: 0.5223
# Accuracy: 0.5333
# Independence ( |ΔP(Y_pred = 1)| ): 0.1193
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0473
# Sufficiency ( |ΔPPV| ) : 0.2627
#
#
# Results for NN_adversarial_debiasing_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.0100
# AUC: 0.4165
# Balanced accuracy: 0.5000
# Accuracy: 0.5133
# Independence ( |ΔP(Y_pred = 1)| ): 0.0000
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0000
# Sufficiency ( |ΔPPV| ) : 0.2365

# %% [markdown]
# #### Metafairness + Procesador de probabilidades igualadas

# %% [markdown]
# ##### Usando labels

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[1]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# 2024-06-19 10:06:25.384977: W tensorflow/c/c_api.cc:305] Operation '{name:'biased_classifier/biased_classifier/classifier_model/b2/Adam_1/Assign' id:264 op device:{requested: '', assigned: ''} def:{{{node biased_classifier/biased_classifier/classifier_model/b2/Adam_1/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](biased_classifier/biased_classifier/classifier_model/b2/Adam_1, biased_classifier/biased_classifier/classifier_model/b2/Adam_1/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:24
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:144, in EqOddsPostprocessing.fit(self, dataset_true, dataset_pred)
#     139 oflip = np.ravel(
#     140     dataset_pred.labels[cond_vec_unpriv] == dataset_pred.unfavorable_label)
#     142 y_true = dataset_true.labels.ravel()
# --> 144 sm_tn = np.logical_and(sflip,
#     145     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     146     dtype=np.float64)
#     147 sm_fn = np.logical_and(sflip,
#     148     y_true[cond_vec_priv] == dataset_true.favorable_label,
#     149     dtype=np.float64)
#     150 sm_fp = np.logical_and(sconst,
#     151     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     152     dtype=np.float64)
#
# TypeError: No loop matching the specified signature and casting was found for ufunc logical_and

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing_mult(
    dataset_true=data_test_copy,
    dataset_preds=data_test_preds,
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %% [markdown]
# #### Usando scores

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[1]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 32.7 ms, sys: 7.27 ms, total: 39.9 ms
# Wall time: 27.8 ms

# %%
display(Markdown("**Validation set results for metafairness**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy,
        dataset_preds=data_test_preds,
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for metafairness**
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.5959
# AUC: 0.5376
# Balanced accuracy: 0.5896
# Accuracy: 0.5867
# Independence ( |ΔP(Y_pred = 1)| ): 0.4070
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0260
# Sufficiency ( |ΔPPV| ) : 0.1364
#
#
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.6161
# AUC: 0.5376
# Balanced accuracy: 0.5527
# Accuracy: 0.5467
# Independence ( |ΔP(Y_pred = 1)| ): 0.1412
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0841
# Sufficiency ( |ΔPPV| ) : 0.3908
#
#
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.5959
# AUC: 0.5376
# Balanced accuracy: 0.5968
# Accuracy: 0.5933
# Independence ( |ΔP(Y_pred = 1)| ): 0.4802
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0247
# Sufficiency ( |ΔPPV| ) : 0.3636

# %% [markdown]
# ##### Usando labels

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[2]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File <timed exec>:4
#
# IndexError: list index out of range

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing_mult(
    dataset_true=data_test_copy,
    dataset_preds=data_test_preds,
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %% [markdown]
# #### Usando scores

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[2]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File <timed exec>:4
#
# IndexError: list index out of range

# %%
display(Markdown("**Validation set results for metafairness**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy,
        dataset_preds=data_test_preds,
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for metafairness**
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.5959
# AUC: 0.5376
# Balanced accuracy: 0.5896
# Accuracy: 0.5867
# Independence ( |ΔP(Y_pred = 1)| ): 0.4070
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0260
# Sufficiency ( |ΔPPV| ) : 0.1364
#
#
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.6161
# AUC: 0.5376
# Balanced accuracy: 0.5527
# Accuracy: 0.5467
# Independence ( |ΔP(Y_pred = 1)| ): 0.1412
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0841
# Sufficiency ( |ΔPPV| ) : 0.3908
#
#
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.5959
# AUC: 0.5376
# Balanced accuracy: 0.5968
# Accuracy: 0.5933
# Independence ( |ΔP(Y_pred = 1)| ): 0.4802
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0247
# Sufficiency ( |ΔPPV| ) : 0.3636

# %% [markdown]
# #### Prejuicios adversarios + Procesador de probabilidades igualadas

# %% [markdown]
# ##### Usando labels

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[3]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

thresh_NN_ADV = metrics_best_thresh_validate['NN_adversarial_debiasing']['best_threshold']

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_scores(data_train_copy, models[model_name].scores_train, thresh_NN_ADV)
data_val_preds = utils.update_dataset_from_scores(data_val_copy, models[model_name].scores_val, thresh_NN_ADV)
data_test_preds = utils.update_dataset_from_scores(data_test_copy, models[model_name].scores_test, thresh_NN_ADV)


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File <timed exec>:4
#
# IndexError: list index out of range

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing_mult(
    dataset_true=data_test_copy,
    dataset_preds=data_test_preds,
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %% [markdown]
# #### Usando scores

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[3]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

thresh_NN_ADV = metrics_best_thresh_validate['NN_adversarial_debiasing']['best_threshold']

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_scores(data_train_copy, models[model_name].scores_train, thresh_NN_ADV)
data_val_preds = utils.update_dataset_from_scores(data_val_copy, models[model_name].scores_val, thresh_NN_ADV)
data_test_preds = utils.update_dataset_from_scores(data_test_copy, models[model_name].scores_test, thresh_NN_ADV)


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File <timed exec>:4
#
# IndexError: list index out of range

# %%
display(Markdown("**Validation set results for adversarial debiasing**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy,
        dataset_preds=data_test_preds,
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for adversarial debiasing**
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.5959
# AUC: 0.5376
# Balanced accuracy: 0.5896
# Accuracy: 0.5867
# Independence ( |ΔP(Y_pred = 1)| ): 0.4070
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0260
# Sufficiency ( |ΔPPV| ) : 0.1364
#
#
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.6161
# AUC: 0.5376
# Balanced accuracy: 0.5527
# Accuracy: 0.5467
# Independence ( |ΔP(Y_pred = 1)| ): 0.1412
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0841
# Sufficiency ( |ΔPPV| ) : 0.3908
#
#
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.5959
# AUC: 0.5376
# Balanced accuracy: 0.5968
# Accuracy: 0.5933
# Independence ( |ΔP(Y_pred = 1)| ): 0.4802
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0247
# Sufficiency ( |ΔPPV| ) : 0.3636

# %% [markdown]
# #### Red neuronal normal + Procesador de probabilidades igualadas

# %% [markdown]
# ##### Usando labels

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[4]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

thresh_no_NN_ADV = metrics_best_thresh_validate['Basic_NN_no_adversarial_debiasing']['best_threshold']

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_scores(data_train_copy, models[model_name].scores_train, thresh_no_NN_ADV)
data_val_preds = utils.update_dataset_from_scores(data_val_copy, models[model_name].scores_val, thresh_no_NN_ADV)
data_test_preds = utils.update_dataset_from_scores(data_test_copy, models[model_name].scores_test, thresh_no_NN_ADV)


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File <timed exec>:4
#
# IndexError: list index out of range

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing_mult(
    dataset_true=data_test_copy,
    dataset_preds=data_test_preds,
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %% [markdown]
# #### Usando scores

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[4]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

thresh_no_NN_ADV = metrics_best_thresh_validate['Basic_NN_no_adversarial_debiasing']['best_threshold']

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_scores(data_train_copy, models[model_name].scores_train, thresh_no_NN_ADV)
data_val_preds = utils.update_dataset_from_scores(data_val_copy, models[model_name].scores_val, thresh_no_NN_ADV)
data_test_preds = utils.update_dataset_from_scores(data_test_copy, models[model_name].scores_test, thresh_no_NN_ADV)


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File <timed exec>:4
#
# IndexError: list index out of range

# %%
display(Markdown("**Validation set results for basic NN**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy,
        dataset_preds=data_test_preds,
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for basic NN**
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.5959
# AUC: 0.5376
# Balanced accuracy: 0.5896
# Accuracy: 0.5867
# Independence ( |ΔP(Y_pred = 1)| ): 0.4070
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0260
# Sufficiency ( |ΔPPV| ) : 0.1364
#
#
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.6161
# AUC: 0.5376
# Balanced accuracy: 0.5527
# Accuracy: 0.5467
# Independence ( |ΔP(Y_pred = 1)| ): 0.1412
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0841
# Sufficiency ( |ΔPPV| ) : 0.3908
#
#
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.5959
# AUC: 0.5376
# Balanced accuracy: 0.5968
# Accuracy: 0.5933
# Independence ( |ΔP(Y_pred = 1)| ): 0.4802
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0247
# Sufficiency ( |ΔPPV| ) : 0.3636

# %% [markdown]
# ## Comparación de modelos
#
# Podemos usar los diccionarios que resumen la calidad de los modelos fair para compararlos todos.

# %% [markdown]
# ### Resultados en validación

# %%
algorithm_performance_summary = pd.DataFrame(metrics_best_thresh_validate).T
algorithm_performance_summary
# Out:
#                                                     best_threshold   bal_acc  \
# logistic_regression                                       0.373673  0.585750
# xgb_classifier                                            0.373673  0.563334
# NN_adversarial_debiasing                                  0.131224  0.522327
# Basic_NN_no_adversarial_debiasing                         0.595918  0.569027
# reweighing_NN_adversarial_debiasing                       0.535306  0.583882
# reweighin_basic_NN_no_adversarial_debiasing               0.616122  0.563601
# disparate_impact_NN_adversarial_debiasing                 0.676735  0.511564
# disparate_impact_basic_NN_no_adversarial_debiasing        0.616122  0.576232
# reweighin_logistic_regression                             0.555510  0.519925
# reweighin_xgb_classifier                                  0.373673  0.563334
# disparate_impact_logistic_regression                      0.373673  0.585750
# disparate_impact_xgb_classifier                           0.373673  0.563334
# reweighin_logistic_regression_reject_option_spd           0.534646  0.532201
# reweighin_logistic_regression_reject_option_aod           0.534646  0.512009
# reweighin_logistic_regression_reject_option_eod           0.495051  0.474204
# reweighin_xgb_classifier_reject_option_spd                0.168384  0.503914
# reweighin_xgb_classifier_reject_option_aod                0.207980  0.525173
# reweighin_xgb_classifier_reject_option_eod                0.207980  0.525173
# disparate_impact_logistic_regression_reject_opt...        0.485152  0.525707
# disparate_impact_logistic_regression_reject_opt...        0.465354  0.496531
# disparate_impact_logistic_regression_reject_opt...        0.485152  0.518858
# disparate_impact_xgb_classifier_reject_option_spd         0.168384  0.503914
# disparate_impact_xgb_classifier_reject_option_aod         0.207980  0.525173
# disparate_impact_xgb_classifier_reject_option_eod         0.207980  0.525173
# reweighin_logistic_regression_platt_scaling               0.558176  0.600872
# reweighin_xgb_classifier_platt_scaling                    0.564358  0.619196
# disparate_impact_logistic_regression_platt_scaling        0.570059  0.609856
# disparate_impact_xgb_classifier_platt_scaling             0.564358  0.619196
# reweighin_logistic_regression_equal_odds_weighted         0.555510  0.519925
# reweighin_logistic_regression_equal_odds_fnr              0.555510  0.519925
# reweighin_logistic_regression_equal_odds_fpr              0.555510  0.519925
# reweighin_xgb_classifier_equal_odds_weighted              0.373673  0.577033
# reweighin_xgb_classifier_equal_odds_fnr                   0.535306  0.560754
# reweighin_xgb_classifier_equal_odds_fpr                   0.373673  0.590731
# disparate_impact_logistic_regression_equal_odds...        0.333265  0.601228
# disparate_impact_logistic_regression_equal_odds...        0.535306  0.593667
# disparate_impact_logistic_regression_equal_odds...        0.333265  0.601228
# disparate_impact_xgb_classifier_equal_odds_weig...        0.373673  0.577033
# disparate_impact_xgb_classifier_equal_odds_fnr            0.535306  0.560754
# disparate_impact_xgb_classifier_equal_odds_fpr            0.373673  0.590731
# meta_fairness_sr_reject_option_spd                        0.168384  0.503914
# meta_fairness_sr_reject_option_aod                        0.207980  0.525173
# meta_fairness_sr_reject_option_eod                        0.207980  0.525173
# meta_fairness_fdr_reject_option_spd                       0.168384  0.540206
# meta_fairness_fdr_reject_option_aod                       0.207980  0.540206
# meta_fairness_fdr_reject_option_eod                       0.207980  0.540206
# NN_adversarial_debiasing_reject_option_spd                0.168384  0.540206
# NN_adversarial_debiasing_reject_option_aod                0.207980  0.540206
# NN_adversarial_debiasing_reject_option_eod                0.207980  0.540206
# NN_adversarial_debiasing_platt_scaling                    0.344516  0.594022
# Basic_NN_no_adversarial_debiasing_platt_scaling           0.374931  0.594022
# NN_adversarial_debiasing_equal_odds_weighted              0.010000  0.500000
# NN_adversarial_debiasing_equal_odds_fnr                   0.131224  0.522327
# NN_adversarial_debiasing_equal_odds_fpr                   0.010000  0.500000
# Basic_NN_no_adversarial_debiasing_equal_odds_we...        0.595918  0.589575
# Basic_NN_no_adversarial_debiasing_equal_odds_fnr          0.616122  0.552749
# Basic_NN_no_adversarial_debiasing_equal_odds_fpr          0.595918  0.596780
#
#                                                          acc  independence  \
# logistic_regression                                 0.593333      0.322172
# xgb_classifier                                      0.566667      0.170136
# NN_adversarial_debiasing                            0.533333      0.037104
# Basic_NN_no_adversarial_debiasing                   0.566667      0.220814
# reweighing_NN_adversarial_debiasing                 0.586667      0.476923
# reweighin_basic_NN_no_adversarial_debiasing         0.560000      0.167421
# disparate_impact_NN_adversarial_debiasing           0.500000      0.036199
# disparate_impact_basic_NN_no_adversarial_debiasing  0.573333      0.201810
# reweighin_logistic_regression                       0.513333      0.041629
# reweighin_xgb_classifier                            0.566667      0.170136
# disparate_impact_logistic_regression                0.593333      0.322172
# disparate_impact_xgb_classifier                     0.566667      0.170136
# reweighin_logistic_regression_reject_option_spd     0.526667      0.000895
# reweighin_logistic_regression_reject_option_aod     0.506667      0.077198
# reweighin_logistic_regression_reject_option_eod     0.473333      0.062654
# reweighin_xgb_classifier_reject_option_spd          0.513333      0.100246
# reweighin_xgb_classifier_reject_option_aod          0.533333      0.270978
# reweighin_xgb_classifier_reject_option_eod          0.533333      0.270978
# disparate_impact_logistic_regression_reject_opt...  0.520000      0.025285
# disparate_impact_logistic_regression_reject_opt...  0.493333      0.019467
# disparate_impact_logistic_regression_reject_opt...  0.513333      0.068024
# disparate_impact_xgb_classifier_reject_option_spd   0.513333      0.100246
# disparate_impact_xgb_classifier_reject_option_aod   0.533333      0.270978
# disparate_impact_xgb_classifier_reject_option_eod   0.533333      0.270978
# reweighin_logistic_regression_platt_scaling         0.606667      0.466968
# reweighin_xgb_classifier_platt_scaling              0.620000      0.361991
# disparate_impact_logistic_regression_platt_scaling  0.613333      0.457014
# disparate_impact_xgb_classifier_platt_scaling       0.620000      0.361991
# reweighin_logistic_regression_equal_odds_weighted   0.513333      0.012978
# reweighin_logistic_regression_equal_odds_fnr        0.513333      0.012978
# reweighin_logistic_regression_equal_odds_fpr        0.513333      0.012978
# reweighin_xgb_classifier_equal_odds_weighted        0.580000      0.508391
# reweighin_xgb_classifier_equal_odds_fnr             0.560000      0.416424
# reweighin_xgb_classifier_equal_odds_fpr             0.593333      0.557172
# disparate_impact_logistic_regression_equal_odds...  0.606667      0.972477
# disparate_impact_logistic_regression_equal_odds...  0.600000      0.951220
# disparate_impact_logistic_regression_equal_odds...  0.606667      0.972477
# disparate_impact_xgb_classifier_equal_odds_weig...  0.580000      0.508391
# disparate_impact_xgb_classifier_equal_odds_fnr      0.560000      0.416424
# disparate_impact_xgb_classifier_equal_odds_fpr      0.593333      0.557172
# meta_fairness_sr_reject_option_spd                  0.513333      0.100246
# meta_fairness_sr_reject_option_aod                  0.533333      0.270978
# meta_fairness_sr_reject_option_eod                  0.533333      0.270978
# meta_fairness_fdr_reject_option_spd                 0.540000      0.106787
# meta_fairness_fdr_reject_option_aod                 0.540000      0.106787
# meta_fairness_fdr_reject_option_eod                 0.540000      0.106787
# NN_adversarial_debiasing_reject_option_spd          0.540000      0.106787
# NN_adversarial_debiasing_reject_option_aod          0.540000      0.106787
# NN_adversarial_debiasing_reject_option_eod          0.540000      0.106787
# NN_adversarial_debiasing_platt_scaling              0.600000      0.482353
# Basic_NN_no_adversarial_debiasing_platt_scaling     0.600000      0.482353
# NN_adversarial_debiasing_equal_odds_weighted        0.513333      0.000000
# NN_adversarial_debiasing_equal_odds_fnr             0.533333      0.119266
# NN_adversarial_debiasing_equal_odds_fpr             0.513333      0.000000
# Basic_NN_no_adversarial_debiasing_equal_odds_we...  0.586667      0.407026
# Basic_NN_no_adversarial_debiasing_equal_odds_fnr    0.546667      0.141195
# Basic_NN_no_adversarial_debiasing_equal_odds_fpr    0.593333      0.480197
#
#                                                     separation  sufficiency  \
# logistic_regression                                   0.116490     0.007792
# xgb_classifier                                        0.083945     0.021277
# NN_adversarial_debiasing                              0.011444     0.105194
# Basic_NN_no_adversarial_debiasing                     0.065970     0.138624
# reweighing_NN_adversarial_debiasing                   0.077070     0.009288
# reweighin_basic_NN_no_adversarial_debiasing           0.047431     0.000000
# disparate_impact_NN_adversarial_debiasing             0.062479     0.380952
# disparate_impact_basic_NN_no_adversarial_debiasing    0.004220     0.059441
# reweighin_logistic_regression                         0.100204     0.100000
# reweighin_xgb_classifier                              0.083945     0.021277
# disparate_impact_logistic_regression                  0.116490     0.007792
# disparate_impact_xgb_classifier                       0.083945     0.021277
# reweighin_logistic_regression_reject_option_spd       0.093685     0.093750
# reweighin_logistic_regression_reject_option_aod       0.109098     0.042857
# reweighin_logistic_regression_reject_option_eod       0.015585     0.217687
# reweighin_xgb_classifier_reject_option_spd            0.132965     0.312500
# reweighin_xgb_classifier_reject_option_aod            0.111801     0.313750
# reweighin_xgb_classifier_reject_option_eod            0.111801     0.313750
# disparate_impact_logistic_regression_reject_opt...    0.131010     0.017045
# disparate_impact_logistic_regression_reject_opt...    0.144640     0.057143
# disparate_impact_logistic_regression_reject_opt...    0.098229     0.058824
# disparate_impact_xgb_classifier_reject_option_spd     0.132965     0.312500
# disparate_impact_xgb_classifier_reject_option_aod     0.111801     0.313750
# disparate_impact_xgb_classifier_reject_option_eod     0.111801     0.313750
# reweighin_logistic_regression_platt_scaling           0.107143     0.012784
# reweighin_xgb_classifier_platt_scaling                0.032690     0.000000
# disparate_impact_logistic_regression_platt_scaling    0.046075     0.008854
# disparate_impact_xgb_classifier_platt_scaling         0.032690     0.000000
# reweighin_logistic_regression_equal_odds_weighted     0.089429     0.071429
# reweighin_logistic_regression_equal_odds_fnr          0.089429     0.071429
# reweighin_logistic_regression_equal_odds_fpr          0.089429     0.071429
# reweighin_xgb_classifier_equal_odds_weighted          0.001553     0.197561
# reweighin_xgb_classifier_equal_odds_fnr               0.087129     0.006696
# reweighin_xgb_classifier_equal_odds_fpr               0.038590     0.097561
# disparate_impact_logistic_regression_equal_odds...    0.013803     0.584906
# disparate_impact_logistic_regression_equal_odds...    0.017196     0.077982
# disparate_impact_logistic_regression_equal_odds...    0.013803     0.584906
# disparate_impact_xgb_classifier_equal_odds_weig...    0.001553     0.197561
# disparate_impact_xgb_classifier_equal_odds_fnr        0.087129     0.006696
# disparate_impact_xgb_classifier_equal_odds_fpr        0.038590     0.097561
# meta_fairness_sr_reject_option_spd                    0.132965     0.312500
# meta_fairness_sr_reject_option_aod                    0.111801     0.313750
# meta_fairness_sr_reject_option_eod                    0.111801     0.313750
# meta_fairness_fdr_reject_option_spd                   0.144037     0.051170
# meta_fairness_fdr_reject_option_aod                   0.144037     0.051170
# meta_fairness_fdr_reject_option_eod                   0.144037     0.051170
# NN_adversarial_debiasing_reject_option_spd            0.144037     0.051170
# NN_adversarial_debiasing_reject_option_aod            0.144037     0.051170
# NN_adversarial_debiasing_reject_option_eod            0.144037     0.051170
# NN_adversarial_debiasing_platt_scaling                0.125000     0.021678
# Basic_NN_no_adversarial_debiasing_platt_scaling       0.125000     0.021678
# NN_adversarial_debiasing_equal_odds_weighted          0.000000     0.236518
# NN_adversarial_debiasing_equal_odds_fnr               0.047274     0.262703
# NN_adversarial_debiasing_equal_odds_fpr               0.000000     0.236518
# Basic_NN_no_adversarial_debiasing_equal_odds_we...    0.025995     0.136364
# Basic_NN_no_adversarial_debiasing_equal_odds_fnr      0.084138     0.390756
# Basic_NN_no_adversarial_debiasing_equal_odds_fpr      0.024672     0.363636
#
#                                                          auc
# logistic_regression                                 0.558086
# xgb_classifier                                      0.529621
# NN_adversarial_debiasing                            0.416474
# Basic_NN_no_adversarial_debiasing                   0.537627
# reweighing_NN_adversarial_debiasing                 0.574809
# reweighin_basic_NN_no_adversarial_debiasing         0.533179
# disparate_impact_NN_adversarial_debiasing           0.433197
# disparate_impact_basic_NN_no_adversarial_debiasing  0.556840
# reweighin_logistic_regression                       0.476428
# reweighin_xgb_classifier                            0.529621
# disparate_impact_logistic_regression                0.558086
# disparate_impact_xgb_classifier                     0.529621
# reweighin_logistic_regression_reject_option_spd     0.476428
# reweighin_logistic_regression_reject_option_aod     0.476428
# reweighin_logistic_regression_reject_option_eod     0.476428
# reweighin_xgb_classifier_reject_option_spd          0.529621
# reweighin_xgb_classifier_reject_option_aod          0.529621
# reweighin_xgb_classifier_reject_option_eod          0.529621
# disparate_impact_logistic_regression_reject_opt...  0.558086
# disparate_impact_logistic_regression_reject_opt...  0.558086
# disparate_impact_logistic_regression_reject_opt...  0.558086
# disparate_impact_xgb_classifier_reject_option_spd   0.529621
# disparate_impact_xgb_classifier_reject_option_aod   0.529621
# disparate_impact_xgb_classifier_reject_option_eod   0.529621
# reweighin_logistic_regression_platt_scaling         0.624978
# reweighin_xgb_classifier_platt_scaling              0.623910
# disparate_impact_logistic_regression_platt_scaling  0.624800
# disparate_impact_xgb_classifier_platt_scaling       0.623910
# reweighin_logistic_regression_equal_odds_weighted   0.476428
# reweighin_logistic_regression_equal_odds_fnr        0.476428
# reweighin_logistic_regression_equal_odds_fpr        0.476428
# reweighin_xgb_classifier_equal_odds_weighted        0.529621
# reweighin_xgb_classifier_equal_odds_fnr             0.529621
# reweighin_xgb_classifier_equal_odds_fpr             0.529621
# disparate_impact_logistic_regression_equal_odds...  0.558086
# disparate_impact_logistic_regression_equal_odds...  0.558086
# disparate_impact_logistic_regression_equal_odds...  0.558086
# disparate_impact_xgb_classifier_equal_odds_weig...  0.529621
# disparate_impact_xgb_classifier_equal_odds_fnr      0.529621
# disparate_impact_xgb_classifier_equal_odds_fpr      0.529621
# meta_fairness_sr_reject_option_spd                  0.529621
# meta_fairness_sr_reject_option_aod                  0.529621
# meta_fairness_sr_reject_option_eod                  0.529621
# meta_fairness_fdr_reject_option_spd                 0.529621
# meta_fairness_fdr_reject_option_aod                 0.529621
# meta_fairness_fdr_reject_option_eod                 0.529621
# NN_adversarial_debiasing_reject_option_spd          0.529621
# NN_adversarial_debiasing_reject_option_aod          0.529621
# NN_adversarial_debiasing_reject_option_eod          0.529621
# NN_adversarial_debiasing_platt_scaling              0.609856
# Basic_NN_no_adversarial_debiasing_platt_scaling     0.608433
# NN_adversarial_debiasing_equal_odds_weighted        0.416474
# NN_adversarial_debiasing_equal_odds_fnr             0.416474
# NN_adversarial_debiasing_equal_odds_fpr             0.416474
# Basic_NN_no_adversarial_debiasing_equal_odds_we...  0.537627
# Basic_NN_no_adversarial_debiasing_equal_odds_fnr    0.537627
# Basic_NN_no_adversarial_debiasing_equal_odds_fpr    0.537627

# %% [markdown]
# ### Resultados en test

# %%
algorithm_performance_summary = pd.DataFrame(metrics_best_thresh_test).T
algorithm_performance_summary
# Out:
#                                                     best_threshold   bal_acc  \
# logistic_regression                                       0.373673  0.536047
# xgb_classifier                                            0.373673  0.537482
# NN_adversarial_debiasing                                  0.131224  0.506277
# Basic_NN_no_adversarial_debiasing                         0.595918  0.473278
# reweighing_NN_adversarial_debiasing                       0.535306  0.553443
# reweighin_basic_NN_no_adversarial_debiasing               0.616122  0.518651
# disparate_impact_NN_adversarial_debiasing                 0.676735  0.468077
# disparate_impact_basic_NN_no_adversarial_debiasing        0.616122  0.487984
# reweighin_logistic_regression                             0.555510  0.440638
# reweighin_xgb_classifier                                  0.373673  0.537482
# disparate_impact_logistic_regression                      0.373673  0.536047
# disparate_impact_xgb_classifier                           0.373673  0.537482
# reweighin_logistic_regression_reject_option_spd           0.534646  0.443867
# reweighin_logistic_regression_reject_option_aod           0.534646  0.443867
# reweighin_logistic_regression_reject_option_eod           0.495051  0.443867
# reweighin_xgb_classifier_reject_option_spd                0.168384  0.541607
# reweighin_xgb_classifier_reject_option_aod                0.207980  0.541607
# reweighin_xgb_classifier_reject_option_eod                0.207980  0.541607
# disparate_impact_logistic_regression_reject_opt...        0.485152  0.537841
# disparate_impact_logistic_regression_reject_opt...        0.465354  0.537841
# disparate_impact_logistic_regression_reject_opt...        0.485152  0.537841
# disparate_impact_xgb_classifier_reject_option_spd         0.168384  0.541607
# disparate_impact_xgb_classifier_reject_option_aod         0.207980  0.541607
# disparate_impact_xgb_classifier_reject_option_eod         0.207980  0.541607
# reweighin_logistic_regression_platt_scaling               0.558176  0.566714
# reweighin_xgb_classifier_platt_scaling                    0.564358  0.601506
# disparate_impact_logistic_regression_platt_scaling        0.570059  0.608680
# disparate_impact_xgb_classifier_platt_scaling             0.564358  0.601506
# reweighin_logistic_regression_equal_odds_weighted         0.555510  0.440638
# reweighin_logistic_regression_equal_odds_fnr              0.555510  0.440638
# reweighin_logistic_regression_equal_odds_fpr              0.555510  0.440638
# reweighin_xgb_classifier_equal_odds_weighted              0.373673  0.537482
# reweighin_xgb_classifier_equal_odds_fnr                   0.535306  0.529412
# reweighin_xgb_classifier_equal_odds_fpr                   0.373673  0.531385
# disparate_impact_logistic_regression_equal_odds...        0.333265  0.575323
# disparate_impact_logistic_regression_equal_odds...        0.535306  0.572812
# disparate_impact_logistic_regression_equal_odds...        0.333265  0.575323
# disparate_impact_xgb_classifier_equal_odds_weig...        0.373673  0.537482
# disparate_impact_xgb_classifier_equal_odds_fnr            0.535306  0.529412
# disparate_impact_xgb_classifier_equal_odds_fpr            0.373673  0.531385
# meta_fairness_sr_reject_option_spd                        0.168384  0.541607
# meta_fairness_sr_reject_option_aod                        0.207980  0.541607
# meta_fairness_sr_reject_option_eod                        0.207980  0.541607
# meta_fairness_fdr_reject_option_spd                       0.168384  0.541607
# meta_fairness_fdr_reject_option_aod                       0.207980  0.541607
# meta_fairness_fdr_reject_option_eod                       0.207980  0.541607
# NN_adversarial_debiasing_reject_option_spd                0.168384  0.541607
# NN_adversarial_debiasing_reject_option_aod                0.207980  0.541607
# NN_adversarial_debiasing_reject_option_eod                0.207980  0.541607
# NN_adversarial_debiasing_platt_scaling                    0.344516  0.566714
# Basic_NN_no_adversarial_debiasing_platt_scaling           0.374931  0.566714
# NN_adversarial_debiasing_equal_odds_weighted              0.010000  0.500000
# NN_adversarial_debiasing_equal_odds_fnr                   0.131224  0.506277
# NN_adversarial_debiasing_equal_odds_fpr                   0.010000  0.500000
# Basic_NN_no_adversarial_debiasing_equal_odds_we...        0.595918  0.473278
# Basic_NN_no_adversarial_debiasing_equal_odds_fnr          0.616122  0.489598
# Basic_NN_no_adversarial_debiasing_equal_odds_fpr          0.595918  0.480631
#
#                                                          acc  independence  \
# logistic_regression                                 0.560000      0.283414
# xgb_classifier                                      0.553333      0.229200
# NN_adversarial_debiasing                            0.546667      0.064412
# Basic_NN_no_adversarial_debiasing                   0.466667      0.149222
# reweighing_NN_adversarial_debiasing                 0.566667      0.359098
# reweighin_basic_NN_no_adversarial_debiasing         0.506667      0.167472
# disparate_impact_NN_adversarial_debiasing           0.426667      0.045089
# disparate_impact_basic_NN_no_adversarial_debiasing  0.480000      0.173913
# reweighin_logistic_regression                       0.420000      0.130435
# reweighin_xgb_classifier                            0.553333      0.229200
# disparate_impact_logistic_regression                0.560000      0.283414
# disparate_impact_xgb_classifier                     0.553333      0.229200
# reweighin_logistic_regression_reject_option_spd     0.440000      0.046162
# reweighin_logistic_regression_reject_option_aod     0.440000      0.046162
# reweighin_logistic_regression_reject_option_eod     0.440000      0.046162
# reweighin_xgb_classifier_reject_option_spd          0.540000      0.199141
# reweighin_xgb_classifier_reject_option_aod          0.540000      0.199141
# reweighin_xgb_classifier_reject_option_eod          0.540000      0.199141
# disparate_impact_logistic_regression_reject_opt...  0.540000      0.232421
# disparate_impact_logistic_regression_reject_opt...  0.540000      0.232421
# disparate_impact_logistic_regression_reject_opt...  0.540000      0.232421
# disparate_impact_xgb_classifier_reject_option_spd   0.540000      0.199141
# disparate_impact_xgb_classifier_reject_option_aod   0.540000      0.199141
# disparate_impact_xgb_classifier_reject_option_eod   0.540000      0.199141
# reweighin_logistic_regression_platt_scaling         0.586667      0.518519
# reweighin_xgb_classifier_platt_scaling              0.600000      0.347826
# disparate_impact_logistic_regression_platt_scaling  0.613333      0.519592
# disparate_impact_xgb_classifier_platt_scaling       0.600000      0.347826
# reweighin_logistic_regression_equal_odds_weighted   0.420000      0.130435
# reweighin_logistic_regression_equal_odds_fnr        0.420000      0.130435
# reweighin_logistic_regression_equal_odds_fpr        0.420000      0.130435
# reweighin_xgb_classifier_equal_odds_weighted        0.553333      0.229200
# reweighin_xgb_classifier_equal_odds_fnr             0.526667      0.250671
# reweighin_xgb_classifier_equal_odds_fpr             0.546667      0.241546
# disparate_impact_logistic_regression_equal_odds...  0.593333      0.475040
# disparate_impact_logistic_regression_equal_odds...  0.593333      0.506173
# disparate_impact_logistic_regression_equal_odds...  0.593333      0.475040
# disparate_impact_xgb_classifier_equal_odds_weig...  0.553333      0.229200
# disparate_impact_xgb_classifier_equal_odds_fnr      0.526667      0.250671
# disparate_impact_xgb_classifier_equal_odds_fpr      0.546667      0.241546
# meta_fairness_sr_reject_option_spd                  0.540000      0.199141
# meta_fairness_sr_reject_option_aod                  0.540000      0.199141
# meta_fairness_sr_reject_option_eod                  0.540000      0.199141
# meta_fairness_fdr_reject_option_spd                 0.540000      0.199141
# meta_fairness_fdr_reject_option_aod                 0.540000      0.199141
# meta_fairness_fdr_reject_option_eod                 0.540000      0.199141
# NN_adversarial_debiasing_reject_option_spd          0.540000      0.199141
# NN_adversarial_debiasing_reject_option_aod          0.540000      0.199141
# NN_adversarial_debiasing_reject_option_eod          0.540000      0.199141
# NN_adversarial_debiasing_platt_scaling              0.586667      0.518519
# Basic_NN_no_adversarial_debiasing_platt_scaling     0.586667      0.518519
# NN_adversarial_debiasing_equal_odds_weighted        0.546667      0.000000
# NN_adversarial_debiasing_equal_odds_fnr             0.546667      0.064412
# NN_adversarial_debiasing_equal_odds_fpr             0.546667      0.000000
# Basic_NN_no_adversarial_debiasing_equal_odds_we...  0.466667      0.149222
# Basic_NN_no_adversarial_debiasing_equal_odds_fnr    0.466667      0.013956
# Basic_NN_no_adversarial_debiasing_equal_odds_fpr    0.473333      0.161567
#
#                                                     separation  sufficiency  \
# logistic_regression                                   0.067030     0.038282
# xgb_classifier                                        0.032796     0.056522
# NN_adversarial_debiasing                              0.008014     0.083954
# Basic_NN_no_adversarial_debiasing                     0.037239     0.060099
# reweighing_NN_adversarial_debiasing                   0.039678     0.039346
# reweighin_basic_NN_no_adversarial_debiasing           0.076220     0.020833
# disparate_impact_NN_adversarial_debiasing             0.010105     0.333333
# disparate_impact_basic_NN_no_adversarial_debiasing    0.062239     0.024339
# reweighin_logistic_regression                         0.083275     0.124339
# reweighin_xgb_classifier                              0.032796     0.056522
# disparate_impact_logistic_regression                  0.067030     0.038282
# disparate_impact_xgb_classifier                       0.032796     0.056522
# reweighin_logistic_regression_reject_option_spd       0.036019     0.058009
# reweighin_logistic_regression_reject_option_aod       0.036019     0.058009
# reweighin_logistic_regression_reject_option_eod       0.036019     0.058009
# reweighin_xgb_classifier_reject_option_spd            0.080096     0.008384
# reweighin_xgb_classifier_reject_option_aod            0.080096     0.008384
# reweighin_xgb_classifier_reject_option_eod            0.080096     0.008384
# disparate_impact_logistic_regression_reject_opt...    0.200610     0.113725
# disparate_impact_logistic_regression_reject_opt...    0.200610     0.113725
# disparate_impact_logistic_regression_reject_opt...    0.200610     0.113725
# disparate_impact_xgb_classifier_reject_option_spd     0.080096     0.008384
# disparate_impact_xgb_classifier_reject_option_aod     0.080096     0.008384
# disparate_impact_xgb_classifier_reject_option_eod     0.080096     0.008384
# reweighin_logistic_regression_platt_scaling           0.080488     0.004459
# reweighin_xgb_classifier_platt_scaling                0.010017     0.029945
# disparate_impact_logistic_regression_platt_scaling    0.018598     0.015915
# disparate_impact_xgb_classifier_platt_scaling         0.010017     0.029945
# reweighin_logistic_regression_equal_odds_weighted     0.083275     0.124339
# reweighin_logistic_regression_equal_odds_fnr          0.083275     0.124339
# reweighin_logistic_regression_equal_odds_fpr          0.083275     0.124339
# reweighin_xgb_classifier_equal_odds_weighted          0.032796     0.056522
# reweighin_xgb_classifier_equal_odds_fnr               0.031315     0.043514
# reweighin_xgb_classifier_equal_odds_fpr               0.020601     0.066667
# disparate_impact_logistic_regression_equal_odds...    0.056969     0.016317
# disparate_impact_logistic_regression_equal_odds...    0.092683     0.005797
# disparate_impact_logistic_regression_equal_odds...    0.056969     0.016317
# disparate_impact_xgb_classifier_equal_odds_weig...    0.032796     0.056522
# disparate_impact_xgb_classifier_equal_odds_fnr        0.031315     0.043514
# disparate_impact_xgb_classifier_equal_odds_fpr        0.020601     0.066667
# meta_fairness_sr_reject_option_spd                    0.080096     0.008384
# meta_fairness_sr_reject_option_aod                    0.080096     0.008384
# meta_fairness_sr_reject_option_eod                    0.080096     0.008384
# meta_fairness_fdr_reject_option_spd                   0.080096     0.008384
# meta_fairness_fdr_reject_option_aod                   0.080096     0.008384
# meta_fairness_fdr_reject_option_eod                   0.080096     0.008384
# NN_adversarial_debiasing_reject_option_spd            0.080096     0.008384
# NN_adversarial_debiasing_reject_option_aod            0.080096     0.008384
# NN_adversarial_debiasing_reject_option_eod            0.080096     0.008384
# NN_adversarial_debiasing_platt_scaling                0.080488     0.004459
# Basic_NN_no_adversarial_debiasing_platt_scaling       0.080488     0.004459
# NN_adversarial_debiasing_equal_odds_weighted          0.000000     0.088030
# NN_adversarial_debiasing_equal_odds_fnr               0.008014     0.083954
# NN_adversarial_debiasing_equal_odds_fpr               0.000000     0.088030
# Basic_NN_no_adversarial_debiasing_equal_odds_we...    0.037239     0.060099
# Basic_NN_no_adversarial_debiasing_equal_odds_fnr      0.036890     0.161111
# Basic_NN_no_adversarial_debiasing_equal_odds_fpr      0.049739     0.042857
#
#                                                          auc
# logistic_regression                                 0.504125
# xgb_classifier                                      0.522956
# NN_adversarial_debiasing                            0.406923
# Basic_NN_no_adversarial_debiasing                   0.515782
# reweighing_NN_adversarial_debiasing                 0.552547
# reweighin_basic_NN_no_adversarial_debiasing         0.551291
# disparate_impact_NN_adversarial_debiasing           0.434720
# disparate_impact_basic_NN_no_adversarial_debiasing  0.518651
# reweighin_logistic_regression                       0.443867
# reweighin_xgb_classifier                            0.522956
# disparate_impact_logistic_regression                0.504125
# disparate_impact_xgb_classifier                     0.522956
# reweighin_logistic_regression_reject_option_spd     0.443867
# reweighin_logistic_regression_reject_option_aod     0.443867
# reweighin_logistic_regression_reject_option_eod     0.443867
# reweighin_xgb_classifier_reject_option_spd          0.522956
# reweighin_xgb_classifier_reject_option_aod          0.522956
# reweighin_xgb_classifier_reject_option_eod          0.522956
# disparate_impact_logistic_regression_reject_opt...  0.504125
# disparate_impact_logistic_regression_reject_opt...  0.504125
# disparate_impact_logistic_regression_reject_opt...  0.504125
# disparate_impact_xgb_classifier_reject_option_spd   0.522956
# disparate_impact_xgb_classifier_reject_option_aod   0.522956
# disparate_impact_xgb_classifier_reject_option_eod   0.522956
# reweighin_logistic_regression_platt_scaling         0.629304
# reweighin_xgb_classifier_platt_scaling              0.596306
# disparate_impact_logistic_regression_platt_scaling  0.626255
# disparate_impact_xgb_classifier_platt_scaling       0.596306
# reweighin_logistic_regression_equal_odds_weighted   0.443867
# reweighin_logistic_regression_equal_odds_fnr        0.443867
# reweighin_logistic_regression_equal_odds_fpr        0.443867
# reweighin_xgb_classifier_equal_odds_weighted        0.522956
# reweighin_xgb_classifier_equal_odds_fnr             0.522956
# reweighin_xgb_classifier_equal_odds_fpr             0.522956
# disparate_impact_logistic_regression_equal_odds...  0.504125
# disparate_impact_logistic_regression_equal_odds...  0.504125
# disparate_impact_logistic_regression_equal_odds...  0.504125
# disparate_impact_xgb_classifier_equal_odds_weig...  0.522956
# disparate_impact_xgb_classifier_equal_odds_fnr      0.522956
# disparate_impact_xgb_classifier_equal_odds_fpr      0.522956
# meta_fairness_sr_reject_option_spd                  0.522956
# meta_fairness_sr_reject_option_aod                  0.522956
# meta_fairness_sr_reject_option_eod                  0.522956
# meta_fairness_fdr_reject_option_spd                 0.522956
# meta_fairness_fdr_reject_option_aod                 0.522956
# meta_fairness_fdr_reject_option_eod                 0.522956
# NN_adversarial_debiasing_reject_option_spd          0.522956
# NN_adversarial_debiasing_reject_option_aod          0.522956
# NN_adversarial_debiasing_reject_option_eod          0.522956
# NN_adversarial_debiasing_platt_scaling              0.528156
# Basic_NN_no_adversarial_debiasing_platt_scaling     0.526722
# NN_adversarial_debiasing_equal_odds_weighted        0.406923
# NN_adversarial_debiasing_equal_odds_fnr             0.406923
# NN_adversarial_debiasing_equal_odds_fpr             0.406923
# Basic_NN_no_adversarial_debiasing_equal_odds_we...  0.515782
# Basic_NN_no_adversarial_debiasing_equal_odds_fnr    0.515782
# Basic_NN_no_adversarial_debiasing_equal_odds_fpr    0.515782

# %%
algorithm_performance_summary.to_csv('SIMULATION_MULTALG_MULTSENS_low', index = True, sep=',', encoding='utf-8')
