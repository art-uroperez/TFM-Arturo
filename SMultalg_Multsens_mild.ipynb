# %% [markdown]
# <img src="img/ibidat.png" alt="drawing" width="600"/>

# %% [markdown]
# # Introducción
#
# En este cuaderno vamos a probar todas las parejas posibles de métodos de fairness que afecten a distintas partes del proceso de la construcción del algoritmo de machine learning usando dos variables sensibles. Vamos a hacer un estudio de simulación.

# %% [markdown]
# # Carga de librerías

# %%
# Con esta celda, podemos hacer cambios en cualquier script/libreria y verlo reflejado en las funciones del notebook.
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
## CARGAMOS LIBRERIAS
# Obs: La primera vez puede tardar en cargar porque AIF360 pre-compila algunas cosas de tensorflow
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Cargamos librerías de sklearn
# vanilla LR
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline

# Cargamos xgboost
from xgboost import XGBClassifier

# Cargamos algoritmos de fairness
# Pre-procesado
from aif360.algorithms.preprocessing import Reweighing
from aif360.algorithms.preprocessing import DisparateImpactRemover
# In-procesado
from aif360.algorithms.inprocessing import PrejudiceRemover
from aif360.algorithms.inprocessing import MetaFairClassifier
from aif360.algorithms.inprocessing.adversarial_debiasing import AdversarialDebiasing
# Post-procesado
from aif360.algorithms.postprocessing import RejectOptionClassification # when scores are given
from aif360.algorithms.postprocessing import CalibratedEqOddsPostprocessing # when scores (R) are given
from aif360.algorithms.postprocessing import EqOddsPostprocessing # when labels (Y^hat) are given
from aif360.datasets import GermanDataset

#Simulacion
from aif360.datasets import BinaryLabelDataset

# TF para adversarial debiasing
import tensorflow.compat.v1 as tf
tf.disable_eager_execution()

from IPython.display import Markdown, display

# Librería local con funciones de ayuda extra
import utils

seed = 12345 # fijamos la semilla de números aleatorios para reproducir exactamante el notebook
# Out:
# WARNING:root:
# `load_boston` has been removed from scikit-learn since version 1.2.
#
# The Boston housing prices dataset has an ethical problem: as
# investigated in [1], the authors of this dataset engineered a
# non-invertible variable "B" assuming that racial self-segregation had a
# positive impact on house prices [2]. Furthermore the goal of the
# research that led to the creation of this dataset was to study the
# impact of air quality but it did not give adequate demonstration of the
# validity of this assumption.
#
# The scikit-learn maintainers therefore strongly discourage the use of
# this dataset unless the purpose of the code is to study and educate
# about ethical issues in data science and machine learning.
#
# In this special case, you can fetch the dataset from the original
# source::
#
#     import pandas as pd
#     import numpy as np
#
#     data_url = "http://lib.stat.cmu.edu/datasets/boston"
#     raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#     data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#     target = raw_df.values[1::2, 2]
#
# Alternative datasets include the California housing dataset and the
# Ames housing dataset. You can load the datasets as follows::
#
#     from sklearn.datasets import fetch_california_housing
#     housing = fetch_california_housing()
#
# for the California housing dataset and::
#
#     from sklearn.datasets import fetch_openml
#     housing = fetch_openml(name="house_prices", as_frame=True)
#
# for the Ames housing dataset.
#
# [1] M Carlisle.
# "Racist data destruction?"
# <https://medium.com/@docintangible/racist-data-destruction-113e3eff54a8>
#
# [2] Harrison Jr, David, and Daniel L. Rubinfeld.
# "Hedonic housing prices and the demand for clean air."
# Journal of environmental economics and management 5.1 (1978): 81-102.
# <https://www.researchgate.net/publication/4974606_Hedonic_housing_prices_and_the_demand_for_clean_air>
# : LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# 2024-06-19 10:07:19.776834: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-19 10:07:19.834695: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-19 10:07:20.793251: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Selección de dataset.
#
# El siguiente bloque permite seleccionar el conjunto de datos sobre el que trabajar. Debe recordarse que el conjunto de `homecredit` es mucho mayor por lo que tardará más tiempo en ejecutarse.

# %%
def logit(x):
    return np.log(x/(1-x))

def inv_logit(x):
    return np.exp(x)/(1+np.exp(x))

def simulated_dataset(n_obs, n_var, n_sens, mean_vec, cov, beta, gamma):
    
    p = n_var + n_sens
    coef = np.concatenate((gamma, beta))
        
    X = np.random.multivariate_normal(mean_vec, cov, size = n_obs)
    probs_var = inv_logit(X)
    bin = np.random.binomial(1, probs_var)
    
    probs_Y = inv_logit(coef.dot(X.T))
    Y = np.random.binomial(1, probs_Y)
    
    names = ['0' for i in range(p+1)]
    sens = ['0' for i in range(n_sens)]
    var = 1
    
    names[0] = 'response'
    
    for i in range(1,p+1):
        if i-1 < n_sens:
            sens[i-1] = 'sens ' + str(i)
            names[i] = 'sens ' + str(i)
        if i-1 >= n_sens:
            names[i] = 'var ' + str(var)
            var += 1
    
    names = np.array(names)
    sens = np.array(sens)
    response = np.array(['response'])
    
    Y = Y.reshape((n_obs,1))
    
    bin = np.concatenate((Y, bin), axis = 1)
    
    data_pd = pd.DataFrame(bin, columns = names)
    data = BinaryLabelDataset(df = data_pd, favorable_label = 1, unfavorable_label = 0, label_names = response, protected_attribute_names = sens)
    return data

# %%
n_obs = 1000
n_var = 30
n_sens = 2
mean_vec = np.zeros(n_var+n_sens)
cov = np.identity(n_var+n_sens)
beta = np.ones(n_var)
gamma = np.ones(n_sens)

dataset1 = simulated_dataset(n_obs, n_var, n_sens, mean_vec, cov, beta, gamma)

#dataset.favorable_label = 1
#dataset.unfavorable_label = 0

new_data = dataset1.convert_to_dataframe()[0]

sens1 = new_data.loc[:,'sens 1']
sens2 = new_data.loc[:,'sens 2']
new_sens = sens1.copy()
new_sens[sens2 == 1] = 1

new_data = new_data.drop(['sens 1', 'sens 2'], axis = 1)
new_data['sens 1'] = new_sens

names = np.array(new_data.columns)
sens = np.array(['sens 1'])
response = np.array(['response'])

dataset = BinaryLabelDataset(df = new_data,
                             favorable_label = 1,
                             unfavorable_label = 0,
                             label_names = response,
                             protected_attribute_names = sens)

# Separamos el conjunto de datos en train, validate, test
data_train, vt = dataset.split([0.7], shuffle=True, seed=seed)
data_val, data_test = vt.split([0.5], shuffle=True, seed=seed)

data_train2, vt2 = dataset1.split([0.7], shuffle=True, seed=seed)
data_val2, data_test2 = vt2.split([0.5], shuffle=True, seed=seed)

# Obtenemos los indicadores del grupo sensible
sensitive_attribute = dataset.protected_attribute_names[0]
privileged_groups, unprivileged_groups = utils.get_privileged_groups(dataset)
    
print(f'Dimensiones del conjunto de datos: {dataset.features.shape}')
print("Grupos privilegiados:", privileged_groups)
print("Grupos no privilegiados:", unprivileged_groups)
print("Label del grupo favorable:", dataset.favorable_label)
print("Label del grupo desfavorable:", dataset.unfavorable_label)
# Out:
# Dimensiones del conjunto de datos: (1000, 31)
# Grupos privilegiados: [{'sens 1': 1.0}]
# Grupos no privilegiados: [{'sens 1': 0.0}]
# Label del grupo favorable: 1.0
# Label del grupo desfavorable: 0.0

# %% [markdown]
# ## Modelos
# Para esta sección, creamos un diccionario de métricas y modelos para poder acceder los resultados de todos los modelos.

# %%
# Inicializamos diccionarios
models = dict()

# Rango de umbrales para evaluar el score de los modelos
thresh_sweep = np.linspace(0.01, 1.0, 50)

metrics_sweep = dict()

# Store results from validation and test
metrics_best_thresh_validate = dict()
metrics_best_thresh_test = dict()

# %% [markdown]
# ### Regresión Logística

# %%
# %%time 

# Nombramos al modelo
model_name = 'logistic_regression'
fairness_method = ''

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Parámetros del modelo
fit_params = {'logisticregression__sample_weight': data_train_copy.instance_weights}

# Asignamos el modelo al diccionario
models[model_name+fairness_method] = make_pipeline(
            #StandardScaler(),
            LogisticRegression(solver='liblinear', random_state=seed))

# Entrenamos el modelo
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy.features, data_train_copy.labels.ravel(), **fit_params)
# Out:
# CPU times: user 4.24 ms, sys: 7.81 ms, total: 12.1 ms
# Wall time: 11.3 ms

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_threshold_sweep_mult(
    dataset=data_val_copy,
    dataset2=data_val2_copy,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_mult(
    dataset=data_test_copy, 
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.5151
# AUC: 0.6457
# Balanced accuracy: 0.6068
# Accuracy: 0.6067
# Independence ( |ΔP(Y_pred = 1)| ): 0.1484
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0628
# Sufficiency ( |ΔPPV| ) : 0.0258
# CPU times: user 153 ms, sys: 25.6 ms, total: 179 ms
# Wall time: 164 ms

# %%
display(Markdown("**Test set results**"))
utils.print_metrics(metrics_best_thresh_test[model_name+fairness_method])
# Out:
# **Test set results**
# Threshold corresponding to *best balanced accuracy*: 0.5151
# AUC: 0.6040
# Balanced accuracy: 0.5764
# Accuracy: 0.5800
# Independence ( |ΔP(Y_pred = 1)| ): 0.0553
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0386
# Sufficiency ( |ΔPPV| ) : 0.1396

# %% [markdown]
# ### XGBoost

# %%
# %%time 

# Nombramos al modelo
model_name = 'xgb_classifier'
fairness_method = ''

# Parámetros del modelo
fit_params = {'eval_metric': 'error', 'eta':0.1, 'max_depth':6, 'subsample':0.8}

# Asignamos el modelo al diccionario
models[model_name+fairness_method] = XGBClassifier(**fit_params)

# Entrenamos el modelo
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy.features, data_train_copy.labels.ravel())
# Out:
# CPU times: user 34.2 s, sys: 198 ms, total: 34.4 s
# Wall time: 596 ms

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_threshold_sweep_mult(
    dataset=data_val_copy,
    dataset2=data_val2_copy,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_mult(
    dataset=data_test_copy, 
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.2727
# AUC: 0.6214
# Balanced accuracy: 0.5983
# Accuracy: 0.6067
# Independence ( |ΔP(Y_pred = 1)| ): 0.0753
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0439
# Sufficiency ( |ΔPPV| ) : 0.0961
# CPU times: user 2.34 s, sys: 56.3 ms, total: 2.4 s
# Wall time: 166 ms

# %%
display(Markdown("**Test set results**"))
utils.print_metrics(metrics_best_thresh_test[model_name+fairness_method])
# Out:
# **Test set results**
# Threshold corresponding to *best balanced accuracy*: 0.2727
# AUC: 0.4644
# Balanced accuracy: 0.4947
# Accuracy: 0.4867
# Independence ( |ΔP(Y_pred = 1)| ): 0.0886
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0859
# Sufficiency ( |ΔPPV| ) : 0.1389

# %% [markdown]
# ## Técnicas de preprocesado

# %% [markdown]
# ### Reponderación

# %%
# %%time 

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos el pre-procesado al conjunto train
# Inicializamos la clase de pre-procesado 
PreProcessor = Reweighing(
    unprivileged_groups=unprivileged_groups,
    privileged_groups=privileged_groups
)
# Pre-procesamos (modifica los datos)
PreProcessor.fit(data_train_copy)
data_train_REW = PreProcessor.transform(data_train_copy)
data_val_REW = PreProcessor.transform(data_val_copy)
data_test_REW = PreProcessor.transform(data_test_copy)
# Out:
# CPU times: user 12.5 ms, sys: 96 µs, total: 12.5 ms
# Wall time: 11.6 ms

# %% [markdown]
# De aquí en adelante, se aplica el modelo de preferencia de manera estándar

# %% [markdown]
# ### Eliminador de impacto dispar

# %%
# %%time 

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Parámetros del modelo
nivel_reparacion = 0.5 # un valor 0 inidica ausencia de reparación (datos se mantienen igual) 
                       # un valor 1 indica reparación completa (se puede perder nivel predictivo).
                       # Se puede establecer cualquier valor entre 0 y 1.

# Hacemos el pre-procesado al conjunto train
# Inicializamos la clase de pre-procesado 
PreProcessor = DisparateImpactRemover(
    repair_level=nivel_reparacion,
    sensitive_attribute=sensitive_attribute
)
# Pre-procesamos (modifica los datos)
PreProcessor.fit(data_train_copy)
data_train_DIR = PreProcessor.fit_transform(data_train_copy)
data_val_DIR = PreProcessor.fit_transform(data_val_copy)
data_test_DIR = PreProcessor.fit_transform(data_test_copy)
# Out:
# CPU times: user 155 ms, sys: 14.6 ms, total: 169 ms
# Wall time: 168 ms

# %% [markdown]
# ## Entrenamiento de técnicas de inprocesado

# %% [markdown]
# Entrenamos ahora los algoritmos de inprocesado para aplicarlos posteriormente cuando hagan falta.

# %% [markdown]
# ### Eliminador de prejuicios por regularización

# %%
# %%time 
# Nombramos al modelo
model_name = 'prejudice_remover'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Parámetros del modelo
η = 50.0 # hyper-parameter de regularización

# Inicializamos el modelo y lo asignamos al diccionario
models[model_name] = PrejudiceRemover(sensitive_attr=sensitive_attribute, eta=η)

# Entrenamos el modelo
models[model_name] = models[model_name].fit(data_train_copy)

models[model_name].scores_train = models[model_name].predict(data_train_copy).scores
models[model_name].scores_val = models[model_name].predict(data_val_copy).scores
models[model_name].scores_test = models[model_name].predict(data_test_copy).scores
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File <timed exec>:15
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/prejudice_remover.py:160, in PrejudiceRemover.fit(self, dataset)
#     156 train_pr = os.path.join(k_path, 'kamfadm-2012ecmlpkdd', 'train_pr.py')
#     157 # changed paths in the calls below to (a) specify path of train_pr,
#     158 # predict_lr RELATIVE to this file, and (b) compute & use absolute path
#     159 #  and (c) replace python3 with python
# --> 160 subprocess.call(['python', train_pr,
#     161                  '-e', str(self.eta),
#     162                  '-i', train_name,
#     163                  '-o', model_name,
#     164                  '--quiet'])
#     165 os.unlink(train_name)
#     167 self.model_name = model_name
#
# File ~/miniconda3/envs/aif360/lib/python3.9/subprocess.py:349, in call(timeout, *popenargs, **kwargs)
#     341 def call(*popenargs, timeout=None, **kwargs):
#     342     """Run command with arguments.  Wait for command to complete or
#     343     timeout, then return the returncode attribute.
#     344
#    (...)
#     347     retcode = call(["ls", "-l"])
#     348     """
# --> 349     with Popen(*popenargs, **kwargs) as p:
#     350         try:
#     351             return p.wait(timeout=timeout)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/subprocess.py:951, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     947         if self.text_mode:
#     948             self.stderr = io.TextIOWrapper(self.stderr,
#     949                     encoding=encoding, errors=errors)
# --> 951     self._execute_child(args, executable, preexec_fn, close_fds,
#     952                         pass_fds, cwd, env,
#     953                         startupinfo, creationflags, shell,
#     954                         p2cread, p2cwrite,
#     955                         c2pread, c2pwrite,
#     956                         errread, errwrite,
#     957                         restore_signals,
#     958                         gid, gids, uid, umask,
#     959                         start_new_session)
#     960 except:
#     961     # Cleanup if the child failed starting.
#     962     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~/miniconda3/envs/aif360/lib/python3.9/subprocess.py:1837, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1835     if errno_num != 0:
#    1836         err_msg = os.strerror(errno_num)
# -> 1837     raise child_exception_type(errno_num, err_msg, err_filename)
#    1838 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'python'

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name] = utils.metrics_threshold_sweep_mult(
    dataset=data_val_copy,
    dataset2=data_val2_copy,
    model=models[model_name],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name] = utils.describe_metrics(metrics_sweep[model_name])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name] = utils.compute_metrics_mult(
    dataset=data_test_copy, 
    dataset2=data_test2_copy,
    model=models[model_name], 
    threshold=metrics_best_thresh_validate[model_name]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name])

# Graficamos el comportamiento del modelo para el rango de umbrales 
f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name])
a.set_title(model_name)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/DEFINITIVO/utils.py:583, in metrics_threshold_sweep_mult(dataset, dataset2, model, thresh_arr)
#     581 try:
#     582     # sklearn classifier
# --> 583     y_val_pred_prob = model.predict_proba(dataset.features)
#     584     pos_ind = np.where(model.classes_ == dataset.favorable_label)[0][0]
#
# AttributeError: 'PrejudiceRemover' object has no attribute 'predict_proba'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:587, in metrics_threshold_sweep_mult(dataset, dataset2, model, thresh_arr)
#     584     pos_ind = np.where(model.classes_ == dataset.favorable_label)[0][0]
#     585 except AttributeError:
#     586     # aif360 inprocessing algorithm
# --> 587     y_val_pred_prob = model.predict(dataset).scores
#     588     pos_ind = 0
#     590 # Remove nans and turn them into score of random prediction (R=0.5)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/prejudice_remover.py:204, in PrejudiceRemover.predict(self, dataset)
#     198 predict_lr = os.path.join(k_path, 'kamfadm-2012ecmlpkdd', 'predict_lr.py')
#     199 # changed paths in the calls below to (a) specify path of train_pr,
#     200 # predict_lr RELATIVE to this file, and (b) compute & use absolute path,
#     201 # and (c) replace python3 with python
#     202 subprocess.call(['python', predict_lr,
#     203                  '-i', test_name,
# --> 204                  '-m', self.model_name,
#     205                  '-o', output_name,
#     206                  '--quiet'])
#     207 os.unlink(test_name)
#     208 m = np.loadtxt(output_name)
#
# AttributeError: 'PrejudiceRemover' object has no attribute 'model_name'

# %% [markdown]
# ### Algoritmo de metafairness

# %%
# %%time 
# Nombramos al modelo
model_name = 'meta_fairness'

# Parámetros del modelo
# hyper-parameter de regularización
τ = 0.8
# métricas fairness a optimizar
quality_constraints = ['sr', 'fdr'] # sr: statistical rate, fdr: false discovery rate

# Optimizamos un modelo nuevo por cada métrica
for quality in quality_constraints:
    
    # Hacemos una copia de los datasets
    data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
    data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)
    
    # nombramos al modelo con su métrica específica
    model_name_quality = '{}_{}'.format(model_name, quality)
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_quality] = MetaFairClassifier(tau=τ, sensitive_attr=sensitive_attribute, type=quality, seed=seed)

    # Entrenamos el modelo
    models[model_name_quality] = models[ model_name_quality ].fit( data_train_copy )
    models[model_name_quality].scores_train = models[model_name_quality].predict(data_train_copy).scores
    models[model_name_quality].scores_val = models[model_name_quality].predict(data_val_copy).scores
    models[model_name_quality].scores_test = models[model_name_quality].predict(data_test_copy).scores
# Out:
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/StatisticalRate.py:36: RuntimeWarning: invalid value encountered in divide
#   prob_y_1 = (prob_1_1 + prob_1_0) / total
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/StatisticalRate.py:37: RuntimeWarning: invalid value encountered in divide
#   prob_z_0 = (prob_m1_0 + prob_1_0) / total
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/StatisticalRate.py:38: RuntimeWarning: invalid value encountered in divide
#   prob_z_1 = (prob_m1_1 + prob_1_1) / total
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:24
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/meta_fair_classifier.py:66, in MetaFairClassifier.fit(self, dataset)
#      59 y_train = np.where(dataset.labels.flatten() == dataset.favorable_label,
#      60                    1, -1)
#      61 x_control_train = np.where(
#      62         np.isin(dataset.protected_attributes[:, sens_idx],
#      63                 dataset.privileged_protected_attributes[sens_idx]),
#      64         1, 0)
# ---> 66 self.model = self.obj.getModel(self.tau, x_train, y_train,
#      67     x_control_train, self.seed)
#      69 return self
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/General.py:99, in General.getModel(self, tau, X, y, sens, random_state)
#      96 samples = dist_x.rvs(size=20)  # TODO: why 20?
#      97 params = self.gradientDescent(dist, a, b, samples, z_1)
# ---> 99 t = self.getValueForX(dist, a, b, params, z_1, X)
#     100 y_pred = np.where(t > 0, 1, -1)
#     102 acc = accuracy_score(y, y_pred)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/StatisticalRate.py:23, in StatisticalRate.getValueForX(self, dist, a, b, params, z_prior, x, return_cs)
#      22 def getValueForX(self, dist, a, b, params, z_prior, x, return_cs=False):
# ---> 23     l_1, l_2 = params
#      24     z_0, z_1 = 1-z_prior, z_prior
#      26     pos = np.ones(len(x))
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
# %%time 

for quality in quality_constraints:
    
    name_suffix = '_{}'.format(quality)
    print(f'Results for {model_name+name_suffix}')

    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name+name_suffix] = utils.metrics_threshold_sweep_mult(
        dataset=data_val_copy,
        dataset2=data_val2_copy,
        model=models[model_name+name_suffix],
        thresh_arr=thresh_sweep
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name+name_suffix] = utils.describe_metrics(metrics_sweep[model_name+name_suffix])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name+name_suffix] = utils.compute_metrics_mult(
        dataset=data_test_copy, 
        dataset2=data_test2_copy,
        model=models[model_name+name_suffix], 
        threshold=metrics_best_thresh_validate[model_name+name_suffix]['best_threshold'])

    utils.print_metrics(metrics_best_thresh_validate[model_name+name_suffix])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name+name_suffix])
    # plt.title(model_name+name_suffix)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+name_suffix])
    a.set_title(model_name+name_suffix)
    f
# Out:
# Results for meta_fairness_sr
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/DEFINITIVO/utils.py:583, in metrics_threshold_sweep_mult(dataset, dataset2, model, thresh_arr)
#     581 try:
#     582     # sklearn classifier
# --> 583     y_val_pred_prob = model.predict_proba(dataset.features)
#     584     pos_ind = np.where(model.classes_ == dataset.favorable_label)[0][0]
#
# AttributeError: 'MetaFairClassifier' object has no attribute 'predict_proba'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:7
#
# File ~/DEFINITIVO/utils.py:587, in metrics_threshold_sweep_mult(dataset, dataset2, model, thresh_arr)
#     584     pos_ind = np.where(model.classes_ == dataset.favorable_label)[0][0]
#     585 except AttributeError:
#     586     # aif360 inprocessing algorithm
# --> 587     y_val_pred_prob = model.predict(dataset).scores
#     588     pos_ind = 0
#     590 # Remove nans and turn them into score of random prediction (R=0.5)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/meta_fair_classifier.py:82, in MetaFairClassifier.predict(self, dataset)
#      71 def predict(self, dataset):
#      72     """Obtain the predictions for the provided dataset using the learned
#      73     classifier model.
#      74
#    (...)
#      80         BinaryLabelDataset: Transformed dataset.
#      81     """
# ---> 82     t = self.model(dataset.features)
#      84     pred_dataset = dataset.copy()
#      85     pred_dataset.labels = (t > 0).astype(int).reshape((-1, 1))
#
# AttributeError: 'MetaFairClassifier' object has no attribute 'model'

# %% [markdown]
# ### Eliminación de prejuicios adversarios

# %%
# %%time

# Nombramos al modelo
model_name = 'NN_adversarial_debiasing'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

sess = tf.Session()

models[model_name] = AdversarialDebiasing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    scope_name = 'debiased_classifier',
    debias=True,
    sess=sess,
    num_epochs=80)

models[model_name].fit(data_train_copy)

models[model_name].scores_train = models[model_name].predict(data_train_copy).scores
models[model_name].scores_val = models[model_name].predict(data_val_copy).scores
models[model_name].scores_test = models[model_name].predict(data_test_copy).scores
# Out:
# 2024-06-19 10:07:25.245476: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# WARNING:tensorflow:From /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1260: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# 2024-06-19 10:07:25.657774: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:388] MLIR V1 optimization pass is not enabled
# epoch 0; iter: 0; batch classifier loss: 0.747661; batch adversarial loss: 0.623399
# epoch 1; iter: 0; batch classifier loss: 0.661440; batch adversarial loss: 0.629242
# epoch 2; iter: 0; batch classifier loss: 0.694202; batch adversarial loss: 0.608350
# epoch 3; iter: 0; batch classifier loss: 0.707438; batch adversarial loss: 0.643171
# epoch 4; iter: 0; batch classifier loss: 0.690692; batch adversarial loss: 0.622036
# epoch 5; iter: 0; batch classifier loss: 0.675138; batch adversarial loss: 0.656280
# epoch 6; iter: 0; batch classifier loss: 0.682487; batch adversarial loss: 0.627651
# epoch 7; iter: 0; batch classifier loss: 0.642338; batch adversarial loss: 0.624987
# epoch 8; iter: 0; batch classifier loss: 0.686526; batch adversarial loss: 0.679306
# epoch 9; iter: 0; batch classifier loss: 0.656905; batch adversarial loss: 0.630247
# epoch 10; iter: 0; batch classifier loss: 0.672979; batch adversarial loss: 0.643836
# epoch 11; iter: 0; batch classifier loss: 0.643444; batch adversarial loss: 0.636096
# epoch 12; iter: 0; batch classifier loss: 0.669889; batch adversarial loss: 0.648217
# epoch 115; iter: 0; batch classifier loss: 0.332260
# epoch 116; iter: 0; batch classifier loss: 0.294133
# epoch 117; iter: 0; batch classifier loss: 0.354534
# epoch 118; iter: 0; batch classifier loss: 0.342808
# epoch 119; iter: 0; batch classifier loss: 0.292524
# epoch 120; iter: 0; batch classifier loss: 0.346254
# epoch 121; iter: 0; batch classifier loss: 0.345767
# epoch 122; iter: 0; batch classifier loss: 0.260657
# epoch 123; iter: 0; batch classifier loss: 0.292079
# epoch 124; iter: 0; batch classifier loss: 0.326641
# CPU times: user 5.46 s, sys: 1.94 s, total: 7.4 s
# Wall time: 2.62 s

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name] = utils.metrics_threshold_sweep_mult(
    dataset=data_val_copy,
    dataset2=data_val2_copy,
    model=models[model_name],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name] = utils.describe_metrics(metrics_sweep[model_name])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name] = utils.compute_metrics_mult(
    dataset=data_test_copy, 
    dataset2=data_test2_copy,
    model=models[model_name], 
    threshold=metrics_best_thresh_validate[model_name]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name])

# Graficamos el comportamiento del modelo para el rango de umbrales 
f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name])
a.set_title(model_name)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.4343
# AUC: 0.6875
# Balanced accuracy: 0.6741
# Accuracy: 0.6733
# Independence ( |ΔP(Y_pred = 1)| ): 0.1782
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0173
# Sufficiency ( |ΔPPV| ) : 0.1097
# CPU times: user 174 ms, sys: 22.4 ms, total: 196 ms
# Wall time: 170 ms

# %% [markdown]
# ## Preprocesado + Inprocesado

# %% [markdown]
# ### Reponderación + Eliminador de prejuicios

# %%
# Nombre del modelo
model_name = 'reweighting_prejudice_remover'

# Hacemos una copia de los datasets (usando uno de lo métodos de pre-procesado vistos anteriormente)
data_train_copy, data_val_copy, data_test_copy = data_train_REW.copy(deepcopy=True), data_val_REW.copy(deepcopy=True), data_test_REW.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Parámetros del modelo
η = 50.0 # hyper-parameter de regularización

# Inicializamos el modelo y lo asignamos al diccionario
models[model_name] = PrejudiceRemover(sensitive_attr=sensitive_attribute, eta=η)

# Entrenamos el modelo
models[model_name] = models[model_name].fit(data_train_copy)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 15
#      12 models[model_name] = PrejudiceRemover(sensitive_attr=sensitive_attribute, eta=η)
#      14 # Entrenamos el modelo
# ---> 15 models[model_name] = models[model_name].fit(data_train_copy)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/prejudice_remover.py:160, in PrejudiceRemover.fit(self, dataset)
#     156 train_pr = os.path.join(k_path, 'kamfadm-2012ecmlpkdd', 'train_pr.py')
#     157 # changed paths in the calls below to (a) specify path of train_pr,
#     158 # predict_lr RELATIVE to this file, and (b) compute & use absolute path
#     159 #  and (c) replace python3 with python
# --> 160 subprocess.call(['python', train_pr,
#     161                  '-e', str(self.eta),
#     162                  '-i', train_name,
#     163                  '-o', model_name,
#     164                  '--quiet'])
#     165 os.unlink(train_name)
#     167 self.model_name = model_name
#
# File ~/miniconda3/envs/aif360/lib/python3.9/subprocess.py:349, in call(timeout, *popenargs, **kwargs)
#     341 def call(*popenargs, timeout=None, **kwargs):
#     342     """Run command with arguments.  Wait for command to complete or
#     343     timeout, then return the returncode attribute.
#     344
#    (...)
#     347     retcode = call(["ls", "-l"])
#     348     """
# --> 349     with Popen(*popenargs, **kwargs) as p:
#     350         try:
#     351             return p.wait(timeout=timeout)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/subprocess.py:951, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     947         if self.text_mode:
#     948             self.stderr = io.TextIOWrapper(self.stderr,
#     949                     encoding=encoding, errors=errors)
# --> 951     self._execute_child(args, executable, preexec_fn, close_fds,
#     952                         pass_fds, cwd, env,
#     953                         startupinfo, creationflags, shell,
#     954                         p2cread, p2cwrite,
#     955                         c2pread, c2pwrite,
#     956                         errread, errwrite,
#     957                         restore_signals,
#     958                         gid, gids, uid, umask,
#     959                         start_new_session)
#     960 except:
#     961     # Cleanup if the child failed starting.
#     962     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~/miniconda3/envs/aif360/lib/python3.9/subprocess.py:1837, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1835     if errno_num != 0:
#    1836         err_msg = os.strerror(errno_num)
# -> 1837     raise child_exception_type(errno_num, err_msg, err_filename)
#    1838 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'python'

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name] = utils.metrics_threshold_sweep_mult(
    dataset=data_val_copy,
    dataset2=data_val2_copy,
    model=models[model_name],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name] = utils.describe_metrics(metrics_sweep[model_name])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name] = utils.compute_metrics_mult(
    dataset=data_test_copy, 
    dataset2=data_test2_copy,
    model=models[model_name], 
    threshold=metrics_best_thresh_validate[model_name]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name])

# Graficamos el comportamiento del modelo para el rango de umbrales 
f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name])
a.set_title(model_name)
f

# %% [markdown]
# ### Impacto dispar + Eliminador de prejuicios

# %%
# Nombre del modelo
model_name = 'disparate_impact_prejudice_remover'

# Hacemos una copia de los datasets (usando uno de lo métodos de pre-procesado vistos anteriormente)
data_train_copy, data_val_copy, data_test_copy = data_train_DIR.copy(deepcopy=True), data_val_DIR.copy(deepcopy=True), data_test_DIR.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Parámetros del modelo
η = 50.0 # hyper-parameter de regularización

# Inicializamos el modelo y lo asignamos al diccionario
models[model_name] = PrejudiceRemover(sensitive_attr=sensitive_attribute, eta=η)

# Entrenamos el modelo
models[model_name] = models[model_name].fit(data_train_copy)

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name] = utils.metrics_threshold_sweep_mult(
    dataset=data_val_copy,
    dataset2=data_val2_copy,
    model=models[model_name],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name] = utils.describe_metrics(metrics_sweep[model_name])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name] = utils.compute_metrics_mult(
    dataset=data_test_copy, 
    dataset2=data_test2_copy,
    model=models[model_name], 
    threshold=metrics_best_thresh_validate[model_name]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name])

# Graficamos el comportamiento del modelo para el rango de umbrales 
f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name])
a.set_title(model_name)
f

# %% [markdown]
# ### Reponderación + metafairness

# %%
# %%time 
# Nombramos al modelo
model_name = 'reweighing_meta_fairness'

# Parámetros del modelo
# hyper-parameter de regularización
τ = 0.8
# métricas fairness a optimizar
quality_constraints = ['sr', 'fdr'] # sr: statistical rate, fdr: false discovery rate

# Optimizamos un modelo nuevo por cada métrica
for quality in quality_constraints:
    
    # Hacemos una copia de los datasets
    data_train_copy, data_val_copy, data_test_copy = data_train_REW.copy(deepcopy=True), data_val_REW.copy(deepcopy=True), data_test_REW.copy(deepcopy=True)
    data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)
    
    # nombramos al modelo con su métrica específica
    model_name_quality = '{}_{}'.format(model_name, quality)
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_quality] = MetaFairClassifier(tau=τ, sensitive_attr=sensitive_attribute, type=quality, seed=seed)

    # Entrenamos el modelo
    models[model_name_quality] = models[ model_name_quality ].fit( data_train_copy )
# Out:
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/StatisticalRate.py:36: RuntimeWarning: invalid value encountered in divide
#   prob_y_1 = (prob_1_1 + prob_1_0) / total
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/StatisticalRate.py:37: RuntimeWarning: invalid value encountered in divide
#   prob_z_0 = (prob_m1_0 + prob_1_0) / total
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/StatisticalRate.py:38: RuntimeWarning: invalid value encountered in divide
#   prob_z_1 = (prob_m1_1 + prob_1_1) / total
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:24
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/meta_fair_classifier.py:66, in MetaFairClassifier.fit(self, dataset)
#      59 y_train = np.where(dataset.labels.flatten() == dataset.favorable_label,
#      60                    1, -1)
#      61 x_control_train = np.where(
#      62         np.isin(dataset.protected_attributes[:, sens_idx],
#      63                 dataset.privileged_protected_attributes[sens_idx]),
#      64         1, 0)
# ---> 66 self.model = self.obj.getModel(self.tau, x_train, y_train,
#      67     x_control_train, self.seed)
#      69 return self
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/General.py:99, in General.getModel(self, tau, X, y, sens, random_state)
#      96 samples = dist_x.rvs(size=20)  # TODO: why 20?
#      97 params = self.gradientDescent(dist, a, b, samples, z_1)
# ---> 99 t = self.getValueForX(dist, a, b, params, z_1, X)
#     100 y_pred = np.where(t > 0, 1, -1)
#     102 acc = accuracy_score(y, y_pred)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/StatisticalRate.py:23, in StatisticalRate.getValueForX(self, dist, a, b, params, z_prior, x, return_cs)
#      22 def getValueForX(self, dist, a, b, params, z_prior, x, return_cs=False):
# ---> 23     l_1, l_2 = params
#      24     z_0, z_1 = 1-z_prior, z_prior
#      26     pos = np.ones(len(x))
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
# %%time 

for quality in quality_constraints:
    
    name_suffix = '_{}'.format(quality)
    print(f'Results for {model_name+name_suffix}')

    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name+name_suffix] = utils.metrics_threshold_sweep_mult(
        dataset=data_val_copy,
        dataset2=data_val2_copy,
        model=models[model_name+name_suffix],
        thresh_arr=thresh_sweep
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name+name_suffix] = utils.describe_metrics(metrics_sweep[model_name+name_suffix])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name+name_suffix] = utils.compute_metrics_mult(
        dataset=data_test_copy, 
        dataset2=data_test2_copy,
        model=models[model_name+name_suffix], 
        threshold=metrics_best_thresh_validate[model_name+name_suffix]['best_threshold'])

    utils.print_metrics(metrics_best_thresh_validate[model_name+name_suffix])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name+name_suffix])
    # plt.title(model_name+name_suffix)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+name_suffix])
    a.set_title(model_name+name_suffix)
    f
# Out:
# Results for reweighing_meta_fairness_sr
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/DEFINITIVO/utils.py:583, in metrics_threshold_sweep_mult(dataset, dataset2, model, thresh_arr)
#     581 try:
#     582     # sklearn classifier
# --> 583     y_val_pred_prob = model.predict_proba(dataset.features)
#     584     pos_ind = np.where(model.classes_ == dataset.favorable_label)[0][0]
#
# AttributeError: 'MetaFairClassifier' object has no attribute 'predict_proba'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:7
#
# File ~/DEFINITIVO/utils.py:587, in metrics_threshold_sweep_mult(dataset, dataset2, model, thresh_arr)
#     584     pos_ind = np.where(model.classes_ == dataset.favorable_label)[0][0]
#     585 except AttributeError:
#     586     # aif360 inprocessing algorithm
# --> 587     y_val_pred_prob = model.predict(dataset).scores
#     588     pos_ind = 0
#     590 # Remove nans and turn them into score of random prediction (R=0.5)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/meta_fair_classifier.py:82, in MetaFairClassifier.predict(self, dataset)
#      71 def predict(self, dataset):
#      72     """Obtain the predictions for the provided dataset using the learned
#      73     classifier model.
#      74
#    (...)
#      80         BinaryLabelDataset: Transformed dataset.
#      81     """
# ---> 82     t = self.model(dataset.features)
#      84     pred_dataset = dataset.copy()
#      85     pred_dataset.labels = (t > 0).astype(int).reshape((-1, 1))
#
# AttributeError: 'MetaFairClassifier' object has no attribute 'model'

# %% [markdown]
# ### Impacto dispar + metafairness

# %%
# %%time 
# Nombramos al modelo
model_name = 'disparate_impact_meta_fairness'

# Parámetros del modelo
# hyper-parameter de regularización
τ = 0.8
# métricas fairness a optimizar
quality_constraints = ['sr', 'fdr'] # sr: statistical rate, fdr: false discovery rate

# Optimizamos un modelo nuevo por cada métrica
for quality in quality_constraints:
    
    # Hacemos una copia de los datasets
    data_train_copy, data_val_copy, data_test_copy = data_train_DIR.copy(deepcopy=True), data_val_DIR.copy(deepcopy=True), data_test_DIR.copy(deepcopy=True)
    data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)
    
    # nombramos al modelo con su métrica específica
    model_name_quality = '{}_{}'.format(model_name, quality)
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_quality] = MetaFairClassifier(tau=τ, sensitive_attr=sensitive_attribute, type=quality, seed=seed)

    # Entrenamos el modelo
    models[model_name_quality] = models[ model_name_quality ].fit( data_train_copy )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:24
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/meta_fair_classifier.py:66, in MetaFairClassifier.fit(self, dataset)
#      59 y_train = np.where(dataset.labels.flatten() == dataset.favorable_label,
#      60                    1, -1)
#      61 x_control_train = np.where(
#      62         np.isin(dataset.protected_attributes[:, sens_idx],
#      63                 dataset.privileged_protected_attributes[sens_idx]),
#      64         1, 0)
# ---> 66 self.model = self.obj.getModel(self.tau, x_train, y_train,
#      67     x_control_train, self.seed)
#      69 return self
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/General.py:99, in General.getModel(self, tau, X, y, sens, random_state)
#      96 samples = dist_x.rvs(size=20)  # TODO: why 20?
#      97 params = self.gradientDescent(dist, a, b, samples, z_1)
# ---> 99 t = self.getValueForX(dist, a, b, params, z_1, X)
#     100 y_pred = np.where(t > 0, 1, -1)
#     102 acc = accuracy_score(y, y_pred)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/StatisticalRate.py:23, in StatisticalRate.getValueForX(self, dist, a, b, params, z_prior, x, return_cs)
#      22 def getValueForX(self, dist, a, b, params, z_prior, x, return_cs=False):
# ---> 23     l_1, l_2 = params
#      24     z_0, z_1 = 1-z_prior, z_prior
#      26     pos = np.ones(len(x))
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
# %%time 

for quality in quality_constraints:
    
    name_suffix = '_{}'.format(quality)
    print(f'Results for {model_name+name_suffix}')

    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name+name_suffix] = utils.metrics_threshold_sweep_mult(
        dataset=data_val_copy,
        dataset2=data_val2_copy,
        model=models[model_name+name_suffix],
        thresh_arr=thresh_sweep
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name+name_suffix] = utils.describe_metrics(metrics_sweep[model_name+name_suffix])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name+name_suffix] = utils.compute_metrics_mult(
        dataset=data_test_copy, 
        dataset2=data_test2_copy,
        model=models[model_name+name_suffix], 
        threshold=metrics_best_thresh_validate[model_name+name_suffix]['best_threshold'])

    utils.print_metrics(metrics_best_thresh_validate[model_name+name_suffix])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name+name_suffix])
    # plt.title(model_name+name_suffix)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+name_suffix])
    a.set_title(model_name+name_suffix)
    f
# Out:
# Results for disparate_impact_meta_fairness_sr
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/DEFINITIVO/utils.py:583, in metrics_threshold_sweep_mult(dataset, dataset2, model, thresh_arr)
#     581 try:
#     582     # sklearn classifier
# --> 583     y_val_pred_prob = model.predict_proba(dataset.features)
#     584     pos_ind = np.where(model.classes_ == dataset.favorable_label)[0][0]
#
# AttributeError: 'MetaFairClassifier' object has no attribute 'predict_proba'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:7
#
# File ~/DEFINITIVO/utils.py:587, in metrics_threshold_sweep_mult(dataset, dataset2, model, thresh_arr)
#     584     pos_ind = np.where(model.classes_ == dataset.favorable_label)[0][0]
#     585 except AttributeError:
#     586     # aif360 inprocessing algorithm
# --> 587     y_val_pred_prob = model.predict(dataset).scores
#     588     pos_ind = 0
#     590 # Remove nans and turn them into score of random prediction (R=0.5)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/meta_fair_classifier.py:82, in MetaFairClassifier.predict(self, dataset)
#      71 def predict(self, dataset):
#      72     """Obtain the predictions for the provided dataset using the learned
#      73     classifier model.
#      74
#    (...)
#      80         BinaryLabelDataset: Transformed dataset.
#      81     """
# ---> 82     t = self.model(dataset.features)
#      84     pred_dataset = dataset.copy()
#      85     pred_dataset.labels = (t > 0).astype(int).reshape((-1, 1))
#
# AttributeError: 'MetaFairClassifier' object has no attribute 'model'

# %% [markdown]
# ### Reponderación + prejuicios adversarios

# %%
# %%time

# Nombramos al modelo
model_name = 'reweighing_NN_adversarial_debiasing'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train_REW.copy(deepcopy=True), data_val_REW.copy(deepcopy=True), data_test_REW.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

sess = tf.Session()

models[model_name] = AdversarialDebiasing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    scope_name = 'debiased_classifier',
    debias=True,
    sess=sess,
    num_epochs=80)

models[model_name].fit(data_train_copy)
# Out:
# epoch 0; iter: 0; batch classifier loss: 0.688316; batch adversarial loss: 0.848397
# epoch 1; iter: 0; batch classifier loss: 0.682540; batch adversarial loss: 0.872645
# epoch 2; iter: 0; batch classifier loss: 0.722168; batch adversarial loss: 0.930204
# epoch 3; iter: 0; batch classifier loss: 0.718064; batch adversarial loss: 0.878270
# epoch 4; iter: 0; batch classifier loss: 0.787251; batch adversarial loss: 0.912973
# epoch 5; iter: 0; batch classifier loss: 0.725242; batch adversarial loss: 0.884514
# epoch 6; iter: 0; batch classifier loss: 0.828960; batch adversarial loss: 0.925783
# epoch 7; iter: 0; batch classifier loss: 0.857804; batch adversarial loss: 0.967796
# epoch 8; iter: 0; batch classifier loss: 0.805474; batch adversarial loss: 0.942492
istic_regression'

# Parámetros del modelo
fit_params = {'logisticregression__sample_weight': data_train_copy.instance_weights}

# Asignamos el modelo al diccionario
models[model_name+fairness_method] = make_pipeline(
            #StandardScaler(),
            LogisticRegression(solver='liblinear', random_state=seed))

# Entrenamos el modelo
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy.features, data_train_copy.labels.ravel(), **fit_params)

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_threshold_sweep_mult(
    dataset=data_val_copy,
    dataset2=data_val2_copy,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_mult(
    dataset=data_test_copy, 
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.4545
# AUC: 0.6457
# Balanced accuracy: 0.6090
# Accuracy: 0.6133
# Independence ( |ΔP(Y_pred = 1)| ): 0.1644
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0484
# Sufficiency ( |ΔPPV| ) : 0.1243

# %%
# %%time 

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train_REW.copy(deepcopy=True), data_val_REW.copy(deepcopy=True), data_test_REW.copy(deepcopy=True)

# Nombramos al modelo
model_name = 'reweighin_xgb_classifier'

# Parámetros del modelo
fit_params = {'eval_metric': 'error', 'eta':0.1, 'max_depth':6, 'subsample':0.8}

# Asignamos el modelo al diccionario
models[model_name+fairness_method] = XGBClassifier(**fit_params)

# Entrenamos el modelo
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy.features, data_train_copy.labels.ravel())

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_threshold_sweep_mult(
    dataset=data_val_copy,
    dataset2=data_val2_copy,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_mult(
    dataset=data_test_copy, 
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.2727
# AUC: 0.6214
# Balanced accuracy: 0.5983
# Accuracy: 0.6067
# Independence ( |ΔP(Y_pred = 1)| ): 0.0753
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0439
# Sufficiency ( |ΔPPV| ) : 0.0961
# CPU times: user 34.3 s, sys: 338 ms, total: 34.6 s
# Wall time: 688 ms

# %% [markdown]
# #### Disparate impact

# %%
# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train_DIR.copy(deepcopy=True), data_val_DIR.copy(deepcopy=True), data_test_DIR.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Regresión logística
model_name = 'disparate_impact_logistic_regression'

# Parámetros del modelo
fit_params = {'logisticregression__sample_weight': data_train_copy.instance_weights}

# Asignamos el modelo al diccionario
models[model_name+fairness_method] = make_pipeline(
            #StandardScaler(),
            LogisticRegression(solver='liblinear', random_state=seed))

# Entrenamos el modelo
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy.features, data_train_copy.labels.ravel(), **fit_params)

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_threshold_sweep_mult(
    dataset=data_val_copy,
    dataset2=data_val2_copy,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_mult(
    dataset=data_test_copy, 
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.5151
# AUC: 0.6457
# Balanced accuracy: 0.6068
# Accuracy: 0.6067
# Independence ( |ΔP(Y_pred = 1)| ): 0.1484
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0628
# Sufficiency ( |ΔPPV| ) : 0.0258

# %%
# %%time 

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train_DIR.copy(deepcopy=True), data_val_DIR.copy(deepcopy=True), data_test_DIR.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Nombramos al modelo
model_name = 'disparate_impact_xgb_classifier'

# Parámetros del modelo
fit_params = {'eval_metric': 'error', 'eta':0.1, 'max_depth':6, 'subsample':0.8}

# Asignamos el modelo al diccionario
models[model_name+fairness_method] = XGBClassifier(**fit_params)

# Entrenamos el modelo
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy.features, data_train_copy.labels.ravel())

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_threshold_sweep_mult(
    dataset=data_val_copy,
    dataset2=data_val2_copy,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_mult(
    dataset=data_test_copy, 
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.2727
# AUC: 0.6214
# Balanced accuracy: 0.5983
# Accuracy: 0.6067
# Independence ( |ΔP(Y_pred = 1)| ): 0.0753
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0439
# Sufficiency ( |ΔPPV| ) : 0.0961
# CPU times: user 34.8 s, sys: 264 ms, total: 35 s
# Wall time: 689 ms

# %%
#Anotamos los nombres de los modelos
model_names = ['reweighin_logistic_regression', 'reweighin_xgb_classifier', 'disparate_impact_logistic_regression', 'disparate_impact_xgb_classifier']

# %% [markdown]
# ### Aplicación de técnicas de postprocesado

# %% [markdown]
# #### Reponderación + Clasificación de rechazo de opción

# %%
# %%time 

# Nombramos al modelo
fairness_method = '_reject_option'

# Nombre del modelo al que le aplicaremos post-processing
model_name = 'reweighin_logistic_regression'

# métricas fair a optimizar
fair_metrics = {'spd': "Statistical parity difference", 'aod': "Average odds difference", 'eod': "Equal opportunity difference"}

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])

# Optimizamos un modelo nuevo por cada métrica
for key_metric in fair_metrics:
    
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    models[model_name_metric] = RejectOptionClassification(
        unprivileged_groups=unprivileged_groups, 
        privileged_groups=privileged_groups, 
        metric_name=fair_metrics[key_metric],
        metric_lb=-0.01, metric_ub=0.01)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 10.5 s, sys: 3.4 s, total: 14 s
# Wall time: 9.96 s

# %%
display(Markdown("**Validation set results for logistic regression**"))
for key_metric in fair_metrics:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_val_copy, 
        dataset_preds=data_val_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
    
    print(model_name_metric)
    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')
    
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy, 
        dataset_preds=data_test_preds, 
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        required_threshold=False)
# Out:
# **Validation set results for logistic regression**
# reweighin_logistic_regression_reject_option_spd
# Threshold corresponding to *best balanced accuracy*: 0.4951
# AUC: 0.6457
# Balanced accuracy: 0.5972
# Accuracy: 0.6000
# Independence ( |ΔP(Y_pred = 1)| ): 0.0222
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0754
# Sufficiency ( |ΔPPV| ) : 0.0538
#
#
# reweighin_logistic_regression_reject_option_aod
# Threshold corresponding to *best balanced accuracy*: 0.4951
# AUC: 0.6457
# Balanced accuracy: 0.5972
# Accuracy: 0.6000
# Independence ( |ΔP(Y_pred = 1)| ): 0.0222
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0754
# Sufficiency ( |ΔPPV| ) : 0.0538
#
#
# reweighin_logistic_regression_reject_option_eod
# Threshold corresponding to *best balanced accuracy*: 0.4456
# AUC: 0.6457
# Balanced accuracy: 0.5668
# Accuracy: 0.5733
# Independence ( |ΔP(Y_pred = 1)| ): 0.0693
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0311
# Sufficiency ( |ΔPPV| ) : 0.0972

# %%
# %%time 

# Nombramos al modelo
fairness_method = '_reject_option'

# Nombre del modelo al que le aplicaremos post-processing
model_name = 'reweighin_xgb_classifier'

# métricas fair a optimizar
fair_metrics = {'spd': "Statistical parity difference", 'aod': "Average odds difference", 'eod': "Equal opportunity difference"}

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])

# Optimizamos un modelo nuevo por cada métrica
for key_metric in fair_metrics:
    
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    models[model_name_metric] = RejectOptionClassification(
        unprivileged_groups=unprivileged_groups, 
        privileged_groups=privileged_groups, 
        metric_name=fair_metrics[key_metric],
        metric_lb=-0.01, metric_ub=0.01)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 12.4 s, sys: 233 ms, total: 12.7 s
# Wall time: 10.5 s

# %%
display(Markdown("**Validation set results for xgb classifier**"))
for key_metric in fair_metrics:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_val_copy, 
        dataset_preds=data_val_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
    
    print(model_name_metric)
    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')
    
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy, 
        dataset_preds=data_test_preds, 
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        required_threshold=False)
# Out:
# **Validation set results for xgb classifier**
# reweighin_xgb_classifier_reject_option_spd
# Threshold corresponding to *best balanced accuracy*: 0.2377
# AUC: 0.6214
# Balanced accuracy: 0.5700
# Accuracy: 0.5800
# Independence ( |ΔP(Y_pred = 1)| ): 0.1254
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0596
# Sufficiency ( |ΔPPV| ) : 0.1580
#
#
# reweighin_xgb_classifier_reject_option_aod
# Threshold corresponding to *best balanced accuracy*: 0.2377
# AUC: 0.6214
# Balanced accuracy: 0.5700
# Accuracy: 0.5800
# Independence ( |ΔP(Y_pred = 1)| ): 0.1254
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0596
# Sufficiency ( |ΔPPV| ) : 0.1580
#
#
# reweighin_xgb_classifier_reject_option_eod
# Threshold corresponding to *best balanced accuracy*: 0.2377
# AUC: 0.6214
# Balanced accuracy: 0.5700
# Accuracy: 0.5800
# Independence ( |ΔP(Y_pred = 1)| ): 0.1254
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0596
# Sufficiency ( |ΔPPV| ) : 0.1580

# %% [markdown]
# #### Impacto dispar + Rechazo de opción

# %%
# %%time 

# Nombramos al modelo
fairness_method = '_reject_option'

# Nombre del modelo al que le aplicaremos post-processing
model_name = 'disparate_impact_logistic_regression'

# métricas fair a optimizar
fair_metrics = {'spd': "Statistical parity difference", 'aod': "Average odds difference", 'eod': "Equal opportunity difference"}

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])

# Optimizamos un modelo nuevo por cada métrica
for key_metric in fair_metrics:
    
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    models[model_name_metric] = RejectOptionClassification(
        unprivileged_groups=unprivileged_groups, 
        privileged_groups=privileged_groups, 
        metric_name=fair_metrics[key_metric],
        metric_lb=-0.01, metric_ub=0.01)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 10.4 s, sys: 3.21 s, total: 13.6 s
# Wall time: 9.7 s

# %%
display(Markdown("**Validation set results for logistic regression**"))
for key_metric in fair_metrics:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_val_copy, 
        dataset_preds=data_val_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
    
    print(model_name_metric)
    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')
    
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy, 
        dataset_preds=data_test_preds, 
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        required_threshold=False)
# Out:
# **Validation set results for logistic regression**
# disparate_impact_logistic_regression_reject_option_spd
# Threshold corresponding to *best balanced accuracy*: 0.3070
# AUC: 0.6457
# Balanced accuracy: 0.5235
# Accuracy: 0.5400
# Independence ( |ΔP(Y_pred = 1)| ): 0.0478
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0439
# Sufficiency ( |ΔPPV| ) : 0.1376
#
#
# disparate_impact_logistic_regression_reject_option_aod
# Threshold corresponding to *best balanced accuracy*: 0.3070
# AUC: 0.6457
# Balanced accuracy: 0.5235
# Accuracy: 0.5400
# Independence ( |ΔP(Y_pred = 1)| ): 0.0478
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0439
# Sufficiency ( |ΔPPV| ) : 0.1376
#
#
# disparate_impact_logistic_regression_reject_option_eod
# Threshold corresponding to *best balanced accuracy*: 0.4456
# AUC: 0.6457
# Balanced accuracy: 0.5668
# Accuracy: 0.5733
# Independence ( |ΔP(Y_pred = 1)| ): 0.0693
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0311
# Sufficiency ( |ΔPPV| ) : 0.0972

# %%
# %%time 

# Nombramos al modelo
fairness_method = '_reject_option'

# Nombre del modelo al que le aplicaremos post-processing
model_name = 'disparate_impact_xgb_classifier'

# métricas fair a optimizar
fair_metrics = {'spd': "Statistical parity difference", 'aod': "Average odds difference", 'eod': "Equal opportunity difference"}

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])

# Optimizamos un modelo nuevo por cada métrica
for key_metric in fair_metrics:
    
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    models[model_name_metric] = RejectOptionClassification(
        unprivileged_groups=unprivileged_groups, 
        privileged_groups=privileged_groups, 
        metric_name=fair_metrics[key_metric],
        metric_lb=-0.01, metric_ub=0.01)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 11.1 s, sys: 142 ms, total: 11.3 s
# Wall time: 9.8 s

# %%
display(Markdown("**Validation set results for xgb classifier**"))
for key_metric in fair_metrics:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_val_copy, 
        dataset_preds=data_val_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
    
    print(model_name_metric)
    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')
    
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy, 
        dataset_preds=data_test_preds, 
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        required_threshold=False)
# Out:
# **Validation set results for xgb classifier**
# disparate_impact_xgb_classifier_reject_option_spd
# Threshold corresponding to *best balanced accuracy*: 0.2377
# AUC: 0.6214
# Balanced accuracy: 0.5700
# Accuracy: 0.5800
# Independence ( |ΔP(Y_pred = 1)| ): 0.1254
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0596
# Sufficiency ( |ΔPPV| ) : 0.1580
#
#
# disparate_impact_xgb_classifier_reject_option_aod
# Threshold corresponding to *best balanced accuracy*: 0.2377
# AUC: 0.6214
# Balanced accuracy: 0.5700
# Accuracy: 0.5800
# Independence ( |ΔP(Y_pred = 1)| ): 0.1254
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0596
# Sufficiency ( |ΔPPV| ) : 0.1580
#
#
# disparate_impact_xgb_classifier_reject_option_eod
# Threshold corresponding to *best balanced accuracy*: 0.2377
# AUC: 0.6214
# Balanced accuracy: 0.5700
# Accuracy: 0.5800
# Independence ( |ΔP(Y_pred = 1)| ): 0.1254
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0596
# Sufficiency ( |ΔPPV| ) : 0.1580

# %% [markdown]
# #### Reponderación y impacto dispar + Escalado de Platt por grupos

# %%
# %%time
fairness_method = '_platt_scaling'
model_names = model_names
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy = True), data_val.copy(deepcopy = True), data_test.copy(deepcopy = True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

for model_name in model_names:
    # Hacemos una copia de las predicciones del modelo de referencia
    model_thresh = metrics_best_thresh_validate[model_name]['best_threshold']
    data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name], class_thresh = model_thresh)
    data_val_preds_m = utils.update_dataset_from_model2(data_val, data_val2_copy, models[model_name], class_thresh = model_thresh)
    ## Plat Scaling:
    #1. dividir el validation data usando los groups sensibles
    data_val_preds_priv, data_val_preds_unpriv, priv_indices, unpriv_indices = utils.split_dataset_on_sensitive_attribute(
        dataset = data_val_preds, privileged_group_label = list((privileged_groups[0].values()))[0])
    #2. copia el validation data para guardar los scores
    data_val_preds2_m = data_val_preds_m.copy(deepcopy = True)
    data_val_preds2 = data_val_preds.copy(deepcopy = True)
    #3. hacer un modelo para cada grupo
    sensitive_groups_data = {'priv': [data_val_preds_priv, priv_indices],
                             'unpriv': [data_val_preds_unpriv, unpriv_indices]}

    for group, data_group_list in sensitive_groups_data.items():

        # nombramos al modelo con su grupo específico
        model_name_group = '{}_{}_{}'.format(model_name, fairness_method, group)

        # Inicializamos el modelo y lo asignamos al diccionario
        models[model_name_group] = LogisticRegression()

        # Realizamos el modelo usando datos para cada grupo en el validation data
        models[ model_name_group ] = models[model_name_group].fit(data_group_list[0].scores,   # data_group_list[0] -> data_val_preds_priv or data_val_preds_unpriv
                                                                  data_val_copy.subset(data_group_list[1]).labels.ravel()) # data_group_list[1] -> priv_indices or unpriv_indices
        # haz predicciones de probabilidad con el modelo de cada groupo y guardar lo en data_val_preds2
        # las predicciones de probabilidad son los platt scores
        scores_group = models[model_name_group].predict_proba(data_group_list[0].scores)
        pos_ind_group = np.where(models[model_name_group].classes_ == data_group_list[0].favorable_label)[0][0]
        data_val_preds2.scores[data_group_list[1]] = scores_group[:, pos_ind_group].reshape(-1,1)
        data_val_preds2_m.scores[data_group_list[1]] = scores_group[:, pos_ind_group].reshape(-1,1)
        
        # Evaluamos a los modelos para el rango de umbrales
    thresh_sweep_platt = np.linspace(np.min(data_val_preds2.scores.ravel()),
                                     np.max(data_val_preds2.scores.ravel()),
                                     50)

    metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep_from_scores_mult(
            dataset_true = data_val_copy,
            dataset2 =data_val2_copy,
            dataset_preds = data_val_preds2_m,
            thresh_arr = thresh_sweep_platt
        )

    # Evaluamos las métricas para el mejor umbral y las guardamos
    metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics( metrics_sweep[model_name+fairness_method] )

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    print('\nValidation set results for {}'.format(model_name))
    utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
    # utils.plot_fairness_and_accuracy( metrics_sweep[model_name+fairness_method] )
    # plt.title( model_name+fairness_method )
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
    a.set_title(model_name+fairness_method )
    f
# Out:
# Validation set results for reweighin_logistic_regression
# Threshold corresponding to *best balanced accuracy*: 0.5232
# AUC: 0.6359
# Balanced accuracy: 0.6047
# Accuracy: 0.6067
# Independence ( |ΔP(Y_pred = 1)| ): 0.2138
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0474
# Sufficiency ( |ΔPPV| ) : 0.0655
#
# Validation set results for reweighin_xgb_classifier
# Threshold corresponding to *best balanced accuracy*: 0.4873
# AUC: 0.6312
# Balanced accuracy: 0.6271
# Accuracy: 0.6333
# Independence ( |ΔP(Y_pred = 1)| ): 0.1559
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0374
# Sufficiency ( |ΔPPV| ) : 0.0078
#
# Validation set results for disparate_impact_logistic_regression
# Threshold corresponding to *best balanced accuracy*: 0.5233
# AUC: 0.6359
# Balanced accuracy: 0.6047
# Accuracy: 0.6067
# Independence ( |ΔP(Y_pred = 1)| ): 0.2138
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0474
# Sufficiency ( |ΔPPV| ) : 0.0655
#
# Validation set results for disparate_impact_xgb_classifier
# Threshold corresponding to *best balanced accuracy*: 0.4873
# AUC: 0.6312
# Balanced accuracy: 0.6271
# Accuracy: 0.6333
# Independence ( |ΔP(Y_pred = 1)| ): 0.1559
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0374
# Sufficiency ( |ΔPPV| ) : 0.0078
# CPU times: user 7.39 s, sys: 563 ms, total: 7.95 s
# Wall time: 541 ms

# %%
# usa el optimal cutoff para predecir usando el test dato

for model_name in model_names:
    model_thresh = metrics_best_thresh_validate[model_name]['best_threshold']
    data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name], class_thresh = model_thresh)
    data_test_preds_m = utils.update_dataset_from_model2(data_test_copy, data_test2_copy, models[model_name], class_thresh = model_thresh)
    
    # 1. dividir el validation data usando los groups sensibles
    data_test_preds_priv, data_test_preds_unpriv, priv_indices, unpriv_indices = utils.split_dataset_on_sensitive_attribute(dataset = data_test_preds,
                                                                                                                            privileged_group_label = list((privileged_groups[0].values()))[0])
    # 2. copia el test data para guardar los platt scores
    data_test_preds2 = data_test_preds.copy(deepcopy = True)
    data_test_preds2_m = data_test_preds_m.copy(deepcopy = True)
    
    # 3. predecir con el modelo de cada grupo
    sensitive_groups_data_test = {'priv': [data_test_preds_priv, priv_indices],
                                  'unpriv': [data_test_preds_unpriv, unpriv_indices]}

    for group, data_group_list in sensitive_groups_data_test.items():    
        # nombramos al modelo con su grupo específico
        model_name_group = '{}_{}_{}'.format(model_name, fairness_method, group)

        # haz predicciones de probabilidad con el modelo de cada groupo y guardar lo en data_val_preds2
        # las predicciones de probabilidad son los platt scores
        scores_group = models[model_name_group].predict_proba(data_group_list[0].scores)
        pos_ind_group = np.where(models[model_name_group].classes_ == data_group_list[0].favorable_label)[0][0]
        data_test_preds2.scores[data_group_list[1]] = scores_group[:, pos_ind_group].reshape(-1,1)

    data_test_preds2_m = data_test2_copy.copy(deepcopy = True)
    data_test_preds2_m.scores = data_test_preds2.scores
    
    metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_from_scores_mult(dataset_true = data_test_copy,
                                                                                             dataset_pred = data_test_preds2_m,
                                                                                             dataset2=data_test2_copy,
                                                                                             threshold = metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

# %% [markdown]
# #### Reponderación + Procesador de probabilidades igualadas

# %% [markdown]
# ##### Usando labels

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'reweighin_logistic_regression'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:24
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:144, in EqOddsPostprocessing.fit(self, dataset_true, dataset_pred)
#     139 oflip = np.ravel(
#     140     dataset_pred.labels[cond_vec_unpriv] == dataset_pred.unfavorable_label)
#     142 y_true = dataset_true.labels.ravel()
# --> 144 sm_tn = np.logical_and(sflip,
#     145     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     146     dtype=np.float64)
#     147 sm_fn = np.logical_and(sflip,
#     148     y_true[cond_vec_priv] == dataset_true.favorable_label,
#     149     dtype=np.float64)
#     150 sm_fp = np.logical_and(sconst,
#     151     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     152     dtype=np.float64)
#
# TypeError: No loop matching the specified signature and casting was found for ufunc logical_and

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing_mult(
    dataset_true=data_test_copy,
    dataset2=data_test2_copy,
    dataset_preds=data_test_preds,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'reweighin_xgb_classifier'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:24
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:144, in EqOddsPostprocessing.fit(self, dataset_true, dataset_pred)
#     139 oflip = np.ravel(
#     140     dataset_pred.labels[cond_vec_unpriv] == dataset_pred.unfavorable_label)
#     142 y_true = dataset_true.labels.ravel()
# --> 144 sm_tn = np.logical_and(sflip,
#     145     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     146     dtype=np.float64)
#     147 sm_fn = np.logical_and(sflip,
#     148     y_true[cond_vec_priv] == dataset_true.favorable_label,
#     149     dtype=np.float64)
#     150 sm_fp = np.logical_and(sconst,
#     151     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     152     dtype=np.float64)
#
# TypeError: No loop matching the specified signature and casting was found for ufunc logical_and

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing_mult(
    dataset_true=data_test_copy,
    dataset_preds=data_test_preds,
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %% [markdown]
# #### Usando scores

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'reweighin_logistic_regression'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 401 ms, sys: 1.2 s, total: 1.6 s
# Wall time: 52.9 ms

# %%
display(Markdown("**Validation set results for logistic regression**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy,
        dataset_preds=data_test_preds,
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for logistic regression**
# Results for reweighin_logistic_regression_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.5151
# AUC: 0.6457
# Balanced accuracy: 0.6074
# Accuracy: 0.6067
# Independence ( |ΔP(Y_pred = 1)| ): 0.0353
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0824
# Sufficiency ( |ΔPPV| ) : 0.0415
#
#
# Results for reweighin_logistic_regression_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.4545
# AUC: 0.6457
# Balanced accuracy: 0.5940
# Accuracy: 0.6000
# Independence ( |ΔP(Y_pred = 1)| ): 0.1566
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0022
# Sufficiency ( |ΔPPV| ) : 0.1324
#
#
# Results for reweighin_logistic_regression_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.4545
# AUC: 0.6457
# Balanced accuracy: 0.5946
# Accuracy: 0.6000
# Independence ( |ΔP(Y_pred = 1)| ): 0.0333
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0517
# Sufficiency ( |ΔPPV| ) : 0.0694

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'reweighin_xgb_classifier'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 4.04 s, sys: 108 ms, total: 4.15 s
# Wall time: 79.3 ms

# %%
display(Markdown("**Validation set results for xgb classifier**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy,
        dataset2=data_test2_copy,
        dataset_preds=data_test_preds,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for xgb classifier**
# Results for reweighin_xgb_classifier_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.2727
# AUC: 0.6214
# Balanced accuracy: 0.5983
# Accuracy: 0.6067
# Independence ( |ΔP(Y_pred = 1)| ): 0.0062
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0081
# Sufficiency ( |ΔPPV| ) : 0.1203
#
#
# Results for reweighin_xgb_classifier_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.2727
# AUC: 0.6214
# Balanced accuracy: 0.5983
# Accuracy: 0.6067
# Independence ( |ΔP(Y_pred = 1)| ): 0.0062
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0081
# Sufficiency ( |ΔPPV| ) : 0.1203
#
#
# Results for reweighin_xgb_classifier_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.2727
# AUC: 0.6214
# Balanced accuracy: 0.5983
# Accuracy: 0.6067
# Independence ( |ΔP(Y_pred = 1)| ): 0.0062
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0081
# Sufficiency ( |ΔPPV| ) : 0.1203

# %% [markdown]
# #### Impacto dispar + Procesador de probabilidades igualadas

# %% [markdown]
# ##### Usando labels

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'disparate_impact_logistic_regression'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:24
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:144, in EqOddsPostprocessing.fit(self, dataset_true, dataset_pred)
#     139 oflip = np.ravel(
#     140     dataset_pred.labels[cond_vec_unpriv] == dataset_pred.unfavorable_label)
#     142 y_true = dataset_true.labels.ravel()
# --> 144 sm_tn = np.logical_and(sflip,
#     145     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     146     dtype=np.float64)
#     147 sm_fn = np.logical_and(sflip,
#     148     y_true[cond_vec_priv] == dataset_true.favorable_label,
#     149     dtype=np.float64)
#     150 sm_fp = np.logical_and(sconst,
#     151     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     152     dtype=np.float64)
#
# TypeError: No loop matching the specified signature and casting was found for ufunc logical_and

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing_mult(
    dataset_true=data_test_copy,
    dataset2=data_test2_copy,
    dataset_preds=data_test_preds,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'disparate_impact_xgb_classifier'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:24
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:144, in EqOddsPostprocessing.fit(self, dataset_true, dataset_pred)
#     139 oflip = np.ravel(
#     140     dataset_pred.labels[cond_vec_unpriv] == dataset_pred.unfavorable_label)
#     142 y_true = dataset_true.labels.ravel()
# --> 144 sm_tn = np.logical_and(sflip,
#     145     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     146     dtype=np.float64)
#     147 sm_fn = np.logical_and(sflip,
#     148     y_true[cond_vec_priv] == dataset_true.favorable_label,
#     149     dtype=np.float64)
#     150 sm_fp = np.logical_and(sconst,
#     151     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     152     dtype=np.float64)
#
# TypeError: No loop matching the specified signature and casting was found for ufunc logical_and

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing_mult(
    dataset_true=data_test_copy,
    dataset2=data_test2_copy,
    dataset_preds=data_test_preds,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %% [markdown]
# ##### Usando scores

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'disparate_impact_logistic_regression'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 419 ms, sys: 1.42 s, total: 1.84 s
# Wall time: 60.2 ms

# %%
display(Markdown("**Validation set results for logistic regression**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy,
        dataset2=data_test2_copy,
        dataset_preds=data_test_preds,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for logistic regression**
# Results for disparate_impact_logistic_regression_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.5151
# AUC: 0.6457
# Balanced accuracy: 0.6074
# Accuracy: 0.6067
# Independence ( |ΔP(Y_pred = 1)| ): 0.0353
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0824
# Sufficiency ( |ΔPPV| ) : 0.0415
#
#
# Results for disparate_impact_logistic_regression_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.5151
# AUC: 0.6457
# Balanced accuracy: 0.5881
# Accuracy: 0.5867
# Independence ( |ΔP(Y_pred = 1)| ): 0.0416
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0058
# Sufficiency ( |ΔPPV| ) : 0.1121
#
#
# Results for disparate_impact_logistic_regression_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.4545
# AUC: 0.6457
# Balanced accuracy: 0.5865
# Accuracy: 0.5933
# Independence ( |ΔP(Y_pred = 1)| ): 0.0437
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0326
# Sufficiency ( |ΔPPV| ) : 0.0853

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'disparate_impact_xgb_classifier'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 4.4 s, sys: 89.6 ms, total: 4.49 s
# Wall time: 85.7 ms

# %%
display(Markdown("**Validation set results for xgb classifier**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy,
        dataset_preds=data_test_preds,
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for xgb classifier**
# Results for disparate_impact_xgb_classifier_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.2727
# AUC: 0.6214
# Balanced accuracy: 0.5983
# Accuracy: 0.6067
# Independence ( |ΔP(Y_pred = 1)| ): 0.0062
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0081
# Sufficiency ( |ΔPPV| ) : 0.1203
#
#
# Results for disparate_impact_xgb_classifier_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.2727
# AUC: 0.6214
# Balanced accuracy: 0.5983
# Accuracy: 0.6067
# Independence ( |ΔP(Y_pred = 1)| ): 0.0062
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0081
# Sufficiency ( |ΔPPV| ) : 0.1203
#
#
# Results for disparate_impact_xgb_classifier_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.2727
# AUC: 0.6214
# Balanced accuracy: 0.5983
# Accuracy: 0.6067
# Independence ( |ΔP(Y_pred = 1)| ): 0.0062
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0081
# Sufficiency ( |ΔPPV| ) : 0.1203

# %% [markdown]
# ## Inprocesado + Postprocesado

# %%
#Anotamos los nombres de los modelos que vamos a usar
model_names = ['prejudice_remover', 'meta_fairness_sr', 'meta_fairness_fdr', 'NN_adversarial_debiasing', 'Basic_NN_no_adversarial_debiasing']

# %% [markdown]
# ### Eliminador de prejuicios + rechazo de opción

# %%
# %%time 

# Nombramos al modelo
fairness_method = '_reject_option'

# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[0]

# métricas fair a optimizar
fair_metrics = {'spd': "Statistical parity difference", 'aod': "Average odds difference", 'eod': "Equal opportunity difference"}

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])

# Optimizamos un modelo nuevo por cada métrica
for key_metric in fair_metrics:
    
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    models[model_name_metric] = RejectOptionClassification(
        unprivileged_groups=unprivileged_groups, 
        privileged_groups=privileged_groups, 
        metric_name=fair_metrics[key_metric],
        metric_lb=-0.01, metric_ub=0.01)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/DEFINITIVO/utils.py:142, in update_dataset_from_model(dataset, model, class_thresh)
#     141 try:
# --> 142     y_pred_prob = model.predict_proba(dataset_pred.features)[:, pos_ind]
#     143 except:
#
# AttributeError: 'PrejudiceRemover' object has no attribute 'predict_proba'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:15
#
# File ~/DEFINITIVO/utils.py:144, in update_dataset_from_model(dataset, model, class_thresh)
#     142     y_pred_prob = model.predict_proba(dataset_pred.features)[:, pos_ind]
#     143 except:
# --> 144     y_pred_prob = model.predict(dataset_pred).scores
#     145 # Obtain predicted labels according to class_threshold
#     146 y_pred = np.zeros_like(dataset_pred.labels)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/prejudice_remover.py:204, in PrejudiceRemover.predict(self, dataset)
#     198 predict_lr = os.path.join(k_path, 'kamfadm-2012ecmlpkdd', 'predict_lr.py')
#     199 # changed paths in the calls below to (a) specify path of train_pr,
#     200 # predict_lr RELATIVE to this file, and (b) compute & use absolute path,
#     201 # and (c) replace python3 with python
#     202 subprocess.call(['python', predict_lr,
#     203                  '-i', test_name,
# --> 204                  '-m', self.model_name,
#     205                  '-o', output_name,
#     206                  '--quiet'])
#     207 os.unlink(test_name)
#     208 m = np.loadtxt(output_name)
#
# AttributeError: 'PrejudiceRemover' object has no attribute 'model_name'

# %%
display(Markdown("**Validation set results for logistic regression**"))
for key_metric in fair_metrics:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_val_copy, 
        dataset_preds=data_val_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
    
    print(model_name_metric)
    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')
    
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy, 
        dataset_preds=data_test_preds, 
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        required_threshold=False)
# Out:
# **Validation set results for logistic regression**
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[68], line 9
#       2 for key_metric in fair_metrics:
#       4     model_name_metric = model_name + fairness_method + '_' + key_metric
#       6     metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing(
#       7         dataset_true=data_val_copy,
#       8         dataset_preds=data_val_preds,
# ----> 9         model=models[model_name_metric],
#      10         required_threshold=False)
#      12     print(model_name_metric)
#      13     utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
#
# KeyError: 'prejudice_remover_reject_option_spd'

# %% [markdown]
# ### Metafairness + rechazo de opción

# %%
# %%time 

# Nombramos al modelo
fairness_method = '_reject_option'

# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[1]

# métricas fair a optimizar
fair_metrics = {'spd': "Statistical parity difference", 'aod': "Average odds difference", 'eod': "Equal opportunity difference"}

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
#data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
#data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
#data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])

# Optimizamos un modelo nuevo por cada métrica
for key_metric in fair_metrics:
    
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    models[model_name_metric] = RejectOptionClassification(
        unprivileged_groups=unprivileged_groups, 
        privileged_groups=privileged_groups, 
        metric_name=fair_metrics[key_metric],
        metric_lb=-0.01, metric_ub=0.01)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 9.4 s, sys: 169 ms, total: 9.57 s
# Wall time: 9.57 s

# %%
display(Markdown("**Validation set results for logistic regression**"))
for key_metric in fair_metrics:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_val_copy, 
        dataset_preds=data_val_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
    
    print(model_name_metric)
    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')
    
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy, 
        dataset_preds=data_test_preds, 
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        required_threshold=False)
# Out:
# **Validation set results for logistic regression**
# meta_fairness_sr_reject_option_spd
# Threshold corresponding to *best balanced accuracy*: 0.2377
# AUC: 0.6214
# Balanced accuracy: 0.5700
# Accuracy: 0.5800
# Independence ( |ΔP(Y_pred = 1)| ): 0.1254
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0596
# Sufficiency ( |ΔPPV| ) : 0.1580
#
#
# meta_fairness_sr_reject_option_aod
# Threshold corresponding to *best balanced accuracy*: 0.2377
# AUC: 0.6214
# Balanced accuracy: 0.5700
# Accuracy: 0.5800
# Independence ( |ΔP(Y_pred = 1)| ): 0.1254
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0596
# Sufficiency ( |ΔPPV| ) : 0.1580
#
#
# meta_fairness_sr_reject_option_eod
# Threshold corresponding to *best balanced accuracy*: 0.2377
# AUC: 0.6214
# Balanced accuracy: 0.5700
# Accuracy: 0.5800
# Independence ( |ΔP(Y_pred = 1)| ): 0.1254
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0596
# Sufficiency ( |ΔPPV| ) : 0.1580

# %% [markdown]
# ### Prejuicios adversarios + rechazo de opción

# %%
# %%time 

# Nombramos al modelo
fairness_method = '_reject_option'

# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[2]

# métricas fair a optimizar
fair_metrics = {'spd': "Statistical parity difference", 'aod': "Average odds difference", 'eod': "Equal opportunity difference"}

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
#data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
#data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
#data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])

# Optimizamos un modelo nuevo por cada métrica
for key_metric in fair_metrics:
    
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    models[model_name_metric] = RejectOptionClassification(
        unprivileged_groups=unprivileged_groups, 
        privileged_groups=privileged_groups, 
        metric_name=fair_metrics[key_metric],
        metric_lb=-0.01, metric_ub=0.01)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 9.58 s, sys: 144 ms, total: 9.73 s
# Wall time: 9.72 s

# %%
display(Markdown("**Validation set results for logistic regression**"))
for key_metric in fair_metrics:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_val_copy, 
        dataset_preds=data_val_preds, 
        dataset2=data_val2_copy,
        model=models[model_name_metric], 
        required_threshold=False)
    
    print(model_name_metric)
    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')
    
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy, 
        dataset2=data_test2_copy,
        dataset_preds=data_test_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
# Out:
# **Validation set results for logistic regression**
# meta_fairness_fdr_reject_option_spd
# Threshold corresponding to *best balanced accuracy*: 0.2377
# AUC: 0.6214
# Balanced accuracy: 0.5369
# Accuracy: 0.5333
# Independence ( |ΔP(Y_pred = 1)| ): 0.1266
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0026
# Sufficiency ( |ΔPPV| ) : 0.0702
#
#
# meta_fairness_fdr_reject_option_aod
# Threshold corresponding to *best balanced accuracy*: 0.2377
# AUC: 0.6214
# Balanced accuracy: 0.5369
# Accuracy: 0.5333
# Independence ( |ΔP(Y_pred = 1)| ): 0.1266
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0026
# Sufficiency ( |ΔPPV| ) : 0.0702
#
#
# meta_fairness_fdr_reject_option_eod
# Threshold corresponding to *best balanced accuracy*: 0.2377
# AUC: 0.6214
# Balanced accuracy: 0.5369
# Accuracy: 0.5333
# Independence ( |ΔP(Y_pred = 1)| ): 0.1266
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0026
# Sufficiency ( |ΔPPV| ) : 0.0702

# %% [markdown]
# ### Red neuronal normal + rechazo de opción

# %%
# %%time 

# Nombramos al modelo
fairness_method = '_reject_option'

# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[3]

# métricas fair a optimizar
fair_metrics = {'spd': "Statistical parity difference", 'aod': "Average odds difference", 'eod': "Equal opportunity difference"}

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
#data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
#data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
#data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])

# Optimizamos un modelo nuevo por cada métrica
for key_metric in fair_metrics:
    
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    models[model_name_metric] = RejectOptionClassification(
        unprivileged_groups=unprivileged_groups, 
        privileged_groups=privileged_groups, 
        metric_name=fair_metrics[key_metric],
        metric_lb=-0.01, metric_ub=0.01)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 9.73 s, sys: 116 ms, total: 9.85 s
# Wall time: 9.84 s

# %%
display(Markdown("**Validation set results for logistic regression**"))
for key_metric in fair_metrics:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_val_copy, 
        dataset_preds=data_val_preds, 
        dataset2=data_val2_copy,
        model=models[model_name_metric], 
        required_threshold=False)
    
    print(model_name_metric)
    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')
    
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy, 
        dataset_preds=data_test_preds, 
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        required_threshold=False)
# Out:
# **Validation set results for logistic regression**
# NN_adversarial_debiasing_reject_option_spd
# Threshold corresponding to *best balanced accuracy*: 0.2377
# AUC: 0.6214
# Balanced accuracy: 0.5369
# Accuracy: 0.5333
# Independence ( |ΔP(Y_pred = 1)| ): 0.1266
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0026
# Sufficiency ( |ΔPPV| ) : 0.0702
#
#
# NN_adversarial_debiasing_reject_option_aod
# Threshold corresponding to *best balanced accuracy*: 0.2377
# AUC: 0.6214
# Balanced accuracy: 0.5369
# Accuracy: 0.5333
# Independence ( |ΔP(Y_pred = 1)| ): 0.1266
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0026
# Sufficiency ( |ΔPPV| ) : 0.0702
#
#
# NN_adversarial_debiasing_reject_option_eod
# Threshold corresponding to *best balanced accuracy*: 0.2377
# AUC: 0.6214
# Balanced accuracy: 0.5369
# Accuracy: 0.5333
# Independence ( |ΔP(Y_pred = 1)| ): 0.1266
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0026
# Sufficiency ( |ΔPPV| ) : 0.0702

# %% [markdown]
# ### Inprocesado + Escalado Platt por grupos

# %%
# %%time
fairness_method = '_platt_scaling'

model_names = ['NN_adversarial_debiasing', 'Basic_NN_no_adversarial_debiasing']
#model_names = ['meta_fairness_fdr', 'meta_fairness_sr', 'NN_adversarial_debiasing', 'Basic_NN_no_adversarial_debiasing']
#model_names = ['prejudice_remover', 'meta_fairness_sr', 'meta_fairness_fdr', 'NN_adversarial_debiasing', 'Basic_NN_no_adversarial_debiasing']
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy = True), data_val.copy(deepcopy = True), data_test.copy(deepcopy = True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

for model_name in model_names:
    # Hacemos una copia de las predicciones del modelo de referencia
    model_thresh = metrics_best_thresh_validate[model_name]['best_threshold']
    data_val_preds = utils.update_dataset_from_scores(data_val_copy, models[model_name].scores_val, model_thresh)
    ## Plat Scaling:
    #1. dividir el validation data usando los groups sensibles
    data_val_preds_priv, data_val_preds_unpriv, priv_indices, unpriv_indices = utils.split_dataset_on_sensitive_attribute(
        dataset = data_val_preds, privileged_group_label = list((privileged_groups[0].values()))[0])
    #2. copia el validation data para guardar los scores
    data_val_preds2 = data_val_preds.copy(deepcopy = True)
    #3. hacer un modelo para cada grupo
    sensitive_groups_data = {'priv': [data_val_preds_priv, priv_indices],
                            'unpriv': [data_val_preds_unpriv, unpriv_indices]}
    
    for group, data_group_list in sensitive_groups_data.items():
    
        # nombramos al modelo con su grupo específico
        model_name_group = '{}_{}_{}'.format(model_name, fairness_method, group)
    
        # Inicializamos el modelo y lo asignamos al diccionario
        models[model_name_group] = LogisticRegression()
    
        # Realizamos el modelo usando datos para cada grupo en el validation data
        models[ model_name_group ] = models[model_name_group].fit(data_group_list[0].scores,   # data_group_list[0] -> data_val_preds_priv or data_val_preds_unpriv
                                                                      data_val_copy.subset(data_group_list[1]).labels.ravel()) # data_group_list[1] -> priv_indices or unpriv_indices
        # haz predicciones de probabilidad con el modelo de cada groupo y guardar lo en data_val_preds2
        # las predicciones de probabilidad son los platt scores
        scores_group = models[model_name_group].predict_proba(data_group_list[0].scores)
        pos_ind_group = np.where(models[model_name_group].classes_ == data_group_list[0].favorable_label)[0][0]
        data_val_preds2.scores[data_group_list[1]] = scores_group[:, pos_ind_group].reshape(-1,1)
            
        # Evaluamos a los modelos para el rango de umbrales
        thresh_sweep_platt = np.linspace(np.min(data_val_preds2.scores.ravel()),
                                         np.max(data_val_preds2.scores.ravel()),
                                         50)
        data_val_preds2_m = data_val2_copy.copy(deepcopy = True)
        data_val_preds2_m.scores = data_val_preds2.scores
        metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep_from_scores_mult(
                dataset_true = data_val_copy,
                dataset2=data_val2_copy,
                dataset_preds = data_val_preds2_m,
                thresh_arr = thresh_sweep_platt
            )
    
        # Evaluamos las métricas para el mejor umbral y las guardamos
        metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics( metrics_sweep[model_name+fairness_method] )
    
        # Graficamos el comportamiento del modelo para el rango de umbrales 
        print('\nValidation set results for {}'.format(model_name))
        utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
        # utils.plot_fairness_and_accuracy( metrics_sweep[model_name+fairness_method] )
        # plt.title( model_name+fairness_method )
        
        f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
        a.set_title(model_name+fairness_method )
        f
# Out:
# Validation set results for NN_adversarial_debiasing
# Threshold corresponding to *best balanced accuracy*: 0.5130
# AUC: 0.6052
# Balanced accuracy: 0.6159
# Accuracy: 0.6267
# Independence ( |ΔP(Y_pred = 1)| ): 0.2377
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1722
# Sufficiency ( |ΔPPV| ) : 0.2004
#
# Validation set results for NN_adversarial_debiasing
# Threshold corresponding to *best balanced accuracy*: 0.5108
# AUC: 0.6877
# Balanced accuracy: 0.6597
# Accuracy: 0.6600
# Independence ( |ΔP(Y_pred = 1)| ): 0.2322
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1176
# Sufficiency ( |ΔPPV| ) : 0.1033
#
# Validation set results for Basic_NN_no_adversarial_debiasing
# Threshold corresponding to *best balanced accuracy*: 0.4863
# AUC: 0.7037
# Balanced accuracy: 0.6747
# Accuracy: 0.6800
# Independence ( |ΔP(Y_pred = 1)| ): 0.0032
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0299
# Sufficiency ( |ΔPPV| ) : 0.0329
#
# Validation set results for Basic_NN_no_adversarial_debiasing
# Threshold corresponding to *best balanced accuracy*: 0.4921
# AUC: 0.6920
# Balanced accuracy: 0.6704
# Accuracy: 0.6733
# Independence ( |ΔP(Y_pred = 1)| ): 0.0847
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0422
# Sufficiency ( |ΔPPV| ) : 0.0000
# CPU times: user 519 ms, sys: 457 ms, total: 976 ms
# Wall time: 391 ms

# %%
# usa el optimal cutoff para predecir usando el test dato

for model_name in model_names:
    model_thresh = metrics_best_thresh_validate[model_name]['best_threshold']
    data_test_preds = utils.update_dataset_from_scores(data_test_copy, models[model_name].scores_test, model_thresh)
    
    # 1. dividir el validation data usando los groups sensibles
    data_test_preds_priv, data_test_preds_unpriv, priv_indices, unpriv_indices = utils.split_dataset_on_sensitive_attribute(dataset = data_test_preds,
                                                                                                                            privileged_group_label = list((privileged_groups[0].values()))[0])
    # 2. copia el test data para guardar los platt scores
    data_test_preds2 = data_test_preds.copy(deepcopy = True)
    
    # 3. predecir con el modelo de cada grupo
    sensitive_groups_data_test = {'priv': [data_test_preds_priv, priv_indices],
                                  'unpriv': [data_test_preds_unpriv, unpriv_indices]}

    for group, data_group_list in sensitive_groups_data_test.items():    
        # nombramos al modelo con su grupo específico
        model_name_group = '{}_{}_{}'.format(model_name, fairness_method, group)

        # haz predicciones de probabilidad con el modelo de cada groupo y guardar lo en data_val_preds2
        # las predicciones de probabilidad son los platt scores
        scores_group = models[model_name_group].predict_proba(data_group_list[0].scores)
        pos_ind_group = np.where(models[model_name_group].classes_ == data_group_list[0].favorable_label)[0][0]
        data_test_preds2.scores[data_group_list[1]] = scores_group[:, pos_ind_group].reshape(-1,1)
    data_test_preds2_m = data_test2_copy.copy(deepcopy=True)
    data_test_preds2_m.scores = data_test2_copy.scores
    metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_from_scores_mult(dataset_true = data_test_copy,
                                                                                             dataset_pred = data_test_preds2,
                                                                                             dataset2=data_test2_copy,
                                                                                             threshold = metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

# %% [markdown]
# #### Eliminador de prejuicios + Procesador de probabilidades igualadas

# %% [markdown]
# ##### Usando labels

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[0]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

thresh_NN_ADV = metrics_best_thresh_validate['NN_adversarial_debiasing']['best_threshold']

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_scores(data_train_copy, models[model_name].scores_train, thresh_NN_ADV)
data_val_preds = utils.update_dataset_from_scores(data_val_copy, models[model_name].scores_val, thresh_NN_ADV)
data_test_preds = utils.update_dataset_from_scores(data_test_copy, models[model_name].scores_test, thresh_NN_ADV)


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:26
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:144, in EqOddsPostprocessing.fit(self, dataset_true, dataset_pred)
#     139 oflip = np.ravel(
#     140     dataset_pred.labels[cond_vec_unpriv] == dataset_pred.unfavorable_label)
#     142 y_true = dataset_true.labels.ravel()
# --> 144 sm_tn = np.logical_and(sflip,
#     145     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     146     dtype=np.float64)
#     147 sm_fn = np.logical_and(sflip,
#     148     y_true[cond_vec_priv] == dataset_true.favorable_label,
#     149     dtype=np.float64)
#     150 sm_fp = np.logical_and(sconst,
#     151     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     152     dtype=np.float64)
#
# TypeError: No loop matching the specified signature and casting was found for ufunc logical_and

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing_mult(
    dataset_true=data_test_copy,
    dataset_preds=data_test_preds,
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %% [markdown]
# #### Usando scores

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[0]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

thresh_no_NN_ADV = metrics_best_thresh_validate['Basic_NN_no_adversarial_debiasing']['best_threshold']

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_scores(data_train_copy, models[model_name].scores_train, thresh_no_NN_ADV)
data_val_preds = utils.update_dataset_from_scores(data_val_copy, models[model_name].scores_val, thresh_no_NN_ADV)
data_test_preds = utils.update_dataset_from_scores(data_test_copy, models[model_name].scores_test, thresh_no_NN_ADV)


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 15.3 ms, sys: 3.03 ms, total: 18.4 ms
# Wall time: 17.4 ms

# %%
display(Markdown("**Validation set results for prejudice remover**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy,
        dataset_preds=data_test_preds,
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for prejudice remover**
# Results for NN_adversarial_debiasing_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.1716
# AUC: 0.5988
# Balanced accuracy: 0.5924
# Accuracy: 0.6067
# Independence ( |ΔP(Y_pred = 1)| ): 0.1892
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1372
# Sufficiency ( |ΔPPV| ) : 0.1974
#
#
# Results for NN_adversarial_debiasing_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.1716
# AUC: 0.5988
# Balanced accuracy: 0.6159
# Accuracy: 0.6267
# Independence ( |ΔP(Y_pred = 1)| ): 0.3063
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1762
# Sufficiency ( |ΔPPV| ) : 0.2394
#
#
# Results for NN_adversarial_debiasing_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.8788
# AUC: 0.5988
# Balanced accuracy: 0.5304
# Accuracy: 0.5133
# Independence ( |ΔP(Y_pred = 1)| ): 0.2821
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.1671
# Sufficiency ( |ΔPPV| ) : 0.7273

# %% [markdown]
# #### Metafairness + Procesador de probabilidades igualadas

# %% [markdown]
# ##### Usando labels

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[1]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# 2024-06-19 10:12:18.651078: W tensorflow/c/c_api.cc:305] Operation '{name:'biased_classifier/biased_classifier/classifier_model/b2/Adam_1/Assign' id:264 op device:{requested: '', assigned: ''} def:{{{node biased_classifier/biased_classifier/classifier_model/b2/Adam_1/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](biased_classifier/biased_classifier/classifier_model/b2/Adam_1, biased_classifier/biased_classifier/classifier_model/b2/Adam_1/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:24
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:144, in EqOddsPostprocessing.fit(self, dataset_true, dataset_pred)
#     139 oflip = np.ravel(
#     140     dataset_pred.labels[cond_vec_unpriv] == dataset_pred.unfavorable_label)
#     142 y_true = dataset_true.labels.ravel()
# --> 144 sm_tn = np.logical_and(sflip,
#     145     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     146     dtype=np.float64)
#     147 sm_fn = np.logical_and(sflip,
#     148     y_true[cond_vec_priv] == dataset_true.favorable_label,
#     149     dtype=np.float64)
#     150 sm_fp = np.logical_and(sconst,
#     151     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     152     dtype=np.float64)
#
# TypeError: No loop matching the specified signature and casting was found for ufunc logical_and

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing_mult(
    dataset_true=data_test_copy,
    dataset_preds=data_test_preds,
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %% [markdown]
# #### Usando scores

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[1]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 34.8 ms, sys: 5.45 ms, total: 40.2 ms
# Wall time: 29 ms

# %%
display(Markdown("**Validation set results for metafairness**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy,
        dataset_preds=data_test_preds,
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for metafairness**
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.4343
# AUC: 0.6875
# Balanced accuracy: 0.6672
# Accuracy: 0.6667
# Independence ( |ΔP(Y_pred = 1)| ): 0.0610
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0391
# Sufficiency ( |ΔPPV| ) : 0.0979
#
#
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.4343
# AUC: 0.6875
# Balanced accuracy: 0.6603
# Accuracy: 0.6600
# Independence ( |ΔP(Y_pred = 1)| ): 0.0866
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0163
# Sufficiency ( |ΔPPV| ) : 0.1261
#
#
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.4343
# AUC: 0.6875
# Balanced accuracy: 0.6672
# Accuracy: 0.6667
# Independence ( |ΔP(Y_pred = 1)| ): 0.0610
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0391
# Sufficiency ( |ΔPPV| ) : 0.0979

# %% [markdown]
# ##### Usando labels

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[2]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File <timed exec>:4
#
# IndexError: list index out of range

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing_mult(
    dataset_true=data_test_copy,
    dataset_preds=data_test_preds,
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %% [markdown]
# #### Usando scores

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[2]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File <timed exec>:4
#
# IndexError: list index out of range

# %%
display(Markdown("**Validation set results for metafairness**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy,
        dataset_preds=data_test_preds,
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for metafairness**
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.4343
# AUC: 0.6875
# Balanced accuracy: 0.6672
# Accuracy: 0.6667
# Independence ( |ΔP(Y_pred = 1)| ): 0.0610
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0391
# Sufficiency ( |ΔPPV| ) : 0.0979
#
#
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.4343
# AUC: 0.6875
# Balanced accuracy: 0.6603
# Accuracy: 0.6600
# Independence ( |ΔP(Y_pred = 1)| ): 0.0866
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0163
# Sufficiency ( |ΔPPV| ) : 0.1261
#
#
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.4343
# AUC: 0.6875
# Balanced accuracy: 0.6672
# Accuracy: 0.6667
# Independence ( |ΔP(Y_pred = 1)| ): 0.0610
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0391
# Sufficiency ( |ΔPPV| ) : 0.0979

# %% [markdown]
# #### Prejuicios adversarios + Procesador de probabilidades igualadas

# %% [markdown]
# ##### Usando labels

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[3]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

thresh_NN_ADV = metrics_best_thresh_validate['NN_adversarial_debiasing']['best_threshold']

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_scores(data_train_copy, models[model_name].scores_train, thresh_NN_ADV)
data_val_preds = utils.update_dataset_from_scores(data_val_copy, models[model_name].scores_val, thresh_NN_ADV)
data_test_preds = utils.update_dataset_from_scores(data_test_copy, models[model_name].scores_test, thresh_NN_ADV)


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File <timed exec>:4
#
# IndexError: list index out of range

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing_mult(
    dataset_true=data_test_copy,
    dataset_preds=data_test_preds,
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %% [markdown]
# #### Usando scores

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[3]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

thresh_NN_ADV = metrics_best_thresh_validate['NN_adversarial_debiasing']['best_threshold']

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_scores(data_train_copy, models[model_name].scores_train, thresh_NN_ADV)
data_val_preds = utils.update_dataset_from_scores(data_val_copy, models[model_name].scores_val, thresh_NN_ADV)
data_test_preds = utils.update_dataset_from_scores(data_test_copy, models[model_name].scores_test, thresh_NN_ADV)


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File <timed exec>:4
#
# IndexError: list index out of range

# %%
display(Markdown("**Validation set results for adversarial debiasing**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy,
        dataset_preds=data_test_preds,
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for adversarial debiasing**
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.4343
# AUC: 0.6875
# Balanced accuracy: 0.6672
# Accuracy: 0.6667
# Independence ( |ΔP(Y_pred = 1)| ): 0.0610
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0391
# Sufficiency ( |ΔPPV| ) : 0.0979
#
#
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.4343
# AUC: 0.6875
# Balanced accuracy: 0.6603
# Accuracy: 0.6600
# Independence ( |ΔP(Y_pred = 1)| ): 0.0866
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0163
# Sufficiency ( |ΔPPV| ) : 0.1261
#
#
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.4343
# AUC: 0.6875
# Balanced accuracy: 0.6672
# Accuracy: 0.6667
# Independence ( |ΔP(Y_pred = 1)| ): 0.0610
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0391
# Sufficiency ( |ΔPPV| ) : 0.0979

# %% [markdown]
# #### Red neuronal normal + Procesador de probabilidades igualadas

# %% [markdown]
# ##### Usando labels

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[4]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

thresh_no_NN_ADV = metrics_best_thresh_validate['Basic_NN_no_adversarial_debiasing']['best_threshold']

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_scores(data_train_copy, models[model_name].scores_train, thresh_no_NN_ADV)
data_val_preds = utils.update_dataset_from_scores(data_val_copy, models[model_name].scores_val, thresh_no_NN_ADV)
data_test_preds = utils.update_dataset_from_scores(data_test_copy, models[model_name].scores_test, thresh_no_NN_ADV)


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File <timed exec>:4
#
# IndexError: list index out of range

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing_mult(
    dataset_true=data_test_copy,
    dataset_preds=data_test_preds,
    dataset2=data_test2_copy,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %% [markdown]
# #### Usando scores

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = model_names[4]

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
data_train2_copy, data_val2_copy, data_test2_copy = data_train2.copy(deepcopy=True), data_val2.copy(deepcopy=True), data_test2.copy(deepcopy=True)

thresh_no_NN_ADV = metrics_best_thresh_validate['Basic_NN_no_adversarial_debiasing']['best_threshold']

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_scores(data_train_copy, models[model_name].scores_train, thresh_no_NN_ADV)
data_val_preds = utils.update_dataset_from_scores(data_val_copy, models[model_name].scores_val, thresh_no_NN_ADV)
data_test_preds = utils.update_dataset_from_scores(data_test_copy, models[model_name].scores_test, thresh_no_NN_ADV)


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File <timed exec>:4
#
# IndexError: list index out of range

# %%
display(Markdown("**Validation set results for basic NN**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing_mult(
        dataset_true=data_test_copy,
        dataset_preds=data_test_preds,
        dataset2=data_test2_copy,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for basic NN**
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.4343
# AUC: 0.6875
# Balanced accuracy: 0.6672
# Accuracy: 0.6667
# Independence ( |ΔP(Y_pred = 1)| ): 0.0610
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0391
# Sufficiency ( |ΔPPV| ) : 0.0979
#
#
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.4343
# AUC: 0.6875
# Balanced accuracy: 0.6603
# Accuracy: 0.6600
# Independence ( |ΔP(Y_pred = 1)| ): 0.0866
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0163
# Sufficiency ( |ΔPPV| ) : 0.1261
#
#
# Results for Basic_NN_no_adversarial_debiasing_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.4343
# AUC: 0.6875
# Balanced accuracy: 0.6672
# Accuracy: 0.6667
# Independence ( |ΔP(Y_pred = 1)| ): 0.0610
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0391
# Sufficiency ( |ΔPPV| ) : 0.0979

# %% [markdown]
# ## Comparación de modelos
#
# Podemos usar los diccionarios que resumen la calidad de los modelos fair para compararlos todos.

# %% [markdown]
# ### Resultados en validación

# %%
algorithm_performance_summary = pd.DataFrame(metrics_best_thresh_validate).T
algorithm_performance_summary
# Out:
#                                                     best_threshold   bal_acc  \
# logistic_regression                                       0.515102  0.606838
# xgb_classifier                                            0.272653  0.598291
# NN_adversarial_debiasing                                  0.171633  0.615919
# Basic_NN_no_adversarial_debiasing                         0.434286  0.674145
# reweighing_NN_adversarial_debiasing                       0.575714  0.610577
# reweighin_basic_NN_no_adversarial_debiasing               0.636327  0.682692
# disparate_impact_NN_adversarial_debiasing                 0.494898  0.583868
# disparate_impact_basic_NN_no_adversarial_debiasing        0.595918  0.667735
# reweighin_logistic_regression                             0.454490  0.608974
# reweighin_xgb_classifier                                  0.272653  0.598291
# disparate_impact_logistic_regression                      0.515102  0.606838
# disparate_impact_xgb_classifier                           0.272653  0.598291
# reweighin_logistic_regression_reject_option_spd           0.495051  0.597222
# reweighin_logistic_regression_reject_option_aod           0.495051  0.597222
# reweighin_logistic_regression_reject_option_eod           0.445556  0.566774
# reweighin_xgb_classifier_reject_option_spd                0.237677  0.569979
# reweighin_xgb_classifier_reject_option_aod                0.237677  0.569979
# reweighin_xgb_classifier_reject_option_eod                0.237677  0.569979
# disparate_impact_logistic_regression_reject_opt...        0.306970  0.523504
# disparate_impact_logistic_regression_reject_opt...        0.306970  0.523504
# disparate_impact_logistic_regression_reject_opt...        0.445556  0.566774
# disparate_impact_xgb_classifier_reject_option_spd         0.237677  0.569979
# disparate_impact_xgb_classifier_reject_option_aod         0.237677  0.569979
# disparate_impact_xgb_classifier_reject_option_eod         0.237677  0.569979
# reweighin_logistic_regression_platt_scaling               0.523216  0.604701
# reweighin_xgb_classifier_platt_scaling                    0.487302  0.627137
# disparate_impact_logistic_regression_platt_scaling        0.523289  0.604701
# disparate_impact_xgb_classifier_platt_scaling             0.487302  0.627137
# reweighin_logistic_regression_equal_odds_weighted         0.515102  0.607372
# reweighin_logistic_regression_equal_odds_fnr              0.454490  0.594017
# reweighin_logistic_regression_equal_odds_fpr              0.454490  0.594551
# reweighin_xgb_classifier_equal_odds_weighted              0.272653  0.598291
# reweighin_xgb_classifier_equal_odds_fnr                   0.272653  0.598291
# reweighin_xgb_classifier_equal_odds_fpr                   0.272653  0.598291
# disparate_impact_logistic_regression_equal_odds...        0.515102  0.607372
# disparate_impact_logistic_regression_equal_odds...        0.515102  0.588141
# disparate_impact_logistic_regression_equal_odds...        0.454490  0.586538
# disparate_impact_xgb_classifier_equal_odds_weig...        0.272653  0.598291
# disparate_impact_xgb_classifier_equal_odds_fnr            0.272653  0.598291
# disparate_impact_xgb_classifier_equal_odds_fpr            0.272653  0.598291
# meta_fairness_sr_reject_option_spd                        0.237677  0.569979
# meta_fairness_sr_reject_option_aod                        0.237677  0.569979
# meta_fairness_sr_reject_option_eod                        0.237677  0.569979
# meta_fairness_fdr_reject_option_spd                       0.237677  0.536859
# meta_fairness_fdr_reject_option_aod                       0.237677  0.536859
# meta_fairness_fdr_reject_option_eod                       0.237677  0.536859
# NN_adversarial_debiasing_reject_option_spd                0.237677  0.536859
# NN_adversarial_debiasing_reject_option_aod                0.237677  0.536859
# NN_adversarial_debiasing_reject_option_eod                0.237677  0.536859
# NN_adversarial_debiasing_platt_scaling                    0.510783  0.659722
# Basic_NN_no_adversarial_debiasing_platt_scaling           0.492141  0.670406
# NN_adversarial_debiasing_equal_odds_weighted              0.171633  0.592415
# NN_adversarial_debiasing_equal_odds_fnr                   0.171633  0.615919
# NN_adversarial_debiasing_equal_odds_fpr                   0.878776  0.530449
# Basic_NN_no_adversarial_debiasing_equal_odds_we...        0.434286  0.667201
# Basic_NN_no_adversarial_debiasing_equal_odds_fnr          0.434286  0.660256
# Basic_NN_no_adversarial_debiasing_equal_odds_fpr          0.434286  0.667201
#
#                                                          acc  independence  \
# logistic_regression                                 0.606667      0.148355
# xgb_classifier                                      0.606667      0.075346
# NN_adversarial_debiasing                            0.626667      0.237727
# Basic_NN_no_adversarial_debiasing                   0.673333      0.178205
# reweighing_NN_adversarial_debiasing                 0.613333      0.177666
# reweighin_basic_NN_no_adversarial_debiasing         0.673333      0.116346
# disparate_impact_NN_adversarial_debiasing           0.573333      0.271894
# disparate_impact_basic_NN_no_adversarial_debiasing  0.660000      0.134688
# reweighin_logistic_regression                       0.613333      0.164359
# reweighin_xgb_classifier                            0.606667      0.075346
# disparate_impact_logistic_regression                0.606667      0.148355
# disparate_impact_xgb_classifier                     0.606667      0.075346
# reweighin_logistic_regression_reject_option_spd     0.600000      0.022176
# reweighin_logistic_regression_reject_option_aod     0.600000      0.022176
# reweighin_logistic_regression_reject_option_eod     0.573333      0.069300
# reweighin_xgb_classifier_reject_option_spd          0.580000      0.125433
# reweighin_xgb_classifier_reject_option_aod          0.580000      0.125433
# reweighin_xgb_classifier_reject_option_eod          0.580000      0.125433
# disparate_impact_logistic_regression_reject_opt...  0.540000      0.047817
# disparate_impact_logistic_regression_reject_opt...  0.540000      0.047817
# disparate_impact_logistic_regression_reject_opt...  0.573333      0.069300
# disparate_impact_xgb_classifier_reject_option_spd   0.580000      0.125433
# disparate_impact_xgb_classifier_reject_option_aod   0.580000      0.125433
# disparate_impact_xgb_classifier_reject_option_eod   0.580000      0.125433
# reweighin_logistic_regression_platt_scaling         0.606667      0.213810
# reweighin_xgb_classifier_platt_scaling              0.633333      0.155907
# disparate_impact_logistic_regression_platt_scaling  0.606667      0.213810
# disparate_impact_xgb_classifier_platt_scaling       0.633333      0.155907
# reweighin_logistic_regression_equal_odds_weighted   0.606667      0.035343
# reweighin_logistic_regression_equal_odds_fnr        0.600000      0.156618
# reweighin_logistic_regression_equal_odds_fpr        0.600000      0.033264
# reweighin_xgb_classifier_equal_odds_weighted        0.606667      0.006237
# reweighin_xgb_classifier_equal_odds_fnr             0.606667      0.006237
# reweighin_xgb_classifier_equal_odds_fpr             0.606667      0.006237
# disparate_impact_logistic_regression_equal_odds...  0.606667      0.035343
# disparate_impact_logistic_regression_equal_odds...  0.586667      0.041580
# disparate_impact_logistic_regression_equal_odds...  0.593333      0.043659
# disparate_impact_xgb_classifier_equal_odds_weig...  0.606667      0.006237
# disparate_impact_xgb_classifier_equal_odds_fnr      0.606667      0.006237
# disparate_impact_xgb_classifier_equal_odds_fpr      0.606667      0.006237
# meta_fairness_sr_reject_option_spd                  0.580000      0.125433
# meta_fairness_sr_reject_option_aod                  0.580000      0.125433
# meta_fairness_sr_reject_option_eod                  0.580000      0.125433
# meta_fairness_fdr_reject_option_spd                 0.533333      0.126596
# meta_fairness_fdr_reject_option_aod                 0.533333      0.126596
# meta_fairness_fdr_reject_option_eod                 0.533333      0.126596
# NN_adversarial_debiasing_reject_option_spd          0.533333      0.126596
# NN_adversarial_debiasing_reject_option_aod          0.533333      0.126596
# NN_adversarial_debiasing_reject_option_eod          0.533333      0.126596
# NN_adversarial_debiasing_platt_scaling              0.660000      0.232152
# Basic_NN_no_adversarial_debiasing_platt_scaling     0.673333      0.084697
# NN_adversarial_debiasing_equal_odds_weighted        0.606667      0.189189
# NN_adversarial_debiasing_equal_odds_fnr             0.626667      0.306306
# NN_adversarial_debiasing_equal_odds_fpr             0.513333      0.282051
# Basic_NN_no_adversarial_debiasing_equal_odds_we...  0.666667      0.060984
# Basic_NN_no_adversarial_debiasing_equal_odds_fnr    0.660000      0.086625
# Basic_NN_no_adversarial_debiasing_equal_odds_fpr    0.666667      0.060984
#
#                                                     separation  sufficiency  \
# logistic_regression                                   0.062796     0.025836
# xgb_classifier                                        0.043924     0.096057
# NN_adversarial_debiasing                              0.172171     0.200382
# Basic_NN_no_adversarial_debiasing                     0.017302     0.109656
# reweighing_NN_adversarial_debiasing                   0.073637     0.034146
# reweighin_basic_NN_no_adversarial_debiasing           0.049760     0.113757
# disparate_impact_NN_adversarial_debiasing             0.073954     0.166667
# disparate_impact_basic_NN_no_adversarial_debiasing    0.029394     0.133065
# reweighin_logistic_regression                         0.048366     0.124311
# reweighin_xgb_classifier                              0.043924     0.096057
# disparate_impact_logistic_regression                  0.062796     0.025836
# disparate_impact_xgb_classifier                       0.043924     0.096057
# reweighin_logistic_regression_reject_option_spd       0.075408     0.053830
# reweighin_logistic_regression_reject_option_aod       0.075408     0.053830
# reweighin_logistic_regression_reject_option_eod       0.031124     0.097222
# reweighin_xgb_classifier_reject_option_spd            0.059554     0.157955
# reweighin_xgb_classifier_reject_option_aod            0.059554     0.157955
# reweighin_xgb_classifier_reject_option_eod            0.059554     0.157955
# disparate_impact_logistic_regression_reject_opt...    0.043898     0.137568
# disparate_impact_logistic_regression_reject_opt...    0.043898     0.137568
# disparate_impact_logistic_regression_reject_opt...    0.031124     0.097222
# disparate_impact_xgb_classifier_reject_option_spd     0.059554     0.157955
# disparate_impact_xgb_classifier_reject_option_aod     0.059554     0.157955
# disparate_impact_xgb_classifier_reject_option_eod     0.059554     0.157955
# reweighin_logistic_regression_platt_scaling           0.047409     0.065497
# reweighin_xgb_classifier_platt_scaling                0.037411     0.007755
# disparate_impact_logistic_regression_platt_scaling    0.047409     0.065497
# disparate_impact_xgb_classifier_platt_scaling         0.037411     0.007755
# reweighin_logistic_regression_equal_odds_weighted     0.082434     0.041509
# reweighin_logistic_regression_equal_odds_fnr          0.002192     0.132353
# reweighin_logistic_regression_equal_odds_fpr          0.051697     0.069444
# reweighin_xgb_classifier_equal_odds_weighted          0.008056     0.120253
# reweighin_xgb_classifier_equal_odds_fnr               0.008056     0.120253
# reweighin_xgb_classifier_equal_odds_fpr               0.008056     0.120253
# disparate_impact_logistic_regression_equal_odds...    0.082434     0.041509
# disparate_impact_logistic_regression_equal_odds...    0.005801     0.112098
# disparate_impact_logistic_regression_equal_odds...    0.032576     0.085263
# disparate_impact_xgb_classifier_equal_odds_weig...    0.008056     0.120253
# disparate_impact_xgb_classifier_equal_odds_fnr        0.008056     0.120253
# disparate_impact_xgb_classifier_equal_odds_fpr        0.008056     0.120253
# meta_fairness_sr_reject_option_spd                    0.059554     0.157955
# meta_fairness_sr_reject_option_aod                    0.059554     0.157955
# meta_fairness_sr_reject_option_eod                    0.059554     0.157955
# meta_fairness_fdr_reject_option_spd                   0.002623     0.070234
# meta_fairness_fdr_reject_option_aod                   0.002623     0.070234
# meta_fairness_fdr_reject_option_eod                   0.002623     0.070234
# NN_adversarial_debiasing_reject_option_spd            0.002623     0.070234
# NN_adversarial_debiasing_reject_option_aod            0.002623     0.070234
# NN_adversarial_debiasing_reject_option_eod            0.002623     0.070234
# NN_adversarial_debiasing_platt_scaling                0.117583     0.103283
# Basic_NN_no_adversarial_debiasing_platt_scaling       0.042237     0.000000
# NN_adversarial_debiasing_equal_odds_weighted          0.137213     0.197436
# NN_adversarial_debiasing_equal_odds_fnr               0.176230     0.239427
# NN_adversarial_debiasing_equal_odds_fpr               0.167112     0.727273
# Basic_NN_no_adversarial_debiasing_equal_odds_we...    0.039059     0.097934
# Basic_NN_no_adversarial_debiasing_equal_odds_fnr      0.016332     0.126072
# Basic_NN_no_adversarial_debiasing_equal_odds_fpr      0.039059     0.097934
#
#                                                          auc
# logistic_regression                                 0.645655
# xgb_classifier                                      0.621439
# NN_adversarial_debiasing                            0.598825
# Basic_NN_no_adversarial_debiasing                   0.687500
# reweighing_NN_adversarial_debiasing                 0.645833
# reweighin_basic_NN_no_adversarial_debiasing         0.720442
# disparate_impact_NN_adversarial_debiasing           0.570691
# disparate_impact_basic_NN_no_adversarial_debiasing  0.692308
# reweighin_logistic_regression                       0.645655
# reweighin_xgb_classifier                            0.621439
# disparate_impact_logistic_regression                0.645655
# disparate_impact_xgb_classifier                     0.621439
# reweighin_logistic_regression_reject_option_spd     0.645655
# reweighin_logistic_regression_reject_option_aod     0.645655
# reweighin_logistic_regression_reject_option_eod     0.645655
# reweighin_xgb_classifier_reject_option_spd          0.621439
# reweighin_xgb_classifier_reject_option_aod          0.621439
# reweighin_xgb_classifier_reject_option_eod          0.621439
# disparate_impact_logistic_regression_reject_opt...  0.645655
# disparate_impact_logistic_regression_reject_opt...  0.645655
# disparate_impact_logistic_regression_reject_opt...  0.645655
# disparate_impact_xgb_classifier_reject_option_spd   0.621439
# disparate_impact_xgb_classifier_reject_option_aod   0.621439
# disparate_impact_xgb_classifier_reject_option_eod   0.621439
# reweighin_logistic_regression_platt_scaling         0.635862
# reweighin_xgb_classifier_platt_scaling              0.631232
# disparate_impact_logistic_regression_platt_scaling  0.635862
# disparate_impact_xgb_classifier_platt_scaling       0.631232
# reweighin_logistic_regression_equal_odds_weighted   0.645655
# reweighin_logistic_regression_equal_odds_fnr        0.645655
# reweighin_logistic_regression_equal_odds_fpr        0.645655
# reweighin_xgb_classifier_equal_odds_weighted        0.621439
# reweighin_xgb_classifier_equal_odds_fnr             0.621439
# reweighin_xgb_classifier_equal_odds_fpr             0.621439
# disparate_impact_logistic_regression_equal_odds...  0.645655
# disparate_impact_logistic_regression_equal_odds...  0.645655
# disparate_impact_logistic_regression_equal_odds...  0.645655
# disparate_impact_xgb_classifier_equal_odds_weig...  0.621439
# disparate_impact_xgb_classifier_equal_odds_fnr      0.621439
# disparate_impact_xgb_classifier_equal_odds_fpr      0.621439
# meta_fairness_sr_reject_option_spd                  0.621439
# meta_fairness_sr_reject_option_aod                  0.621439
# meta_fairness_sr_reject_option_eod                  0.621439
# meta_fairness_fdr_reject_option_spd                 0.621439
# meta_fairness_fdr_reject_option_aod                 0.621439
# meta_fairness_fdr_reject_option_eod                 0.621439
# NN_adversarial_debiasing_reject_option_spd          0.621439
# NN_adversarial_debiasing_reject_option_aod          0.621439
# NN_adversarial_debiasing_reject_option_eod          0.621439
# NN_adversarial_debiasing_platt_scaling              0.687678
# Basic_NN_no_adversarial_debiasing_platt_scaling     0.691952
# NN_adversarial_debiasing_equal_odds_weighted        0.598825
# NN_adversarial_debiasing_equal_odds_fnr             0.598825
# NN_adversarial_debiasing_equal_odds_fpr             0.598825
# Basic_NN_no_adversarial_debiasing_equal_odds_we...  0.687500
# Basic_NN_no_adversarial_debiasing_equal_odds_fnr    0.687500
# Basic_NN_no_adversarial_debiasing_equal_odds_fpr    0.687500

# %% [markdown]
# ### Resultados en test

# %%
algorithm_performance_summary = pd.DataFrame(metrics_best_thresh_test).T
algorithm_performance_summary
# Out:
#                                                     best_threshold   bal_acc  \
# logistic_regression                                       0.515102  0.576389
# xgb_classifier                                            0.272653  0.494658
# NN_adversarial_debiasing                                  0.171633  0.483440
# Basic_NN_no_adversarial_debiasing                         0.434286  0.466880
# reweighing_NN_adversarial_debiasing                       0.575714  0.486111
# reweighin_basic_NN_no_adversarial_debiasing               0.636327  0.456197
# disparate_impact_NN_adversarial_debiasing                 0.494898  0.450855
# disparate_impact_basic_NN_no_adversarial_debiasing        0.595918  0.476496
# reweighin_logistic_regression                             0.454490  0.575855
# reweighin_xgb_classifier                                  0.272653  0.494658
# disparate_impact_logistic_regression                      0.515102  0.576389
# disparate_impact_xgb_classifier                           0.272653  0.494658
# reweighin_logistic_regression_reject_option_spd           0.495051  0.576923
# reweighin_logistic_regression_reject_option_aod           0.495051  0.576923
# reweighin_logistic_regression_reject_option_eod           0.445556  0.576923
# reweighin_xgb_classifier_reject_option_spd                0.237677  0.489316
# reweighin_xgb_classifier_reject_option_aod                0.237677  0.489316
# reweighin_xgb_classifier_reject_option_eod                0.237677  0.489316
# disparate_impact_logistic_regression_reject_opt...        0.306970  0.576923
# disparate_impact_logistic_regression_reject_opt...        0.306970  0.576923
# disparate_impact_logistic_regression_reject_opt...        0.445556  0.576923
# disparate_impact_xgb_classifier_reject_option_spd         0.237677  0.489316
# disparate_impact_xgb_classifier_reject_option_aod         0.237677  0.489316
# disparate_impact_xgb_classifier_reject_option_eod         0.237677  0.489316
# reweighin_logistic_regression_platt_scaling               0.523216  0.626603
# reweighin_xgb_classifier_platt_scaling                    0.487302  0.545406
# disparate_impact_logistic_regression_platt_scaling        0.523289  0.626603
# disparate_impact_xgb_classifier_platt_scaling             0.487302  0.545406
# reweighin_logistic_regression_equal_odds_weighted         0.515102  0.588675
# reweighin_logistic_regression_equal_odds_fnr              0.454490  0.590278
# reweighin_logistic_regression_equal_odds_fpr              0.454490  0.563568
# reweighin_xgb_classifier_equal_odds_weighted              0.272653  0.494658
# reweighin_xgb_classifier_equal_odds_fnr                   0.272653  0.494658
# reweighin_xgb_classifier_equal_odds_fpr                   0.272653  0.494658
# disparate_impact_logistic_regression_equal_odds...        0.515102  0.582265
# disparate_impact_logistic_regression_equal_odds...        0.515102  0.595085
# disparate_impact_logistic_regression_equal_odds...        0.454490  0.571581
# disparate_impact_xgb_classifier_equal_odds_weig...        0.272653  0.494658
# disparate_impact_xgb_classifier_equal_odds_fnr            0.272653  0.494658
# disparate_impact_xgb_classifier_equal_odds_fpr            0.272653  0.494658
# meta_fairness_sr_reject_option_spd                        0.237677  0.489316
# meta_fairness_sr_reject_option_aod                        0.237677  0.489316
# meta_fairness_sr_reject_option_eod                        0.237677  0.489316
# meta_fairness_fdr_reject_option_spd                       0.237677  0.489316
# meta_fairness_fdr_reject_option_aod                       0.237677  0.489316
# meta_fairness_fdr_reject_option_eod                       0.237677  0.489316
# NN_adversarial_debiasing_reject_option_spd                0.237677  0.489316
# NN_adversarial_debiasing_reject_option_aod                0.237677  0.489316
# NN_adversarial_debiasing_reject_option_eod                0.237677  0.489316
# NN_adversarial_debiasing_platt_scaling                    0.510783  0.532585
# Basic_NN_no_adversarial_debiasing_platt_scaling           0.492141  0.542735
# NN_adversarial_debiasing_equal_odds_weighted              0.171633  0.480235
# NN_adversarial_debiasing_equal_odds_fnr                   0.171633  0.483440
# NN_adversarial_debiasing_equal_odds_fpr                   0.878776  0.481303
# Basic_NN_no_adversarial_debiasing_equal_odds_we...        0.434286  0.467415
# Basic_NN_no_adversarial_debiasing_equal_odds_fnr          0.434286  0.467415
# Basic_NN_no_adversarial_debiasing_equal_odds_fpr          0.434286  0.467415
#
#                                                          acc  independence  \
# logistic_regression                                 0.580000      0.055287
# xgb_classifier                                      0.486667      0.088567
# NN_adversarial_debiasing                            0.473333      0.160494
# Basic_NN_no_adversarial_debiasing                   0.466667      0.025765
# reweighing_NN_adversarial_debiasing                 0.480000      0.212560
# reweighin_basic_NN_no_adversarial_debiasing         0.466667      0.038647
# disparate_impact_NN_adversarial_debiasing           0.460000      0.345142
# disparate_impact_basic_NN_no_adversarial_debiasing  0.486667      0.053140
# reweighin_logistic_regression                       0.573333      0.124530
# reweighin_xgb_classifier                            0.486667      0.088567
# disparate_impact_logistic_regression                0.580000      0.055287
# disparate_impact_xgb_classifier                     0.486667      0.088567
# reweighin_logistic_regression_reject_option_spd     0.580000      0.053140
# reweighin_logistic_regression_reject_option_aod     0.580000      0.053140
# reweighin_logistic_regression_reject_option_eod     0.580000      0.053140
# reweighin_xgb_classifier_reject_option_spd          0.493333      0.016103
# reweighin_xgb_classifier_reject_option_aod          0.493333      0.016103
# reweighin_xgb_classifier_reject_option_eod          0.493333      0.016103
# disparate_impact_logistic_regression_reject_opt...  0.580000      0.053140
# disparate_impact_logistic_regression_reject_opt...  0.580000      0.053140
# disparate_impact_logistic_regression_reject_opt...  0.580000      0.053140
# disparate_impact_xgb_classifier_reject_option_spd   0.493333      0.016103
# disparate_impact_xgb_classifier_reject_option_aod   0.493333      0.016103
# disparate_impact_xgb_classifier_reject_option_eod   0.493333      0.016103
# reweighin_logistic_regression_platt_scaling         0.626667      0.240472
# reweighin_xgb_classifier_platt_scaling              0.540000      0.330113
# disparate_impact_logistic_regression_platt_scaling  0.626667      0.240472
# disparate_impact_xgb_classifier_platt_scaling       0.540000      0.330113
# reweighin_logistic_regression_equal_odds_weighted   0.593333      0.005904
# reweighin_logistic_regression_equal_odds_fnr        0.586667      0.173913
# reweighin_logistic_regression_equal_odds_fpr        0.560000      0.093398
# reweighin_xgb_classifier_equal_odds_weighted        0.486667      0.088567
# reweighin_xgb_classifier_equal_odds_fnr             0.486667      0.088567
# reweighin_xgb_classifier_equal_odds_fpr             0.486667      0.088567
# disparate_impact_logistic_regression_equal_odds...  0.586667      0.018250
# disparate_impact_logistic_regression_equal_odds...  0.600000      0.006441
# disparate_impact_logistic_regression_equal_odds...  0.566667      0.101449
# disparate_impact_xgb_classifier_equal_odds_weig...  0.486667      0.088567
# disparate_impact_xgb_classifier_equal_odds_fnr      0.486667      0.088567
# disparate_impact_xgb_classifier_equal_odds_fpr      0.486667      0.088567
# meta_fairness_sr_reject_option_spd                  0.493333      0.016103
# meta_fairness_sr_reject_option_aod                  0.493333      0.016103
# meta_fairness_sr_reject_option_eod                  0.493333      0.016103
# meta_fairness_fdr_reject_option_spd                 0.493333      0.016103
# meta_fairness_fdr_reject_option_aod                 0.493333      0.016103
# meta_fairness_fdr_reject_option_eod                 0.493333      0.016103
# NN_adversarial_debiasing_reject_option_spd          0.493333      0.016103
# NN_adversarial_debiasing_reject_option_aod          0.493333      0.016103
# NN_adversarial_debiasing_reject_option_eod          0.493333      0.016103
# NN_adversarial_debiasing_platt_scaling              0.533333      0.292002
# Basic_NN_no_adversarial_debiasing_platt_scaling     0.540000      0.104670
# NN_adversarial_debiasing_equal_odds_weighted        0.466667      0.133119
# NN_adversarial_debiasing_equal_odds_fnr             0.473333      0.160494
# NN_adversarial_debiasing_equal_odds_fpr             0.500000      0.061728
# Basic_NN_no_adversarial_debiasing_equal_odds_we...  0.466667      0.050456
# Basic_NN_no_adversarial_debiasing_equal_odds_fnr    0.466667      0.050456
# Basic_NN_no_adversarial_debiasing_equal_odds_fpr    0.466667      0.050456
#
#                                                     separation  sufficiency  \
# logistic_regression                                   0.038636     0.139560
# xgb_classifier                                        0.085859     0.138889
# NN_adversarial_debiasing                              0.073485     0.125568
# Basic_NN_no_adversarial_debiasing                     0.033838     0.042017
# reweighing_NN_adversarial_debiasing                   0.006061     0.087212
# reweighin_basic_NN_no_adversarial_debiasing           0.098485     0.111111
# disparate_impact_NN_adversarial_debiasing             0.006061     0.066667
# disparate_impact_basic_NN_no_adversarial_debiasing    0.055556     0.023392
# reweighin_logistic_regression                         0.028788     0.068235
# reweighin_xgb_classifier                              0.085859     0.138889
# disparate_impact_logistic_regression                  0.038636     0.139560
# disparate_impact_xgb_classifier                       0.085859     0.138889
# reweighin_logistic_regression_reject_option_spd       0.009596     0.101852
# reweighin_logistic_regression_reject_option_aod       0.009596     0.101852
# reweighin_logistic_regression_reject_option_eod       0.009596     0.101852
# reweighin_xgb_classifier_reject_option_spd            0.039899     0.026936
# reweighin_xgb_classifier_reject_option_aod            0.039899     0.026936
# reweighin_xgb_classifier_reject_option_eod            0.039899     0.026936
# disparate_impact_logistic_regression_reject_opt...    0.009596     0.101852
# disparate_impact_logistic_regression_reject_opt...    0.009596     0.101852
# disparate_impact_logistic_regression_reject_opt...    0.009596     0.101852
# disparate_impact_xgb_classifier_reject_option_spd     0.039899     0.026936
# disparate_impact_xgb_classifier_reject_option_aod     0.039899     0.026936
# disparate_impact_xgb_classifier_reject_option_eod     0.039899     0.026936
# reweighin_logistic_regression_platt_scaling           0.027020     0.008252
# reweighin_xgb_classifier_platt_scaling                0.018939     0.048535
# disparate_impact_logistic_regression_platt_scaling    0.027020     0.008252
# disparate_impact_xgb_classifier_platt_scaling         0.018939     0.048535
# reweighin_logistic_regression_equal_odds_weighted     0.019192     0.105459
# reweighin_logistic_regression_equal_odds_fnr          0.059343     0.051198
# reweighin_logistic_regression_equal_odds_fpr          0.034091     0.057764
# reweighin_xgb_classifier_equal_odds_weighted          0.085859     0.138889
# reweighin_xgb_classifier_equal_odds_fnr               0.085859     0.138889
# reweighin_xgb_classifier_equal_odds_fpr               0.085859     0.138889
# disparate_impact_logistic_regression_equal_odds...    0.030303     0.122596
# disparate_impact_logistic_regression_equal_odds...    0.008081     0.087179
# disparate_impact_logistic_regression_equal_odds...    0.052020     0.045584
# disparate_impact_xgb_classifier_equal_odds_weig...    0.085859     0.138889
# disparate_impact_xgb_classifier_equal_odds_fnr        0.085859     0.138889
# disparate_impact_xgb_classifier_equal_odds_fpr        0.085859     0.138889
# meta_fairness_sr_reject_option_spd                    0.039899     0.026936
# meta_fairness_sr_reject_option_aod                    0.039899     0.026936
# meta_fairness_sr_reject_option_eod                    0.039899     0.026936
# meta_fairness_fdr_reject_option_spd                   0.039899     0.026936
# meta_fairness_fdr_reject_option_aod                   0.039899     0.026936
# meta_fairness_fdr_reject_option_eod                   0.039899     0.026936
# NN_adversarial_debiasing_reject_option_spd            0.039899     0.026936
# NN_adversarial_debiasing_reject_option_aod            0.039899     0.026936
# NN_adversarial_debiasing_reject_option_eod            0.039899     0.026936
# NN_adversarial_debiasing_platt_scaling                0.016414     0.081169
# Basic_NN_no_adversarial_debiasing_platt_scaling       0.012121     0.081949
# NN_adversarial_debiasing_equal_odds_weighted          0.007828     0.071078
# NN_adversarial_debiasing_equal_odds_fnr               0.073485     0.125568
# NN_adversarial_debiasing_equal_odds_fpr               0.030556     0.200000
# Basic_NN_no_adversarial_debiasing_equal_odds_we...    0.036616     0.038770
# Basic_NN_no_adversarial_debiasing_equal_odds_fnr      0.036616     0.038770
# Basic_NN_no_adversarial_debiasing_equal_odds_fpr      0.036616     0.038770
#
#                                                          auc
# logistic_regression                                 0.603989
# xgb_classifier                                      0.464387
# NN_adversarial_debiasing                            0.438034
# Basic_NN_no_adversarial_debiasing                   0.475249
# reweighing_NN_adversarial_debiasing                 0.468483
# reweighin_basic_NN_no_adversarial_debiasing         0.458689
# disparate_impact_NN_adversarial_debiasing           0.472578
# disparate_impact_basic_NN_no_adversarial_debiasing  0.488426
# reweighin_logistic_regression                       0.603989
# reweighin_xgb_classifier                            0.464387
# disparate_impact_logistic_regression                0.603989
# disparate_impact_xgb_classifier                     0.464387
# reweighin_logistic_regression_reject_option_spd     0.603989
# reweighin_logistic_regression_reject_option_aod     0.603989
# reweighin_logistic_regression_reject_option_eod     0.603989
# reweighin_xgb_classifier_reject_option_spd          0.464387
# reweighin_xgb_classifier_reject_option_aod          0.464387
# reweighin_xgb_classifier_reject_option_eod          0.464387
# disparate_impact_logistic_regression_reject_opt...  0.603989
# disparate_impact_logistic_regression_reject_opt...  0.603989
# disparate_impact_logistic_regression_reject_opt...  0.603989
# disparate_impact_xgb_classifier_reject_option_spd   0.464387
# disparate_impact_xgb_classifier_reject_option_aod   0.464387
# disparate_impact_xgb_classifier_reject_option_eod   0.464387
# reweighin_logistic_regression_platt_scaling         0.624644
# reweighin_xgb_classifier_platt_scaling              0.522614
# disparate_impact_logistic_regression_platt_scaling  0.624822
# disparate_impact_xgb_classifier_platt_scaling       0.522614
# reweighin_logistic_regression_equal_odds_weighted   0.603989
# reweighin_logistic_regression_equal_odds_fnr        0.603989
# reweighin_logistic_regression_equal_odds_fpr        0.603989
# reweighin_xgb_classifier_equal_odds_weighted        0.464387
# reweighin_xgb_classifier_equal_odds_fnr             0.464387
# reweighin_xgb_classifier_equal_odds_fpr             0.464387
# disparate_impact_logistic_regression_equal_odds...  0.603989
# disparate_impact_logistic_regression_equal_odds...  0.603989
# disparate_impact_logistic_regression_equal_odds...  0.603989
# disparate_impact_xgb_classifier_equal_odds_weig...  0.464387
# disparate_impact_xgb_classifier_equal_odds_fnr      0.464387
# disparate_impact_xgb_classifier_equal_odds_fpr      0.464387
# meta_fairness_sr_reject_option_spd                  0.464387
# meta_fairness_sr_reject_option_aod                  0.464387
# meta_fairness_sr_reject_option_eod                  0.464387
# meta_fairness_fdr_reject_option_spd                 0.464387
# meta_fairness_fdr_reject_option_aod                 0.464387
# meta_fairness_fdr_reject_option_eod                 0.464387
# NN_adversarial_debiasing_reject_option_spd          0.464387
# NN_adversarial_debiasing_reject_option_aod          0.464387
# NN_adversarial_debiasing_reject_option_eod          0.464387
# NN_adversarial_debiasing_platt_scaling              0.537215
# Basic_NN_no_adversarial_debiasing_platt_scaling     0.509793
# NN_adversarial_debiasing_equal_odds_weighted        0.438034
# NN_adversarial_debiasing_equal_odds_fnr             0.438034
# NN_adversarial_debiasing_equal_odds_fpr             0.438034
# Basic_NN_no_adversarial_debiasing_equal_odds_we...  0.475249
# Basic_NN_no_adversarial_debiasing_equal_odds_fnr    0.475249
# Basic_NN_no_adversarial_debiasing_equal_odds_fpr    0.475249

# %%
algorithm_performance_summary.to_csv('SIMULATION_MULTALG_MULTSENS_mild', index = True, sep=',', encoding='utf-8')
