# %% [markdown]
# <img src="img/ibidat.png" alt="drawing" width="600"/>

# %% [markdown]
# # Introducción
#
# En este cuaderno hacemos un estudio de simulación de los distintos métodos de fairness que se han revisado en el TFM.
#
# # Modelo
#
# Vamos a generar los datos a través de una normal multivariada. En concreto:
#
# $$
# (A_l, X_l) \sim \mathcal{N}(\mu, \Sigma)
# $$
#
# donde $A_l$ representan los atributos sensibles, $X_l$ los no sensibles y $\mu$ y $\Sigma$ son parámetros de la simulación a determinar. En nuestro caso, $\mu$ será el vector nulo y $\Sigma$, la identidad. Otros parámetros a determinar son las dimensiones de nuestros datos. En concreto nosotros vamos a tomar $30$ atributos no sensibles y $1$ o $2$ sensibles según que caso estemos estudiando: Será $1$ en `Simulation_simple` y `Simulation_multalg`, mientras que en `Simulation_multsens` y `Simulation_general` usaremos $2$ atributos sensibles. Generaremos una matriz que tendrá tantas columnas como variables tengamos, y con tantas filas como observaciones queramos. En nuestro caso generaremos $1000$ observaciones.
#
# Una vez hemos generada una matriz a partir de $(A_l, X_l)$ procederemos generando una variable más por medio de una relación lineal:
#
# $$
# Y_l = X_l \cdot \beta + A_l \cdot \gamma
# $$
#
# Donde $\beta$ y $\gamma$ son vectores a elegir. En nuestro caso consideraremos tres escenarios diferentes:
#
# 1. Alta correlación con los atributos sensibles: donde $\gamma$ será idénticamente uno y $\beta$ será nulo.
# 2. Correlación moderada con los atributos sensibles: donde $\gamma$ y $\beta$ serán idénticamente uno.
# 3. Baja correlación con los atributos sensibles: donde $\gamma$ será nulo y $\beta$ será identicamente uno.
#
# Vamos a tratar con variables binarias por simplicidad. Así pues, las variables con subíndice l que hemos generado representan las log-odds de las probabilidades de las variables reales. De tal modo, deshaciendo esta transformación por medio de la función logística obtendremos las probabilidades de las variables, es decir:
#
# $$
# p_J = logit(J_l) \quad \quad J \in \{Y, X, A\}
# $$
#
# Así pues, al elemento $x_{ij}$ de nuestro dataset le asignaremos un uno con probabilidad dada por la función logística aplicado al correspondiente elemento de la matriz generada a partir de una normal con los parámetros especificados. Una vez que hayamos convertido los valores simulados en unos y ceros, habremos obtenido ya nuestro dataset real: las variables reales $Y, X, A$ son aquellas generadas de esta forma.

# %% [markdown]
# # Carga de librerías

# %%
# Con esta celda, podemos hacer cambios en cualquier script/libreria y verlo reflejado en las funciones del notebook.
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
## CARGAMOS LIBRERIAS
# Obs: La primera vez puede tardar en cargar porque AIF360 pre-compila algunas cosas de tensorflow
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Cargamos librerías de sklearn
# vanilla LR
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline

# Cargamos xgboost
from xgboost import XGBClassifier

# Cargamos algoritmos de fairness
# Pre-procesado
from aif360.algorithms.preprocessing import Reweighing
from aif360.algorithms.preprocessing import DisparateImpactRemover
# In-procesado
from aif360.algorithms.inprocessing import PrejudiceRemover
from aif360.algorithms.inprocessing import MetaFairClassifier
from aif360.algorithms.inprocessing.adversarial_debiasing import AdversarialDebiasing
# Post-procesado
from aif360.algorithms.postprocessing import RejectOptionClassification # when scores are given
from aif360.algorithms.postprocessing import CalibratedEqOddsPostprocessing # when scores (R) are given
from aif360.algorithms.postprocessing import EqOddsPostprocessing # when labels (Y^hat) are given
from aif360.datasets import GermanDataset

#Simulacion
from aif360.datasets import BinaryLabelDataset

# TF para adversarial debiasing
import tensorflow.compat.v1 as tf
tf.disable_eager_execution()

from IPython.display import Markdown, display

# Librería local con funciones de ayuda extra
import utils

seed = 12345 # fijamos la semilla de números aleatorios para reproducir exactamante el notebook
np.random.seed(seed)
# Out:
# WARNING:root:
# `load_boston` has been removed from scikit-learn since version 1.2.
#
# The Boston housing prices dataset has an ethical problem: as
# investigated in [1], the authors of this dataset engineered a
# non-invertible variable "B" assuming that racial self-segregation had a
# positive impact on house prices [2]. Furthermore the goal of the
# research that led to the creation of this dataset was to study the
# impact of air quality but it did not give adequate demonstration of the
# validity of this assumption.
#
# The scikit-learn maintainers therefore strongly discourage the use of
# this dataset unless the purpose of the code is to study and educate
# about ethical issues in data science and machine learning.
#
# In this special case, you can fetch the dataset from the original
# source::
#
#     import pandas as pd
#     import numpy as np
#
#     data_url = "http://lib.stat.cmu.edu/datasets/boston"
#     raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#     data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#     target = raw_df.values[1::2, 2]
#
# Alternative datasets include the California housing dataset and the
# Ames housing dataset. You can load the datasets as follows::
#
#     from sklearn.datasets import fetch_california_housing
#     housing = fetch_california_housing()
#
# for the California housing dataset and::
#
#     from sklearn.datasets import fetch_openml
#     housing = fetch_openml(name="house_prices", as_frame=True)
#
# for the Ames housing dataset.
#
# [1] M Carlisle.
# "Racist data destruction?"
# <https://medium.com/@docintangible/racist-data-destruction-113e3eff54a8>
#
# [2] Harrison Jr, David, and Daniel L. Rubinfeld.
# "Hedonic housing prices and the demand for clean air."
# Journal of environmental economics and management 5.1 (1978): 81-102.
# <https://www.researchgate.net/publication/4974606_Hedonic_housing_prices_and_the_demand_for_clean_air>
# : LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# 2024-06-14 08:13:34.718318: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-14 08:13:34.774302: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-14 08:13:35.644224: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Simulación de dataset.
#
# El siguiente bloque permite generar el conjunto de datos sobre el que vamos a trabajar.

# %%
def logit(x):
    return np.log(x/(1-x))

def inv_logit(x):
    return np.exp(x)/(1+np.exp(x))

def simulated_dataset(n_obs, n_var, n_sens, mean_vec, cov, beta, gamma):
    
    p = n_var + n_sens
    coef = np.concatenate((gamma, beta))
        
    X = np.random.multivariate_normal(mean_vec, cov, size = n_obs)
    probs_var = inv_logit(X)
    bin = np.random.binomial(1, probs_var)
    
    probs_Y = inv_logit(coef.dot(X.T))
    Y = np.random.binomial(1, probs_Y)
    
    names = ['0' for i in range(p+1)]
    sens = ['0' for i in range(n_sens)]
    var = 1
    
    names[0] = 'response'
    
    for i in range(1,p+1):
        if i-1 < n_sens:
            sens[i-1] = 'sens ' + str(i)
            names[i] = 'sens ' + str(i)
        if i-1 >= n_sens:
            names[i] = 'var ' + str(var)
            var += 1
    
    names = np.array(names)
    sens = np.array(sens)
    response = np.array(['response'])
    
    Y = Y.reshape((n_obs,1))
    
    bin = np.concatenate((Y, bin), axis = 1)
    
    data_pd = pd.DataFrame(bin, columns = names)
    data = BinaryLabelDataset(df = data_pd, favorable_label = 1, unfavorable_label = 0, label_names = response, protected_attribute_names = sens)
    return data

# %%
n_obs = 1000
n_var = 30
n_sens = 1
mean_vec = np.zeros(n_var+n_sens)
cov = np.identity(n_var+n_sens)
beta = np.ones(n_var)
gamma = np.ones(n_sens)

dataset = simulated_dataset(n_obs, n_var, n_sens, mean_vec, cov, beta, gamma)

#dataset.favorable_label = 1
#dataset.unfavorable_label = 0

# Separamos el conjunto de datos en train, validate, test
data_train, vt = dataset.split([0.7], shuffle=True, seed=seed)
data_val, data_test = vt.split([0.5], shuffle=True, seed=seed)

# Obtenemos los indicadores del grupo sensible
sensitive_attribute = dataset.protected_attribute_names[0]
privileged_groups, unprivileged_groups = utils.get_privileged_groups(dataset)
    
print(f'Dimensiones del conjunto de datos: {dataset.features.shape}')
print("Grupos privilegiados:", privileged_groups)
print("Grupos no privilegiados:", unprivileged_groups)
print("Label del grupo favorable:", dataset.favorable_label)
print("Label del grupo desfavorable:", dataset.unfavorable_label)
# Out:
# Dimensiones del conjunto de datos: (1000, 31)
# Grupos privilegiados: [{'sens 1': 1.0}]
# Grupos no privilegiados: [{'sens 1': 0.0}]
# Label del grupo favorable: 1.0
# Label del grupo desfavorable: 0.0

# %% [markdown]
# ## Modelos
# Para esta sección, creamos un diccionario de métricas y modelos para poder acceder los resultados de todos los modelos.

# %%
# Inicializamos diccionarios
models = dict()

# Rango de umbrales para evaluar el score de los modelos
thresh_sweep = np.linspace(0.01, 1.0, 50)

metrics_sweep = dict()

# Store results from validation and test
metrics_best_thresh_validate = dict()
metrics_best_thresh_test = dict()

# %% [markdown]
# ### Regresión Logística

# %%
# %%time 

# Nombramos al modelo
model_name = 'logistic_regression'
fairness_method = ''

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Parámetros del modelo
fit_params = {'logisticregression__sample_weight': data_train_copy.instance_weights}

# Asignamos el modelo al diccionario
models[model_name+fairness_method] = make_pipeline(
            #StandardScaler(),
            LogisticRegression(solver='liblinear', random_state=seed))

# Entrenamos el modelo
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy.features, data_train_copy.labels.ravel(), **fit_params)
# Out:
# CPU times: user 4.85 ms, sys: 465 µs, total: 5.31 ms
# Wall time: 4.97 ms

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_threshold_sweep(
    dataset=data_val_copy,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics(
    dataset=data_test_copy, 
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.3737
# AUC: 0.5104
# Balanced accuracy: 0.5533
# Accuracy: 0.5533
# Independence ( |ΔP(Y_pred = 1)| ): 0.1625
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0227
# Sufficiency ( |ΔPPV| ) : 0.0199
# CPU times: user 123 ms, sys: 13.4 ms, total: 136 ms
# Wall time: 126 ms

# %%
display(Markdown("**Test set results**"))
utils.print_metrics(metrics_best_thresh_test[model_name+fairness_method])
# Out:
# **Test set results**
# Threshold corresponding to *best balanced accuracy*: 0.3737
# AUC: 0.6539
# Balanced accuracy: 0.6054
# Accuracy: 0.5933
# Independence ( |ΔP(Y_pred = 1)| ): 0.2294
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0430
# Sufficiency ( |ΔPPV| ) : 0.0591

# %% [markdown]
# ### XGBoost

# %%
# %%time 

# Nombramos al modelo
model_name = 'xgb_classifier'
fairness_method = ''

# Parámetros del modelo
fit_params = {'eval_metric': 'error', 'eta':0.1, 'max_depth':6, 'subsample':0.8}

# Asignamos el modelo al diccionario
models[model_name+fairness_method] = XGBClassifier(**fit_params)

# Entrenamos el modelo
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy.features, data_train_copy.labels.ravel())
# Out:
# CPU times: user 1h 8min 10s, sys: 3.06 s, total: 1h 8min 13s
# Wall time: 9min 33s

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_threshold_sweep(
    dataset=data_val_copy,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics(
    dataset=data_test_copy, 
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.2727
# AUC: 0.5529
# Balanced accuracy: 0.5600
# Accuracy: 0.5600
# Independence ( |ΔP(Y_pred = 1)| ): 0.1184
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0177
# Sufficiency ( |ΔPPV| ) : 0.0468
# CPU times: user 3.02 s, sys: 28.2 ms, total: 3.04 s
# Wall time: 719 ms

# %%
display(Markdown("**Test set results**"))
utils.print_metrics(metrics_best_thresh_test[model_name+fairness_method])
# Out:
# **Test set results**
# Threshold corresponding to *best balanced accuracy*: 0.2727
# AUC: 0.6081
# Balanced accuracy: 0.5891
# Accuracy: 0.5800
# Independence ( |ΔP(Y_pred = 1)| ): 0.1623
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0308
# Sufficiency ( |ΔPPV| ) : 0.0000

# %% [markdown]
# ## Técnicas de preprocesado

# %% [markdown]
# ### Reponderación

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_reweighting'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos el pre-procesado al conjunto train
# Inicializamos la clase de pre-procesado 
PreProcessor = Reweighing(
    unprivileged_groups=unprivileged_groups,
    privileged_groups=privileged_groups
)
# Pre-procesamos (modifica los datos)
PreProcessor.fit(data_train_copy)
data_train_copy = PreProcessor.transform(data_train_copy)
data_val_copy = PreProcessor.transform(data_val_copy)
data_test_copy = PreProcessor.transform(data_test_copy)
# Out:
# CPU times: user 8.73 ms, sys: 0 ns, total: 8.73 ms
# Wall time: 26.3 ms

# %% [markdown]
# De aquí en adelante, se aplica el modelo de preferencia de manera estándar

# %%
# %%time 

# Regresión logística
model_name = 'logistic_regression'

# Parámetros del modelo
fit_params = {'logisticregression__sample_weight': data_train_copy.instance_weights}

# Asignamos el modelo al diccionario
models[model_name+fairness_method] = make_pipeline(
            #StandardScaler(),
            LogisticRegression(solver='liblinear', random_state=seed))

# Entrenamos el modelo
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy.features, data_train_copy.labels.ravel(), **fit_params)

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_threshold_sweep(
    dataset=data_val_copy,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics(
    dataset=data_test_copy, 
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.4343
# AUC: 0.5104
# Balanced accuracy: 0.5290
# Accuracy: 0.5300
# Independence ( |ΔP(Y_pred = 1)| ): 0.1501
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0600
# Sufficiency ( |ΔPPV| ) : 0.2002
# CPU times: user 178 ms, sys: 44.2 ms, total: 222 ms
# Wall time: 427 ms

# %%
# %%time 

# Nombramos al modelo
model_name = 'xgb_classifier'

# Parámetros del modelo
fit_params = {'eval_metric': 'error', 'eta':0.1, 'max_depth':6, 'subsample':0.8}

# Asignamos el modelo al diccionario
models[model_name+fairness_method] = XGBClassifier(**fit_params)

# Entrenamos el modelo
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy.features, data_train_copy.labels.ravel())

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_threshold_sweep(
    dataset=data_val_copy,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics(
    dataset=data_test_copy, 
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.3131
# AUC: 0.5529
# Balanced accuracy: 0.5534
# Accuracy: 0.5548
# Independence ( |ΔP(Y_pred = 1)| ): 0.0882
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0221
# Sufficiency ( |ΔPPV| ) : 0.1761
# CPU times: user 1h 7min 53s, sys: 3.15 s, total: 1h 7min 56s
# Wall time: 8min 6s

# %% [markdown]
# ### Eliminador de impacto dispar

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_di_remover'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Parámetros del modelo
nivel_reparacion = 0.5 # un valor 0 inidica ausencia de reparación (datos se mantienen igual) 
                       # un valor 1 indica reparación completa (se puede perder nivel predictivo).
                       # Se puede establecer cualquier valor entre 0 y 1.

# Hacemos el pre-procesado al conjunto train
# Inicializamos la clase de pre-procesado 
PreProcessor = DisparateImpactRemover(
    repair_level=nivel_reparacion,
    sensitive_attribute=sensitive_attribute
)
# Pre-procesamos (modifica los datos)
PreProcessor.fit_transform(data_train_copy)
data_train_copy = PreProcessor.fit_transform(data_train_copy)
data_val_copy = PreProcessor.fit_transform(data_val_copy)
data_test_copy = PreProcessor.fit_transform(data_test_copy)
# Out:
# CPU times: user 209 ms, sys: 8.02 ms, total: 217 ms
# Wall time: 646 ms

# %% [markdown]
# Aplicamos los métodos de regresión logística y XGBoost

# %%
# %%time 
# Regresión logística
model_name = 'logistic_regression'

# Parámetros del modelo
fit_params = {'logisticregression__sample_weight': data_train_copy.instance_weights}

# Asignamos el modelo al diccionario
models[model_name+fairness_method] = make_pipeline(
            #StandardScaler(),
            LogisticRegression(solver='liblinear', random_state=seed))

# Entrenamos el modelo
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy.features, data_train_copy.labels.ravel(), **fit_params)

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_threshold_sweep(
    dataset=data_val_copy,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics(
    dataset=data_test_copy, 
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.3737
# AUC: 0.5104
# Balanced accuracy: 0.5533
# Accuracy: 0.5533
# Independence ( |ΔP(Y_pred = 1)| ): 0.1625
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0227
# Sufficiency ( |ΔPPV| ) : 0.0199
# CPU times: user 365 ms, sys: 104 ms, total: 469 ms
# Wall time: 1.36 s

# %%
# %%time 

# Nombramos al modelo
model_name = 'xgb_classifier'

# Parámetros del modelo
fit_params = {'eval_metric': 'error', 'eta':0.1, 'max_depth':6, 'subsample':0.8}

# Asignamos el modelo al diccionario
models[model_name+fairness_method] = XGBClassifier(**fit_params)

# Entrenamos el modelo
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy.features, data_train_copy.labels.ravel())

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_threshold_sweep(
    dataset=data_val_copy,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])


# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics(
    dataset=data_test_copy, 
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.2727
# AUC: 0.5529
# Balanced accuracy: 0.5600
# Accuracy: 0.5600
# Independence ( |ΔP(Y_pred = 1)| ): 0.1184
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0177
# Sufficiency ( |ΔPPV| ) : 0.0468
# CPU times: user 1h 3min 19s, sys: 3.25 s, total: 1h 3min 22s
# Wall time: 4min 13s

# %% [markdown]
# ## Técnicas de inprocesado

# %% [markdown]
# ### Eliminador de prejuicios por regularización

# %%
# %%time 
# Nombramos al modelo
model_name = 'prejudice_remover'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Parámetros del modelo
η = 50.0 # hyper-parameter de regularización

# Inicializamos el modelo y lo asignamos al diccionario
models[model_name] = PrejudiceRemover(sensitive_attr=sensitive_attribute, eta=η)

# Entrenamos el modelo
models[model_name] = models[model_name].fit(data_train_copy)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File <timed exec>:14
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/prejudice_remover.py:160, in PrejudiceRemover.fit(self, dataset)
#     156 train_pr = os.path.join(k_path, 'kamfadm-2012ecmlpkdd', 'train_pr.py')
#     157 # changed paths in the calls below to (a) specify path of train_pr,
#     158 # predict_lr RELATIVE to this file, and (b) compute & use absolute path
#     159 #  and (c) replace python3 with python
# --> 160 subprocess.call(['python', train_pr,
#     161                  '-e', str(self.eta),
#     162                  '-i', train_name,
#     163                  '-o', model_name,
#     164                  '--quiet'])
#     165 os.unlink(train_name)
#     167 self.model_name = model_name
#
# File ~/miniconda3/envs/aif360/lib/python3.9/subprocess.py:349, in call(timeout, *popenargs, **kwargs)
#     341 def call(*popenargs, timeout=None, **kwargs):
#     342     """Run command with arguments.  Wait for command to complete or
#     343     timeout, then return the returncode attribute.
#     344
#    (...)
#     347     retcode = call(["ls", "-l"])
#     348     """
# --> 349     with Popen(*popenargs, **kwargs) as p:
#     350         try:
#     351             return p.wait(timeout=timeout)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/subprocess.py:951, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     947         if self.text_mode:
#     948             self.stderr = io.TextIOWrapper(self.stderr,
#     949                     encoding=encoding, errors=errors)
# --> 951     self._execute_child(args, executable, preexec_fn, close_fds,
#     952                         pass_fds, cwd, env,
#     953                         startupinfo, creationflags, shell,
#     954                         p2cread, p2cwrite,
#     955                         c2pread, c2pwrite,
#     956                         errread, errwrite,
#     957                         restore_signals,
#     958                         gid, gids, uid, umask,
#     959                         start_new_session)
#     960 except:
#     961     # Cleanup if the child failed starting.
#     962     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~/miniconda3/envs/aif360/lib/python3.9/subprocess.py:1837, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1835     if errno_num != 0:
#    1836         err_msg = os.strerror(errno_num)
# -> 1837     raise child_exception_type(errno_num, err_msg, err_filename)
#    1838 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'python'

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name] = utils.metrics_threshold_sweep(
    dataset=data_val_copy,
    model=models[model_name],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name] = utils.describe_metrics(metrics_sweep[model_name])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name] = utils.compute_metrics(
    dataset=data_test_copy, 
    model=models[model_name], 
    threshold=metrics_best_thresh_validate[model_name]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name])

# Graficamos el comportamiento del modelo para el rango de umbrales 
f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name])
a.set_title(model_name)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/DEFINITIVO/utils.py:502, in metrics_threshold_sweep(dataset, model, thresh_arr)
#     500 try:
#     501     # sklearn classifier
# --> 502     y_val_pred_prob = model.predict_proba(dataset.features)
#     503     pos_ind = np.where(model.classes_ == dataset.favorable_label)[0][0]
#
# AttributeError: 'PrejudiceRemover' object has no attribute 'predict_proba'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:506, in metrics_threshold_sweep(dataset, model, thresh_arr)
#     503     pos_ind = np.where(model.classes_ == dataset.favorable_label)[0][0]
#     504 except AttributeError:
#     505     # aif360 inprocessing algorithm
# --> 506     y_val_pred_prob = model.predict(dataset).scores
#     507     pos_ind = 0
#     509 # Remove nans and turn them into score of random prediction (R=0.5)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/prejudice_remover.py:204, in PrejudiceRemover.predict(self, dataset)
#     198 predict_lr = os.path.join(k_path, 'kamfadm-2012ecmlpkdd', 'predict_lr.py')
#     199 # changed paths in the calls below to (a) specify path of train_pr,
#     200 # predict_lr RELATIVE to this file, and (b) compute & use absolute path,
#     201 # and (c) replace python3 with python
#     202 subprocess.call(['python', predict_lr,
#     203                  '-i', test_name,
# --> 204                  '-m', self.model_name,
#     205                  '-o', output_name,
#     206                  '--quiet'])
#     207 os.unlink(test_name)
#     208 m = np.loadtxt(output_name)
#
# AttributeError: 'PrejudiceRemover' object has no attribute 'model_name'

# %% [markdown]
# ### Algoritmo de metafairness

# %%
# %%time 
# Nombramos al modelo
model_name = 'meta_fairness'

# Parámetros del modelo
# hyper-parameter de regularización
τ = 0.8
# métricas fairness a optimizar
quality_constraints = ['sr', 'fdr'] # sr: statistical rate, fdr: false discovery rate

# Optimizamos un modelo nuevo por cada métrica
for quality in quality_constraints:
    
    # Hacemos una copia de los datasets
    data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)
    
    # nombramos al modelo con su métrica específica
    model_name_quality = '{}_{}'.format(model_name, quality)
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_quality] = MetaFairClassifier(tau=τ, sensitive_attr=sensitive_attribute, type=quality, seed=seed)

    # Entrenamos el modelo
    models[model_name_quality] = models[ model_name_quality ].fit( data_train_copy )
# Out:
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/StatisticalRate.py:36: RuntimeWarning: invalid value encountered in divide
#   prob_y_1 = (prob_1_1 + prob_1_0) / total
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/StatisticalRate.py:37: RuntimeWarning: invalid value encountered in divide
#   prob_z_0 = (prob_m1_0 + prob_1_0) / total
# /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/StatisticalRate.py:38: RuntimeWarning: invalid value encountered in divide
#   prob_z_1 = (prob_m1_1 + prob_1_1) / total
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:23
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/meta_fair_classifier.py:66, in MetaFairClassifier.fit(self, dataset)
#      59 y_train = np.where(dataset.labels.flatten() == dataset.favorable_label,
#      60                    1, -1)
#      61 x_control_train = np.where(
#      62         np.isin(dataset.protected_attributes[:, sens_idx],
#      63                 dataset.privileged_protected_attributes[sens_idx]),
#      64         1, 0)
# ---> 66 self.model = self.obj.getModel(self.tau, x_train, y_train,
#      67     x_control_train, self.seed)
#      69 return self
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/General.py:99, in General.getModel(self, tau, X, y, sens, random_state)
#      96 samples = dist_x.rvs(size=20)  # TODO: why 20?
#      97 params = self.gradientDescent(dist, a, b, samples, z_1)
# ---> 99 t = self.getValueForX(dist, a, b, params, z_1, X)
#     100 y_pred = np.where(t > 0, 1, -1)
#     102 acc = accuracy_score(y, y_pred)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/celisMeta/StatisticalRate.py:23, in StatisticalRate.getValueForX(self, dist, a, b, params, z_prior, x, return_cs)
#      22 def getValueForX(self, dist, a, b, params, z_prior, x, return_cs=False):
# ---> 23     l_1, l_2 = params
#      24     z_0, z_1 = 1-z_prior, z_prior
#      26     pos = np.ones(len(x))
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
# %%time 

for quality in quality_constraints:
    
    name_suffix = '_{}'.format(quality)
    print(f'Results for {model_name+name_suffix}')

    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name+name_suffix] = utils.metrics_threshold_sweep(
        dataset=data_val_copy,
        model=models[model_name+name_suffix],
        thresh_arr=thresh_sweep
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name+name_suffix] = utils.describe_metrics(metrics_sweep[model_name+name_suffix])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name+name_suffix] = utils.compute_metrics(
        dataset=data_test_copy, 
        model=models[model_name+name_suffix], 
        threshold=metrics_best_thresh_validate[model_name+name_suffix]['best_threshold'])

    utils.print_metrics(metrics_best_thresh_validate[model_name+name_suffix])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name+name_suffix])
    # plt.title(model_name+name_suffix)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+name_suffix])
    a.set_title(model_name+name_suffix)
    f
# Out:
# Results for meta_fairness_sr
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/DEFINITIVO/utils.py:502, in metrics_threshold_sweep(dataset, model, thresh_arr)
#     500 try:
#     501     # sklearn classifier
# --> 502     y_val_pred_prob = model.predict_proba(dataset.features)
#     503     pos_ind = np.where(model.classes_ == dataset.favorable_label)[0][0]
#
# AttributeError: 'MetaFairClassifier' object has no attribute 'predict_proba'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:7
#
# File ~/DEFINITIVO/utils.py:506, in metrics_threshold_sweep(dataset, model, thresh_arr)
#     503     pos_ind = np.where(model.classes_ == dataset.favorable_label)[0][0]
#     504 except AttributeError:
#     505     # aif360 inprocessing algorithm
# --> 506     y_val_pred_prob = model.predict(dataset).scores
#     507     pos_ind = 0
#     509 # Remove nans and turn them into score of random prediction (R=0.5)
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/inprocessing/meta_fair_classifier.py:82, in MetaFairClassifier.predict(self, dataset)
#      71 def predict(self, dataset):
#      72     """Obtain the predictions for the provided dataset using the learned
#      73     classifier model.
#      74
#    (...)
#      80         BinaryLabelDataset: Transformed dataset.
#      81     """
# ---> 82     t = self.model(dataset.features)
#      84     pred_dataset = dataset.copy()
#      85     pred_dataset.labels = (t > 0).astype(int).reshape((-1, 1))
#
# AttributeError: 'MetaFairClassifier' object has no attribute 'model'

# %% [markdown]
# ### Eliminación de prejuicios adversarios

# %%
# %%time

# Nombramos al modelo
model_name = 'NN_adversarial_debiasing'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

sess = tf.Session()

models[model_name] = AdversarialDebiasing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    scope_name = 'debiased_classifier',
    debias=True,
    sess=sess,
    num_epochs=80)

models[model_name].fit(data_train_copy)
# Out:
# 2024-06-14 08:35:39.848779: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# WARNING:tensorflow:From /home/arturo_perez/miniconda3/envs/aif360/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1260: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# 2024-06-14 08:35:40.242236: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:388] MLIR V1 optimization pass is not enabled
# epoch 0; iter: 0; batch classifier loss: 0.739015; batch adversarial loss: 0.716687
# epoch 1; iter: 0; batch classifier loss: 0.692879; batch adversarial loss: 0.713344
# epoch 2; iter: 0; batch classifier loss: 0.695775; batch adversarial loss: 0.781104
# epoch 3; iter: 0; batch classifier loss: 0.676931; batch adversarial loss: 0.759987
# epoch 4; iter: 0; batch classifier loss: 0.666908; batch adversarial loss: 0.736895
# epoch 5; iter: 0; batch classifier loss: 0.671623; batch adversarial loss: 0.723315
# epoch 6; iter: 0; batch classifier loss: 0.666712; batch adversarial loss: 0.787696
# epoch 7; iter: 0; batch classifier loss: 0.675349; batch adversarial loss: 0.760140
# epoch 8; iter: 0; batch classifier loss: 0.681517; batch adversarial loss: 0.757107
# epoch 9; iter: 0; batch classifier loss: 0.670847; batch adversarial loss: 0.763960
# epoch 10; iter: 0; batch classifier loss: 0.677559; batch adversarial loss: 0.751502
# epoch 11; iter: 0; batch classifier loss: 0.679347; batch adversarial loss: 0.813802
# epoch 12; iter: 0; batch classifier loss: 0.639770; batch adversarial loss: 0.752847
# epoch 13; iter: 0; batch classifier loss: 0.662696; batch adversarial loss: 0.773357
# epoch 14; iter: 0; batch classifier loss: 0.668728; batch adversarial loss: 0.758877
# epoch 15; iter: 0; batch classifier loss: 0.635481; batch adversarial loss: 0.778173
# epoch 16; iter: 0; batch classifier loss: 0.650592; batch adversarial loss: 0.761076
# epoch 17; iter: 0; batch classifier loss: 0.625899; batch adversarial loss: 0.776748
# epoch 18; iter: 0; batch classifier loss: 0.649870; batch adversarial loss: 0.762324
# epoch 19; iter: 0; batch classifier loss: 0.659959; batch adversarial loss: 0.775880
# epoch 20; iter: 0; batch classifier loss: 0.657335; batch adversarial loss: 0.760254
# epoch 21; iter: 0; batch classifier loss: 0.635250; batch adversarial loss: 0.791250
# epoch 22; iter: 0; batch classifier loss: 0.656154; batch adversarial loss: 0.756994
# epoch 23; iter: 0; batch classifier loss: 0.607257; batch adversarial loss: 0.781497
# epoch 24; iter: 0; batch classifier loss: 0.599239; batch adversarial loss: 0.770899
# epoch 25; iter: 0; batch classifier loss: 0.626449; batch adversarial loss: 0.787425
# epoch 26; iter: 0; batch classifier loss: 0.613265; batch adversarial loss: 0.790865
# epoch 27; iter: 0; batch classifier loss: 0.576267; batch adversarial loss: 0.757114
# epoch 28; iter: 0; batch classifier loss: 0.624239; batch adversarial loss: 0.773995
# epoch 29; iter: 0; batch classifier loss: 0.609606; batch adversarial loss: 0.787057
# epoch 30; iter: 0; batch classifier loss: 0.617925; batch adversarial loss: 0.767764
# epoch 31; iter: 0; batch classifier loss: 0.653969; batch adversarial loss: 0.765493
# epoch 32; iter: 0; batch classifier loss: 0.601289; batch adversarial loss: 0.764975
# epoch 33; iter: 0; batch classifier loss: 0.580427; batch adversarial loss: 0.749905
# epoch 34; iter: 0; batch classifier loss: 0.608058; batch adversarial loss: 0.769844
# epoch 35; iter: 0; batch classifier loss: 0.609623; batch adversarial loss: 0.766480
# epoch 36; iter: 0; batch classifier loss: 0.605139; batch adversarial loss: 0.768879
# epoch 37; iter: 0; batch classifier loss: 0.586884; batch adversarial loss: 0.774745
# epoch 38; iter: 0; batch classifier loss: 0.605208; batch adversarial loss: 0.768181
# epoch 39; iter: 0; batch classifier loss: 0.624287; batch adversarial loss: 0.791500
# epoch 40; iter: 0; batch classifier loss: 0.608969; batch adversarial loss: 0.778174
# epoch 41; iter: 0; batch classifier loss: 0.587084; batch adversarial loss: 0.761012
# epoch 42; iter: 0; batch classifier loss: 0.549097; batch adversarial loss: 0.757570
# epoch 43; iter: 0; batch classifier loss: 0.585164; batch adversarial loss: 0.767824
# epoch 44; iter: 0; batch classifier loss: 0.627858; batch adversarial loss: 0.769679
# epoch 45; iter: 0; batch classifier loss: 0.589112; batch adversarial loss: 0.761780
# epoch 46; iter: 0; batch classifier loss: 0.598771; batch adversarial loss: 0.758738
# epoch 47; iter: 0; batch classifier loss: 0.627288; batch adversarial loss: 0.765456
# epoch 48; iter: 0; batch classifier loss: 0.577066; batch adversarial loss: 0.767339
# epoch 49; iter: 0; batch classifier loss: 0.650732; batch adversarial loss: 0.777225
# epoch 50; iter: 0; batch classifier loss: 0.604353; batch adversarial loss: 0.770285
# epoch 51; iter: 0; batch classifier loss: 0.595760; batch adversarial loss: 0.761005
# epoch 52; iter: 0; batch classifier loss: 0.589843; batch adversarial loss: 0.764815
# epoch 53; iter: 0; batch classifier loss: 0.625133; batch adversarial loss: 0.760143
# epoch 54; iter: 0; batch classifier loss: 0.580076; batch adversarial loss: 0.755416
# epoch 55; iter: 0; batch classifier loss: 0.548649; batch adversarial loss: 0.754134
# epoch 56; iter: 0; batch classifier loss: 0.632672; batch adversarial loss: 0.762442
# epoch 57; iter: 0; batch classifier loss: 0.591045; batch adversarial loss: 0.754856
# epoch 58; iter: 0; batch classifier loss: 0.603647; batch adversarial loss: 0.760350
# epoch 59; iter: 0; batch classifier loss: 0.605350; batch adversarial loss: 0.762117
# epoch 60; iter: 0; batch classifier loss: 0.578462; batch adversarial loss: 0.757264
# epoch 61; iter: 0; batch classifier loss: 0.576264; batch adversarial loss: 0.742626
# epoch 62; iter: 0; batch classifier loss: 0.566423; batch adversarial loss: 0.750038
# epoch 63; iter: 0; batch classifier loss: 0.644510; batch adversarial loss: 0.755294
# epoch 64; iter: 0; batch classifier loss: 0.600768; batch adversarial loss: 0.756979
# epoch 65; iter: 0; batch classifier loss: 0.587305; batch adversarial loss: 0.747823
# epoch 66; iter: 0; batch classifier loss: 0.609175; batch adversarial loss: 0.751713
# epoch 67; iter: 0; batch classifier loss: 0.640668; batch adversarial loss: 0.760386
# epoch 68; iter: 0; batch classifier loss: 0.639703; batch adversarial loss: 0.750564
# epoch 69; iter: 0; batch classifier loss: 0.630230; batch adversarial loss: 0.752062
# epoch 70; iter: 0; batch classifier loss: 0.523761; batch adversarial loss: 0.742382
# epoch 71; iter: 0; batch classifier loss: 0.634118; batch adversarial loss: 0.747956
# epoch 72; iter: 0; batch classifier loss: 0.556554; batch adversarial loss: 0.741448
# epoch 73; iter: 0; batch classifier loss: 0.571447; batch adversarial loss: 0.733370
# epoch 74; iter: 0; batch classifier loss: 0.547701; batch adversarial loss: 0.734882
# epoch 75; iter: 0; batch classifier loss: 0.533303; batch adversarial loss: 0.735945
# epoch 76; iter: 0; batch classifier loss: 0.617237; batch adversarial loss: 0.738853
# epoch 77; iter: 0; batch classifier loss: 0.533975; batch adversarial loss: 0.734365
# epoch 78; iter: 0; batch classifier loss: 0.539399; batch adversarial loss: 0.737960
# epoch 79; iter: 0; batch classifier loss: 0.553496; batch adversarial loss: 0.732222
# CPU times: user 1.92 s, sys: 361 ms, total: 2.28 s
# Wall time: 1.53 s

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name] = utils.metrics_threshold_sweep(
    dataset=data_val_copy,
    model=models[model_name],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name] = utils.describe_metrics(metrics_sweep[model_name])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name] = utils.compute_metrics(
    dataset=data_test_copy, 
    model=models[model_name], 
    threshold=metrics_best_thresh_validate[model_name]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name])

# Graficamos el comportamiento del modelo para el rango de umbrales 
f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name])
a.set_title(model_name)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.5151
# AUC: 0.5266
# Balanced accuracy: 0.5467
# Accuracy: 0.5467
# Independence ( |ΔP(Y_pred = 1)| ): 0.6819
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0239
# Sufficiency ( |ΔPPV| ) : 0.0730
# CPU times: user 312 ms, sys: 762 ms, total: 1.07 s
# Wall time: 306 ms

# %% [markdown]
# #### Eliminación de prejuicios adversarios: Red neuronal sin eliminación de prejuicios

# %%
# %%time

sess.close()
tf.reset_default_graph()
sess = tf.Session()

# Nombramos al modelo
model_name = 'Basic_NN_no_adversarial_debiasing'

# Hacemos una copia de los datasets"
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

models[model_name] = AdversarialDebiasing(privileged_groups = privileged_groups,
                                          unprivileged_groups = unprivileged_groups,
                                          scope_name = 'biased_classifier',
                                          debias=False,
                                          sess=sess,
                                          num_epochs=125)
models[model_name].fit(data_train_copy)
# Out:
# epoch 0; iter: 0; batch classifier loss: 0.713279
# epoch 1; iter: 0; batch classifier loss: 0.709168
# epoch 2; iter: 0; batch classifier loss: 0.656881
# epoch 3; iter: 0; batch classifier loss: 0.677009
# epoch 4; iter: 0; batch classifier loss: 0.673881
# epoch 5; iter: 0; batch classifier loss: 0.664628
# epoch 6; iter: 0; batch classifier loss: 0.638314
# epoch 7; iter: 0; batch classifier loss: 0.651415
# epoch 8; iter: 0; batch classifier loss: 0.663431
# epoch 9; iter: 0; batch classifier loss: 0.635999
# epoch 10; iter: 0; batch classifier loss: 0.628514
# epoch 11; iter: 0; batch classifier loss: 0.596408
# epoch 12; iter: 0; batch classifier loss: 0.620819
# epoch 13; iter: 0; batch classifier loss: 0.602028
# epoch 14; iter: 0; batch classifier loss: 0.632144
# epoch 15; iter: 0; batch classifier loss: 0.639273
# epoch 16; iter: 0; batch classifier loss: 0.591718
# epoch 17; iter: 0; batch classifier loss: 0.608414
# epoch 18; iter: 0; batch classifier loss: 0.568291
# epoch 19; iter: 0; batch classifier loss: 0.580825
# epoch 20; iter: 0; batch classifier loss: 0.607852
# epoch 21; iter: 0; batch classifier loss: 0.603101
# epoch 22; iter: 0; batch classifier loss: 0.615208
# epoch 23; iter: 0; batch classifier loss: 0.642102
# epoch 24; iter: 0; batch classifier loss: 0.599950
# epoch 25; iter: 0; batch classifier loss: 0.575877
# epoch 26; iter: 0; batch classifier loss: 0.559781
# epoch 27; iter: 0; batch classifier loss: 0.554158
# epoch 28; iter: 0; batch classifier loss: 0.566456
# epoch 29; iter: 0; batch classifier loss: 0.550710
# epoch 30; iter: 0; batch classifier loss: 0.542077
# epoch 31; iter: 0; batch classifier loss: 0.546883
# epoch 32; iter: 0; batch classifier loss: 0.534345
# epoch 33; iter: 0; batch classifier loss: 0.545803
# epoch 34; iter: 0; batch classifier loss: 0.554637
# epoch 35; iter: 0; batch classifier loss: 0.526908
# epoch 36; iter: 0; batch classifier loss: 0.529410
# epoch 37; iter: 0; batch classifier loss: 0.544652
# epoch 38; iter: 0; batch classifier loss: 0.564941
# epoch 39; iter: 0; batch classifier loss: 0.566993
# epoch 40; iter: 0; batch classifier loss: 0.537184
# epoch 41; iter: 0; batch classifier loss: 0.494018
# epoch 42; iter: 0; batch classifier loss: 0.529046
# epoch 43; iter: 0; batch classifier loss: 0.490862
# epoch 44; iter: 0; batch classifier loss: 0.475179
# epoch 45; iter: 0; batch classifier loss: 0.494852
# epoch 46; iter: 0; batch classifier loss: 0.484691
# epoch 47; iter: 0; batch classifier loss: 0.485015
# epoch 48; iter: 0; batch classifier loss: 0.531174
# epoch 49; iter: 0; batch classifier loss: 0.476394
# epoch 50; iter: 0; batch classifier loss: 0.469604
# epoch 51; iter: 0; batch classifier loss: 0.454805
# epoch 52; iter: 0; batch classifier loss: 0.497945
# epoch 53; iter: 0; batch classifier loss: 0.420372
# epoch 54; iter: 0; batch classifier loss: 0.428519
# epoch 55; iter: 0; batch classifier loss: 0.487081
# epoch 56; iter: 0; batch classifier loss: 0.475412
# epoch 57; iter: 0; batch classifier loss: 0.435449
# epoch 58; iter: 0; batch classifier loss: 0.482604
# epoch 59; iter: 0; batch classifier loss: 0.438815
# epoch 60; iter: 0; batch classifier loss: 0.457699
# epoch 61; iter: 0; batch classifier loss: 0.402870
# epoch 62; iter: 0; batch classifier loss: 0.388285
# epoch 63; iter: 0; batch classifier loss: 0.480335
# epoch 64; iter: 0; batch classifier loss: 0.384997
# epoch 65; iter: 0; batch classifier loss: 0.434261
# epoch 66; iter: 0; batch classifier loss: 0.404100
# epoch 67; iter: 0; batch classifier loss: 0.418888
# epoch 68; iter: 0; batch classifier loss: 0.434431
# epoch 69; iter: 0; batch classifier loss: 0.438799
# epoch 70; iter: 0; batch classifier loss: 0.409267
# epoch 71; iter: 0; batch classifier loss: 0.426737
# epoch 72; iter: 0; batch classifier loss: 0.466992
# epoch 73; iter: 0; batch classifier loss: 0.378161
# epoch 74; iter: 0; batch classifier loss: 0.417204
# epoch 75; iter: 0; batch classifier loss: 0.451624
# epoch 76; iter: 0; batch classifier loss: 0.353127
# epoch 77; iter: 0; batch classifier loss: 0.355596
# epoch 78; iter: 0; batch classifier loss: 0.412939
# epoch 79; iter: 0; batch classifier loss: 0.364396
# epoch 80; iter: 0; batch classifier loss: 0.377788
# epoch 81; iter: 0; batch classifier loss: 0.351533
# epoch 82; iter: 0; batch classifier loss: 0.383340
# epoch 83; iter: 0; batch classifier loss: 0.368413
# epoch 84; iter: 0; batch classifier loss: 0.356794
# epoch 85; iter: 0; batch classifier loss: 0.399305
# epoch 86; iter: 0; batch classifier loss: 0.340039
# epoch 87; iter: 0; batch classifier loss: 0.354283
# epoch 88; iter: 0; batch classifier loss: 0.389639
# epoch 89; iter: 0; batch classifier loss: 0.347120
# epoch 90; iter: 0; batch classifier loss: 0.421432
# epoch 91; iter: 0; batch classifier loss: 0.337068
# epoch 92; iter: 0; batch classifier loss: 0.386441
# epoch 93; iter: 0; batch classifier loss: 0.378847
# epoch 94; iter: 0; batch classifier loss: 0.354955
# epoch 95; iter: 0; batch classifier loss: 0.365063
# epoch 96; iter: 0; batch classifier loss: 0.349386
# epoch 97; iter: 0; batch classifier loss: 0.293501
# epoch 98; iter: 0; batch classifier loss: 0.379277
# epoch 99; iter: 0; batch classifier loss: 0.340279
# epoch 100; iter: 0; batch classifier loss: 0.353795
# epoch 101; iter: 0; batch classifier loss: 0.306587
# epoch 102; iter: 0; batch classifier loss: 0.309023
# epoch 103; iter: 0; batch classifier loss: 0.339838
# epoch 104; iter: 0; batch classifier loss: 0.314723
# epoch 105; iter: 0; batch classifier loss: 0.318341
# epoch 106; iter: 0; batch classifier loss: 0.300049
# epoch 107; iter: 0; batch classifier loss: 0.285935
# epoch 108; iter: 0; batch classifier loss: 0.290386
# epoch 109; iter: 0; batch classifier loss: 0.345753
# epoch 110; iter: 0; batch classifier loss: 0.310546
# epoch 111; iter: 0; batch classifier loss: 0.326995
# epoch 112; iter: 0; batch classifier loss: 0.352085
# epoch 113; iter: 0; batch classifier loss: 0.286528
# epoch 114; iter: 0; batch classifier loss: 0.321468
# epoch 115; iter: 0; batch classifier loss: 0.253660
# epoch 116; iter: 0; batch classifier loss: 0.305866
# epoch 117; iter: 0; batch classifier loss: 0.312217
# epoch 118; iter: 0; batch classifier loss: 0.290614
# epoch 119; iter: 0; batch classifier loss: 0.267835
# epoch 120; iter: 0; batch classifier loss: 0.294408
# epoch 121; iter: 0; batch classifier loss: 0.239406
# epoch 122; iter: 0; batch classifier loss: 0.257734
# epoch 123; iter: 0; batch classifier loss: 0.257007
# epoch 124; iter: 0; batch classifier loss: 0.273893
# CPU times: user 1.57 s, sys: 253 ms, total: 1.82 s
# Wall time: 1.05 s

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name] = utils.metrics_threshold_sweep(
    dataset=data_val_copy,
    model=models[model_name],
    thresh_arr=thresh_sweep
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name] = utils.describe_metrics(metrics_sweep[model_name])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name] = utils.compute_metrics(
    dataset=data_test_copy, 
    model=models[model_name], 
    threshold=metrics_best_thresh_validate[model_name]['best_threshold'])

display(Markdown("**Validation set results**"))
utils.print_metrics(metrics_best_thresh_validate[model_name])

# Graficamos el comportamiento del modelo para el rango de umbrales 
f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name])
a.set_title(model_name)
f
# Out:
# **Validation set results**
# Threshold corresponding to *best balanced accuracy*: 0.8384
# AUC: 0.4956
# Balanced accuracy: 0.5600
# Accuracy: 0.5600
# Independence ( |ΔP(Y_pred = 1)| ): 0.0936
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0210
# Sufficiency ( |ΔPPV| ) : 0.2596
# CPU times: user 184 ms, sys: 28.1 ms, total: 212 ms
# Wall time: 204 ms

# %% [markdown]
# ## Técnicas de postprocesado

# %% [markdown]
# ### Clasificación de rechazo de opción

# %%
# %%time 

# Nombramos al modelo
fairness_method = '_reject_option'

# Nombre del modelo al que le aplicaremos post-processing
model_name = 'logistic_regression'

# métricas fair a optimizar
fair_metrics = {'spd': "Statistical parity difference", 'aod': "Average odds difference", 'eod': "Equal opportunity difference"}

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])

# Optimizamos un modelo nuevo por cada métrica
for key_metric in fair_metrics:
    
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    models[model_name_metric] = RejectOptionClassification(
        unprivileged_groups=unprivileged_groups, 
        privileged_groups=privileged_groups, 
        metric_name=fair_metrics[key_metric],
        metric_lb=-0.01, metric_ub=0.01)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 14.6 s, sys: 2.69 s, total: 17.3 s
# Wall time: 15.5 s

# %%
display(Markdown("**Validation set results for logistic regression**"))
for key_metric in fair_metrics:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_val_copy, 
        dataset_preds=data_val_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
    
    print(model_name_metric)
    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')
    
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_test_copy, 
        dataset_preds=data_test_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
# Out:
# **Validation set results for logistic regression**
# logistic_regression_reject_option_spd
# Threshold corresponding to *best balanced accuracy*: 0.5247
# AUC: 0.5104
# Balanced accuracy: 0.5067
# Accuracy: 0.5067
# Independence ( |ΔP(Y_pred = 1)| ): 0.1840
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0196
# Sufficiency ( |ΔPPV| ) : 0.0526
#
#
# logistic_regression_reject_option_aod
# Threshold corresponding to *best balanced accuracy*: 0.5148
# AUC: 0.5104
# Balanced accuracy: 0.4867
# Accuracy: 0.4867
# Independence ( |ΔP(Y_pred = 1)| ): 0.0886
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0360
# Sufficiency ( |ΔPPV| ) : 0.0795
#
#
# logistic_regression_reject_option_eod
# Threshold corresponding to *best balanced accuracy*: 0.5049
# AUC: 0.5104
# Balanced accuracy: 0.4733
# Accuracy: 0.4733
# Independence ( |ΔP(Y_pred = 1)| ): 0.0786
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0625
# Sufficiency ( |ΔPPV| ) : 0.1054

# %%
# %%time 

# Nombramos al modelo
fairness_method = '_reject_option'

# Nombre del modelo al que le aplicaremos post-processing
model_name = 'xgb_classifier'

# métricas fair a optimizar
fair_metrics = {'spd': "Statistical parity difference", 'aod': "Average odds difference", 'eod': "Equal opportunity difference"}

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])

# Optimizamos un modelo nuevo por cada métrica
for key_metric in fair_metrics:
    
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    models[model_name_metric] = RejectOptionClassification(
        unprivileged_groups=unprivileged_groups, 
        privileged_groups=privileged_groups, 
        metric_name=fair_metrics[key_metric],
        metric_lb=-0.01, metric_ub=0.01)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 17.4 s, sys: 148 ms, total: 17.5 s
# Wall time: 14.3 s

# %%
display(Markdown("**Validation set results for xgb classifier**"))
for key_metric in fair_metrics:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    metrics_best_thresh_validate[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_val_copy, 
        dataset_preds=data_val_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
    
    print(model_name_metric)
    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')
    
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_test_copy, 
        dataset_preds=data_test_preds, 
        model=models[model_name_metric], 
        required_threshold=False)
# Out:
# **Validation set results for xgb classifier**
# xgb_classifier_reject_option_spd
# Threshold corresponding to *best balanced accuracy*: 0.2278
# AUC: 0.5529
# Balanced accuracy: 0.5467
# Accuracy: 0.5467
# Independence ( |ΔP(Y_pred = 1)| ): 0.2432
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0092
# Sufficiency ( |ΔPPV| ) : 0.0115
#
#
# xgb_classifier_reject_option_aod
# Threshold corresponding to *best balanced accuracy*: 0.3268
# AUC: 0.5529
# Balanced accuracy: 0.5600
# Accuracy: 0.5600
# Independence ( |ΔP(Y_pred = 1)| ): 0.0739
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0229
# Sufficiency ( |ΔPPV| ) : 0.0517
#
#
# xgb_classifier_reject_option_eod
# Threshold corresponding to *best balanced accuracy*: 0.3268
# AUC: 0.5529
# Balanced accuracy: 0.5600
# Accuracy: 0.5600
# Independence ( |ΔP(Y_pred = 1)| ): 0.0739
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0229
# Sufficiency ( |ΔPPV| ) : 0.0517

# %% [markdown]
# ### Escalado de Platt por grupos

# %%
# %%time
fairness_method = '_platt_scaling'
model_names = ['logistic_regression', 'xgb_classifier']
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy = True), data_val.copy(deepcopy = True), data_test.copy(deepcopy = True)

for model_name in model_names:
    # Hacemos una copia de las predicciones del modelo de referencia
    model_thresh = metrics_best_thresh_validate[model_name]['best_threshold']
    data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name], class_thresh = model_thresh)
    ## Plat Scaling:
    #1. dividir el validation data usando los groups sensibles
    data_val_preds_priv, data_val_preds_unpriv, priv_indices, unpriv_indices = utils.split_dataset_on_sensitive_attribute(
        dataset = data_val_preds, privileged_group_label = list((privileged_groups[0].values()))[0])
    #2. copia el validation data para guardar los scores
    data_val_preds2 = data_val_preds.copy(deepcopy = True)
    #3. hacer un modelo para cada grupo
    sensitive_groups_data = {'priv': [data_val_preds_priv, priv_indices],
                             'unpriv': [data_val_preds_unpriv, unpriv_indices]}

    for group, data_group_list in sensitive_groups_data.items():

        # nombramos al modelo con su grupo específico
        model_name_group = '{}_{}_{}'.format(model_name, fairness_method, group)

        # Inicializamos el modelo y lo asignamos al diccionario
        models[model_name_group] = LogisticRegression()

        # Realizamos el modelo usando datos para cada grupo en el validation data
        models[ model_name_group ] = models[model_name_group].fit(data_group_list[0].scores,   # data_group_list[0] -> data_val_preds_priv or data_val_preds_unpriv
                                                                  data_val_copy.subset(data_group_list[1]).labels.ravel()) # data_group_list[1] -> priv_indices or unpriv_indices
        # haz predicciones de probabilidad con el modelo de cada groupo y guardar lo en data_val_preds2
        # las predicciones de probabilidad son los platt scores
        scores_group = models[model_name_group].predict_proba(data_group_list[0].scores)
        pos_ind_group = np.where(models[model_name_group].classes_ == data_group_list[0].favorable_label)[0][0]
        data_val_preds2.scores[data_group_list[1]] = scores_group[:, pos_ind_group].reshape(-1,1)
        
        # Evaluamos a los modelos para el rango de umbrales
    thresh_sweep_platt = np.linspace(np.min(data_val_preds2.scores.ravel()),
                                     np.max(data_val_preds2.scores.ravel()),
                                     50)

    metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep_from_scores(
            dataset_true = data_val_copy,
            dataset_preds = data_val_preds2,
            thresh_arr = thresh_sweep_platt
        )

    # Evaluamos las métricas para el mejor umbral y las guardamos
    metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics( metrics_sweep[model_name+fairness_method] )

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    print('\nValidation set results for {}'.format(model_name))
    utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
    # utils.plot_fairness_and_accuracy( metrics_sweep[model_name+fairness_method] )
    # plt.title( model_name+fairness_method )
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
    a.set_title(model_name+fairness_method )
    f
# Out:
# Validation set results for logistic_regression
# Threshold corresponding to *best balanced accuracy*: 0.5087
# AUC: 0.5220
# Balanced accuracy: 0.5333
# Accuracy: 0.5333
# Independence ( |ΔP(Y_pred = 1)| ): 0.5732
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0470
# Sufficiency ( |ΔPPV| ) : 0.5532
#
# Validation set results for xgb_classifier
# Threshold corresponding to *best balanced accuracy*: 0.5002
# AUC: 0.5492
# Balanced accuracy: 0.5733
# Accuracy: 0.5733
# Independence ( |ΔP(Y_pred = 1)| ): 0.3841
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0306
# Sufficiency ( |ΔPPV| ) : 0.0113
# CPU times: user 2.47 s, sys: 180 ms, total: 2.65 s
# Wall time: 264 ms

# %%
# usa el optimal cutoff para predecir usando el test dato

for model_name in model_names:
    model_thresh = metrics_best_thresh_validate[model_name]['best_threshold']
    data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name], class_thresh = model_thresh)
    
    # 1. dividir el validation data usando los groups sensibles
    data_test_preds_priv, data_test_preds_unpriv, priv_indices, unpriv_indices = utils.split_dataset_on_sensitive_attribute(dataset = data_test_preds,
                                                                                                                            privileged_group_label = list((privileged_groups[0].values()))[0])
    # 2. copia el test data para guardar los platt scores
    data_test_preds2 = data_test_preds.copy(deepcopy = True)
    
    # 3. predecir con el modelo de cada grupo
    sensitive_groups_data_test = {'priv': [data_test_preds_priv, priv_indices],
                                  'unpriv': [data_test_preds_unpriv, unpriv_indices]}

    for group, data_group_list in sensitive_groups_data_test.items():    
        # nombramos al modelo con su grupo específico
        model_name_group = '{}_{}_{}'.format(model_name, fairness_method, group)

        # haz predicciones de probabilidad con el modelo de cada groupo y guardar lo en data_val_preds2
        # las predicciones de probabilidad son los platt scores
        scores_group = models[model_name_group].predict_proba(data_group_list[0].scores)
        pos_ind_group = np.where(models[model_name_group].classes_ == data_group_list[0].favorable_label)[0][0]
        data_test_preds2.scores[data_group_list[1]] = scores_group[:, pos_ind_group].reshape(-1,1)
    
    metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_from_scores(dataset_true = data_test_copy,
                                                                                             dataset_pred = data_test_preds2,
                                                                                             threshold = metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'])

# %% [markdown]
# ### Procesador de probabilidades igualadas

# %% [markdown]
# #### Usando labels

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'logistic_regression'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:23
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:144, in EqOddsPostprocessing.fit(self, dataset_true, dataset_pred)
#     139 oflip = np.ravel(
#     140     dataset_pred.labels[cond_vec_unpriv] == dataset_pred.unfavorable_label)
#     142 y_true = dataset_true.labels.ravel()
# --> 144 sm_tn = np.logical_and(sflip,
#     145     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     146     dtype=np.float64)
#     147 sm_fn = np.logical_and(sflip,
#     148     y_true[cond_vec_priv] == dataset_true.favorable_label,
#     149     dtype=np.float64)
#     150 sm_fp = np.logical_and(sconst,
#     151     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     152     dtype=np.float64)
#
# TypeError: No loop matching the specified signature and casting was found for ufunc logical_and

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing(
    dataset_true=data_test_copy,
    dataset_preds=data_test_preds,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'xgb_classifier'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Inicializamos el modelo (dadas las predicciones, no los scores) y lo asignamos al diccionario
models[model_name+fairness_method] = EqOddsPostprocessing(
    privileged_groups = privileged_groups,
    unprivileged_groups = unprivileged_groups,
    # cost_constraint = quality,
    seed = seed)

# Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
models[model_name+fairness_method] = models[model_name+fairness_method].fit(data_train_copy, data_train_preds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:23
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:144, in EqOddsPostprocessing.fit(self, dataset_true, dataset_pred)
#     139 oflip = np.ravel(
#     140     dataset_pred.labels[cond_vec_unpriv] == dataset_pred.unfavorable_label)
#     142 y_true = dataset_true.labels.ravel()
# --> 144 sm_tn = np.logical_and(sflip,
#     145     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     146     dtype=np.float64)
#     147 sm_fn = np.logical_and(sflip,
#     148     y_true[cond_vec_priv] == dataset_true.favorable_label,
#     149     dtype=np.float64)
#     150 sm_fp = np.logical_and(sconst,
#     151     y_true[cond_vec_priv] == dataset_true.unfavorable_label,
#     152     dtype=np.float64)
#
# TypeError: No loop matching the specified signature and casting was found for ufunc logical_and

# %%
# %%time 

# Evaluamos al modelo para un rango de umbrales
metrics_sweep[model_name+fairness_method] = utils.metrics_postprocessing_threshold_sweep(
    dataset_true=data_val_copy,
    dataset_preds=data_val_preds,
    model=models[model_name+fairness_method],
    thresh_arr=thresh_sweep,
    scores_or_labels='labels'
)

# Evaluamos las métricas para el mejor umbral
metrics_best_thresh_validate[model_name+fairness_method] = utils.describe_metrics(metrics_sweep[model_name+fairness_method])

# Usando el mejor umbral, calculamos las métricas en el test set
metrics_best_thresh_test[model_name+fairness_method] = utils.compute_metrics_postprocessing(
    dataset_true=data_test_copy,
    dataset_preds=data_test_preds,
    model=models[model_name+fairness_method], 
    threshold=metrics_best_thresh_validate[model_name+fairness_method]['best_threshold'], 
    scores_or_labels='labels')

utils.print_metrics(metrics_best_thresh_validate[model_name+fairness_method])
print('\n')

# Graficamos el comportamiento del modelo para el rango de umbrales 
# utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
# plt.title(model_name+fairness_method)

f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name+fairness_method])
a.set_title(model_name+fairness_method)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/DEFINITIVO/utils.py:783, in metrics_postprocessing_threshold_sweep(dataset_true, dataset_preds, model, thresh_arr, scores_or_labels)
#     781     dataset_preds = update_dataset_from_scores(dataset_preds, dataset_preds.scores, t)
#     782     dataset_preds_trans = dataset_preds.copy()
# --> 783     dataset_preds_trans.labels = model.predict(dataset_preds).labels
#     784 else:
#     785     raise ValueError('Invalid value for parameter scores_or_labels. Valid values are: scores; labels')
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/miniconda3/envs/aif360/lib/python3.9/site-packages/aif360/algorithms/postprocessing/eq_odds_postprocessing.py:207, in EqOddsPostprocessing.predict(self, dataset)
#     204     np.random.seed(self.seed)
#     206 # Get the model parameters output from fit
# --> 207 sp2p, sn2p, op2p, on2p = self.model_params.x
#     209 # Create boolean conditioning vectors for protected groups
#     210 cond_vec_priv = utils.compute_boolean_conditioning_vector(
#     211     dataset.protected_attributes, dataset.protected_attribute_names,
#     212     self.privileged_groups)
#
# AttributeError: 'NoneType' object has no attribute 'x'

# %% [markdown]
# #### Usando scores

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'logistic_regression'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 295 ms, sys: 1.79 s, total: 2.08 s
# Wall time: 46.1 ms

# %%
display(Markdown("**Validation set results for logistic regression**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_test_copy,
        dataset_preds=data_test_preds,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for logistic regression**
# Results for logistic_regression_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.3737
# AUC: 0.5104
# Balanced accuracy: 0.5533
# Accuracy: 0.5533
# Independence ( |ΔP(Y_pred = 1)| ): 0.0893
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0245
# Sufficiency ( |ΔPPV| ) : 0.0151
#
#
# Results for logistic_regression_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.3737
# AUC: 0.5104
# Balanced accuracy: 0.5200
# Accuracy: 0.5200
# Independence ( |ΔP(Y_pred = 1)| ): 0.3537
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0452
# Sufficiency ( |ΔPPV| ) : 0.0619
#
#
# Results for logistic_regression_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.3737
# AUC: 0.5104
# Balanced accuracy: 0.5333
# Accuracy: 0.5333
# Independence ( |ΔP(Y_pred = 1)| ): 0.1912
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0680
# Sufficiency ( |ΔPPV| ) : 0.0151

# %%
# %%time 
# Nombramos al modelo
fairness_method = '_equal_odds'
# Nombre del modelo al que le aplicaremos post-processing
model_name = 'xgb_classifier'

# Hacemos una copia de los datasets
data_train_copy, data_val_copy, data_test_copy = data_train.copy(deepcopy=True), data_val.copy(deepcopy=True), data_test.copy(deepcopy=True)

# Hacemos una copia de las predicciones del modelo de referencia
data_train_preds = utils.update_dataset_from_model(data_train_copy, models[model_name])
data_val_preds = utils.update_dataset_from_model(data_val_copy, models[model_name])
data_test_preds = utils.update_dataset_from_model(data_test_copy, models[model_name])


# Parámetros del modelo
# métricas fair a optimizar
quality_constraints = ["weighted", 'fnr', 'fpr'] # "weighted" average of fnr and fpr

for quality in quality_constraints:
    # nombramos al modelo con su métrica específica
    model_name_metric = model_name + fairness_method + '_' + quality
    
    # Inicializamos el modelo y lo asignamos al diccionario
    models[model_name_metric] = CalibratedEqOddsPostprocessing(
        privileged_groups=privileged_groups,
        unprivileged_groups=unprivileged_groups,
        cost_constraint=quality,
        seed=seed)

    # Realizamos el post-procesado en función de las clases realies (data_copy) y las predicciones del modelo de referencia (data_preds)
    models[model_name_metric] = models[model_name_metric].fit(data_train_copy, data_train_preds)
# Out:
# CPU times: user 4.77 s, sys: 120 ms, total: 4.89 s
# Wall time: 100 ms

# %%
display(Markdown("**Validation set results for xgb classifier**"))
for key_metric in quality_constraints:
    
    model_name_metric = model_name + fairness_method + '_' + key_metric
    
    print(f'Results for {model_name_metric}')
    
    # Evaluamos al modelo para un rango de umbrales
    metrics_sweep[model_name_metric] = utils.metrics_postprocessing_threshold_sweep(
        dataset_true=data_val_copy,
        dataset_preds=data_val_preds,
        model=models[model_name_metric],
        thresh_arr=thresh_sweep,
        scores_or_labels='scores'
    )

    # Evaluamos las métricas para el mejor umbral
    metrics_best_thresh_validate[model_name_metric] = utils.describe_metrics(metrics_sweep[model_name_metric])

    # Usando el mejor umbral, calculamos las métricas en el test set
    metrics_best_thresh_test[model_name_metric] = utils.compute_metrics_postprocessing(
        dataset_true=data_test_copy,
        dataset_preds=data_test_preds,
        model=models[model_name_metric], 
        threshold=metrics_best_thresh_validate[model_name_metric]['best_threshold'], 
        scores_or_labels='scores')

    utils.print_metrics(metrics_best_thresh_validate[model_name_metric])
    print('\n')

    # Graficamos el comportamiento del modelo para el rango de umbrales 
    # utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    # plt.title(model_name_metric)
    
    f,a = utils.plot_fairness_and_accuracy(metrics_sweep[model_name_metric])
    a.set_title(model_name_metric)
    f
# Out:
# **Validation set results for xgb classifier**
# Results for xgb_classifier_equal_odds_weighted
# Threshold corresponding to *best balanced accuracy*: 0.2727
# AUC: 0.5529
# Balanced accuracy: 0.5600
# Accuracy: 0.5600
# Independence ( |ΔP(Y_pred = 1)| ): 0.1184
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0177
# Sufficiency ( |ΔPPV| ) : 0.0468
#
#
# Results for xgb_classifier_equal_odds_fnr
# Threshold corresponding to *best balanced accuracy*: 0.2727
# AUC: 0.5529
# Balanced accuracy: 0.5667
# Accuracy: 0.5667
# Independence ( |ΔP(Y_pred = 1)| ): 0.1331
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0025
# Sufficiency ( |ΔPPV| ) : 0.0377
#
#
# Results for xgb_classifier_equal_odds_fpr
# Threshold corresponding to *best balanced accuracy*: 0.2727
# AUC: 0.5529
# Balanced accuracy: 0.5667
# Accuracy: 0.5667
# Independence ( |ΔP(Y_pred = 1)| ): 0.1062
# Separation ( |ΔFPR + ΔFNR|/2 ): 0.0296
# Sufficiency ( |ΔPPV| ) : 0.0548

# %% [markdown]
# ## Comparación de modelos
#
# Podemos usar los diccionarios que resumen la calidad de los modelos fair para compararlos todos.

# %% [markdown]
# ### Resultados en validación

# %%
algorithm_performance_summary = pd.DataFrame(metrics_best_thresh_validate).T
algorithm_performance_summary
# Out:
#                                          best_threshold   bal_acc       acc  \
# logistic_regression                            0.373673  0.553333  0.553333
# xgb_classifier                                 0.272653  0.560000  0.560000
# logistic_regression_reweighting                0.434286  0.529036  0.529980
# xgb_classifier_reweighting                     0.313061  0.553403  0.554771
# logistic_regression_di_remover                 0.373673  0.553333  0.553333
# xgb_classifier_di_remover                      0.272653  0.560000  0.560000
# NN_adversarial_debiasing                       0.515102  0.546667  0.546667
# Basic_NN_no_adversarial_debiasing              0.838367  0.560000  0.560000
# logistic_regression_reject_option_spd          0.524747  0.506667  0.506667
# logistic_regression_reject_option_aod          0.514848  0.486667  0.486667
# logistic_regression_reject_option_eod          0.504949  0.473333  0.473333
# xgb_classifier_reject_option_spd               0.227778  0.546667  0.546667
# xgb_classifier_reject_option_aod               0.326768  0.560000  0.560000
# xgb_classifier_reject_option_eod               0.326768  0.560000  0.560000
# logistic_regression_platt_scaling              0.508738  0.533333  0.533333
# xgb_classifier_platt_scaling                   0.500216  0.573333  0.573333
# logistic_regression_equal_odds_weighted        0.373673  0.553333  0.553333
# logistic_regression_equal_odds_fnr             0.373673  0.520000  0.520000
# logistic_regression_equal_odds_fpr             0.373673  0.533333  0.533333
# xgb_classifier_equal_odds_weighted             0.272653  0.560000  0.560000
# xgb_classifier_equal_odds_fnr                  0.272653  0.566667  0.566667
# xgb_classifier_equal_odds_fpr                  0.272653  0.566667  0.566667
#
#                                          independence  separation  \
# logistic_regression                          0.162482    0.022727
# xgb_classifier                               0.118364    0.017695
# logistic_regression_reweighting              0.150117    0.059957
# xgb_classifier_reweighting                   0.088208    0.022078
# logistic_regression_di_remover               0.162482    0.022727
# xgb_classifier_di_remover                    0.118364    0.017695
# NN_adversarial_debiasing                     0.681851    0.023864
# Basic_NN_no_adversarial_debiasing            0.093615    0.021050
# logistic_regression_reject_option_spd        0.184003    0.019589
# logistic_regression_reject_option_aod        0.088594    0.035985
# logistic_regression_reject_option_eod        0.078551    0.062500
# xgb_classifier_reject_option_spd             0.243185    0.009199
# xgb_classifier_reject_option_aod             0.073888    0.022944
# xgb_classifier_reject_option_eod             0.073888    0.022944
# logistic_regression_platt_scaling            0.573171    0.047024
# xgb_classifier_platt_scaling                 0.384146    0.030628
# logistic_regression_equal_odds_weighted      0.089311    0.024513
# logistic_regression_equal_odds_fnr           0.353659    0.045238
# logistic_regression_equal_odds_fpr           0.191176    0.067965
# xgb_classifier_equal_odds_weighted           0.118364    0.017695
# xgb_classifier_equal_odds_fnr                0.133070    0.002543
# xgb_classifier_equal_odds_fpr                0.106169    0.029600
#
#                                          sufficiency       auc
# logistic_regression                         0.019897  0.510400
# xgb_classifier                              0.046807  0.552889
# logistic_regression_reweighting             0.200221  0.510400
# xgb_classifier_reweighting                  0.176057  0.552889
# logistic_regression_di_remover              0.019897  0.510400
# xgb_classifier_di_remover                   0.046807  0.552889
# NN_adversarial_debiasing                    0.072973  0.526578
# Basic_NN_no_adversarial_debiasing           0.259615  0.495644
# logistic_regression_reject_option_spd       0.052632  0.510400
# logistic_regression_reject_option_aod       0.079503  0.510400
# logistic_regression_reject_option_eod       0.105413  0.510400
# xgb_classifier_reject_option_spd            0.011519  0.552889
# xgb_classifier_reject_option_aod            0.051741  0.552889
# xgb_classifier_reject_option_eod            0.051741  0.552889
# logistic_regression_platt_scaling           0.553191  0.521956
# xgb_classifier_platt_scaling                0.011312  0.549156
# logistic_regression_equal_odds_weighted     0.015100  0.510400
# logistic_regression_equal_odds_fnr          0.061876  0.510400
# logistic_regression_equal_odds_fpr          0.015078  0.510400
# xgb_classifier_equal_odds_weighted          0.046807  0.552889
# xgb_classifier_equal_odds_fnr               0.037736  0.552889
# xgb_classifier_equal_odds_fpr               0.054843  0.552889

# %% [markdown]
# ### Resultados en test

# %%
algorithm_performance_summary = pd.DataFrame(metrics_best_thresh_test).T
algorithm_performance_summary
# Out:
#                                          best_threshold   bal_acc       acc  \
# logistic_regression                            0.373673  0.605366  0.593333
# xgb_classifier                                 0.272653  0.589142  0.580000
# logistic_regression_reweighting                0.434286  0.598400  0.594188
# xgb_classifier_reweighting                     0.313061  0.562879  0.557373
# logistic_regression_di_remover                 0.373673  0.605366  0.593333
# xgb_classifier_di_remover                      0.272653  0.589142  0.580000
# NN_adversarial_debiasing                       0.515102  0.518720  0.513333
# Basic_NN_no_adversarial_debiasing              0.838367  0.493047  0.513333
# logistic_regression_reject_option_spd          0.524747  0.614994  0.620000
# logistic_regression_reject_option_aod          0.514848  0.609378  0.613333
# logistic_regression_reject_option_eod          0.504949  0.596720  0.600000
# xgb_classifier_reject_option_spd               0.227778  0.549117  0.533333
# xgb_classifier_reject_option_aod               0.326768  0.574345  0.566667
# xgb_classifier_reject_option_eod               0.326768  0.574345  0.566667
# logistic_regression_platt_scaling              0.508738  0.596630  0.606667
# xgb_classifier_platt_scaling                   0.500216  0.579872  0.580000
# logistic_regression_equal_odds_weighted        0.373673  0.600464  0.586667
# logistic_regression_equal_odds_fnr             0.373673  0.568818  0.553333
# logistic_regression_equal_odds_fpr             0.373673  0.536548  0.513333
# xgb_classifier_equal_odds_weighted             0.272653  0.589142  0.580000
# xgb_classifier_equal_odds_fnr                  0.272653  0.589142  0.580000
# xgb_classifier_equal_odds_fpr                  0.272653  0.596185  0.586667
#
#                                          independence  separation  \
# logistic_regression                          0.229437    0.042972
# xgb_classifier                               0.162338    0.030776
# logistic_regression_reweighting              0.013103    0.056583
# xgb_classifier_reweighting                   0.163727    0.028283
# logistic_regression_di_remover               0.229437    0.042972
# xgb_classifier_di_remover                    0.162338    0.030776
# NN_adversarial_debiasing                     0.638528    0.003435
# Basic_NN_no_adversarial_debiasing            0.029221    0.054373
# logistic_regression_reject_option_spd        0.119048    0.059803
# logistic_regression_reject_option_aod        0.046537    0.097895
# logistic_regression_reject_option_eod        0.070346    0.075168
# xgb_classifier_reject_option_spd             0.090909    0.074874
# xgb_classifier_reject_option_aod             0.182900    0.028283
# xgb_classifier_reject_option_eod             0.182900    0.028283
# logistic_regression_platt_scaling            0.547619    0.169318
# xgb_classifier_platt_scaling                 0.204545    0.018836
# logistic_regression_equal_odds_weighted      0.169913    0.033881
# logistic_regression_equal_odds_fnr           0.380952    0.125000
# logistic_regression_equal_odds_fpr           0.151515    0.082028
# xgb_classifier_equal_odds_weighted           0.162338    0.030776
# xgb_classifier_equal_odds_fnr                0.162338    0.030776
# xgb_classifier_equal_odds_fpr                0.150433    0.018276
#
#                                          sufficiency       auc
# logistic_regression                         0.059066  0.653949
# xgb_classifier                              0.000000  0.608130
# logistic_regression_reweighting             0.178052  0.660011
# xgb_classifier_reweighting                  0.126409  0.608130
# logistic_regression_di_remover              0.059066  0.653949
# xgb_classifier_di_remover                   0.000000  0.608130
# NN_adversarial_debiasing                    0.013514  0.572295
# Basic_NN_no_adversarial_debiasing           0.222222  0.587984
# logistic_regression_reject_option_spd       0.040670  0.653949
# logistic_regression_reject_option_aod       0.110187  0.653949
# logistic_regression_reject_option_eod       0.076923  0.653949
# xgb_classifier_reject_option_spd            0.044898  0.608130
# xgb_classifier_reject_option_aod            0.001303  0.608130
# xgb_classifier_reject_option_eod            0.001303  0.608130
# logistic_regression_platt_scaling           0.630435  0.534498
# xgb_classifier_platt_scaling                0.008980  0.589766
# logistic_regression_equal_odds_weighted     0.043546  0.653949
# logistic_regression_equal_odds_fnr          0.107226  0.653949
# logistic_regression_equal_odds_fpr          0.041667  0.653949
# xgb_classifier_equal_odds_weighted          0.000000  0.608130
# xgb_classifier_equal_odds_fnr               0.000000  0.608130
# xgb_classifier_equal_odds_fpr               0.009020  0.608130

# %%
algorithm_performance_summary.to_csv('SIMULATION_SIMPLE_mild', index = True, sep=',', encoding='utf-8')
